# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input, Activation, Dropout, Add, LSTM, GRU, RNN, LayerNormalization, BatchNormalization, SpectralNormalization, Conv1D, MaxPooling1D, Flatten, Layer
from keras import backend as K
from keras.optimizers import Adam,SGD
import tensorflow as tf
from keras import Model, regularizers, activations, initializers
from keras.constraints import Constraint
import pickle

# %%
# specifying constant parameters

T_0 = 300
V = 1
k_0 = 8.46*(np.power(10,6))
C_p = 0.231
rho_L = 1000
Q_s = 0.0
T_s = 401.8727
F = 5
E = 5*(np.power(10,4))
delta_H = -1.15*(np.power(10,4))
R = 8.314
C_A0s = 4
C_As = 1.9537
t_final = 0.005
t_step = 1e-4
P = np.array([[1060, 22], [22, 0.52]])

num_step = 10

# %%
# generating inputs and initial states for CSTR, all expressed in deviation form

u1_list = np.linspace(-3.5, 3.5, 4, endpoint=True)
u2_list = np.linspace(-5e5, 5e5, 4, endpoint=True)
T_initial = np.linspace(300, 600, 100, endpoint=True) - T_s
CA_initial = np.linspace(0, 6, 100, endpoint=True) - C_As

# %%
# sieve out initial states that lie outside of stability region

T_start = list()
CA_start = list()

for T in T_initial:
    for CA in CA_initial:
        x = np.array([CA, T])
        if x @ P @ x < 372:
            CA_start.append(CA)
            T_start.append(T)
print("number of initial conditions: {}".format(len(CA_start)))

# convert to np.arrays
CA_start = np.array([CA_start])
T_start = np.array([T_start])
x_deviation = np.concatenate((CA_start.T, T_start.T), axis=1)  # every row is a pair of initial states within stability region
print("shape of x_deviation is {}".format(x_deviation.shape))
# Out:
# number of initial conditions: 772
# shape of x_deviation is (772, 2)

# %%
def CSTR_simulation(F, V, C_A0, k_0, E, R, T_0, delta_H, rho_L, C_p, Q, t_final, t_step, C_A_initial, T_initial):
    """
        simulating CSTR using forward Euler method
    """

    C_A_list = list()  # evolution of CA over time
    T_list = list()  # evolution of T over time

    C_A = C_A_initial + C_As
    T = T_initial + T_s

    for i in range(int(t_final / t_step)):
        dCAdt = F / V * (C_A0 - C_A) - k_0 * np.exp(-E / (R * T)) * C_A**2
        dTdt = F / V * (T_0 - T) - delta_H / (rho_L * C_p) * k_0 * np.exp(-E / (R * T)) * C_A**2 + Q / (rho_L * C_p * V)

        T += dTdt * t_step
        C_A += dCAdt * t_step

        if (i+1) % 5 == 0:
            C_A_list.append(C_A - C_As)  # in deviation form
            T_list.append(T - T_s)  # in deviation form

    return C_A_list, T_list

# %%
# get X and y data for training and testing

CA_output = list()
T_output = list()
CA_input = list()
T_input = list()
CA0_input = list()
Q_input = list()

for u1 in u1_list:
    C_A0 = u1 + C_A0s

    for u2 in u2_list:
        Q = u2 + Q_s

        for C_A_initial, T_initial in x_deviation:
            CA0_input.append(u1)
            Q_input.append(u2)
            CA_input.append(C_A_initial)
            T_input.append(T_initial)

            C_A_list, T_list = CSTR_simulation(F, V, C_A0, k_0, E, R, T_0, delta_H, rho_L, C_p, Q, t_final, t_step, C_A_initial, T_initial)
            CA_output.append(C_A_list)
            T_output.append(T_list)

# %%
CA0_input = np.array(CA0_input)
print(CA0_input.shape)
CA_output = np.array(CA_output)
print(CA_output.shape)
# Out:
# (12352,)
# (12352, 10)

# %%
# collate input for RNN

CA0_input = np.array(CA0_input)
CA0_input = CA0_input.reshape(-1,1,1)

Q_input = np.array(Q_input)
Q_input = Q_input.reshape(-1,1,1)

CA_input = np.array(CA_input)
CA_input = CA_input.reshape(-1,1,1)

T_input = np.array(T_input)
T_input = T_input.reshape(-1,1,1)

# RNN_input = np.concatenate((T_input, CA_input, Q_input, CA0_input), axis=2)
RNN_input = np.concatenate((T_input, CA_input, Q_input, CA0_input, -T_input, -CA_input, -Q_input, -CA0_input), axis=2)

"""
    the input to RNN is in the shape [number of samples x timestep x variables], and the input variables are same for every
    time step, not sure if my treatment here is correct
"""

RNN_input = RNN_input.repeat(num_step, axis=1)
print("RNN_input shape is {}".format(RNN_input.shape))
# Out:
# RNN_input shape is (12352, 10, 8)

# %%
# checking the input is duplicated 100 times for each time step
print(RNN_input[0, 0])
print(RNN_input[0, 1])
# Out:
# [-7.45999727e+01  1.44023939e+00 -5.00000000e+05 -3.50000000e+00
#   7.45999727e+01 -1.44023939e+00  5.00000000e+05  3.50000000e+00]
# [-7.45999727e+01  1.44023939e+00 -5.00000000e+05 -3.50000000e+00
#   7.45999727e+01 -1.44023939e+00  5.00000000e+05  3.50000000e+00]

# %%
# collate output for RNN

CA_output = np.array(CA_output)
CA_output = CA_output.reshape(-1, num_step, 1)

T_output = np.array(T_output)
T_output = T_output.reshape(-1, num_step, 1)

RNN_output = np.concatenate((T_output, CA_output), axis=2)
print("RNN_output shape is {}".format(RNN_output.shape))  # output shape: number of samples x timestep x variables
# Out:
# RNN_output shape is (12352, 10, 2)

# %%
# checking output
print(RNN_output[0, :5])
# Out:
# [[-75.72458929   1.4325163 ]
#  [-76.84802004   1.4248451 ]
#  [-77.97016868   1.41722366]
#  [-79.09094468   1.40964998]
#  [-80.21026299   1.40212216]]

# %%
tf.random.set_seed(42)

class MyRNNCell(tf.keras.layers.Layer):

    def __init__(self, units, input_shape_custom, **kwargs):
        self.units = units
        self.input_shape_custom = input_shape_custom
        self.state_size = [tf.TensorShape([units]), tf.TensorShape([input_shape_custom])]
        super(MyRNNCell, self).__init__(**kwargs)

    def build(self, input_shape):
        self.kernel = self.add_weight(shape=(input_shape[-1], self.units),
                                      initializer='uniform',
                                      name='kernel',
                                      constraint=tf.keras.constraints.NonNeg(),
                                      trainable=True)
        self.recurrent_kernel = self.add_weight(shape=(self.units, self.units),
                                                initializer='uniform',
                                                name='recurrent_kernel',
                                                constraint=tf.keras.constraints.NonNeg(),
                                                trainable=True)
        self.D1 = self.add_weight(shape=(self.units, self.units),
                                 initializer='uniform',
                                 name='D1',
                                 constraint=tf.keras.constraints.NonNeg(),
                                 trainable=True)
        self.D2 = self.add_weight(shape=(input_shape[-1], self.units),
                                 initializer='uniform',
                                 name='D2',
                                 constraint=tf.keras.constraints.NonNeg(),
                                 trainable=True)
        self.D3 = self.add_weight(shape=(input_shape[-1], self.units),
                                 initializer='uniform',
                                 name='D3',
                                 constraint=tf.keras.constraints.NonNeg(),
                                 trainable=True)
        self.V = self.add_weight(shape=(self.units, self.units),
                                 initializer='uniform',
                                 name='V',
                                 constraint=tf.keras.constraints.NonNeg(),
                                 trainable=True)
        self.built = True

    def call(self, inputs, states):
        # ICRNN
        prev_h, prev_input = states
        h = K.dot(inputs, self.kernel) + K.dot(prev_h, self.recurrent_kernel) + K.dot(prev_input, self.D2)
        h = tf.nn.relu(h)
        y = K.dot(h, self.V) + K.dot(prev_h, self.D1) + K.dot(inputs, self.D3)
        y = tf.nn.relu(y)
        return y, [h, inputs]

    def get_config(self):
        config = super(MyRNNCell, self).get_config()
        config.update({"units": self.units, "input_shape_custom": self.input_shape_custom})
        return config

# %%
def check_non_negative_weights_ignore_bias(model):
    all_non_negative = True
    for layer in model.layers:
        weights = layer.get_weights()
        if weights:  # tf the layer has weights
            # check only the weight matrices (ignoring biases if present)
            weight_only = weights[0]  # assume weights are the first element, bias (if any) is second
            if not np.all(weight_only >= 0):
                print(f"Non-negative check failed in layer: {layer.name}")
                all_non_negative = False
    if all_non_negative:
        print("All weights are non-negative (ignoring biases).")
    else:
        print("Some weights are negative (ignoring biases).")

# %%
def evaluate_lip_const(model: Model, x, eps, seed=None):
    """
    Evaluate the Lipschitz constant of a model, with the naive method.
    Please note that the estimation of the lipschitz constant is done locally around
    input sample. This may not correctly estimate the behaviour in the whole domain.

    Args:
        model: built keras model used to make predictions
        x: inputs used to compute the lipschitz constant
        eps (float): magnitude of noise to add to input in order to compute the constant
        seed (int): seed used when generating the noise ( can be set to None )

    Returns:
        float: the empirically evaluated lipschitz constant. The computation might also
            be inaccurate in high dimensional space.

    """
    y_pred = model.predict(x)
    x_var = x + K.random_uniform(
        shape=x.shape, minval=eps * 0.25, maxval=eps, seed=seed
    )
#     x_var = x + K.random_normal(
#         shape=x.shape, mean=0, stddev=eps, seed=seed
#     )
    y_pred_var = model.predict(x_var)
    dx = x - x_var
    dfx = y_pred - y_pred_var
    ndx = K.sqrt(K.sum(K.square(dx), axis=range(1, len(x.shape))))
    ndfx = K.sqrt(K.sum(K.square(dfx), axis=range(1, len(y_pred.shape))))
    lip_cst = K.max(ndfx / ndx)
    print(f"lip cst: {lip_cst:.3f}")
    return lip_cst

# %%
# set the seed for reproducibility
tf.random.set_seed(42)

training_loss = [0]*19
test_loss = [0]*19
lip = [0]*19
noise = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]

for i in range(19):
    num_dims = 8

    # split into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(RNN_input, RNN_output, test_size=0.3, random_state=123)

    # define scalers for both X and y base on training data only
    scaler_X = preprocessing.MinMaxScaler().fit(X_train.reshape(-1, num_dims))
    scaler_y = preprocessing.MinMaxScaler().fit(y_train.reshape(-1, 2))

    X_train = scaler_X.transform(X_train.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
    X_test = scaler_X.transform(X_test.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
    y_train = scaler_y.transform(y_train.reshape(-1,2)).reshape(-1,num_step,2)
    y_test_normalized = scaler_y.transform(y_test.reshape(-1,2)).reshape(-1,num_step,2)

    # X is just the initial condition, so we introduce noise to the output trajectory y
    y_train = y_train + np.random.normal(0, noise[i], y_train.shape)

    # ICRNN
    model = Sequential()
    model.add(RNN(MyRNNCell(units=64, input_shape_custom=X_train.shape[2]), return_sequences=True))
    model.add(RNN(MyRNNCell(units=64, input_shape_custom=64), return_sequences=True))
    model.add(Dense(2, activation='relu', kernel_constraint=tf.keras.constraints.NonNeg()))

    model.compile(optimizer='adam', loss='mean_squared_error', metrics=[tf.keras.metrics.MeanSquaredError()])
    history = model.fit(X_train, y_train, epochs=1000, batch_size=256, validation_split=0.25, verbose=2)

    training_loss[i] = history.history['val_loss'][-1]
    print(noise)
    print(training_loss)

    loss = model.evaluate(X_test, y_test_normalized, batch_size=256)
    test_loss[i] = loss[0]
    print(test_loss)
    
    # check convexity by checking the weights
    check_non_negative_weights_ignore_bias(model)
    
    # compute the Lipschitz constant for the 2-layer RNN
    lipschitz_constant = evaluate_lip_const(model, X_train, 1e-04, 42)
    print(f"Estimated Lipschitz constant of the 2-layer RNN: {lipschitz_constant}")
    
    lip[i] = lipschitz_constant

model.summary()
# Out:
# Epoch 1/1000
# 26/26 - 7s - loss: 51.9793 - mean_squared_error: 51.9793 - val_loss: 0.6374 - val_mean_squared_error: 0.6374 - 7s/epoch - 273ms/step
# Epoch 2/1000
# 26/26 - 1s - loss: 0.3476 - mean_squared_error: 0.3476 - val_loss: 0.2250 - val_mean_squared_error: 0.2250 - 540ms/epoch - 21ms/step
# Epoch 3/1000
# 26/26 - 1s - loss: 0.2066 - mean_squared_error: 0.2066 - val_loss: 0.1886 - val_mean_squared_error: 0.1886 - 542ms/epoch - 21ms/step
# Epoch 4/1000
# 26/26 - 1s - loss: 0.1822 - mean_squared_error: 0.1822 - val_loss: 0.1709 - val_mean_squared_error: 0.1709 - 550ms/epoch - 21ms/step
# Epoch 5/1000
# 26/26 - 1s - loss: 0.1663 - mean_squared_error: 0.1663 - val_loss: 0.1568 - val_mean_squared_error: 0.1568 - 545ms/epoch - 21ms/step
# Epoch 6/1000
# 26/26 - 1s - loss: 0.1533 - mean_squared_error: 0.1533 - val_loss: 0.1452 - val_mean_squared_error: 0.1452 - 536ms/epoch - 21ms/step
# Epoch 7/1000
# 26/26 - 1s - loss: 0.1426 - mean_squared_error: 0.1426 - val_loss: 0.1358 - val_mean_squared_error: 0.1358 - 534ms/epoch - 21ms/step
# Epoch 8/1000
# 26/26 - 1s - loss: 0.1340 - mean_squared_error: 0.1340 - val_loss: 0.1283 - val_mean_squared_error: 0.1283 - 532ms/epoch - 20ms/step
# Epoch 9/1000
# 26/26 - 1s - loss: 0.1272 - mean_squared_error: 0.1272 - val_loss: 0.1224 - val_mean_squared_error: 0.1224 - 533ms/epoch - 21ms/step
# Epoch 10/1000
# 26/26 - 1s - loss: 0.1217 - mean_squared_error: 0.1217 - val_loss: 0.1177 - val_mean_squared_error: 0.1177 - 533ms/epoch - 20ms/step
# Epoch 11/1000
# 26/26 - 1s - loss: 0.1175 - mean_squared_error: 0.1175 - val_loss: 0.1140 - val_mean_squared_error: 0.1140 - 533ms/epoch - 21ms/step
# Epoch 12/1000
# 26/26 - 1s - loss: 0.1140 - mean_squared_error: 0.1140 - val_loss: 0.1110 - val_mean_squared_error: 0.1110 - 543ms/epoch - 21ms/step
# Epoch 13/1000
# 26/26 - 1s - loss: 0.1113 - mean_squared_error: 0.1113 - val_loss: 0.1087 - val_mean_squared_error: 0.1087 - 550ms/epoch - 21ms/step
# Epoch 14/1000
# 26/26 - 1s - loss: 0.1091 - mean_squared_error: 0.1091 - val_loss: 0.1067 - val_mean_squared_error: 0.1067 - 544ms/epoch - 21ms/step
# Epoch 15/1000
# 26/26 - 1s - loss: 0.1073 - mean_squared_error: 0.1073 - val_loss: 0.1052 - val_mean_squared_error: 0.1052 - 548ms/epoch - 21ms/step
# Epoch 16/1000
# 26/26 - 1s - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1038 - val_mean_squared_error: 0.1038 - 546ms/epoch - 21ms/step
# Epoch 17/1000
# 26/26 - 1s - loss: 0.1044 - mean_squared_error: 0.1044 - val_loss: 0.1027 - val_mean_squared_error: 0.1027 - 548ms/epoch - 21ms/step
# Epoch 18/1000
# 26/26 - 1s - loss: 0.1033 - mean_squared_error: 0.1033 - val_loss: 0.1016 - val_mean_squared_error: 0.1016 - 546ms/epoch - 21ms/step
# Epoch 19/1000
# 26/26 - 1s - loss: 0.1022 - mean_squared_error: 0.1022 - val_loss: 0.1007 - val_mean_squared_error: 0.1007 - 562ms/epoch - 22ms/step
# Epoch 20/1000
# 26/26 - 1s - loss: 0.1013 - mean_squared_error: 0.1013 - val_loss: 0.0999 - val_mean_squared_error: 0.0999 - 548ms/epoch - 21ms/step
# Epoch 21/1000
# 26/26 - 1s - loss: 0.1004 - mean_squared_error: 0.1004 - val_loss: 0.0991 - val_mean_squared_error: 0.0991 - 562ms/epoch - 22ms/step
# Epoch 22/1000
# 26/26 - 1s - loss: 0.0996 - mean_squared_error: 0.0996 - val_loss: 0.0983 - val_mean_squared_error: 0.0983 - 547ms/epoch - 21ms/step
# Epoch 23/1000
# 26/26 - 1s - loss: 0.0988 - mean_squared_error: 0.0988 - val_loss: 0.0976 - val_mean_squared_error: 0.0976 - 529ms/epoch - 20ms/step
# Epoch 24/1000
# 26/26 - 1s - loss: 0.0980 - mean_squared_error: 0.0980 - val_loss: 0.0969 - val_mean_squared_error: 0.0969 - 548ms/epoch - 21ms/step
# Epoch 25/1000
# 26/26 - 1s - loss: 0.0973 - mean_squared_error: 0.0973 - val_loss: 0.0962 - val_mean_squared_error: 0.0962 - 515ms/epoch - 20ms/step
# Epoch 26/1000
# 26/26 - 1s - loss: 0.0965 - mean_squared_error: 0.0965 - val_loss: 0.0955 - val_mean_squared_error: 0.0955 - 532ms/epoch - 20ms/step
# Epoch 27/1000
# 26/26 - 1s - loss: 0.0958 - mean_squared_error: 0.0958 - val_loss: 0.0948 - val_mean_squared_error: 0.0948 - 530ms/epoch - 20ms/step
# Epoch 28/1000
# 26/26 - 1s - loss: 0.0950 - mean_squared_error: 0.0950 - val_loss: 0.0941 - val_mean_squared_error: 0.0941 - 534ms/epoch - 21ms/step
# Epoch 29/1000
# 26/26 - 1s - loss: 0.0943 - mean_squared_error: 0.0943 - val_loss: 0.0935 - val_mean_squared_error: 0.0935 - 509ms/epoch - 20ms/step
# Epoch 30/1000
# 26/26 - 1s - loss: 0.0936 - mean_squared_error: 0.0936 - val_loss: 0.0929 - val_mean_squared_error: 0.0929 - 530ms/epoch - 20ms/step
# Epoch 31/1000
# 26/26 - 1s - loss: 0.0930 - mean_squared_error: 0.0930 - val_loss: 0.0923 - val_mean_squared_error: 0.0923 - 516ms/epoch - 20ms/step
# Epoch 32/1000
# 26/26 - 1s - loss: 0.0923 - mean_squared_error: 0.0923 - val_loss: 0.0917 - val_mean_squared_error: 0.0917 - 531ms/epoch - 20ms/step
# Epoch 33/1000
# 26/26 - 1s - loss: 0.0917 - mean_squared_error: 0.0917 - val_loss: 0.0911 - val_mean_squared_error: 0.0911 - 549ms/epoch - 21ms/step
# Epoch 34/1000
# 26/26 - 1s - loss: 0.0911 - mean_squared_error: 0.0911 - val_loss: 0.0905 - val_mean_squared_error: 0.0905 - 530ms/epoch - 20ms/step
# Epoch 35/1000
# 26/26 - 1s - loss: 0.0905 - mean_squared_error: 0.0905 - val_loss: 0.0899 - val_mean_squared_error: 0.0899 - 548ms/epoch - 21ms/step
# Epoch 36/1000
# 26/26 - 1s - loss: 0.0899 - mean_squared_error: 0.0899 - val_loss: 0.0893 - val_mean_squared_error: 0.0893 - 531ms/epoch - 20ms/step
# Epoch 37/1000
# 26/26 - 1s - loss: 0.0893 - mean_squared_error: 0.0893 - val_loss: 0.0887 - val_mean_squared_error: 0.0887 - 533ms/epoch - 21ms/step
# Epoch 38/1000
# 26/26 - 1s - loss: 0.0887 - mean_squared_error: 0.0887 - val_loss: 0.0881 - val_mean_squared_error: 0.0881 - 514ms/epoch - 20ms/step
# Epoch 39/1000
# 26/26 - 1s - loss: 0.0881 - mean_squared_error: 0.0881 - val_loss: 0.0875 - val_mean_squared_error: 0.0875 - 502ms/epoch - 19ms/step
# Epoch 40/1000
# 26/26 - 1s - loss: 0.0875 - mean_squared_error: 0.0875 - val_loss: 0.0869 - val_mean_squared_error: 0.0869 - 531ms/epoch - 20ms/step
# Epoch 41/1000
# 26/26 - 1s - loss: 0.0869 - mean_squared_error: 0.0869 - val_loss: 0.0863 - val_mean_squared_error: 0.0863 - 532ms/epoch - 20ms/step
# Epoch 42/1000
# 26/26 - 1s - loss: 0.0863 - mean_squared_error: 0.0863 - val_loss: 0.0858 - val_mean_squared_error: 0.0858 - 517ms/epoch - 20ms/step
# Epoch 43/1000
# 26/26 - 1s - loss: 0.0857 - mean_squared_error: 0.0857 - val_loss: 0.0852 - val_mean_squared_error: 0.0852 - 532ms/epoch - 20ms/step
# Epoch 44/1000
# 26/26 - 1s - loss: 0.0851 - mean_squared_error: 0.0851 - val_loss: 0.0846 - val_mean_squared_error: 0.0846 - 533ms/epoch - 21ms/step
# Epoch 45/1000
# 26/26 - 1s - loss: 0.0846 - mean_squared_error: 0.0846 - val_loss: 0.0840 - val_mean_squared_error: 0.0840 - 502ms/epoch - 19ms/step
# Epoch 46/1000
# 26/26 - 1s - loss: 0.0840 - mean_squared_error: 0.0840 - val_loss: 0.0835 - val_mean_squared_error: 0.0835 - 531ms/epoch - 20ms/step
# Epoch 47/1000
# 26/26 - 1s - loss: 0.0834 - mean_squared_error: 0.0834 - val_loss: 0.0829 - val_mean_squared_error: 0.0829 - 533ms/epoch - 20ms/step
# Epoch 48/1000
# 26/26 - 1s - loss: 0.0828 - mean_squared_error: 0.0828 - val_loss: 0.0823 - val_mean_squared_error: 0.0823 - 531ms/epoch - 20ms/step
# Epoch 49/1000
# 26/26 - 1s - loss: 0.0822 - mean_squared_error: 0.0822 - val_loss: 0.0817 - val_mean_squared_error: 0.0817 - 532ms/epoch - 20ms/step
# Epoch 50/1000
# 26/26 - 1s - loss: 0.0817 - mean_squared_error: 0.0817 - val_loss: 0.0812 - val_mean_squared_error: 0.0812 - 533ms/epoch - 20ms/step
# Epoch 51/1000
# 26/26 - 1s - loss: 0.0811 - mean_squared_error: 0.0811 - val_loss: 0.0806 - val_mean_squared_error: 0.0806 - 514ms/epoch - 20ms/step
# Epoch 52/1000
# 26/26 - 1s - loss: 0.0805 - mean_squared_error: 0.0805 - val_loss: 0.0800 - val_mean_squared_error: 0.0800 - 519ms/epoch - 20ms/step
# Epoch 53/1000
# 26/26 - 1s - loss: 0.0800 - mean_squared_error: 0.0800 - val_loss: 0.0795 - val_mean_squared_error: 0.0795 - 548ms/epoch - 21ms/step
# Epoch 54/1000
# 26/26 - 1s - loss: 0.0794 - mean_squared_error: 0.0794 - val_loss: 0.0789 - val_mean_squared_error: 0.0789 - 532ms/epoch - 20ms/step
# Epoch 55/1000
# 26/26 - 1s - loss: 0.0788 - mean_squared_error: 0.0788 - val_loss: 0.0784 - val_mean_squared_error: 0.0784 - 534ms/epoch - 21ms/step
# Epoch 56/1000
# 26/26 - 1s - loss: 0.0783 - mean_squared_error: 0.0783 - val_loss: 0.0778 - val_mean_squared_error: 0.0778 - 533ms/epoch - 20ms/step
# Epoch 57/1000
# 26/26 - 1s - loss: 0.0777 - mean_squared_error: 0.0777 - val_loss: 0.0772 - val_mean_squared_error: 0.0772 - 528ms/epoch - 20ms/step
# Epoch 58/1000
# 26/26 - 1s - loss: 0.0771 - mean_squared_error: 0.0771 - val_loss: 0.0766 - val_mean_squared_error: 0.0766 - 533ms/epoch - 21ms/step
# Epoch 59/1000
# 26/26 - 1s - loss: 0.0766 - mean_squared_error: 0.0766 - val_loss: 0.0761 - val_mean_squared_error: 0.0761 - 516ms/epoch - 20ms/step
# Epoch 60/1000
# 26/26 - 1s - loss: 0.0760 - mean_squared_error: 0.0760 - val_loss: 0.0755 - val_mean_squared_error: 0.0755 - 532ms/epoch - 20ms/step
# Epoch 61/1000
# 26/26 - 1s - loss: 0.0754 - mean_squared_error: 0.0754 - val_loss: 0.0749 - val_mean_squared_error: 0.0749 - 515ms/epoch - 20ms/step
# Epoch 62/1000
# 26/26 - 1s - loss: 0.0748 - mean_squared_error: 0.0748 - val_loss: 0.0744 - val_mean_squared_error: 0.0744 - 532ms/epoch - 20ms/step
# Epoch 63/1000
# 26/26 - 1s - loss: 0.0742 - mean_squared_error: 0.0742 - val_loss: 0.0738 - val_mean_squared_error: 0.0738 - 517ms/epoch - 20ms/step
# Epoch 64/1000
# 26/26 - 1s - loss: 0.0736 - mean_squared_error: 0.0736 - val_loss: 0.0732 - val_mean_squared_error: 0.0732 - 533ms/epoch - 21ms/step
# Epoch 65/1000
# 26/26 - 1s - loss: 0.0730 - mean_squared_error: 0.0730 - val_loss: 0.0726 - val_mean_squared_error: 0.0726 - 531ms/epoch - 20ms/step
# Epoch 66/1000
# 26/26 - 1s - loss: 0.0724 - mean_squared_error: 0.0724 - val_loss: 0.0720 - val_mean_squared_error: 0.0720 - 533ms/epoch - 20ms/step
# Epoch 67/1000
# 26/26 - 1s - loss: 0.0718 - mean_squared_error: 0.0718 - val_loss: 0.0714 - val_mean_squared_error: 0.0714 - 516ms/epoch - 20ms/step
# Epoch 68/1000
# 26/26 - 1s - loss: 0.0712 - mean_squared_error: 0.0712 - val_loss: 0.0707 - val_mean_squared_error: 0.0707 - 531ms/epoch - 20ms/step
# Epoch 69/1000
# 26/26 - 1s - loss: 0.0705 - mean_squared_error: 0.0705 - val_loss: 0.0701 - val_mean_squared_error: 0.0701 - 516ms/epoch - 20ms/step
# Epoch 70/1000
# 26/26 - 1s - loss: 0.0698 - mean_squared_error: 0.0698 - val_loss: 0.0694 - val_mean_squared_error: 0.0694 - 516ms/epoch - 20ms/step
# Epoch 71/1000
# 26/26 - 1s - loss: 0.0692 - mean_squared_error: 0.0692 - val_loss: 0.0687 - val_mean_squared_error: 0.0687 - 516ms/epoch - 20ms/step
# Epoch 72/1000
# 26/26 - 1s - loss: 0.0685 - mean_squared_error: 0.0685 - val_loss: 0.0680 - val_mean_squared_error: 0.0680 - 532ms/epoch - 20ms/step
# Epoch 73/1000
# 26/26 - 1s - loss: 0.0677 - mean_squared_error: 0.0677 - val_loss: 0.0673 - val_mean_squared_error: 0.0673 - 517ms/epoch - 20ms/step
# Epoch 74/1000
# 26/26 - 1s - loss: 0.0670 - mean_squared_error: 0.0670 - val_loss: 0.0666 - val_mean_squared_error: 0.0666 - 523ms/epoch - 20ms/step
# Epoch 75/1000
# 26/26 - 1s - loss: 0.0662 - mean_squared_error: 0.0662 - val_loss: 0.0658 - val_mean_squared_error: 0.0658 - 518ms/epoch - 20ms/step
# Epoch 76/1000
# 26/26 - 1s - loss: 0.0654 - mean_squared_error: 0.0654 - val_loss: 0.0650 - val_mean_squared_error: 0.0650 - 516ms/epoch - 20ms/step
# Epoch 77/1000
# 26/26 - 1s - loss: 0.0646 - mean_squared_error: 0.0646 - val_loss: 0.0642 - val_mean_squared_error: 0.0642 - 517ms/epoch - 20ms/step
# Epoch 78/1000
# 26/26 - 0s - loss: 0.0637 - mean_squared_error: 0.0637 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - 499ms/epoch - 19ms/step
# Epoch 79/1000
# 26/26 - 1s - loss: 0.0628 - mean_squared_error: 0.0628 - val_loss: 0.0624 - val_mean_squared_error: 0.0624 - 533ms/epoch - 20ms/step
# Epoch 80/1000
# 26/26 - 1s - loss: 0.0619 - mean_squared_error: 0.0619 - val_loss: 0.0615 - val_mean_squared_error: 0.0615 - 513ms/epoch - 20ms/step
# Epoch 81/1000
# 26/26 - 1s - loss: 0.0609 - mean_squared_error: 0.0609 - val_loss: 0.0605 - val_mean_squared_error: 0.0605 - 533ms/epoch - 21ms/step
# Epoch 82/1000
# 26/26 - 1s - loss: 0.0599 - mean_squared_error: 0.0599 - val_loss: 0.0595 - val_mean_squared_error: 0.0595 - 532ms/epoch - 20ms/step
# Epoch 83/1000
# 26/26 - 1s - loss: 0.0589 - mean_squared_error: 0.0589 - val_loss: 0.0584 - val_mean_squared_error: 0.0584 - 532ms/epoch - 20ms/step
# Epoch 84/1000
# 26/26 - 1s - loss: 0.0578 - mean_squared_error: 0.0578 - val_loss: 0.0573 - val_mean_squared_error: 0.0573 - 516ms/epoch - 20ms/step
# Epoch 85/1000
# 26/26 - 1s - loss: 0.0567 - mean_squared_error: 0.0567 - val_loss: 0.0562 - val_mean_squared_error: 0.0562 - 532ms/epoch - 20ms/step
# Epoch 86/1000
# 26/26 - 1s - loss: 0.0556 - mean_squared_error: 0.0556 - val_loss: 0.0551 - val_mean_squared_error: 0.0551 - 513ms/epoch - 20ms/step
# Epoch 87/1000
# 26/26 - 1s - loss: 0.0545 - mean_squared_error: 0.0545 - val_loss: 0.0540 - val_mean_squared_error: 0.0540 - 548ms/epoch - 21ms/step
# Epoch 88/1000
# 26/26 - 1s - loss: 0.0533 - mean_squared_error: 0.0533 - val_loss: 0.0528 - val_mean_squared_error: 0.0528 - 512ms/epoch - 20ms/step
# Epoch 89/1000
# 26/26 - 1s - loss: 0.0521 - mean_squared_error: 0.0521 - val_loss: 0.0516 - val_mean_squared_error: 0.0516 - 532ms/epoch - 20ms/step
# Epoch 90/1000
# 26/26 - 1s - loss: 0.0509 - mean_squared_error: 0.0509 - val_loss: 0.0504 - val_mean_squared_error: 0.0504 - 515ms/epoch - 20ms/step
# Epoch 91/1000
# 26/26 - 1s - loss: 0.0497 - mean_squared_error: 0.0497 - val_loss: 0.0492 - val_mean_squared_error: 0.0492 - 517ms/epoch - 20ms/step
# Epoch 92/1000
# 26/26 - 1s - loss: 0.0485 - mean_squared_error: 0.0485 - val_loss: 0.0479 - val_mean_squared_error: 0.0479 - 548ms/epoch - 21ms/step
# Epoch 93/1000
# 26/26 - 1s - loss: 0.0472 - mean_squared_error: 0.0472 - val_loss: 0.0466 - val_mean_squared_error: 0.0466 - 547ms/epoch - 21ms/step
# Epoch 94/1000
# 26/26 - 1s - loss: 0.0459 - mean_squared_error: 0.0459 - val_loss: 0.0453 - val_mean_squared_error: 0.0453 - 532ms/epoch - 20ms/step
# Epoch 95/1000
# 26/26 - 1s - loss: 0.0446 - mean_squared_error: 0.0446 - val_loss: 0.0440 - val_mean_squared_error: 0.0440 - 530ms/epoch - 20ms/step
# Epoch 96/1000
# 26/26 - 1s - loss: 0.0433 - mean_squared_error: 0.0433 - val_loss: 0.0427 - val_mean_squared_error: 0.0427 - 549ms/epoch - 21ms/step
# Epoch 97/1000
# 26/26 - 1s - loss: 0.0420 - mean_squared_error: 0.0420 - val_loss: 0.0414 - val_mean_squared_error: 0.0414 - 528ms/epoch - 20ms/step
# Epoch 98/1000
# 26/26 - 1s - loss: 0.0407 - mean_squared_error: 0.0407 - val_loss: 0.0401 - val_mean_squared_error: 0.0401 - 548ms/epoch - 21ms/step
# Epoch 99/1000
# 26/26 - 1s - loss: 0.0394 - mean_squared_error: 0.0394 - val_loss: 0.0388 - val_mean_squared_error: 0.0388 - 527ms/epoch - 20ms/step
# Epoch 100/1000
# 26/26 - 1s - loss: 0.0381 - mean_squared_error: 0.0381 - val_loss: 0.0375 - val_mean_squared_error: 0.0375 - 548ms/epoch - 21ms/step
# Epoch 101/1000
# 26/26 - 1s - loss: 0.0368 - mean_squared_error: 0.0368 - val_loss: 0.0361 - val_mean_squared_error: 0.0361 - 530ms/epoch - 20ms/step
# Epoch 102/1000
# 26/26 - 1s - loss: 0.0355 - mean_squared_error: 0.0355 - val_loss: 0.0348 - val_mean_squared_error: 0.0348 - 514ms/epoch - 20ms/step
# Epoch 103/1000
# 26/26 - 1s - loss: 0.0342 - mean_squared_error: 0.0342 - val_loss: 0.0335 - val_mean_squared_error: 0.0335 - 514ms/epoch - 20ms/step
# Epoch 104/1000
# 26/26 - 1s - loss: 0.0329 - mean_squared_error: 0.0329 - val_loss: 0.0323 - val_mean_squared_error: 0.0323 - 515ms/epoch - 20ms/step
# Epoch 105/1000
# 26/26 - 1s - loss: 0.0317 - mean_squared_error: 0.0317 - val_loss: 0.0310 - val_mean_squared_error: 0.0310 - 519ms/epoch - 20ms/step
# Epoch 106/1000
# 26/26 - 1s - loss: 0.0304 - mean_squared_error: 0.0304 - val_loss: 0.0298 - val_mean_squared_error: 0.0298 - 525ms/epoch - 20ms/step
# Epoch 107/1000
# 26/26 - 1s - loss: 0.0292 - mean_squared_error: 0.0292 - val_loss: 0.0286 - val_mean_squared_error: 0.0286 - 513ms/epoch - 20ms/step
# Epoch 108/1000
# 26/26 - 1s - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - 531ms/epoch - 20ms/step
# Epoch 109/1000
# 26/26 - 1s - loss: 0.0269 - mean_squared_error: 0.0269 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - 517ms/epoch - 20ms/step
# Epoch 110/1000
# 26/26 - 1s - loss: 0.0258 - mean_squared_error: 0.0258 - val_loss: 0.0252 - val_mean_squared_error: 0.0252 - 516ms/epoch - 20ms/step
# Epoch 111/1000
# 26/26 - 1s - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.0242 - val_mean_squared_error: 0.0242 - 550ms/epoch - 21ms/step
# Epoch 112/1000
# 26/26 - 1s - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0232 - val_mean_squared_error: 0.0232 - 513ms/epoch - 20ms/step
# Epoch 113/1000
# 26/26 - 1s - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0222 - val_mean_squared_error: 0.0222 - 533ms/epoch - 21ms/step
# Epoch 114/1000
# 26/26 - 1s - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - 514ms/epoch - 20ms/step
# Epoch 115/1000
# 26/26 - 1s - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - 532ms/epoch - 20ms/step
# Epoch 116/1000
# 26/26 - 1s - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0195 - val_mean_squared_error: 0.0195 - 546ms/epoch - 21ms/step
# Epoch 117/1000
# 26/26 - 1s - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0187 - val_mean_squared_error: 0.0187 - 533ms/epoch - 20ms/step
# Epoch 118/1000
# 26/26 - 1s - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0178 - val_mean_squared_error: 0.0178 - 511ms/epoch - 20ms/step
# Epoch 119/1000
# 26/26 - 1s - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0171 - val_mean_squared_error: 0.0171 - 517ms/epoch - 20ms/step
# Epoch 120/1000
# 26/26 - 1s - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0163 - val_mean_squared_error: 0.0163 - 528ms/epoch - 20ms/step
# Epoch 121/1000
# 26/26 - 1s - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0156 - val_mean_squared_error: 0.0156 - 526ms/epoch - 20ms/step
# Epoch 122/1000
# 26/26 - 1s - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.0149 - val_mean_squared_error: 0.0149 - 520ms/epoch - 20ms/step
# Epoch 123/1000
# 26/26 - 1s - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0143 - val_mean_squared_error: 0.0143 - 527ms/epoch - 20ms/step
# Epoch 124/1000
# 26/26 - 1s - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 503ms/epoch - 19ms/step
# Epoch 125/1000
# 26/26 - 1s - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 531ms/epoch - 20ms/step
# Epoch 126/1000
# 26/26 - 1s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - 516ms/epoch - 20ms/step
# Epoch 127/1000
# 26/26 - 1s - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0119 - val_mean_squared_error: 0.0119 - 529ms/epoch - 20ms/step
# Epoch 128/1000
# 26/26 - 1s - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - 516ms/epoch - 20ms/step
# Epoch 129/1000
# 26/26 - 1s - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 545ms/epoch - 21ms/step
# Epoch 130/1000
# 26/26 - 1s - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 516ms/epoch - 20ms/step
# Epoch 131/1000
# 26/26 - 1s - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 548ms/epoch - 21ms/step
# Epoch 132/1000
# 26/26 - 1s - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 516ms/epoch - 20ms/step
# Epoch 133/1000
# 26/26 - 1s - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 530ms/epoch - 20ms/step
# Epoch 134/1000
# 26/26 - 1s - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 532ms/epoch - 20ms/step
# Epoch 135/1000
# 26/26 - 1s - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 530ms/epoch - 20ms/step
# Epoch 136/1000
# 26/26 - 1s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - 548ms/epoch - 21ms/step
# Epoch 137/1000
# 26/26 - 1s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0075 - val_mean_squared_error: 0.0075 - 529ms/epoch - 20ms/step
# Epoch 138/1000
# 26/26 - 1s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0071 - val_mean_squared_error: 0.0071 - 538ms/epoch - 21ms/step
# Epoch 139/1000
# 26/26 - 1s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0068 - val_mean_squared_error: 0.0068 - 505ms/epoch - 19ms/step
# Epoch 140/1000
# 26/26 - 1s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 531ms/epoch - 20ms/step
# Epoch 141/1000
# 26/26 - 1s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 532ms/epoch - 20ms/step
# Epoch 142/1000
# 26/26 - 1s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 545ms/epoch - 21ms/step
# Epoch 143/1000
# 26/26 - 1s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 517ms/epoch - 20ms/step
# Epoch 144/1000
# 26/26 - 1s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 513ms/epoch - 20ms/step
# Epoch 145/1000
# 26/26 - 1s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - 531ms/epoch - 20ms/step
# Epoch 146/1000
# 26/26 - 1s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - 531ms/epoch - 20ms/step
# Epoch 147/1000
# 26/26 - 1s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0048 - val_mean_squared_error: 0.0048 - 517ms/epoch - 20ms/step
# Epoch 148/1000
# 26/26 - 1s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0046 - val_mean_squared_error: 0.0046 - 516ms/epoch - 20ms/step
# Epoch 149/1000
# 26/26 - 1s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0044 - val_mean_squared_error: 0.0044 - 516ms/epoch - 20ms/step
# Epoch 150/1000
# 26/26 - 1s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0042 - val_mean_squared_error: 0.0042 - 532ms/epoch - 20ms/step
# Epoch 151/1000
# 26/26 - 1s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0041 - val_mean_squared_error: 0.0041 - 548ms/epoch - 21ms/step
# Epoch 152/1000
# 26/26 - 1s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - 514ms/epoch - 20ms/step
# Epoch 153/1000
# 26/26 - 1s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - 517ms/epoch - 20ms/step
# Epoch 154/1000
# 26/26 - 1s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - 530ms/epoch - 20ms/step
# Epoch 155/1000
# 26/26 - 1s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - 532ms/epoch - 20ms/step
# Epoch 156/1000
# 26/26 - 1s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - 529ms/epoch - 20ms/step
# Epoch 157/1000
# 26/26 - 1s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - 530ms/epoch - 20ms/step
# Epoch 158/1000
# 26/26 - 1s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - 516ms/epoch - 20ms/step
# Epoch 159/1000
# 26/26 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - 499ms/epoch - 19ms/step
# Epoch 160/1000
# 26/26 - 1s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - 533ms/epoch - 20ms/step
# Epoch 161/1000
# 26/26 - 1s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0029 - val_mean_squared_error: 0.0029 - 514ms/epoch - 20ms/step
# Epoch 162/1000
# 26/26 - 1s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - 517ms/epoch - 20ms/step
# Epoch 163/1000
# 26/26 - 1s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - 531ms/epoch - 20ms/step
# Epoch 164/1000
# 26/26 - 1s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0026 - val_mean_squared_error: 0.0026 - 517ms/epoch - 20ms/step
# Epoch 165/1000
# 26/26 - 1s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - 513ms/epoch - 20ms/step
# Epoch 166/1000
# 26/26 - 1s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - 517ms/epoch - 20ms/step
# Epoch 167/1000
# 26/26 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0024 - val_mean_squared_error: 0.0024 - 529ms/epoch - 20ms/step
# Epoch 168/1000
# 26/26 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - 532ms/epoch - 20ms/step
# Epoch 169/1000
# 26/26 - 1s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - 528ms/epoch - 20ms/step
# Epoch 170/1000
# 26/26 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - 516ms/epoch - 20ms/step
# Epoch 171/1000
# 26/26 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - 515ms/epoch - 20ms/step
# Epoch 172/1000
# 26/26 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - 525ms/epoch - 20ms/step
# Epoch 173/1000
# 26/26 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - 523ms/epoch - 20ms/step
# Epoch 174/1000
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 535ms/epoch - 21ms/step
# Epoch 175/1000
# 26/26 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - 524ms/epoch - 20ms/step
# Epoch 176/1000
# 26/26 - 1s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 530ms/epoch - 20ms/step
# Epoch 177/1000
# 26/26 - 1s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 516ms/epoch - 20ms/step
# Epoch 178/1000
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 514ms/epoch - 20ms/step
# Epoch 179/1000
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 532ms/epoch - 20ms/step
# Epoch 180/1000
# 26/26 - 1s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 515ms/epoch - 20ms/step
# Epoch 181/1000
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 519ms/epoch - 20ms/step
# Epoch 182/1000
# 26/26 - 1s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - 512ms/epoch - 20ms/step
# Epoch 183/1000
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - 532ms/epoch - 20ms/step
# Epoch 184/1000
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - 530ms/epoch - 20ms/step
# Epoch 185/1000
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - 516ms/epoch - 20ms/step
# Epoch 186/1000
# 26/26 - 1s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - 552ms/epoch - 21ms/step
# Epoch 187/1000
# 26/26 - 1s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - 524ms/epoch - 20ms/step
# Epoch 188/1000
# 26/26 - 1s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - 565ms/epoch - 22ms/step
# Epoch 189/1000
# 26/26 - 1s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - 521ms/epoch - 20ms/step
# Epoch 190/1000
# 26/26 - 1s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - 508ms/epoch - 20ms/step
# Epoch 191/1000
# 26/26 - 1s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - 512ms/epoch - 20ms/step
# Epoch 192/1000
# 26/26 - 1s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - 518ms/epoch - 20ms/step
# Epoch 193/1000
# 26/26 - 1s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0013 - val_mean_squared_error: 0.0013 - 555ms/epoch - 21ms/step
# Epoch 194/1000
# 26/26 - 1s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0013 - val_mean_squared_error: 0.0013 - 557ms/epoch - 21ms/step
# Epoch 195/1000
# 26/26 - 1s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0013 - val_mean_squared_error: 0.0013 - 561ms/epoch - 22ms/step
# Epoch 196/1000
# 26/26 - 1s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0013 - val_mean_squared_error: 0.0013 - 533ms/epoch - 21ms/step
# Epoch 197/1000
# 26/26 - 1s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012 - 545ms/epoch - 21ms/step
# Epoch 198/1000
# 26/26 - 1s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012 - 518ms/epoch - 20ms/step
# Epoch 199/1000
# 26/26 - 1s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012 - 530ms/epoch - 20ms/step
# Epoch 200/1000
# 26/26 - 1s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012 - 532ms/epoch - 20ms/step
# Epoch 201/1000
# 26/26 - 1s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - 531ms/epoch - 20ms/step
# Epoch 202/1000
# 26/26 - 1s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - 516ms/epoch - 20ms/step
# Epoch 203/1000
# 26/26 - 1s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - 532ms/epoch - 20ms/step
# Epoch 204/1000
# 26/26 - 1s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - 517ms/epoch - 20ms/step
# Epoch 205/1000
# 26/26 - 0s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - 498ms/epoch - 19ms/step
# Epoch 206/1000
# 26/26 - 1s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0010 - val_mean_squared_error: 0.0010 - 533ms/epoch - 20ms/step
# Epoch 207/1000
# 26/26 - 1s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0010 - val_mean_squared_error: 0.0010 - 513ms/epoch - 20ms/step
# Epoch 208/1000
# 26/26 - 1s - loss: 9.9399e-04 - mean_squared_error: 9.9399e-04 - val_loss: 9.9356e-04 - val_mean_squared_error: 9.9356e-04 - 517ms/epoch - 20ms/step
# Epoch 209/1000
# 26/26 - 1s - loss: 9.7496e-04 - mean_squared_error: 9.7496e-04 - val_loss: 9.7451e-04 - val_mean_squared_error: 9.7451e-04 - 530ms/epoch - 20ms/step
# Epoch 210/1000
# 26/26 - 1s - loss: 9.5616e-04 - mean_squared_error: 9.5616e-04 - val_loss: 9.5594e-04 - val_mean_squared_error: 9.5594e-04 - 523ms/epoch - 20ms/step
# Epoch 211/1000
# 26/26 - 0s - loss: 9.3805e-04 - mean_squared_error: 9.3805e-04 - val_loss: 9.3842e-04 - val_mean_squared_error: 9.3842e-04 - 490ms/epoch - 19ms/step
# Epoch 212/1000
# 26/26 - 1s - loss: 9.2042e-04 - mean_squared_error: 9.2042e-04 - val_loss: 9.1973e-04 - val_mean_squared_error: 9.1973e-04 - 515ms/epoch - 20ms/step
# Epoch 213/1000
# 26/26 - 1s - loss: 9.0282e-04 - mean_squared_error: 9.0282e-04 - val_loss: 9.0270e-04 - val_mean_squared_error: 9.0270e-04 - 534ms/epoch - 21ms/step
# Epoch 214/1000
# 26/26 - 1s - loss: 8.8566e-04 - mean_squared_error: 8.8566e-04 - val_loss: 8.8579e-04 - val_mean_squared_error: 8.8579e-04 - 514ms/epoch - 20ms/step
# Epoch 215/1000
# 26/26 - 1s - loss: 8.6898e-04 - mean_squared_error: 8.6898e-04 - val_loss: 8.6938e-04 - val_mean_squared_error: 8.6938e-04 - 533ms/epoch - 20ms/step
# Epoch 216/1000
# 26/26 - 1s - loss: 8.5273e-04 - mean_squared_error: 8.5273e-04 - val_loss: 8.5266e-04 - val_mean_squared_error: 8.5266e-04 - 516ms/epoch - 20ms/step
# Epoch 217/1000
# 26/26 - 1s - loss: 8.3669e-04 - mean_squared_error: 8.3669e-04 - val_loss: 8.3631e-04 - val_mean_squared_error: 8.3631e-04 - 517ms/epoch - 20ms/step
# Epoch 218/1000
# 26/26 - 1s - loss: 8.2122e-04 - mean_squared_error: 8.2122e-04 - val_loss: 8.2055e-04 - val_mean_squared_error: 8.2055e-04 - 516ms/epoch - 20ms/step
# Epoch 219/1000
# 26/26 - 1s - loss: 8.0586e-04 - mean_squared_error: 8.0586e-04 - val_loss: 8.0538e-04 - val_mean_squared_error: 8.0538e-04 - 519ms/epoch - 20ms/step
# Epoch 220/1000
# 26/26 - 1s - loss: 7.9082e-04 - mean_squared_error: 7.9082e-04 - val_loss: 7.9044e-04 - val_mean_squared_error: 7.9044e-04 - 528ms/epoch - 20ms/step
# Epoch 221/1000
# 26/26 - 1s - loss: 7.7603e-04 - mean_squared_error: 7.7603e-04 - val_loss: 7.7670e-04 - val_mean_squared_error: 7.7670e-04 - 533ms/epoch - 20ms/step
# Epoch 222/1000
# 26/26 - 1s - loss: 7.6151e-04 - mean_squared_error: 7.6151e-04 - val_loss: 7.6093e-04 - val_mean_squared_error: 7.6093e-04 - 530ms/epoch - 20ms/step
# Epoch 223/1000
# 26/26 - 1s - loss: 7.4727e-04 - mean_squared_error: 7.4727e-04 - val_loss: 7.4636e-04 - val_mean_squared_error: 7.4636e-04 - 548ms/epoch - 21ms/step
# Epoch 224/1000
# 26/26 - 1s - loss: 7.3296e-04 - mean_squared_error: 7.3296e-04 - val_loss: 7.3371e-04 - val_mean_squared_error: 7.3371e-04 - 515ms/epoch - 20ms/step
# Epoch 225/1000
# 26/26 - 1s - loss: 7.1942e-04 - mean_squared_error: 7.1942e-04 - val_loss: 7.1853e-04 - val_mean_squared_error: 7.1853e-04 - 548ms/epoch - 21ms/step
# Epoch 226/1000
# 26/26 - 1s - loss: 7.0575e-04 - mean_squared_error: 7.0575e-04 - val_loss: 7.0512e-04 - val_mean_squared_error: 7.0512e-04 - 517ms/epoch - 20ms/step
# Epoch 227/1000
# 26/26 - 1s - loss: 6.9303e-04 - mean_squared_error: 6.9303e-04 - val_loss: 6.9230e-04 - val_mean_squared_error: 6.9230e-04 - 532ms/epoch - 20ms/step
# Epoch 228/1000
# 26/26 - 1s - loss: 6.7965e-04 - mean_squared_error: 6.7965e-04 - val_loss: 6.7901e-04 - val_mean_squared_error: 6.7901e-04 - 532ms/epoch - 20ms/step
# Epoch 229/1000
# 26/26 - 1s - loss: 6.6684e-04 - mean_squared_error: 6.6684e-04 - val_loss: 6.6644e-04 - val_mean_squared_error: 6.6644e-04 - 503ms/epoch - 19ms/step
# Epoch 230/1000
# 26/26 - 1s - loss: 6.5456e-04 - mean_squared_error: 6.5456e-04 - val_loss: 6.5372e-04 - val_mean_squared_error: 6.5372e-04 - 515ms/epoch - 20ms/step
# Epoch 231/1000
# 26/26 - 1s - loss: 6.4208e-04 - mean_squared_error: 6.4208e-04 - val_loss: 6.4151e-04 - val_mean_squared_error: 6.4151e-04 - 501ms/epoch - 19ms/step
# Epoch 232/1000
# 26/26 - 1s - loss: 6.2991e-04 - mean_squared_error: 6.2991e-04 - val_loss: 6.2942e-04 - val_mean_squared_error: 6.2942e-04 - 529ms/epoch - 20ms/step
# Epoch 233/1000
# 26/26 - 1s - loss: 6.1782e-04 - mean_squared_error: 6.1782e-04 - val_loss: 6.1697e-04 - val_mean_squared_error: 6.1697e-04 - 516ms/epoch - 20ms/step
# Epoch 234/1000
# 26/26 - 1s - loss: 6.0622e-04 - mean_squared_error: 6.0622e-04 - val_loss: 6.0520e-04 - val_mean_squared_error: 6.0520e-04 - 517ms/epoch - 20ms/step
# Epoch 235/1000
# 26/26 - 1s - loss: 5.9462e-04 - mean_squared_error: 5.9462e-04 - val_loss: 5.9391e-04 - val_mean_squared_error: 5.9391e-04 - 500ms/epoch - 19ms/step
# Epoch 236/1000
# 26/26 - 1s - loss: 5.8316e-04 - mean_squared_error: 5.8316e-04 - val_loss: 5.8231e-04 - val_mean_squared_error: 5.8231e-04 - 514ms/epoch - 20ms/step
# Epoch 237/1000
# 26/26 - 0s - loss: 5.7209e-04 - mean_squared_error: 5.7209e-04 - val_loss: 5.7115e-04 - val_mean_squared_error: 5.7115e-04 - 486ms/epoch - 19ms/step
# Epoch 238/1000
# 26/26 - 1s - loss: 5.6103e-04 - mean_squared_error: 5.6103e-04 - val_loss: 5.6005e-04 - val_mean_squared_error: 5.6005e-04 - 515ms/epoch - 20ms/step
# Epoch 239/1000
# 26/26 - 1s - loss: 5.5019e-04 - mean_squared_error: 5.5019e-04 - val_loss: 5.4947e-04 - val_mean_squared_error: 5.4947e-04 - 515ms/epoch - 20ms/step
# Epoch 240/1000
# 26/26 - 1s - loss: 5.3965e-04 - mean_squared_error: 5.3965e-04 - val_loss: 5.3890e-04 - val_mean_squared_error: 5.3890e-04 - 519ms/epoch - 20ms/step
# Epoch 241/1000
# 26/26 - 1s - loss: 5.2932e-04 - mean_squared_error: 5.2932e-04 - val_loss: 5.2878e-04 - val_mean_squared_error: 5.2878e-04 - 519ms/epoch - 20ms/step
# Epoch 242/1000
# 26/26 - 1s - loss: 5.1919e-04 - mean_squared_error: 5.1919e-04 - val_loss: 5.1818e-04 - val_mean_squared_error: 5.1818e-04 - 527ms/epoch - 20ms/step
# Epoch 243/1000
# 26/26 - 1s - loss: 5.0934e-04 - mean_squared_error: 5.0934e-04 - val_loss: 5.0836e-04 - val_mean_squared_error: 5.0836e-04 - 529ms/epoch - 20ms/step
# Epoch 244/1000
# 26/26 - 1s - loss: 4.9956e-04 - mean_squared_error: 4.9956e-04 - val_loss: 4.9841e-04 - val_mean_squared_error: 4.9841e-04 - 516ms/epoch - 20ms/step
# Epoch 245/1000
# 26/26 - 1s - loss: 4.8972e-04 - mean_squared_error: 4.8972e-04 - val_loss: 4.8919e-04 - val_mean_squared_error: 4.8919e-04 - 515ms/epoch - 20ms/step
# Epoch 246/1000
# 26/26 - 1s - loss: 4.8034e-04 - mean_squared_error: 4.8034e-04 - val_loss: 4.7942e-04 - val_mean_squared_error: 4.7942e-04 - 518ms/epoch - 20ms/step
# Epoch 247/1000
# 26/26 - 1s - loss: 4.7112e-04 - mean_squared_error: 4.7112e-04 - val_loss: 4.7031e-04 - val_mean_squared_error: 4.7031e-04 - 528ms/epoch - 20ms/step
# Epoch 248/1000
# 26/26 - 1s - loss: 4.6205e-04 - mean_squared_error: 4.6205e-04 - val_loss: 4.6121e-04 - val_mean_squared_error: 4.6121e-04 - 548ms/epoch - 21ms/step
# Epoch 249/1000
# 26/26 - 1s - loss: 4.5335e-04 - mean_squared_error: 4.5335e-04 - val_loss: 4.5237e-04 - val_mean_squared_error: 4.5237e-04 - 529ms/epoch - 20ms/step
# Epoch 250/1000
# 26/26 - 1s - loss: 4.4461e-04 - mean_squared_error: 4.4461e-04 - val_loss: 4.4414e-04 - val_mean_squared_error: 4.4414e-04 - 548ms/epoch - 21ms/step
# Epoch 251/1000
# 26/26 - 1s - loss: 4.3611e-04 - mean_squared_error: 4.3611e-04 - val_loss: 4.3518e-04 - val_mean_squared_error: 4.3518e-04 - 528ms/epoch - 20ms/step
# Epoch 252/1000
# 26/26 - 1s - loss: 4.2777e-04 - mean_squared_error: 4.2777e-04 - val_loss: 4.2716e-04 - val_mean_squared_error: 4.2716e-04 - 532ms/epoch - 20ms/step
# Epoch 253/1000
# 26/26 - 1s - loss: 4.1965e-04 - mean_squared_error: 4.1965e-04 - val_loss: 4.1975e-04 - val_mean_squared_error: 4.1975e-04 - 530ms/epoch - 20ms/step
# Epoch 254/1000
# 26/26 - 1s - loss: 4.1196e-04 - mean_squared_error: 4.1197e-04 - val_loss: 4.1138e-04 - val_mean_squared_error: 4.1138e-04 - 537ms/epoch - 21ms/step
# Epoch 255/1000
# 26/26 - 1s - loss: 4.0409e-04 - mean_squared_error: 4.0409e-04 - val_loss: 4.0323e-04 - val_mean_squared_error: 4.0323e-04 - 505ms/epoch - 19ms/step
# Epoch 256/1000
# 26/26 - 1s - loss: 3.9634e-04 - mean_squared_error: 3.9634e-04 - val_loss: 3.9573e-04 - val_mean_squared_error: 3.9573e-04 - 532ms/epoch - 20ms/step
# Epoch 257/1000
# 26/26 - 1s - loss: 3.8901e-04 - mean_squared_error: 3.8901e-04 - val_loss: 3.8836e-04 - val_mean_squared_error: 3.8836e-04 - 515ms/epoch - 20ms/step
# Epoch 258/1000
# 26/26 - 1s - loss: 3.8205e-04 - mean_squared_error: 3.8205e-04 - val_loss: 3.8119e-04 - val_mean_squared_error: 3.8119e-04 - 514ms/epoch - 20ms/step
# Epoch 259/1000
# 26/26 - 1s - loss: 3.7484e-04 - mean_squared_error: 3.7484e-04 - val_loss: 3.7431e-04 - val_mean_squared_error: 3.7431e-04 - 516ms/epoch - 20ms/step
# Epoch 260/1000
# 26/26 - 1s - loss: 3.6803e-04 - mean_squared_error: 3.6803e-04 - val_loss: 3.6754e-04 - val_mean_squared_error: 3.6754e-04 - 531ms/epoch - 20ms/step
# Epoch 261/1000
# 26/26 - 1s - loss: 3.6153e-04 - mean_squared_error: 3.6153e-04 - val_loss: 3.6085e-04 - val_mean_squared_error: 3.6085e-04 - 501ms/epoch - 19ms/step
# Epoch 262/1000
# 26/26 - 1s - loss: 3.5504e-04 - mean_squared_error: 3.5504e-04 - val_loss: 3.5451e-04 - val_mean_squared_error: 3.5451e-04 - 516ms/epoch - 20ms/step
# Epoch 263/1000
# 26/26 - 1s - loss: 3.4884e-04 - mean_squared_error: 3.4884e-04 - val_loss: 3.4852e-04 - val_mean_squared_error: 3.4852e-04 - 531ms/epoch - 20ms/step
# Epoch 264/1000
# 26/26 - 1s - loss: 3.4290e-04 - mean_squared_error: 3.4290e-04 - val_loss: 3.4253e-04 - val_mean_squared_error: 3.4253e-04 - 532ms/epoch - 20ms/step
# Epoch 265/1000
# 26/26 - 1s - loss: 3.3723e-04 - mean_squared_error: 3.3723e-04 - val_loss: 3.3671e-04 - val_mean_squared_error: 3.3671e-04 - 548ms/epoch - 21ms/step
# Epoch 266/1000
# 26/26 - 1s - loss: 3.3156e-04 - mean_squared_error: 3.3156e-04 - val_loss: 3.3136e-04 - val_mean_squared_error: 3.3136e-04 - 530ms/epoch - 20ms/step
# Epoch 267/1000
# 26/26 - 1s - loss: 3.2598e-04 - mean_squared_error: 3.2598e-04 - val_loss: 3.2580e-04 - val_mean_squared_error: 3.2580e-04 - 516ms/epoch - 20ms/step
# Epoch 268/1000
# 26/26 - 1s - loss: 3.2077e-04 - mean_squared_error: 3.2077e-04 - val_loss: 3.2064e-04 - val_mean_squared_error: 3.2064e-04 - 515ms/epoch - 20ms/step
# Epoch 269/1000
# 26/26 - 1s - loss: 3.1574e-04 - mean_squared_error: 3.1574e-04 - val_loss: 3.1554e-04 - val_mean_squared_error: 3.1554e-04 - 532ms/epoch - 20ms/step
# Epoch 270/1000
# 26/26 - 1s - loss: 3.1071e-04 - mean_squared_error: 3.1071e-04 - val_loss: 3.1059e-04 - val_mean_squared_error: 3.1059e-04 - 531ms/epoch - 20ms/step
# Epoch 271/1000
# 26/26 - 1s - loss: 3.0591e-04 - mean_squared_error: 3.0591e-04 - val_loss: 3.0578e-04 - val_mean_squared_error: 3.0578e-04 - 539ms/epoch - 21ms/step
# Epoch 272/1000
# 26/26 - 1s - loss: 3.0121e-04 - mean_squared_error: 3.0121e-04 - val_loss: 3.0108e-04 - val_mean_squared_error: 3.0108e-04 - 539ms/epoch - 21ms/step
# Epoch 273/1000
# 26/26 - 1s - loss: 2.9675e-04 - mean_squared_error: 2.9675e-04 - val_loss: 2.9666e-04 - val_mean_squared_error: 2.9666e-04 - 520ms/epoch - 20ms/step
# Epoch 274/1000
# 26/26 - 1s - loss: 2.9234e-04 - mean_squared_error: 2.9234e-04 - val_loss: 2.9235e-04 - val_mean_squared_error: 2.9235e-04 - 525ms/epoch - 20ms/step
# Epoch 275/1000
# 26/26 - 1s - loss: 2.8806e-04 - mean_squared_error: 2.8806e-04 - val_loss: 2.8802e-04 - val_mean_squared_error: 2.8802e-04 - 529ms/epoch - 20ms/step
# Epoch 276/1000
# 26/26 - 1s - loss: 2.8403e-04 - mean_squared_error: 2.8403e-04 - val_loss: 2.8403e-04 - val_mean_squared_error: 2.8403e-04 - 539ms/epoch - 21ms/step
# Epoch 277/1000
# 26/26 - 1s - loss: 2.8023e-04 - mean_squared_error: 2.8023e-04 - val_loss: 2.8034e-04 - val_mean_squared_error: 2.8034e-04 - 506ms/epoch - 19ms/step
# Epoch 278/1000
# 26/26 - 1s - loss: 2.7644e-04 - mean_squared_error: 2.7644e-04 - val_loss: 2.7645e-04 - val_mean_squared_error: 2.7645e-04 - 532ms/epoch - 20ms/step
# Epoch 279/1000
# 26/26 - 1s - loss: 2.7277e-04 - mean_squared_error: 2.7277e-04 - val_loss: 2.7285e-04 - val_mean_squared_error: 2.7285e-04 - 516ms/epoch - 20ms/step
# Epoch 280/1000
# 26/26 - 1s - loss: 2.6925e-04 - mean_squared_error: 2.6925e-04 - val_loss: 2.6928e-04 - val_mean_squared_error: 2.6928e-04 - 534ms/epoch - 21ms/step
# Epoch 281/1000
# 26/26 - 1s - loss: 2.6570e-04 - mean_squared_error: 2.6570e-04 - val_loss: 2.6591e-04 - val_mean_squared_error: 2.6591e-04 - 514ms/epoch - 20ms/step
# Epoch 282/1000
# 26/26 - 1s - loss: 2.6238e-04 - mean_squared_error: 2.6238e-04 - val_loss: 2.6246e-04 - val_mean_squared_error: 2.6246e-04 - 532ms/epoch - 20ms/step
# Epoch 283/1000
# 26/26 - 1s - loss: 2.5912e-04 - mean_squared_error: 2.5912e-04 - val_loss: 2.5923e-04 - val_mean_squared_error: 2.5923e-04 - 517ms/epoch - 20ms/step
# Epoch 284/1000
# 26/26 - 1s - loss: 2.5596e-04 - mean_squared_error: 2.5596e-04 - val_loss: 2.5606e-04 - val_mean_squared_error: 2.5606e-04 - 532ms/epoch - 20ms/step
# Epoch 285/1000
# 26/26 - 1s - loss: 2.5293e-04 - mean_squared_error: 2.5293e-04 - val_loss: 2.5329e-04 - val_mean_squared_error: 2.5329e-04 - 503ms/epoch - 19ms/step
# Epoch 286/1000
# 26/26 - 1s - loss: 2.4989e-04 - mean_squared_error: 2.4989e-04 - val_loss: 2.5016e-04 - val_mean_squared_error: 2.5016e-04 - 521ms/epoch - 20ms/step
# Epoch 287/1000
# 26/26 - 1s - loss: 2.4700e-04 - mean_squared_error: 2.4700e-04 - val_loss: 2.4714e-04 - val_mean_squared_error: 2.4714e-04 - 527ms/epoch - 20ms/step
# Epoch 288/1000
# 26/26 - 1s - loss: 2.4418e-04 - mean_squared_error: 2.4418e-04 - val_loss: 2.4439e-04 - val_mean_squared_error: 2.4439e-04 - 516ms/epoch - 20ms/step
# Epoch 289/1000
# 26/26 - 1s - loss: 2.4149e-04 - mean_squared_error: 2.4149e-04 - val_loss: 2.4162e-04 - val_mean_squared_error: 2.4162e-04 - 521ms/epoch - 20ms/step
# Epoch 290/1000
# 26/26 - 1s - loss: 2.3883e-04 - mean_squared_error: 2.3883e-04 - val_loss: 2.3907e-04 - val_mean_squared_error: 2.3907e-04 - 517ms/epoch - 20ms/step
# Epoch 291/1000
# 26/26 - 1s - loss: 2.3632e-04 - mean_squared_error: 2.3632e-04 - val_loss: 2.3653e-04 - val_mean_squared_error: 2.3653e-04 - 531ms/epoch - 20ms/step
# Epoch 292/1000
# 26/26 - 1s - loss: 2.3382e-04 - mean_squared_error: 2.3382e-04 - val_loss: 2.3402e-04 - val_mean_squared_error: 2.3402e-04 - 532ms/epoch - 20ms/step
# Epoch 293/1000
# 26/26 - 1s - loss: 2.3142e-04 - mean_squared_error: 2.3142e-04 - val_loss: 2.3166e-04 - val_mean_squared_error: 2.3166e-04 - 533ms/epoch - 20ms/step
# Epoch 294/1000
# 26/26 - 1s - loss: 2.2917e-04 - mean_squared_error: 2.2917e-04 - val_loss: 2.2932e-04 - val_mean_squared_error: 2.2932e-04 - 533ms/epoch - 20ms/step
# Epoch 295/1000
# 26/26 - 1s - loss: 2.2686e-04 - mean_squared_error: 2.2686e-04 - val_loss: 2.2711e-04 - val_mean_squared_error: 2.2711e-04 - 528ms/epoch - 20ms/step
# Epoch 296/1000
# 26/26 - 1s - loss: 2.2465e-04 - mean_squared_error: 2.2465e-04 - val_loss: 2.2488e-04 - val_mean_squared_error: 2.2488e-04 - 516ms/epoch - 20ms/step
# Epoch 297/1000
# 26/26 - 1s - loss: 2.2255e-04 - mean_squared_error: 2.2255e-04 - val_loss: 2.2276e-04 - val_mean_squared_error: 2.2276e-04 - 531ms/epoch - 20ms/step
# Epoch 298/1000
# 26/26 - 1s - loss: 2.2050e-04 - mean_squared_error: 2.2050e-04 - val_loss: 2.2074e-04 - val_mean_squared_error: 2.2074e-04 - 517ms/epoch - 20ms/step
# Epoch 299/1000
# 26/26 - 1s - loss: 2.1849e-04 - mean_squared_error: 2.1849e-04 - val_loss: 2.1878e-04 - val_mean_squared_error: 2.1878e-04 - 530ms/epoch - 20ms/step
# Epoch 300/1000
# 26/26 - 1s - loss: 2.1657e-04 - mean_squared_error: 2.1657e-04 - val_loss: 2.1681e-04 - val_mean_squared_error: 2.1681e-04 - 544ms/epoch - 21ms/step
# Epoch 301/1000
# 26/26 - 1s - loss: 2.1468e-04 - mean_squared_error: 2.1468e-04 - val_loss: 2.1497e-04 - val_mean_squared_error: 2.1497e-04 - 518ms/epoch - 20ms/step
# Epoch 302/1000
# 26/26 - 1s - loss: 2.1288e-04 - mean_squared_error: 2.1288e-04 - val_loss: 2.1308e-04 - val_mean_squared_error: 2.1308e-04 - 529ms/epoch - 20ms/step
# Epoch 303/1000
# 26/26 - 1s - loss: 2.1106e-04 - mean_squared_error: 2.1106e-04 - val_loss: 2.1129e-04 - val_mean_squared_error: 2.1129e-04 - 527ms/epoch - 20ms/step
# Epoch 304/1000
# 26/26 - 1s - loss: 2.0937e-04 - mean_squared_error: 2.0937e-04 - val_loss: 2.0957e-04 - val_mean_squared_error: 2.0957e-04 - 520ms/epoch - 20ms/step
# Epoch 305/1000
# 26/26 - 1s - loss: 2.0769e-04 - mean_squared_error: 2.0769e-04 - val_loss: 2.0790e-04 - val_mean_squared_error: 2.0790e-04 - 550ms/epoch - 21ms/step
# Epoch 306/1000
# 26/26 - 1s - loss: 2.0606e-04 - mean_squared_error: 2.0606e-04 - val_loss: 2.0628e-04 - val_mean_squared_error: 2.0628e-04 - 535ms/epoch - 21ms/step
# Epoch 307/1000
# 26/26 - 1s - loss: 2.0448e-04 - mean_squared_error: 2.0448e-04 - val_loss: 2.0468e-04 - val_mean_squared_error: 2.0468e-04 - 544ms/epoch - 21ms/step
# Epoch 308/1000
# 26/26 - 1s - loss: 2.0296e-04 - mean_squared_error: 2.0296e-04 - val_loss: 2.0314e-04 - val_mean_squared_error: 2.0314e-04 - 544ms/epoch - 21ms/step
# Epoch 309/1000
# 26/26 - 1s - loss: 2.0145e-04 - mean_squared_error: 2.0145e-04 - val_loss: 2.0164e-04 - val_mean_squared_error: 2.0164e-04 - 571ms/epoch - 22ms/step
# Epoch 310/1000
# 26/26 - 1s - loss: 1.9997e-04 - mean_squared_error: 1.9997e-04 - val_loss: 2.0020e-04 - val_mean_squared_error: 2.0020e-04 - 534ms/epoch - 21ms/step
# Epoch 311/1000
# 26/26 - 1s - loss: 1.9860e-04 - mean_squared_error: 1.9860e-04 - val_loss: 1.9881e-04 - val_mean_squared_error: 1.9881e-04 - 526ms/epoch - 20ms/step
# Epoch 312/1000
# 26/26 - 1s - loss: 1.9721e-04 - mean_squared_error: 1.9721e-04 - val_loss: 1.9732e-04 - val_mean_squared_error: 1.9732e-04 - 532ms/epoch - 20ms/step
# Epoch 313/1000
# 26/26 - 1s - loss: 1.9581e-04 - mean_squared_error: 1.9581e-04 - val_loss: 1.9597e-04 - val_mean_squared_error: 1.9597e-04 - 534ms/epoch - 21ms/step
# Epoch 314/1000
# ...
# Epoch 906/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 69ms/step
# Epoch 907/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8104 - val_mean_squared_error: 0.8104 - 2s/epoch - 69ms/step
# Epoch 908/1000
# 26/26 - 2s - loss: 0.8080 - mean_squared_error: 0.8080 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 68ms/step
# Epoch 909/1000
# 26/26 - 2s - loss: 0.8079 - mean_squared_error: 0.8079 - val_loss: 0.8103 - val_mean_squared_error: 0.8103 - 2s/epoch - 68ms/step
# Epoch 910/1000
# 26/26 - 2s - loss: 0.8082 - mean_squared_error: 0.8082 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 67ms/step
# Epoch 911/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 68ms/step
# Epoch 912/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 67ms/step
# Epoch 913/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 69ms/step
# Epoch 914/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 67ms/step
# Epoch 915/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 70ms/step
# Epoch 916/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 73ms/step
# Epoch 917/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 75ms/step
# Epoch 918/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 74ms/step
# Epoch 919/1000
# 26/26 - 2s - loss: 0.8080 - mean_squared_error: 0.8080 - val_loss: 0.8101 - val_mean_squared_error: 0.8101 - 2s/epoch - 70ms/step
# Epoch 920/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 75ms/step
# Epoch 921/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8102 - val_mean_squared_error: 0.8102 - 2s/epoch - 69ms/step
# Epoch 922/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8101 - val_mean_squared_error: 0.8101 - 2s/epoch - 79ms/step
# Epoch 923/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 72ms/step
# Epoch 924/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 67ms/step
# Epoch 925/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 70ms/step
# Epoch 926/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 78ms/step
# Epoch 927/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8101 - val_mean_squared_error: 0.8101 - 2s/epoch - 75ms/step
# Epoch 928/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 76ms/step
# Epoch 929/1000
# 26/26 - 2s - loss: 0.8079 - mean_squared_error: 0.8079 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 68ms/step
# Epoch 930/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 81ms/step
# Epoch 931/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 72ms/step
# Epoch 932/1000
# 26/26 - 2s - loss: 0.8079 - mean_squared_error: 0.8079 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 70ms/step
# Epoch 933/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8103 - val_mean_squared_error: 0.8103 - 2s/epoch - 72ms/step
# Epoch 934/1000
# 26/26 - 2s - loss: 0.8079 - mean_squared_error: 0.8079 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 68ms/step
# Epoch 935/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 78ms/step
# Epoch 936/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 67ms/step
# Epoch 937/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 66ms/step
# Epoch 938/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 68ms/step
# Epoch 939/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 68ms/step
# Epoch 940/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 66ms/step
# Epoch 941/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 68ms/step
# Epoch 942/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 68ms/step
# Epoch 943/1000
# 26/26 - 2s - loss: 0.8076 - mean_squared_error: 0.8076 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 68ms/step
# Epoch 944/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8101 - val_mean_squared_error: 0.8101 - 2s/epoch - 69ms/step
# Epoch 945/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 70ms/step
# Epoch 946/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 69ms/step
# Epoch 947/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 66ms/step
# Epoch 948/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 74ms/step
# Epoch 949/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 70ms/step
# Epoch 950/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 69ms/step
# Epoch 951/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8101 - val_mean_squared_error: 0.8101 - 2s/epoch - 82ms/step
# Epoch 952/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 68ms/step
# Epoch 953/1000
# 26/26 - 2s - loss: 0.8079 - mean_squared_error: 0.8079 - val_loss: 0.8106 - val_mean_squared_error: 0.8106 - 2s/epoch - 75ms/step
# Epoch 954/1000
# 26/26 - 2s - loss: 0.8079 - mean_squared_error: 0.8079 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 68ms/step
# Epoch 955/1000
# 26/26 - 2s - loss: 0.8080 - mean_squared_error: 0.8080 - val_loss: 0.8102 - val_mean_squared_error: 0.8102 - 2s/epoch - 73ms/step
# Epoch 956/1000
# 26/26 - 2s - loss: 0.8079 - mean_squared_error: 0.8079 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 89ms/step
# Epoch 957/1000
# 26/26 - 2s - loss: 0.8079 - mean_squared_error: 0.8079 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 81ms/step
# Epoch 958/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 76ms/step
# Epoch 959/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 71ms/step
# Epoch 960/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8105 - val_mean_squared_error: 0.8105 - 2s/epoch - 70ms/step
# Epoch 961/1000
# 26/26 - 2s - loss: 0.8081 - mean_squared_error: 0.8081 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 79ms/step
# Epoch 962/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 81ms/step
# Epoch 963/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 75ms/step
# Epoch 964/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8102 - val_mean_squared_error: 0.8102 - 2s/epoch - 68ms/step
# Epoch 965/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 71ms/step
# Epoch 966/1000
# 26/26 - 2s - loss: 0.8079 - mean_squared_error: 0.8079 - val_loss: 0.8101 - val_mean_squared_error: 0.8101 - 2s/epoch - 73ms/step
# Epoch 967/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 71ms/step
# Epoch 968/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8102 - val_mean_squared_error: 0.8102 - 2s/epoch - 67ms/step
# Epoch 969/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 76ms/step
# Epoch 970/1000
# 26/26 - 2s - loss: 0.8079 - mean_squared_error: 0.8079 - val_loss: 0.8106 - val_mean_squared_error: 0.8106 - 2s/epoch - 67ms/step
# Epoch 971/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 70ms/step
# Epoch 972/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8105 - val_mean_squared_error: 0.8105 - 2s/epoch - 66ms/step
# Epoch 973/1000
# 26/26 - 2s - loss: 0.8082 - mean_squared_error: 0.8082 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 68ms/step
# Epoch 974/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8101 - val_mean_squared_error: 0.8101 - 2s/epoch - 68ms/step
# Epoch 975/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8104 - val_mean_squared_error: 0.8104 - 2s/epoch - 66ms/step
# Epoch 976/1000
# 26/26 - 2s - loss: 0.8079 - mean_squared_error: 0.8079 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 74ms/step
# Epoch 977/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 68ms/step
# Epoch 978/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 74ms/step
# Epoch 979/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 70ms/step
# Epoch 980/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 69ms/step
# Epoch 981/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8101 - val_mean_squared_error: 0.8101 - 2s/epoch - 93ms/step
# Epoch 982/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 67ms/step
# Epoch 983/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8101 - val_mean_squared_error: 0.8101 - 2s/epoch - 69ms/step
# Epoch 984/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8102 - val_mean_squared_error: 0.8102 - 2s/epoch - 71ms/step
# Epoch 985/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 70ms/step
# Epoch 986/1000
# 26/26 - 2s - loss: 0.8079 - mean_squared_error: 0.8079 - val_loss: 0.8101 - val_mean_squared_error: 0.8101 - 2s/epoch - 77ms/step
# Epoch 987/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8102 - val_mean_squared_error: 0.8102 - 2s/epoch - 77ms/step
# Epoch 988/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8101 - val_mean_squared_error: 0.8101 - 2s/epoch - 79ms/step
# Epoch 989/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 72ms/step
# Epoch 990/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8101 - val_mean_squared_error: 0.8101 - 2s/epoch - 71ms/step
# Epoch 991/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 69ms/step
# Epoch 992/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 70ms/step
# Epoch 993/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 71ms/step
# Epoch 994/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 73ms/step
# Epoch 995/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 79ms/step
# Epoch 996/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8099 - val_mean_squared_error: 0.8099 - 2s/epoch - 71ms/step
# Epoch 997/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8098 - val_mean_squared_error: 0.8098 - 2s/epoch - 70ms/step
# Epoch 998/1000
# 26/26 - 2s - loss: 0.8077 - mean_squared_error: 0.8077 - val_loss: 0.8102 - val_mean_squared_error: 0.8102 - 2s/epoch - 89ms/step
# Epoch 999/1000
# 26/26 - 2s - loss: 0.8080 - mean_squared_error: 0.8080 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 69ms/step
# Epoch 1000/1000
# 26/26 - 2s - loss: 0.8078 - mean_squared_error: 0.8078 - val_loss: 0.8100 - val_mean_squared_error: 0.8100 - 2s/epoch - 71ms/step
# [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# [9.036632400238886e-05, 0.002591991564258933, 0.010223986580967903, 0.0224640853703022, 0.039795659482479095, 0.06258682906627655, 0.09100593626499176, 0.12220484763383865, 0.15909330546855927, 0.20140069723129272, 0.2515099048614502, 0.3037073016166687, 0.3616955876350403, 0.4212110638618469, 0.4917086362838745, 0.5646544098854065, 0.6409049034118652, 0.7131882905960083, 0.8100106716156006]
# 15/15 [==============================] - 0s 14ms/step - loss: 2.9302e-04 - mean_squared_error: 2.9302e-04
# [8.995951066026464e-05, 9.239621431333944e-05, 0.00013226873124949634, 0.00010275832755723968, 0.00010316991392755881, 0.00012356086517684162, 0.00018369060126133263, 0.0002674389397725463, 0.00014890269085299224, 0.000408374413382262, 0.00012321087706368417, 0.00015056288975756615, 0.00012973872071597725, 0.0003605744568631053, 0.00023901823442429304, 0.00029865975375287235, 0.00036160979652777314, 0.0004889311967417598, 0.00029301538597792387]
# All weights are non-negative (ignoring biases).
# 271/271 [==============================] - 1s 3ms/step
# 271/271 [==============================] - 1s 4ms/step
# lip cst: 0.641
# Estimated Lipschitz constant of the 2-layer RNN: 0.6405521035194397
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rnn_36 (RNN)                (None, 10, 64)            13824
#
#  rnn_37 (RNN)                (None, 10, 64)            24576
#
#  dense_18 (Dense)            (None, 10, 2)             130
#
# =================================================================
# Total params: 38530 (150.51 KB)
# Trainable params: 38530 (150.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
print(np.array(lip))
# Out:
# [0.66782415 0.6449329  0.69914657 0.6837406  0.6637195  0.6715355
#  0.7002532  0.6276158  0.6464743  0.651618   0.7044543  0.6587134
#  0.59058046 0.60432047 0.61178106 0.6589735  0.63318974 0.64698035
#  0.6405521 ]

# %%
# ICRNN with ReLU
# model.save('icrnn_cstr.h5')
# model = tf.keras.models.load_model('iclrnn_cstr.h5', custom_objects={'MyRNNCell': MyRNNCell})

# %%
results = model.evaluate(X_test, y_test_normalized, batch_size=256)
print("test loss, test acc:", results)
# Out:
# 15/15 [==============================] - 0s 14ms/step - loss: 2.9302e-04 - mean_squared_error: 2.9302e-04
# test loss, test acc: [0.00029301538597792387, 0.0002930154150817543]

# %%
from tensorflow.python.framework.convert_to_constants import  convert_variables_to_constants_v2_as_graph

def get_flops(model):
    concrete = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete.get_concrete_function(
        [tf.TensorSpec([1, *inputs.shape[1:]]) for inputs in model.inputs])
    frozen_func, graph_def = convert_variables_to_constants_v2_as_graph(concrete_func, lower_control_flow=False)
    with tf.Graph().as_default() as graph:
        tf.graph_util.import_graph_def(graph_def, name='')
        run_meta = tf.compat.v1.RunMetadata()
        opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
        flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd="op", options=opts)
        return flops.total_float_ops

print("The FLOPs is:{}".format(get_flops(model)) ,flush=True )
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\zihaow19\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\profiler\internal\flops_registry.py:453: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# The FLOPs is:79892
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rnn_36 (RNN)                (None, 10, 64)            13824
#
#  rnn_37 (RNN)                (None, 10, 64)            24576
#
#  dense_18 (Dense)            (None, 10, 2)             130
#
# =================================================================
# Total params: 38530 (150.51 KB)
# Trainable params: 38530 (150.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# plot training and validation losses against epochs

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Normal RNN Training and validation loss')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
"""
    equation for the stability ellipse is 1060x^2 + 44xy + 0.52y^2 - 372 = 0
"""
# prepare x and y coordinates for plotting the stability region
y = np.linspace(-100, 100, 100000, endpoint=True)

x_upper = list()
x_lower = list()
y_plot = list()

for i in y:
    sqrt = np.sqrt(-2688000 * i**2 + 15772800000)
    if sqrt >= 0:
        y_plot.append(i)
        x_upper.append((-4400 * i + sqrt) / 212000)
        x_lower.append((-4400 * i - sqrt) / 212000)
        pass
    pass

plt.figure(figsize=(10,10))

# # plot the first 10 samples and their trajectories
y_predict = model.predict(X_test)
print(y_predict.shape)

y_predict = y_predict.reshape(-1,2)
y_predict = scaler_y.inverse_transform(y_predict)
y_predict = y_predict.reshape(-1,num_step,2)

X_plot = X_test.reshape(-1,num_dims)
X_plot = scaler_X.inverse_transform(X_plot)
X_plot = X_plot.reshape(-1,num_step,num_dims)

for i in range(10):
    if i == 0:  # only add label to 1 data point
        plt.plot(X_plot[i, 0, 1], X_plot[i, 0, 0], marker="*", markersize=15, color='pink')
        plt.plot(y_test[i, :, 1], y_test[i, :, 0], color='cyan', lw=2, label='Test')
        plt.plot(y_predict[i, :, 1], y_predict[i, :, 0], color='black', lw=2, ls=':', label='Predicted')
    else:
        plt.plot(X_plot[i, 0, 1], X_plot[i, 0, 0], marker="*", markersize=15, color='pink')
        plt.plot(y_test[i, :, 1], y_test[i, :, 0], color='cyan', lw=2)
        plt.plot(y_predict[i, :, 1], y_predict[i, :, 0], color='black', lw=2, ls=':')

# plot stability region
plt.plot(x_lower, y_plot, color='steelblue', label='stability region')
plt.plot(x_upper, y_plot, color='steelblue')
plt.ylim([-100, 100])
plt.xlim([-2, 2])

plt.xlabel("C_A - C_As")
plt.ylabel("T - T_s")
plt.legend()
# plt.savefig('iclrnn_noise_0.4.pdf')
plt.show()
# Out:
# C:\Users\zihaow19\AppData\Local\Temp\ipykernel_4376\151401212.py:12: RuntimeWarning: invalid value encountered in sqrt
#   sqrt = np.sqrt(-2688000 * i**2 + 15772800000)
# 116/116 [==============================] - 0s 3ms/step
# (3706, 10, 2)
