# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input, Activation, Dropout, Add, LSTM, GRU, RNN, LayerNormalization, BatchNormalization, SpectralNormalization, Conv1D, MaxPooling1D, Flatten, Layer
from keras import backend as K
from keras.optimizers import Adam,SGD
import tensorflow as tf
from keras import Model, regularizers, activations, initializers
from keras.constraints import Constraint
import pickle

# %%
# specifying constant parameters

T_0 = 300
V = 1
k_0 = 8.46*(np.power(10,6))
C_p = 0.231
rho_L = 1000
Q_s = 0.0
T_s = 401.8727
F = 5
E = 5*(np.power(10,4))
delta_H = -1.15*(np.power(10,4))
R = 8.314
C_A0s = 4
C_As = 1.9537
t_final = 0.005
t_step = 1e-4
P = np.array([[1060, 22], [22, 0.52]])

num_step = 10

# %%
# generating inputs and initial states for CSTR, all expressed in deviation form

u1_list = np.linspace(-3.5, 3.5, 4, endpoint=True)
u2_list = np.linspace(-5e5, 5e5, 4, endpoint=True)
T_initial = np.linspace(300, 600, 100, endpoint=True) - T_s
CA_initial = np.linspace(0, 6, 100, endpoint=True) - C_As

# %%
# sieve out initial states that lie outside of stability region

T_start = list()
CA_start = list()

for T in T_initial:
    for CA in CA_initial:
        x = np.array([CA, T])
        if x @ P @ x < 372:
            CA_start.append(CA)
            T_start.append(T)
print("number of initial conditions: {}".format(len(CA_start)))

# convert to np.arrays
CA_start = np.array([CA_start])
T_start = np.array([T_start])
x_deviation = np.concatenate((CA_start.T, T_start.T), axis=1)  # every row is a pair of initial states within stability region
print("shape of x_deviation is {}".format(x_deviation.shape))
# Out:
# number of initial conditions: 772
# shape of x_deviation is (772, 2)

# %%
def CSTR_simulation(F, V, C_A0, k_0, E, R, T_0, delta_H, rho_L, C_p, Q, t_final, t_step, C_A_initial, T_initial):
    """
        simulating CSTR using forward Euler method
    """

    C_A_list = list()  # evolution of CA over time
    T_list = list()  # evolution of T over time

    C_A = C_A_initial + C_As
    T = T_initial + T_s

    for i in range(int(t_final / t_step)):
        dCAdt = F / V * (C_A0 - C_A) - k_0 * np.exp(-E / (R * T)) * C_A**2
        dTdt = F / V * (T_0 - T) - delta_H / (rho_L * C_p) * k_0 * np.exp(-E / (R * T)) * C_A**2 + Q / (rho_L * C_p * V)

        T += dTdt * t_step
        C_A += dCAdt * t_step

        if (i+1) % 5 == 0:
            C_A_list.append(C_A - C_As)  # in deviation form
            T_list.append(T - T_s)  # in deviation form

    return C_A_list, T_list

# %%
# get X and y data for training and testing

CA_output = list()
T_output = list()
CA_input = list()
T_input = list()
CA0_input = list()
Q_input = list()

for u1 in u1_list:
    C_A0 = u1 + C_A0s

    for u2 in u2_list:
        Q = u2 + Q_s

        for C_A_initial, T_initial in x_deviation:
            CA0_input.append(u1)
            Q_input.append(u2)
            CA_input.append(C_A_initial)
            T_input.append(T_initial)

            C_A_list, T_list = CSTR_simulation(F, V, C_A0, k_0, E, R, T_0, delta_H, rho_L, C_p, Q, t_final, t_step, C_A_initial, T_initial)
            CA_output.append(C_A_list)
            T_output.append(T_list)

# %%
CA0_input = np.array(CA0_input)
print(CA0_input.shape)
CA_output = np.array(CA_output)
print(CA_output.shape)
# Out:
# (12352,)
# (12352, 10)

# %%
# collate input for RNN

CA0_input = np.array(CA0_input)
CA0_input = CA0_input.reshape(-1,1,1)

Q_input = np.array(Q_input)
Q_input = Q_input.reshape(-1,1,1)

CA_input = np.array(CA_input)
CA_input = CA_input.reshape(-1,1,1)

T_input = np.array(T_input)
T_input = T_input.reshape(-1,1,1)

RNN_input = np.concatenate((T_input, CA_input, Q_input, CA0_input), axis=2)
# RNN_input = np.concatenate((T_input, CA_input, Q_input, CA0_input, -T_input, -CA_input, -Q_input, -CA0_input), axis=2)

"""
    the input to RNN is in the shape [number of samples x timestep x variables], and the input variables are same for every
    time step, not sure if my treatment here is correct
"""

RNN_input = RNN_input.repeat(num_step, axis=1)
print("RNN_input shape is {}".format(RNN_input.shape))
# Out:
# RNN_input shape is (12352, 10, 4)

# %%
# checking the input is duplicated 100 times for each time step
print(RNN_input[0, 0])
print(RNN_input[0, 1])
# Out:
# [-7.45999727e+01  1.44023939e+00 -5.00000000e+05 -3.50000000e+00]
# [-7.45999727e+01  1.44023939e+00 -5.00000000e+05 -3.50000000e+00]

# %%
# collate output for RNN

CA_output = np.array(CA_output)
CA_output = CA_output.reshape(-1, num_step, 1)

T_output = np.array(T_output)
T_output = T_output.reshape(-1, num_step, 1)

RNN_output = np.concatenate((T_output, CA_output), axis=2)
print("RNN_output shape is {}".format(RNN_output.shape))  # output shape: number of samples x timestep x variables
# Out:
# RNN_output shape is (12352, 10, 2)

# %%
# checking output
print(RNN_output[0, :5])
# Out:
# [[-75.72458929   1.4325163 ]
#  [-76.84802004   1.4248451 ]
#  [-77.97016868   1.41722366]
#  [-79.09094468   1.40964998]
#  [-80.21026299   1.40212216]]

# %%
def check_non_negative_weights_ignore_bias(model):
    all_non_negative = True
    for layer in model.layers:
        weights = layer.get_weights()
        if weights:  # tf the layer has weights
            # check only the weight matrices (ignoring biases if present)
            weight_only = weights[0]  # assume weights are the first element, bias (if any) is second
            if not np.all(weight_only >= 0):
                print(f"Non-negative check failed in layer: {layer.name}")
                all_non_negative = False
    if all_non_negative:
        print("All weights are non-negative (ignoring biases).")
    else:
        print("Some weights are negative (ignoring biases).")

# %%
# this method will provide an overestimate of the Lipschitz constant
def evaluate_lip_const(model: Model, x, eps, seed=None):
    """
    Evaluate the Lipschitz constant of a model, with the naive method.
    Please note that the estimation of the lipschitz constant is done locally around
    input sample. This may not correctly estimate the behaviour in the whole domain.

    Args:
        model: built keras model used to make predictions
        x: inputs used to compute the lipschitz constant
        eps (float): magnitude of noise to add to input in order to compute the constant
        seed (int): seed used when generating the noise ( can be set to None )

    Returns:
        float: the empirically evaluated lipschitz constant. The computation might also
            be inaccurate in high dimensional space.

    """
    y_pred = model.predict(x)
    x_var = x + K.random_uniform(
        shape=x.shape, minval=eps * 0.25, maxval=eps, seed=seed
    )
#     x_var = x + K.random_normal(
#         shape=x.shape, mean=0, stddev=eps, seed=seed
#     )
    y_pred_var = model.predict(x_var)
    dx = x - x_var
    dfx = y_pred - y_pred_var
    ndx = K.sqrt(K.sum(K.square(dx), axis=range(1, len(x.shape))))
    ndfx = K.sqrt(K.sum(K.square(dfx), axis=range(1, len(y_pred.shape))))
    lip_cst = K.max(ndfx / ndx)
    print(f"lip cst: {lip_cst:.3f}")
    return lip_cst

# %%
# set the seed for reproducibility
tf.random.set_seed(42)

training_loss = [0]*19
test_loss = [0]*19
lip = [0]*19
noise = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]

for i in range(19):
    num_dims = 4

    # split into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(RNN_input, RNN_output, test_size=0.3, random_state=123)

    # define scalers for both X and y base on training data only
    scaler_X = preprocessing.MinMaxScaler().fit(X_train.reshape(-1, num_dims))
    scaler_y = preprocessing.MinMaxScaler().fit(y_train.reshape(-1, 2))

    X_train = scaler_X.transform(X_train.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
    X_test = scaler_X.transform(X_test.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
    y_train = scaler_y.transform(y_train.reshape(-1,2)).reshape(-1,num_step,2)
    y_test_normalized = scaler_y.transform(y_test.reshape(-1,2)).reshape(-1,num_step,2)

    # X is just the initial condition, so we introduce noise to the output trajectory y
    y_train = y_train + np.random.normal(0, noise[i], y_train.shape)

    # RNN
    nh = 64
    input = Input(shape=(X_train.shape[1],X_train.shape[2]))
    x = LSTM(nh,
          return_sequences=True,
          )(input)
    x = LSTM(nh,
          return_sequences=True,
          )(x)
    x = Dense(2,
            activation='linear',
            )(x)
    model = Model(input, x)

    model.compile(optimizer='adam', loss='mean_squared_error', metrics=[tf.keras.metrics.MeanSquaredError()])
    history = model.fit(X_train, y_train, epochs=1000, batch_size=256, validation_split=0.25, verbose=2)

    training_loss[i] = history.history['val_loss'][-1]
    print(noise)
    print(training_loss)

    loss = model.evaluate(X_test, y_test_normalized, batch_size=256)
    test_loss[i] = loss[0]
    print(test_loss)

    # check convexity by checking the weights
    check_non_negative_weights_ignore_bias(model)

    # compute the Lipschitz constant
    lipschitz_constant = evaluate_lip_const(model, X_train, 1e-04, 42)
    print(f"Estimated Lipschitz constant of the 2-layer RNN: {lipschitz_constant}")

    lip[i] = lipschitz_constant

model.summary()
# Out:
# Epoch 1/1000
# 26/26 - 5s - loss: 0.1382 - mean_squared_error: 0.1382 - val_loss: 0.0659 - val_mean_squared_error: 0.0659 - 5s/epoch - 207ms/step
# Epoch 2/1000
# 26/26 - 1s - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0361 - val_mean_squared_error: 0.0361 - 596ms/epoch - 23ms/step
# Epoch 3/1000
# 26/26 - 1s - loss: 0.0298 - mean_squared_error: 0.0298 - val_loss: 0.0247 - val_mean_squared_error: 0.0247 - 587ms/epoch - 23ms/step
# Epoch 4/1000
# 26/26 - 1s - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.0177 - val_mean_squared_error: 0.0177 - 575ms/epoch - 22ms/step
# Epoch 5/1000
# 26/26 - 1s - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - 637ms/epoch - 24ms/step
# Epoch 6/1000
# 26/26 - 1s - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 601ms/epoch - 23ms/step
# Epoch 7/1000
# 26/26 - 1s - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0070 - val_mean_squared_error: 0.0070 - 624ms/epoch - 24ms/step
# Epoch 8/1000
# 26/26 - 1s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 606ms/epoch - 23ms/step
# Epoch 9/1000
# 26/26 - 1s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0041 - val_mean_squared_error: 0.0041 - 623ms/epoch - 24ms/step
# Epoch 10/1000
# 26/26 - 1s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - 575ms/epoch - 22ms/step
# Epoch 11/1000
# 26/26 - 1s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0024 - val_mean_squared_error: 0.0024 - 611ms/epoch - 23ms/step
# Epoch 12/1000
# 26/26 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - 617ms/epoch - 24ms/step
# Epoch 13/1000
# 26/26 - 1s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - 622ms/epoch - 24ms/step
# Epoch 14/1000
# 26/26 - 1s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0012 - val_mean_squared_error: 0.0012 - 606ms/epoch - 23ms/step
# Epoch 15/1000
# 26/26 - 1s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 9.6901e-04 - val_mean_squared_error: 9.6901e-04 - 664ms/epoch - 26ms/step
# Epoch 16/1000
# 26/26 - 1s - loss: 8.8171e-04 - mean_squared_error: 8.8171e-04 - val_loss: 8.0393e-04 - val_mean_squared_error: 8.0393e-04 - 592ms/epoch - 23ms/step
# Epoch 17/1000
# 26/26 - 1s - loss: 7.3354e-04 - mean_squared_error: 7.3354e-04 - val_loss: 6.7092e-04 - val_mean_squared_error: 6.7092e-04 - 601ms/epoch - 23ms/step
# Epoch 18/1000
# 26/26 - 1s - loss: 6.1393e-04 - mean_squared_error: 6.1393e-04 - val_loss: 5.6304e-04 - val_mean_squared_error: 5.6304e-04 - 587ms/epoch - 23ms/step
# Epoch 19/1000
# 26/26 - 1s - loss: 5.1693e-04 - mean_squared_error: 5.1693e-04 - val_loss: 4.7858e-04 - val_mean_squared_error: 4.7858e-04 - 600ms/epoch - 23ms/step
# Epoch 20/1000
# 26/26 - 1s - loss: 4.4023e-04 - mean_squared_error: 4.4023e-04 - val_loss: 4.1085e-04 - val_mean_squared_error: 4.1085e-04 - 595ms/epoch - 23ms/step
# Epoch 21/1000
# 26/26 - 1s - loss: 3.8078e-04 - mean_squared_error: 3.8078e-04 - val_loss: 3.5916e-04 - val_mean_squared_error: 3.5916e-04 - 589ms/epoch - 23ms/step
# Epoch 22/1000
# 26/26 - 1s - loss: 3.3545e-04 - mean_squared_error: 3.3545e-04 - val_loss: 3.2004e-04 - val_mean_squared_error: 3.2004e-04 - 604ms/epoch - 23ms/step
# Epoch 23/1000
# 26/26 - 1s - loss: 3.0098e-04 - mean_squared_error: 3.0098e-04 - val_loss: 2.8947e-04 - val_mean_squared_error: 2.8947e-04 - 597ms/epoch - 23ms/step
# Epoch 24/1000
# 26/26 - 1s - loss: 2.7378e-04 - mean_squared_error: 2.7378e-04 - val_loss: 2.6569e-04 - val_mean_squared_error: 2.6569e-04 - 593ms/epoch - 23ms/step
# Epoch 25/1000
# 26/26 - 1s - loss: 2.5256e-04 - mean_squared_error: 2.5256e-04 - val_loss: 2.4649e-04 - val_mean_squared_error: 2.4649e-04 - 634ms/epoch - 24ms/step
# Epoch 26/1000
# 26/26 - 1s - loss: 2.3545e-04 - mean_squared_error: 2.3545e-04 - val_loss: 2.2960e-04 - val_mean_squared_error: 2.2960e-04 - 614ms/epoch - 24ms/step
# Epoch 27/1000
# 26/26 - 1s - loss: 2.1989e-04 - mean_squared_error: 2.1989e-04 - val_loss: 2.1534e-04 - val_mean_squared_error: 2.1534e-04 - 608ms/epoch - 23ms/step
# Epoch 28/1000
# 26/26 - 1s - loss: 2.0658e-04 - mean_squared_error: 2.0658e-04 - val_loss: 2.0317e-04 - val_mean_squared_error: 2.0317e-04 - 614ms/epoch - 24ms/step
# Epoch 29/1000
# 26/26 - 1s - loss: 1.9504e-04 - mean_squared_error: 1.9504e-04 - val_loss: 1.9204e-04 - val_mean_squared_error: 1.9204e-04 - 657ms/epoch - 25ms/step
# Epoch 30/1000
# 26/26 - 1s - loss: 1.8388e-04 - mean_squared_error: 1.8388e-04 - val_loss: 1.8035e-04 - val_mean_squared_error: 1.8035e-04 - 639ms/epoch - 25ms/step
# Epoch 31/1000
# 26/26 - 1s - loss: 1.7378e-04 - mean_squared_error: 1.7378e-04 - val_loss: 1.7027e-04 - val_mean_squared_error: 1.7027e-04 - 630ms/epoch - 24ms/step
# Epoch 32/1000
# 26/26 - 1s - loss: 1.6415e-04 - mean_squared_error: 1.6415e-04 - val_loss: 1.6124e-04 - val_mean_squared_error: 1.6124e-04 - 644ms/epoch - 25ms/step
# Epoch 33/1000
# 26/26 - 1s - loss: 1.5537e-04 - mean_squared_error: 1.5537e-04 - val_loss: 1.5308e-04 - val_mean_squared_error: 1.5308e-04 - 611ms/epoch - 23ms/step
# Epoch 34/1000
# 26/26 - 1s - loss: 1.4694e-04 - mean_squared_error: 1.4694e-04 - val_loss: 1.4411e-04 - val_mean_squared_error: 1.4411e-04 - 637ms/epoch - 24ms/step
# Epoch 35/1000
# 26/26 - 1s - loss: 1.4019e-04 - mean_squared_error: 1.4019e-04 - val_loss: 1.3737e-04 - val_mean_squared_error: 1.3737e-04 - 596ms/epoch - 23ms/step
# Epoch 36/1000
# 26/26 - 1s - loss: 1.3266e-04 - mean_squared_error: 1.3266e-04 - val_loss: 1.3021e-04 - val_mean_squared_error: 1.3021e-04 - 620ms/epoch - 24ms/step
# Epoch 37/1000
# 26/26 - 1s - loss: 1.2561e-04 - mean_squared_error: 1.2561e-04 - val_loss: 1.2265e-04 - val_mean_squared_error: 1.2265e-04 - 604ms/epoch - 23ms/step
# Epoch 38/1000
# 26/26 - 1s - loss: 1.1891e-04 - mean_squared_error: 1.1891e-04 - val_loss: 1.1662e-04 - val_mean_squared_error: 1.1662e-04 - 603ms/epoch - 23ms/step
# Epoch 39/1000
# 26/26 - 1s - loss: 1.1345e-04 - mean_squared_error: 1.1345e-04 - val_loss: 1.1055e-04 - val_mean_squared_error: 1.1055e-04 - 622ms/epoch - 24ms/step
# Epoch 40/1000
# 26/26 - 1s - loss: 1.0735e-04 - mean_squared_error: 1.0735e-04 - val_loss: 1.0515e-04 - val_mean_squared_error: 1.0515e-04 - 618ms/epoch - 24ms/step
# Epoch 41/1000
# 26/26 - 1s - loss: 1.0230e-04 - mean_squared_error: 1.0230e-04 - val_loss: 9.9942e-05 - val_mean_squared_error: 9.9942e-05 - 627ms/epoch - 24ms/step
# Epoch 42/1000
# 26/26 - 1s - loss: 9.7341e-05 - mean_squared_error: 9.7341e-05 - val_loss: 9.6208e-05 - val_mean_squared_error: 9.6208e-05 - 660ms/epoch - 25ms/step
# Epoch 43/1000
# 26/26 - 1s - loss: 9.2785e-05 - mean_squared_error: 9.2785e-05 - val_loss: 9.0607e-05 - val_mean_squared_error: 9.0607e-05 - 591ms/epoch - 23ms/step
# Epoch 44/1000
# 26/26 - 1s - loss: 8.8305e-05 - mean_squared_error: 8.8305e-05 - val_loss: 8.7003e-05 - val_mean_squared_error: 8.7003e-05 - 619ms/epoch - 24ms/step
# Epoch 45/1000
# 26/26 - 1s - loss: 8.4390e-05 - mean_squared_error: 8.4390e-05 - val_loss: 8.2952e-05 - val_mean_squared_error: 8.2952e-05 - 615ms/epoch - 24ms/step
# Epoch 46/1000
# 26/26 - 1s - loss: 8.1125e-05 - mean_squared_error: 8.1125e-05 - val_loss: 7.8444e-05 - val_mean_squared_error: 7.8444e-05 - 633ms/epoch - 24ms/step
# Epoch 47/1000
# 26/26 - 1s - loss: 7.7237e-05 - mean_squared_error: 7.7237e-05 - val_loss: 7.5546e-05 - val_mean_squared_error: 7.5546e-05 - 604ms/epoch - 23ms/step
# Epoch 48/1000
# 26/26 - 1s - loss: 7.3917e-05 - mean_squared_error: 7.3917e-05 - val_loss: 7.2715e-05 - val_mean_squared_error: 7.2715e-05 - 615ms/epoch - 24ms/step
# Epoch 49/1000
# 26/26 - 1s - loss: 7.0545e-05 - mean_squared_error: 7.0545e-05 - val_loss: 6.9426e-05 - val_mean_squared_error: 6.9426e-05 - 601ms/epoch - 23ms/step
# Epoch 50/1000
# 26/26 - 1s - loss: 6.7757e-05 - mean_squared_error: 6.7757e-05 - val_loss: 6.6637e-05 - val_mean_squared_error: 6.6637e-05 - 606ms/epoch - 23ms/step
# Epoch 51/1000
# 26/26 - 1s - loss: 6.5167e-05 - mean_squared_error: 6.5167e-05 - val_loss: 6.4592e-05 - val_mean_squared_error: 6.4592e-05 - 626ms/epoch - 24ms/step
# Epoch 52/1000
# 26/26 - 1s - loss: 6.2814e-05 - mean_squared_error: 6.2814e-05 - val_loss: 6.1316e-05 - val_mean_squared_error: 6.1316e-05 - 617ms/epoch - 24ms/step
# Epoch 53/1000
# 26/26 - 1s - loss: 5.9846e-05 - mean_squared_error: 5.9846e-05 - val_loss: 5.8832e-05 - val_mean_squared_error: 5.8832e-05 - 599ms/epoch - 23ms/step
# Epoch 54/1000
# 26/26 - 1s - loss: 5.7522e-05 - mean_squared_error: 5.7522e-05 - val_loss: 5.5894e-05 - val_mean_squared_error: 5.5894e-05 - 585ms/epoch - 23ms/step
# Epoch 55/1000
# 26/26 - 1s - loss: 5.5325e-05 - mean_squared_error: 5.5325e-05 - val_loss: 5.3774e-05 - val_mean_squared_error: 5.3774e-05 - 593ms/epoch - 23ms/step
# Epoch 56/1000
# 26/26 - 1s - loss: 5.3259e-05 - mean_squared_error: 5.3259e-05 - val_loss: 5.1841e-05 - val_mean_squared_error: 5.1841e-05 - 578ms/epoch - 22ms/step
# Epoch 57/1000
# 26/26 - 1s - loss: 5.1332e-05 - mean_squared_error: 5.1332e-05 - val_loss: 4.9871e-05 - val_mean_squared_error: 4.9871e-05 - 632ms/epoch - 24ms/step
# Epoch 58/1000
# 26/26 - 1s - loss: 4.9268e-05 - mean_squared_error: 4.9268e-05 - val_loss: 4.8050e-05 - val_mean_squared_error: 4.8050e-05 - 613ms/epoch - 24ms/step
# Epoch 59/1000
# 26/26 - 1s - loss: 4.7453e-05 - mean_squared_error: 4.7453e-05 - val_loss: 4.7638e-05 - val_mean_squared_error: 4.7638e-05 - 612ms/epoch - 24ms/step
# Epoch 60/1000
# 26/26 - 1s - loss: 4.6215e-05 - mean_squared_error: 4.6215e-05 - val_loss: 4.5692e-05 - val_mean_squared_error: 4.5692e-05 - 611ms/epoch - 23ms/step
# Epoch 61/1000
# 26/26 - 1s - loss: 4.4340e-05 - mean_squared_error: 4.4340e-05 - val_loss: 4.3309e-05 - val_mean_squared_error: 4.3309e-05 - 607ms/epoch - 23ms/step
# Epoch 62/1000
# 26/26 - 1s - loss: 4.2861e-05 - mean_squared_error: 4.2861e-05 - val_loss: 4.1881e-05 - val_mean_squared_error: 4.1881e-05 - 614ms/epoch - 24ms/step
# Epoch 63/1000
# 26/26 - 1s - loss: 4.1310e-05 - mean_squared_error: 4.1310e-05 - val_loss: 4.0332e-05 - val_mean_squared_error: 4.0332e-05 - 625ms/epoch - 24ms/step
# Epoch 64/1000
# 26/26 - 1s - loss: 3.9954e-05 - mean_squared_error: 3.9954e-05 - val_loss: 3.8650e-05 - val_mean_squared_error: 3.8650e-05 - 595ms/epoch - 23ms/step
# Epoch 65/1000
# 26/26 - 1s - loss: 3.9377e-05 - mean_squared_error: 3.9377e-05 - val_loss: 3.8354e-05 - val_mean_squared_error: 3.8354e-05 - 596ms/epoch - 23ms/step
# Epoch 66/1000
# 26/26 - 1s - loss: 3.8163e-05 - mean_squared_error: 3.8163e-05 - val_loss: 3.6270e-05 - val_mean_squared_error: 3.6270e-05 - 648ms/epoch - 25ms/step
# Epoch 67/1000
# 26/26 - 1s - loss: 3.6657e-05 - mean_squared_error: 3.6657e-05 - val_loss: 3.5554e-05 - val_mean_squared_error: 3.5554e-05 - 603ms/epoch - 23ms/step
# Epoch 68/1000
# 26/26 - 1s - loss: 3.4998e-05 - mean_squared_error: 3.4998e-05 - val_loss: 3.5947e-05 - val_mean_squared_error: 3.5947e-05 - 612ms/epoch - 24ms/step
# Epoch 69/1000
# 26/26 - 1s - loss: 3.4611e-05 - mean_squared_error: 3.4611e-05 - val_loss: 3.2734e-05 - val_mean_squared_error: 3.2734e-05 - 627ms/epoch - 24ms/step
# Epoch 70/1000
# 26/26 - 1s - loss: 3.3035e-05 - mean_squared_error: 3.3035e-05 - val_loss: 3.3875e-05 - val_mean_squared_error: 3.3875e-05 - 595ms/epoch - 23ms/step
# Epoch 71/1000
# 26/26 - 1s - loss: 3.3615e-05 - mean_squared_error: 3.3615e-05 - val_loss: 3.0583e-05 - val_mean_squared_error: 3.0583e-05 - 607ms/epoch - 23ms/step
# Epoch 72/1000
# 26/26 - 1s - loss: 3.1297e-05 - mean_squared_error: 3.1297e-05 - val_loss: 2.9761e-05 - val_mean_squared_error: 2.9761e-05 - 694ms/epoch - 27ms/step
# Epoch 73/1000
# 26/26 - 1s - loss: 3.0280e-05 - mean_squared_error: 3.0280e-05 - val_loss: 2.8956e-05 - val_mean_squared_error: 2.8956e-05 - 694ms/epoch - 27ms/step
# Epoch 74/1000
# 26/26 - 1s - loss: 3.1444e-05 - mean_squared_error: 3.1444e-05 - val_loss: 2.9620e-05 - val_mean_squared_error: 2.9620e-05 - 708ms/epoch - 27ms/step
# Epoch 75/1000
# 26/26 - 1s - loss: 2.9511e-05 - mean_squared_error: 2.9511e-05 - val_loss: 2.9024e-05 - val_mean_squared_error: 2.9024e-05 - 694ms/epoch - 27ms/step
# Epoch 76/1000
# 26/26 - 1s - loss: 3.1995e-05 - mean_squared_error: 3.1995e-05 - val_loss: 2.6959e-05 - val_mean_squared_error: 2.6959e-05 - 693ms/epoch - 27ms/step
# Epoch 77/1000
# 26/26 - 1s - loss: 2.7176e-05 - mean_squared_error: 2.7176e-05 - val_loss: 2.6400e-05 - val_mean_squared_error: 2.6400e-05 - 696ms/epoch - 27ms/step
# Epoch 78/1000
# 26/26 - 1s - loss: 2.6557e-05 - mean_squared_error: 2.6557e-05 - val_loss: 2.8602e-05 - val_mean_squared_error: 2.8602e-05 - 694ms/epoch - 27ms/step
# Epoch 79/1000
# 26/26 - 1s - loss: 2.7594e-05 - mean_squared_error: 2.7594e-05 - val_loss: 2.5540e-05 - val_mean_squared_error: 2.5540e-05 - 694ms/epoch - 27ms/step
# Epoch 80/1000
# 26/26 - 1s - loss: 2.6994e-05 - mean_squared_error: 2.6994e-05 - val_loss: 2.6638e-05 - val_mean_squared_error: 2.6638e-05 - 712ms/epoch - 27ms/step
# Epoch 81/1000
# 26/26 - 1s - loss: 2.4453e-05 - mean_squared_error: 2.4453e-05 - val_loss: 2.3601e-05 - val_mean_squared_error: 2.3601e-05 - 662ms/epoch - 25ms/step
# Epoch 82/1000
# 26/26 - 1s - loss: 2.2673e-05 - mean_squared_error: 2.2673e-05 - val_loss: 2.1831e-05 - val_mean_squared_error: 2.1831e-05 - 694ms/epoch - 27ms/step
# Epoch 83/1000
# 26/26 - 1s - loss: 2.2682e-05 - mean_squared_error: 2.2682e-05 - val_loss: 2.4225e-05 - val_mean_squared_error: 2.4225e-05 - 712ms/epoch - 27ms/step
# Epoch 84/1000
# 26/26 - 1s - loss: 2.1730e-05 - mean_squared_error: 2.1730e-05 - val_loss: 2.2416e-05 - val_mean_squared_error: 2.2416e-05 - 726ms/epoch - 28ms/step
# Epoch 85/1000
# 26/26 - 1s - loss: 2.1289e-05 - mean_squared_error: 2.1289e-05 - val_loss: 2.1109e-05 - val_mean_squared_error: 2.1109e-05 - 684ms/epoch - 26ms/step
# Epoch 86/1000
# 26/26 - 1s - loss: 2.1999e-05 - mean_squared_error: 2.1999e-05 - val_loss: 2.2097e-05 - val_mean_squared_error: 2.2097e-05 - 697ms/epoch - 27ms/step
# Epoch 87/1000
# 26/26 - 1s - loss: 2.0988e-05 - mean_squared_error: 2.0988e-05 - val_loss: 2.0564e-05 - val_mean_squared_error: 2.0564e-05 - 694ms/epoch - 27ms/step
# Epoch 88/1000
# 26/26 - 1s - loss: 1.9010e-05 - mean_squared_error: 1.9010e-05 - val_loss: 1.8328e-05 - val_mean_squared_error: 1.8328e-05 - 730ms/epoch - 28ms/step
# Epoch 89/1000
# 26/26 - 1s - loss: 2.2073e-05 - mean_squared_error: 2.2073e-05 - val_loss: 2.0446e-05 - val_mean_squared_error: 2.0446e-05 - 691ms/epoch - 27ms/step
# Epoch 90/1000
# 26/26 - 1s - loss: 1.8904e-05 - mean_squared_error: 1.8904e-05 - val_loss: 1.8164e-05 - val_mean_squared_error: 1.8164e-05 - 693ms/epoch - 27ms/step
# Epoch 91/1000
# 26/26 - 1s - loss: 2.0253e-05 - mean_squared_error: 2.0253e-05 - val_loss: 2.1056e-05 - val_mean_squared_error: 2.1056e-05 - 679ms/epoch - 26ms/step
# Epoch 92/1000
# 26/26 - 1s - loss: 1.7993e-05 - mean_squared_error: 1.7993e-05 - val_loss: 1.9303e-05 - val_mean_squared_error: 1.9303e-05 - 695ms/epoch - 27ms/step
# Epoch 93/1000
# 26/26 - 1s - loss: 1.9435e-05 - mean_squared_error: 1.9435e-05 - val_loss: 1.9312e-05 - val_mean_squared_error: 1.9312e-05 - 694ms/epoch - 27ms/step
# Epoch 94/1000
# 26/26 - 1s - loss: 1.7676e-05 - mean_squared_error: 1.7676e-05 - val_loss: 1.5742e-05 - val_mean_squared_error: 1.5742e-05 - 694ms/epoch - 27ms/step
# Epoch 95/1000
# 26/26 - 1s - loss: 1.6454e-05 - mean_squared_error: 1.6454e-05 - val_loss: 1.4982e-05 - val_mean_squared_error: 1.4982e-05 - 663ms/epoch - 25ms/step
# Epoch 96/1000
# 26/26 - 1s - loss: 1.5750e-05 - mean_squared_error: 1.5750e-05 - val_loss: 1.6238e-05 - val_mean_squared_error: 1.6238e-05 - 710ms/epoch - 27ms/step
# Epoch 97/1000
# 26/26 - 1s - loss: 1.6969e-05 - mean_squared_error: 1.6969e-05 - val_loss: 1.6503e-05 - val_mean_squared_error: 1.6503e-05 - 699ms/epoch - 27ms/step
# Epoch 98/1000
# 26/26 - 1s - loss: 1.6338e-05 - mean_squared_error: 1.6338e-05 - val_loss: 1.4059e-05 - val_mean_squared_error: 1.4059e-05 - 674ms/epoch - 26ms/step
# Epoch 99/1000
# 26/26 - 1s - loss: 1.8304e-05 - mean_squared_error: 1.8304e-05 - val_loss: 1.4824e-05 - val_mean_squared_error: 1.4824e-05 - 681ms/epoch - 26ms/step
# Epoch 100/1000
# 26/26 - 1s - loss: 1.5811e-05 - mean_squared_error: 1.5811e-05 - val_loss: 1.5531e-05 - val_mean_squared_error: 1.5531e-05 - 680ms/epoch - 26ms/step
# Epoch 101/1000
# 26/26 - 1s - loss: 1.4416e-05 - mean_squared_error: 1.4416e-05 - val_loss: 1.3054e-05 - val_mean_squared_error: 1.3054e-05 - 693ms/epoch - 27ms/step
# Epoch 102/1000
# 26/26 - 1s - loss: 1.2921e-05 - mean_squared_error: 1.2921e-05 - val_loss: 1.2897e-05 - val_mean_squared_error: 1.2897e-05 - 694ms/epoch - 27ms/step
# Epoch 103/1000
# 26/26 - 1s - loss: 1.3336e-05 - mean_squared_error: 1.3336e-05 - val_loss: 1.8404e-05 - val_mean_squared_error: 1.8404e-05 - 696ms/epoch - 27ms/step
# Epoch 104/1000
# 26/26 - 1s - loss: 2.0339e-05 - mean_squared_error: 2.0339e-05 - val_loss: 1.2289e-05 - val_mean_squared_error: 1.2289e-05 - 693ms/epoch - 27ms/step
# Epoch 105/1000
# 26/26 - 1s - loss: 1.3757e-05 - mean_squared_error: 1.3757e-05 - val_loss: 1.2873e-05 - val_mean_squared_error: 1.2873e-05 - 663ms/epoch - 26ms/step
# Epoch 106/1000
# 26/26 - 1s - loss: 1.5293e-05 - mean_squared_error: 1.5293e-05 - val_loss: 1.3342e-05 - val_mean_squared_error: 1.3342e-05 - 699ms/epoch - 27ms/step
# Epoch 107/1000
# 26/26 - 1s - loss: 1.3682e-05 - mean_squared_error: 1.3682e-05 - val_loss: 1.7577e-05 - val_mean_squared_error: 1.7577e-05 - 680ms/epoch - 26ms/step
# Epoch 108/1000
# 26/26 - 1s - loss: 1.4229e-05 - mean_squared_error: 1.4229e-05 - val_loss: 1.2973e-05 - val_mean_squared_error: 1.2973e-05 - 694ms/epoch - 27ms/step
# Epoch 109/1000
# 26/26 - 1s - loss: 1.2026e-05 - mean_squared_error: 1.2026e-05 - val_loss: 1.1346e-05 - val_mean_squared_error: 1.1346e-05 - 697ms/epoch - 27ms/step
# Epoch 110/1000
# 26/26 - 1s - loss: 1.2872e-05 - mean_squared_error: 1.2872e-05 - val_loss: 1.1842e-05 - val_mean_squared_error: 1.1842e-05 - 689ms/epoch - 27ms/step
# Epoch 111/1000
# 26/26 - 1s - loss: 1.2085e-05 - mean_squared_error: 1.2085e-05 - val_loss: 1.3143e-05 - val_mean_squared_error: 1.3143e-05 - 678ms/epoch - 26ms/step
# Epoch 112/1000
# 26/26 - 1s - loss: 1.0678e-05 - mean_squared_error: 1.0678e-05 - val_loss: 9.6710e-06 - val_mean_squared_error: 9.6710e-06 - 683ms/epoch - 26ms/step
# Epoch 113/1000
# 26/26 - 1s - loss: 1.5173e-05 - mean_squared_error: 1.5173e-05 - val_loss: 1.0298e-05 - val_mean_squared_error: 1.0298e-05 - 705ms/epoch - 27ms/step
# Epoch 114/1000
# 26/26 - 1s - loss: 1.3122e-05 - mean_squared_error: 1.3122e-05 - val_loss: 9.0564e-06 - val_mean_squared_error: 9.0564e-06 - 694ms/epoch - 27ms/step
# Epoch 115/1000
# 26/26 - 1s - loss: 1.2440e-05 - mean_squared_error: 1.2440e-05 - val_loss: 9.6383e-06 - val_mean_squared_error: 9.6383e-06 - 682ms/epoch - 26ms/step
# Epoch 116/1000
# 26/26 - 1s - loss: 1.4440e-05 - mean_squared_error: 1.4440e-05 - val_loss: 9.6121e-06 - val_mean_squared_error: 9.6121e-06 - 709ms/epoch - 27ms/step
# Epoch 117/1000
# 26/26 - 1s - loss: 9.8672e-06 - mean_squared_error: 9.8672e-06 - val_loss: 9.1825e-06 - val_mean_squared_error: 9.1825e-06 - 676ms/epoch - 26ms/step
# Epoch 118/1000
# 26/26 - 1s - loss: 9.9568e-06 - mean_squared_error: 9.9568e-06 - val_loss: 9.0954e-06 - val_mean_squared_error: 9.0954e-06 - 679ms/epoch - 26ms/step
# Epoch 119/1000
# 26/26 - 1s - loss: 1.1710e-05 - mean_squared_error: 1.1710e-05 - val_loss: 1.3414e-05 - val_mean_squared_error: 1.3414e-05 - 696ms/epoch - 27ms/step
# Epoch 120/1000
# 26/26 - 1s - loss: 1.0531e-05 - mean_squared_error: 1.0531e-05 - val_loss: 1.4070e-05 - val_mean_squared_error: 1.4070e-05 - 710ms/epoch - 27ms/step
# Epoch 121/1000
# 26/26 - 1s - loss: 1.6220e-05 - mean_squared_error: 1.6220e-05 - val_loss: 1.4952e-05 - val_mean_squared_error: 1.4952e-05 - 703ms/epoch - 27ms/step
# Epoch 122/1000
# 26/26 - 1s - loss: 1.1830e-05 - mean_squared_error: 1.1830e-05 - val_loss: 1.1493e-05 - val_mean_squared_error: 1.1493e-05 - 683ms/epoch - 26ms/step
# Epoch 123/1000
# 26/26 - 1s - loss: 1.0126e-05 - mean_squared_error: 1.0126e-05 - val_loss: 8.3482e-06 - val_mean_squared_error: 8.3482e-06 - 710ms/epoch - 27ms/step
# Epoch 124/1000
# 26/26 - 1s - loss: 1.1092e-05 - mean_squared_error: 1.1092e-05 - val_loss: 8.5374e-06 - val_mean_squared_error: 8.5374e-06 - 693ms/epoch - 27ms/step
# Epoch 125/1000
# 26/26 - 1s - loss: 8.4823e-06 - mean_squared_error: 8.4823e-06 - val_loss: 7.3623e-06 - val_mean_squared_error: 7.3623e-06 - 694ms/epoch - 27ms/step
# Epoch 126/1000
# 26/26 - 1s - loss: 7.8325e-06 - mean_squared_error: 7.8325e-06 - val_loss: 1.1880e-05 - val_mean_squared_error: 1.1880e-05 - 678ms/epoch - 26ms/step
# Epoch 127/1000
# 26/26 - 1s - loss: 1.0825e-05 - mean_squared_error: 1.0825e-05 - val_loss: 1.4596e-05 - val_mean_squared_error: 1.4596e-05 - 728ms/epoch - 28ms/step
# Epoch 128/1000
# 26/26 - 1s - loss: 1.0064e-05 - mean_squared_error: 1.0064e-05 - val_loss: 1.3223e-05 - val_mean_squared_error: 1.3223e-05 - 708ms/epoch - 27ms/step
# Epoch 129/1000
# 26/26 - 1s - loss: 9.2487e-06 - mean_squared_error: 9.2487e-06 - val_loss: 1.3039e-05 - val_mean_squared_error: 1.3039e-05 - 698ms/epoch - 27ms/step
# Epoch 130/1000
# 26/26 - 1s - loss: 9.5510e-06 - mean_squared_error: 9.5510e-06 - val_loss: 8.5211e-06 - val_mean_squared_error: 8.5211e-06 - 706ms/epoch - 27ms/step
# Epoch 131/1000
# 26/26 - 1s - loss: 9.4908e-06 - mean_squared_error: 9.4908e-06 - val_loss: 7.4081e-06 - val_mean_squared_error: 7.4081e-06 - 677ms/epoch - 26ms/step
# Epoch 132/1000
# 26/26 - 1s - loss: 9.4641e-06 - mean_squared_error: 9.4641e-06 - val_loss: 7.3428e-06 - val_mean_squared_error: 7.3428e-06 - 724ms/epoch - 28ms/step
# Epoch 133/1000
# 26/26 - 1s - loss: 2.0705e-05 - mean_squared_error: 2.0705e-05 - val_loss: 1.1529e-05 - val_mean_squared_error: 1.1529e-05 - 696ms/epoch - 27ms/step
# Epoch 134/1000
# 26/26 - 1s - loss: 1.0688e-05 - mean_squared_error: 1.0688e-05 - val_loss: 7.1969e-06 - val_mean_squared_error: 7.1969e-06 - 695ms/epoch - 27ms/step
# Epoch 135/1000
# 26/26 - 1s - loss: 6.6871e-06 - mean_squared_error: 6.6871e-06 - val_loss: 6.1836e-06 - val_mean_squared_error: 6.1836e-06 - 710ms/epoch - 27ms/step
# Epoch 136/1000
# 26/26 - 1s - loss: 6.3536e-06 - mean_squared_error: 6.3536e-06 - val_loss: 5.9322e-06 - val_mean_squared_error: 5.9322e-06 - 711ms/epoch - 27ms/step
# Epoch 137/1000
# 26/26 - 1s - loss: 7.1387e-06 - mean_squared_error: 7.1387e-06 - val_loss: 1.1665e-05 - val_mean_squared_error: 1.1665e-05 - 663ms/epoch - 26ms/step
# Epoch 138/1000
# 26/26 - 1s - loss: 1.1670e-05 - mean_squared_error: 1.1670e-05 - val_loss: 8.3883e-06 - val_mean_squared_error: 8.3883e-06 - 706ms/epoch - 27ms/step
# Epoch 139/1000
# 26/26 - 1s - loss: 9.9942e-06 - mean_squared_error: 9.9942e-06 - val_loss: 7.8177e-06 - val_mean_squared_error: 7.8177e-06 - 679ms/epoch - 26ms/step
# Epoch 140/1000
# 26/26 - 1s - loss: 7.0829e-06 - mean_squared_error: 7.0829e-06 - val_loss: 7.1883e-06 - val_mean_squared_error: 7.1883e-06 - 677ms/epoch - 26ms/step
# Epoch 141/1000
# 26/26 - 1s - loss: 1.1530e-05 - mean_squared_error: 1.1530e-05 - val_loss: 1.0229e-05 - val_mean_squared_error: 1.0229e-05 - 711ms/epoch - 27ms/step
# Epoch 142/1000
# 26/26 - 1s - loss: 1.1498e-05 - mean_squared_error: 1.1498e-05 - val_loss: 1.5559e-05 - val_mean_squared_error: 1.5559e-05 - 710ms/epoch - 27ms/step
# Epoch 143/1000
# 26/26 - 1s - loss: 8.1552e-06 - mean_squared_error: 8.1552e-06 - val_loss: 6.1593e-06 - val_mean_squared_error: 6.1593e-06 - 696ms/epoch - 27ms/step
# Epoch 144/1000
# 26/26 - 1s - loss: 6.0055e-06 - mean_squared_error: 6.0055e-06 - val_loss: 6.5690e-06 - val_mean_squared_error: 6.5690e-06 - 709ms/epoch - 27ms/step
# Epoch 145/1000
# 26/26 - 1s - loss: 8.9220e-06 - mean_squared_error: 8.9220e-06 - val_loss: 1.3214e-05 - val_mean_squared_error: 1.3214e-05 - 725ms/epoch - 28ms/step
# Epoch 146/1000
# 26/26 - 1s - loss: 8.0188e-06 - mean_squared_error: 8.0188e-06 - val_loss: 7.9084e-06 - val_mean_squared_error: 7.9084e-06 - 695ms/epoch - 27ms/step
# Epoch 147/1000
# 26/26 - 1s - loss: 1.2155e-05 - mean_squared_error: 1.2155e-05 - val_loss: 1.5069e-05 - val_mean_squared_error: 1.5069e-05 - 725ms/epoch - 28ms/step
# Epoch 148/1000
# 26/26 - 1s - loss: 9.5834e-06 - mean_squared_error: 9.5834e-06 - val_loss: 6.5940e-06 - val_mean_squared_error: 6.5940e-06 - 693ms/epoch - 27ms/step
# Epoch 149/1000
# 26/26 - 1s - loss: 5.9553e-06 - mean_squared_error: 5.9553e-06 - val_loss: 8.7598e-06 - val_mean_squared_error: 8.7598e-06 - 696ms/epoch - 27ms/step
# Epoch 150/1000
# 26/26 - 1s - loss: 8.2271e-06 - mean_squared_error: 8.2271e-06 - val_loss: 7.0830e-06 - val_mean_squared_error: 7.0830e-06 - 710ms/epoch - 27ms/step
# Epoch 151/1000
# 26/26 - 1s - loss: 6.5489e-06 - mean_squared_error: 6.5489e-06 - val_loss: 5.1954e-06 - val_mean_squared_error: 5.1954e-06 - 704ms/epoch - 27ms/step
# Epoch 152/1000
# 26/26 - 1s - loss: 1.1766e-05 - mean_squared_error: 1.1766e-05 - val_loss: 8.6426e-06 - val_mean_squared_error: 8.6426e-06 - 683ms/epoch - 26ms/step
# Epoch 153/1000
# 26/26 - 1s - loss: 1.0665e-05 - mean_squared_error: 1.0665e-05 - val_loss: 5.1539e-06 - val_mean_squared_error: 5.1539e-06 - 708ms/epoch - 27ms/step
# Epoch 154/1000
# 26/26 - 1s - loss: 5.8400e-06 - mean_squared_error: 5.8400e-06 - val_loss: 1.1187e-05 - val_mean_squared_error: 1.1187e-05 - 696ms/epoch - 27ms/step
# Epoch 155/1000
# 26/26 - 1s - loss: 7.6139e-06 - mean_squared_error: 7.6139e-06 - val_loss: 8.0274e-06 - val_mean_squared_error: 8.0274e-06 - 677ms/epoch - 26ms/step
# Epoch 156/1000
# 26/26 - 1s - loss: 7.3871e-06 - mean_squared_error: 7.3871e-06 - val_loss: 7.6715e-06 - val_mean_squared_error: 7.6715e-06 - 713ms/epoch - 27ms/step
# Epoch 157/1000
# 26/26 - 1s - loss: 9.1463e-06 - mean_squared_error: 9.1463e-06 - val_loss: 4.8309e-06 - val_mean_squared_error: 4.8309e-06 - 679ms/epoch - 26ms/step
# Epoch 158/1000
# 26/26 - 1s - loss: 1.0305e-05 - mean_squared_error: 1.0305e-05 - val_loss: 9.7097e-06 - val_mean_squared_error: 9.7097e-06 - 711ms/epoch - 27ms/step
# Epoch 159/1000
# 26/26 - 1s - loss: 7.0999e-06 - mean_squared_error: 7.0999e-06 - val_loss: 1.0304e-05 - val_mean_squared_error: 1.0304e-05 - 718ms/epoch - 28ms/step
# Epoch 160/1000
# 26/26 - 1s - loss: 1.0623e-05 - mean_squared_error: 1.0623e-05 - val_loss: 7.1908e-06 - val_mean_squared_error: 7.1908e-06 - 699ms/epoch - 27ms/step
# Epoch 161/1000
# 26/26 - 1s - loss: 1.0547e-05 - mean_squared_error: 1.0547e-05 - val_loss: 6.7610e-06 - val_mean_squared_error: 6.7610e-06 - 694ms/epoch - 27ms/step
# Epoch 162/1000
# 26/26 - 1s - loss: 5.2601e-06 - mean_squared_error: 5.2601e-06 - val_loss: 5.1923e-06 - val_mean_squared_error: 5.1923e-06 - 727ms/epoch - 28ms/step
# Epoch 163/1000
# 26/26 - 1s - loss: 6.1088e-06 - mean_squared_error: 6.1088e-06 - val_loss: 7.4557e-06 - val_mean_squared_error: 7.4557e-06 - 694ms/epoch - 27ms/step
# Epoch 164/1000
# 26/26 - 1s - loss: 8.5828e-06 - mean_squared_error: 8.5828e-06 - val_loss: 7.1456e-06 - val_mean_squared_error: 7.1456e-06 - 697ms/epoch - 27ms/step
# Epoch 165/1000
# 26/26 - 1s - loss: 5.6614e-06 - mean_squared_error: 5.6614e-06 - val_loss: 8.8491e-06 - val_mean_squared_error: 8.8491e-06 - 707ms/epoch - 27ms/step
# Epoch 166/1000
# 26/26 - 1s - loss: 2.7648e-05 - mean_squared_error: 2.7648e-05 - val_loss: 8.5477e-06 - val_mean_squared_error: 8.5477e-06 - 709ms/epoch - 27ms/step
# Epoch 167/1000
# 26/26 - 1s - loss: 1.0358e-05 - mean_squared_error: 1.0358e-05 - val_loss: 4.7446e-06 - val_mean_squared_error: 4.7446e-06 - 713ms/epoch - 27ms/step
# Epoch 168/1000
# 26/26 - 1s - loss: 5.1077e-06 - mean_squared_error: 5.1077e-06 - val_loss: 5.3516e-06 - val_mean_squared_error: 5.3516e-06 - 709ms/epoch - 27ms/step
# Epoch 169/1000
# 26/26 - 1s - loss: 5.0900e-06 - mean_squared_error: 5.0900e-06 - val_loss: 5.3731e-06 - val_mean_squared_error: 5.3731e-06 - 693ms/epoch - 27ms/step
# Epoch 170/1000
# 26/26 - 1s - loss: 5.3463e-06 - mean_squared_error: 5.3463e-06 - val_loss: 4.1374e-06 - val_mean_squared_error: 4.1374e-06 - 734ms/epoch - 28ms/step
# Epoch 171/1000
# 26/26 - 1s - loss: 5.4014e-06 - mean_squared_error: 5.4014e-06 - val_loss: 5.3124e-06 - val_mean_squared_error: 5.3124e-06 - 673ms/epoch - 26ms/step
# Epoch 172/1000
# 26/26 - 1s - loss: 6.4254e-06 - mean_squared_error: 6.4254e-06 - val_loss: 4.3816e-06 - val_mean_squared_error: 4.3816e-06 - 699ms/epoch - 27ms/step
# Epoch 173/1000
# 26/26 - 1s - loss: 6.8931e-06 - mean_squared_error: 6.8931e-06 - val_loss: 4.9315e-06 - val_mean_squared_error: 4.9315e-06 - 705ms/epoch - 27ms/step
# Epoch 174/1000
# 26/26 - 1s - loss: 7.4407e-06 - mean_squared_error: 7.4407e-06 - val_loss: 4.0967e-06 - val_mean_squared_error: 4.0967e-06 - 694ms/epoch - 27ms/step
# Epoch 175/1000
# 26/26 - 1s - loss: 8.4830e-06 - mean_squared_error: 8.4830e-06 - val_loss: 5.1438e-06 - val_mean_squared_error: 5.1438e-06 - 694ms/epoch - 27ms/step
# Epoch 176/1000
# 26/26 - 1s - loss: 4.9006e-06 - mean_squared_error: 4.9006e-06 - val_loss: 6.8123e-06 - val_mean_squared_error: 6.8123e-06 - 696ms/epoch - 27ms/step
# Epoch 177/1000
# 26/26 - 1s - loss: 7.1602e-06 - mean_squared_error: 7.1602e-06 - val_loss: 4.3458e-06 - val_mean_squared_error: 4.3458e-06 - 710ms/epoch - 27ms/step
# Epoch 178/1000
# 26/26 - 1s - loss: 7.7309e-06 - mean_squared_error: 7.7309e-06 - val_loss: 1.0540e-05 - val_mean_squared_error: 1.0540e-05 - 711ms/epoch - 27ms/step
# Epoch 179/1000
# 26/26 - 1s - loss: 9.0990e-06 - mean_squared_error: 9.0990e-06 - val_loss: 4.9073e-06 - val_mean_squared_error: 4.9073e-06 - 708ms/epoch - 27ms/step
# Epoch 180/1000
# 26/26 - 1s - loss: 5.9579e-06 - mean_squared_error: 5.9579e-06 - val_loss: 8.2740e-06 - val_mean_squared_error: 8.2740e-06 - 697ms/epoch - 27ms/step
# Epoch 181/1000
# 26/26 - 1s - loss: 1.0555e-05 - mean_squared_error: 1.0555e-05 - val_loss: 1.2290e-05 - val_mean_squared_error: 1.2290e-05 - 689ms/epoch - 27ms/step
# Epoch 182/1000
# 26/26 - 1s - loss: 6.2999e-06 - mean_squared_error: 6.2999e-06 - val_loss: 6.8212e-06 - val_mean_squared_error: 6.8212e-06 - 677ms/epoch - 26ms/step
# Epoch 183/1000
# 26/26 - 1s - loss: 7.6004e-06 - mean_squared_error: 7.6004e-06 - val_loss: 8.1315e-06 - val_mean_squared_error: 8.1315e-06 - 695ms/epoch - 27ms/step
# Epoch 184/1000
# 26/26 - 1s - loss: 7.5630e-06 - mean_squared_error: 7.5630e-06 - val_loss: 5.0951e-06 - val_mean_squared_error: 5.0951e-06 - 725ms/epoch - 28ms/step
# Epoch 185/1000
# 26/26 - 1s - loss: 5.6038e-06 - mean_squared_error: 5.6038e-06 - val_loss: 5.0278e-06 - val_mean_squared_error: 5.0278e-06 - 700ms/epoch - 27ms/step
# Epoch 186/1000
# 26/26 - 1s - loss: 6.5788e-06 - mean_squared_error: 6.5788e-06 - val_loss: 9.5038e-06 - val_mean_squared_error: 9.5038e-06 - 686ms/epoch - 26ms/step
# Epoch 187/1000
# 26/26 - 1s - loss: 7.7101e-06 - mean_squared_error: 7.7101e-06 - val_loss: 3.6885e-06 - val_mean_squared_error: 3.6885e-06 - 716ms/epoch - 28ms/step
# Epoch 188/1000
# 26/26 - 1s - loss: 1.0513e-05 - mean_squared_error: 1.0513e-05 - val_loss: 8.1028e-06 - val_mean_squared_error: 8.1028e-06 - 684ms/epoch - 26ms/step
# Epoch 189/1000
# 26/26 - 1s - loss: 7.6782e-06 - mean_squared_error: 7.6782e-06 - val_loss: 5.0839e-06 - val_mean_squared_error: 5.0839e-06 - 725ms/epoch - 28ms/step
# Epoch 190/1000
# 26/26 - 1s - loss: 4.2285e-06 - mean_squared_error: 4.2285e-06 - val_loss: 5.5581e-06 - val_mean_squared_error: 5.5581e-06 - 720ms/epoch - 28ms/step
# Epoch 191/1000
# 26/26 - 1s - loss: 1.0625e-05 - mean_squared_error: 1.0625e-05 - val_loss: 1.1803e-05 - val_mean_squared_error: 1.1803e-05 - 713ms/epoch - 27ms/step
# Epoch 192/1000
# 26/26 - 1s - loss: 1.0268e-05 - mean_squared_error: 1.0268e-05 - val_loss: 7.4648e-06 - val_mean_squared_error: 7.4648e-06 - 713ms/epoch - 27ms/step
# Epoch 193/1000
# 26/26 - 1s - loss: 5.6953e-06 - mean_squared_error: 5.6953e-06 - val_loss: 4.9908e-06 - val_mean_squared_error: 4.9908e-06 - 717ms/epoch - 28ms/step
# Epoch 194/1000
# 26/26 - 1s - loss: 6.4427e-06 - mean_squared_error: 6.4427e-06 - val_loss: 3.0924e-05 - val_mean_squared_error: 3.0924e-05 - 682ms/epoch - 26ms/step
# Epoch 195/1000
# 26/26 - 1s - loss: 1.4039e-05 - mean_squared_error: 1.4039e-05 - val_loss: 3.7116e-06 - val_mean_squared_error: 3.7116e-06 - 712ms/epoch - 27ms/step
# Epoch 196/1000
# 26/26 - 1s - loss: 5.7668e-06 - mean_squared_error: 5.7668e-06 - val_loss: 3.7641e-06 - val_mean_squared_error: 3.7641e-06 - 677ms/epoch - 26ms/step
# Epoch 197/1000
# 26/26 - 1s - loss: 3.8907e-06 - mean_squared_error: 3.8907e-06 - val_loss: 3.6561e-06 - val_mean_squared_error: 3.6561e-06 - 726ms/epoch - 28ms/step
# Epoch 198/1000
# 26/26 - 1s - loss: 4.1385e-06 - mean_squared_error: 4.1385e-06 - val_loss: 3.4884e-06 - val_mean_squared_error: 3.4884e-06 - 706ms/epoch - 27ms/step
# Epoch 199/1000
# 26/26 - 1s - loss: 6.6684e-06 - mean_squared_error: 6.6684e-06 - val_loss: 5.7815e-06 - val_mean_squared_error: 5.7815e-06 - 693ms/epoch - 27ms/step
# Epoch 200/1000
# 26/26 - 1s - loss: 7.7855e-06 - mean_squared_error: 7.7855e-06 - val_loss: 4.3827e-06 - val_mean_squared_error: 4.3827e-06 - 711ms/epoch - 27ms/step
# Epoch 201/1000
# 26/26 - 1s - loss: 5.7532e-06 - mean_squared_error: 5.7532e-06 - val_loss: 5.4283e-06 - val_mean_squared_error: 5.4283e-06 - 692ms/epoch - 27ms/step
# Epoch 202/1000
# 26/26 - 1s - loss: 4.8185e-06 - mean_squared_error: 4.8185e-06 - val_loss: 4.3471e-06 - val_mean_squared_error: 4.3471e-06 - 701ms/epoch - 27ms/step
# Epoch 203/1000
# 26/26 - 1s - loss: 1.3806e-05 - mean_squared_error: 1.3806e-05 - val_loss: 7.7635e-06 - val_mean_squared_error: 7.7635e-06 - 685ms/epoch - 26ms/step
# Epoch 204/1000
# 26/26 - 1s - loss: 7.2200e-06 - mean_squared_error: 7.2200e-06 - val_loss: 5.8122e-06 - val_mean_squared_error: 5.8122e-06 - 677ms/epoch - 26ms/step
# Epoch 205/1000
# 26/26 - 1s - loss: 4.3308e-06 - mean_squared_error: 4.3308e-06 - val_loss: 7.4435e-06 - val_mean_squared_error: 7.4435e-06 - 711ms/epoch - 27ms/step
# Epoch 206/1000
# 26/26 - 1s - loss: 8.4741e-06 - mean_squared_error: 8.4741e-06 - val_loss: 8.3296e-06 - val_mean_squared_error: 8.3296e-06 - 693ms/epoch - 27ms/step
# Epoch 207/1000
# 26/26 - 1s - loss: 4.8761e-06 - mean_squared_error: 4.8761e-06 - val_loss: 4.0124e-06 - val_mean_squared_error: 4.0124e-06 - 713ms/epoch - 27ms/step
# Epoch 208/1000
# 26/26 - 1s - loss: 7.0016e-06 - mean_squared_error: 7.0016e-06 - val_loss: 2.7238e-05 - val_mean_squared_error: 2.7238e-05 - 695ms/epoch - 27ms/step
# Epoch 209/1000
# 26/26 - 1s - loss: 1.3954e-05 - mean_squared_error: 1.3954e-05 - val_loss: 4.6795e-06 - val_mean_squared_error: 4.6795e-06 - 685ms/epoch - 26ms/step
# Epoch 210/1000
# 26/26 - 1s - loss: 4.7327e-06 - mean_squared_error: 4.7327e-06 - val_loss: 3.1660e-06 - val_mean_squared_error: 3.1661e-06 - 695ms/epoch - 27ms/step
# Epoch 211/1000
# 26/26 - 1s - loss: 3.5202e-06 - mean_squared_error: 3.5202e-06 - val_loss: 3.5869e-06 - val_mean_squared_error: 3.5869e-06 - 693ms/epoch - 27ms/step
# Epoch 212/1000
# 26/26 - 1s - loss: 3.6708e-06 - mean_squared_error: 3.6708e-06 - val_loss: 4.0386e-06 - val_mean_squared_error: 4.0386e-06 - 680ms/epoch - 26ms/step
# Epoch 213/1000
# 26/26 - 1s - loss: 4.0121e-06 - mean_squared_error: 4.0121e-06 - val_loss: 7.7489e-06 - val_mean_squared_error: 7.7489e-06 - 724ms/epoch - 28ms/step
# Epoch 214/1000
# 26/26 - 1s - loss: 2.3024e-05 - mean_squared_error: 2.3024e-05 - val_loss: 4.4616e-06 - val_mean_squared_error: 4.4616e-06 - 677ms/epoch - 26ms/step
# Epoch 215/1000
# 26/26 - 1s - loss: 6.2651e-06 - mean_squared_error: 6.2651e-06 - val_loss: 3.3615e-06 - val_mean_squared_error: 3.3615e-06 - 695ms/epoch - 27ms/step
# Epoch 216/1000
# 26/26 - 1s - loss: 3.5093e-06 - mean_squared_error: 3.5093e-06 - val_loss: 4.0243e-06 - val_mean_squared_error: 4.0243e-06 - 710ms/epoch - 27ms/step
# Epoch 217/1000
# 26/26 - 1s - loss: 6.6904e-06 - mean_squared_error: 6.6904e-06 - val_loss: 1.3059e-05 - val_mean_squared_error: 1.3059e-05 - 697ms/epoch - 27ms/step
# Epoch 218/1000
# 26/26 - 1s - loss: 5.3526e-06 - mean_squared_error: 5.3526e-06 - val_loss: 8.6720e-06 - val_mean_squared_error: 8.6720e-06 - 728ms/epoch - 28ms/step
# Epoch 219/1000
# 26/26 - 1s - loss: 9.4065e-06 - mean_squared_error: 9.4065e-06 - val_loss: 5.2741e-06 - val_mean_squared_error: 5.2741e-06 - 685ms/epoch - 26ms/step
# Epoch 220/1000
# 26/26 - 1s - loss: 9.1660e-06 - mean_squared_error: 9.1660e-06 - val_loss: 7.4654e-06 - val_mean_squared_error: 7.4654e-06 - 710ms/epoch - 27ms/step
# Epoch 221/1000
# 26/26 - 1s - loss: 3.4756e-06 - mean_squared_error: 3.4756e-06 - val_loss: 3.4762e-06 - val_mean_squared_error: 3.4762e-06 - 711ms/epoch - 27ms/step
# Epoch 222/1000
# 26/26 - 1s - loss: 3.8589e-06 - mean_squared_error: 3.8589e-06 - val_loss: 4.1083e-06 - val_mean_squared_error: 4.1083e-06 - 713ms/epoch - 27ms/step
# Epoch 223/1000
# 26/26 - 1s - loss: 4.6377e-06 - mean_squared_error: 4.6377e-06 - val_loss: 3.3229e-06 - val_mean_squared_error: 3.3229e-06 - 699ms/epoch - 27ms/step
# Epoch 224/1000
# 26/26 - 1s - loss: 3.5638e-06 - mean_squared_error: 3.5638e-06 - val_loss: 4.9434e-06 - val_mean_squared_error: 4.9434e-06 - 699ms/epoch - 27ms/step
# Epoch 225/1000
# 26/26 - 1s - loss: 4.7477e-06 - mean_squared_error: 4.7477e-06 - val_loss: 1.1154e-05 - val_mean_squared_error: 1.1154e-05 - 709ms/epoch - 27ms/step
# Epoch 226/1000
# 26/26 - 1s - loss: 1.7331e-05 - mean_squared_error: 1.7331e-05 - val_loss: 5.2428e-06 - val_mean_squared_error: 5.2428e-06 - 679ms/epoch - 26ms/step
# Epoch 227/1000
# 26/26 - 1s - loss: 5.1890e-06 - mean_squared_error: 5.1890e-06 - val_loss: 3.2342e-06 - val_mean_squared_error: 3.2342e-06 - 694ms/epoch - 27ms/step
# Epoch 228/1000
# 26/26 - 1s - loss: 3.5500e-06 - mean_squared_error: 3.5500e-06 - val_loss: 3.1175e-06 - val_mean_squared_error: 3.1175e-06 - 695ms/epoch - 27ms/step
# Epoch 229/1000
# 26/26 - 1s - loss: 1.2616e-05 - mean_squared_error: 1.2616e-05 - val_loss: 1.2336e-05 - val_mean_squared_error: 1.2336e-05 - 709ms/epoch - 27ms/step
# Epoch 230/1000
# 26/26 - 1s - loss: 6.4131e-06 - mean_squared_error: 6.4131e-06 - val_loss: 4.2917e-06 - val_mean_squared_error: 4.2917e-06 - 711ms/epoch - 27ms/step
# Epoch 231/1000
# 26/26 - 1s - loss: 3.9984e-06 - mean_squared_error: 3.9984e-06 - val_loss: 4.0469e-06 - val_mean_squared_error: 4.0469e-06 - 690ms/epoch - 27ms/step
# Epoch 232/1000
# 26/26 - 1s - loss: 4.0622e-06 - mean_squared_error: 4.0622e-06 - val_loss: 2.9135e-06 - val_mean_squared_error: 2.9135e-06 - 681ms/epoch - 26ms/step
# Epoch 233/1000
# 26/26 - 1s - loss: 3.6046e-06 - mean_squared_error: 3.6046e-06 - val_loss: 3.1017e-06 - val_mean_squared_error: 3.1017e-06 - 695ms/epoch - 27ms/step
# Epoch 234/1000
# 26/26 - 1s - loss: 3.8818e-06 - mean_squared_error: 3.8818e-06 - val_loss: 7.4004e-06 - val_mean_squared_error: 7.4004e-06 - 709ms/epoch - 27ms/step
# Epoch 235/1000
# 26/26 - 1s - loss: 9.7008e-06 - mean_squared_error: 9.7008e-06 - val_loss: 2.8635e-06 - val_mean_squared_error: 2.8635e-06 - 694ms/epoch - 27ms/step
# Epoch 236/1000
# 26/26 - 1s - loss: 3.2116e-06 - mean_squared_error: 3.2116e-06 - val_loss: 4.6116e-06 - val_mean_squared_error: 4.6116e-06 - 694ms/epoch - 27ms/step
# Epoch 237/1000
# 26/26 - 1s - loss: 1.3446e-05 - mean_squared_error: 1.3446e-05 - val_loss: 2.0121e-05 - val_mean_squared_error: 2.0121e-05 - 660ms/epoch - 25ms/step
# Epoch 238/1000
# 26/26 - 1s - loss: 8.3028e-06 - mean_squared_error: 8.3028e-06 - val_loss: 4.1464e-06 - val_mean_squared_error: 4.1464e-06 - 711ms/epoch - 27ms/step
# Epoch 239/1000
# 26/26 - 1s - loss: 4.9341e-06 - mean_squared_error: 4.9341e-06 - val_loss: 5.4988e-06 - val_mean_squared_error: 5.4988e-06 - 671ms/epoch - 26ms/step
# Epoch 240/1000
# 26/26 - 1s - loss: 3.6780e-06 - mean_squared_error: 3.6780e-06 - val_loss: 2.6512e-06 - val_mean_squared_error: 2.6512e-06 - 701ms/epoch - 27ms/step
# Epoch 241/1000
# 26/26 - 1s - loss: 4.9492e-06 - mean_squared_error: 4.9492e-06 - val_loss: 7.8004e-06 - val_mean_squared_error: 7.8004e-06 - 696ms/epoch - 27ms/step
# Epoch 242/1000
# 26/26 - 1s - loss: 7.8172e-06 - mean_squared_error: 7.8172e-06 - val_loss: 3.7943e-06 - val_mean_squared_error: 3.7943e-06 - 677ms/epoch - 26ms/step
# Epoch 243/1000
# 26/26 - 1s - loss: 5.2140e-06 - mean_squared_error: 5.2140e-06 - val_loss: 3.2582e-06 - val_mean_squared_error: 3.2582e-06 - 688ms/epoch - 26ms/step
# Epoch 244/1000
# 26/26 - 1s - loss: 4.8709e-06 - mean_squared_error: 4.8709e-06 - val_loss: 6.0364e-06 - val_mean_squared_error: 6.0364e-06 - 684ms/epoch - 26ms/step
# Epoch 245/1000
# 26/26 - 1s - loss: 4.3521e-06 - mean_squared_error: 4.3521e-06 - val_loss: 3.8025e-06 - val_mean_squared_error: 3.8025e-06 - 675ms/epoch - 26ms/step
# Epoch 246/1000
# 26/26 - 1s - loss: 4.9323e-06 - mean_squared_error: 4.9323e-06 - val_loss: 5.2255e-06 - val_mean_squared_error: 5.2255e-06 - 685ms/epoch - 26ms/step
# Epoch 247/1000
# 26/26 - 1s - loss: 1.2410e-05 - mean_squared_error: 1.2410e-05 - val_loss: 8.6959e-06 - val_mean_squared_error: 8.6959e-06 - 700ms/epoch - 27ms/step
# Epoch 248/1000
# 26/26 - 1s - loss: 3.5207e-06 - mean_squared_error: 3.5207e-06 - val_loss: 3.2988e-06 - val_mean_squared_error: 3.2988e-06 - 692ms/epoch - 27ms/step
# Epoch 249/1000
# 26/26 - 1s - loss: 4.0491e-06 - mean_squared_error: 4.0491e-06 - val_loss: 3.6835e-06 - val_mean_squared_error: 3.6835e-06 - 712ms/epoch - 27ms/step
# Epoch 250/1000
# 26/26 - 1s - loss: 1.0314e-05 - mean_squared_error: 1.0314e-05 - val_loss: 4.0309e-06 - val_mean_squared_error: 4.0309e-06 - 678ms/epoch - 26ms/step
# Epoch 251/1000
# 26/26 - 1s - loss: 7.6879e-06 - mean_squared_error: 7.6879e-06 - val_loss: 6.0504e-06 - val_mean_squared_error: 6.0504e-06 - 699ms/epoch - 27ms/step
# Epoch 252/1000
# 26/26 - 1s - loss: 5.0112e-06 - mean_squared_error: 5.0112e-06 - val_loss: 5.3512e-06 - val_mean_squared_error: 5.3512e-06 - 703ms/epoch - 27ms/step
# Epoch 253/1000
# 26/26 - 1s - loss: 4.2492e-06 - mean_squared_error: 4.2492e-06 - val_loss: 3.1662e-06 - val_mean_squared_error: 3.1662e-06 - 693ms/epoch - 27ms/step
# Epoch 254/1000
# 26/26 - 1s - loss: 3.9741e-06 - mean_squared_error: 3.9741e-06 - val_loss: 2.8529e-06 - val_mean_squared_error: 2.8529e-06 - 727ms/epoch - 28ms/step
# Epoch 255/1000
# 26/26 - 1s - loss: 1.3085e-05 - mean_squared_error: 1.3085e-05 - val_loss: 1.6812e-05 - val_mean_squared_error: 1.6812e-05 - 694ms/epoch - 27ms/step
# Epoch 256/1000
# 26/26 - 1s - loss: 7.2488e-06 - mean_squared_error: 7.2488e-06 - val_loss: 3.4337e-06 - val_mean_squared_error: 3.4337e-06 - 700ms/epoch - 27ms/step
# Epoch 257/1000
# 26/26 - 1s - loss: 2.6574e-06 - mean_squared_error: 2.6574e-06 - val_loss: 3.3205e-06 - val_mean_squared_error: 3.3205e-06 - 700ms/epoch - 27ms/step
# Epoch 258/1000
# 26/26 - 1s - loss: 3.7055e-06 - mean_squared_error: 3.7055e-06 - val_loss: 2.8809e-06 - val_mean_squared_error: 2.8809e-06 - 692ms/epoch - 27ms/step
# Epoch 259/1000
# 26/26 - 1s - loss: 3.2148e-06 - mean_squared_error: 3.2148e-06 - val_loss: 3.5527e-06 - val_mean_squared_error: 3.5527e-06 - 709ms/epoch - 27ms/step
# Epoch 260/1000
# 26/26 - 1s - loss: 2.5419e-06 - mean_squared_error: 2.5419e-06 - val_loss: 2.3843e-06 - val_mean_squared_error: 2.3843e-06 - 679ms/epoch - 26ms/step
# Epoch 261/1000
# 26/26 - 1s - loss: 6.5637e-06 - mean_squared_error: 6.5637e-06 - val_loss: 1.4778e-05 - val_mean_squared_error: 1.4778e-05 - 710ms/epoch - 27ms/step
# Epoch 262/1000
# 26/26 - 1s - loss: 7.8300e-06 - mean_squared_error: 7.8300e-06 - val_loss: 7.5206e-06 - val_mean_squared_error: 7.5206e-06 - 692ms/epoch - 27ms/step
# Epoch 263/1000
# 26/26 - 1s - loss: 7.5681e-06 - mean_squared_error: 7.5681e-06 - val_loss: 5.9199e-06 - val_mean_squared_error: 5.9199e-06 - 693ms/epoch - 27ms/step
# Epoch 264/1000
# 26/26 - 1s - loss: 4.1801e-06 - mean_squared_error: 4.1801e-06 - val_loss: 7.8867e-06 - val_mean_squared_error: 7.8867e-06 - 696ms/epoch - 27ms/step
# Epoch 265/1000
# 26/26 - 1s - loss: 4.6841e-06 - mean_squared_error: 4.6841e-06 - val_loss: 5.8692e-06 - val_mean_squared_error: 5.8692e-06 - 694ms/epoch - 27ms/step
# Epoch 266/1000
# 26/26 - 1s - loss: 3.7384e-06 - mean_squared_error: 3.7384e-06 - val_loss: 7.5743e-06 - val_mean_squared_error: 7.5743e-06 - 710ms/epoch - 27ms/step
# Epoch 267/1000
# 26/26 - 1s - loss: 4.9464e-06 - mean_squared_error: 4.9464e-06 - val_loss: 4.7233e-06 - val_mean_squared_error: 4.7233e-06 - 679ms/epoch - 26ms/step
# Epoch 268/1000
# 26/26 - 1s - loss: 1.3551e-05 - mean_squared_error: 1.3551e-05 - val_loss: 1.5426e-05 - val_mean_squared_error: 1.5426e-05 - 707ms/epoch - 27ms/step
# Epoch 269/1000
# 26/26 - 1s - loss: 4.6891e-06 - mean_squared_error: 4.6891e-06 - val_loss: 2.4307e-06 - val_mean_squared_error: 2.4307e-06 - 714ms/epoch - 27ms/step
# Epoch 270/1000
# 26/26 - 1s - loss: 3.1885e-06 - mean_squared_error: 3.1885e-06 - val_loss: 3.0008e-06 - val_mean_squared_error: 3.0008e-06 - 689ms/epoch - 27ms/step
# Epoch 271/1000
# 26/26 - 1s - loss: 2.6534e-06 - mean_squared_error: 2.6534e-06 - val_loss: 4.2271e-06 - val_mean_squared_error: 4.2271e-06 - 709ms/epoch - 27ms/step
# Epoch 272/1000
# 26/26 - 1s - loss: 9.3456e-06 - mean_squared_error: 9.3456e-06 - val_loss: 7.8465e-05 - val_mean_squared_error: 7.8465e-05 - 709ms/epoch - 27ms/step
# Epoch 273/1000
# 26/26 - 1s - loss: 1.5811e-05 - mean_squared_error: 1.5811e-05 - val_loss: 5.3780e-06 - val_mean_squared_error: 5.3780e-06 - 694ms/epoch - 27ms/step
# Epoch 274/1000
# 26/26 - 1s - loss: 3.2554e-06 - mean_squared_error: 3.2554e-06 - val_loss: 2.3621e-06 - val_mean_squared_error: 2.3621e-06 - 710ms/epoch - 27ms/step
# Epoch 275/1000
# 26/26 - 1s - loss: 3.7808e-06 - mean_squared_error: 3.7808e-06 - val_loss: 4.3304e-06 - val_mean_squared_error: 4.3304e-06 - 695ms/epoch - 27ms/step
# Epoch 276/1000
# 26/26 - 1s - loss: 3.8139e-06 - mean_squared_error: 3.8139e-06 - val_loss: 3.9042e-06 - val_mean_squared_error: 3.9042e-06 - 697ms/epoch - 27ms/step
# Epoch 277/1000
# 26/26 - 1s - loss: 4.0870e-06 - mean_squared_error: 4.0870e-06 - val_loss: 3.1168e-06 - val_mean_squared_error: 3.1168e-06 - 705ms/epoch - 27ms/step
# Epoch 278/1000
# 26/26 - 1s - loss: 5.6469e-06 - mean_squared_error: 5.6469e-06 - val_loss: 7.7573e-06 - val_mean_squared_error: 7.7573e-06 - 694ms/epoch - 27ms/step
# Epoch 279/1000
# 26/26 - 1s - loss: 3.8225e-06 - mean_squared_error: 3.8225e-06 - val_loss: 2.1543e-06 - val_mean_squared_error: 2.1543e-06 - 714ms/epoch - 27ms/step
# Epoch 280/1000
# 26/26 - 1s - loss: 2.2430e-06 - mean_squared_error: 2.2430e-06 - val_loss: 2.0957e-06 - val_mean_squared_error: 2.0957e-06 - 671ms/epoch - 26ms/step
# Epoch 281/1000
# 26/26 - 1s - loss: 5.7606e-06 - mean_squared_error: 5.7606e-06 - val_loss: 2.5635e-06 - val_mean_squared_error: 2.5635e-06 - 693ms/epoch - 27ms/step
# Epoch 282/1000
# 26/26 - 1s - loss: 7.9325e-06 - mean_squared_error: 7.9325e-06 - val_loss: 7.6327e-06 - val_mean_squared_error: 7.6327e-06 - 696ms/epoch - 27ms/step
# Epoch 283/1000
# 26/26 - 1s - loss: 4.7240e-06 - mean_squared_error: 4.7240e-06 - val_loss: 4.7671e-06 - val_mean_squared_error: 4.7671e-06 - 693ms/epoch - 27ms/step
# Epoch 284/1000
# 26/26 - 1s - loss: 4.0200e-06 - mean_squared_error: 4.0200e-06 - val_loss: 3.7955e-06 - val_mean_squared_error: 3.7955e-06 - 691ms/epoch - 27ms/step
# Epoch 285/1000
# 26/26 - 1s - loss: 1.2535e-05 - mean_squared_error: 1.2535e-05 - val_loss: 4.0713e-06 - val_mean_squared_error: 4.0713e-06 - 694ms/epoch - 27ms/step
# Epoch 286/1000
# 26/26 - 1s - loss: 4.5246e-06 - mean_squared_error: 4.5246e-06 - val_loss: 2.7457e-06 - val_mean_squared_error: 2.7457e-06 - 692ms/epoch - 27ms/step
# Epoch 287/1000
# 26/26 - 1s - loss: 5.2430e-06 - mean_squared_error: 5.2430e-06 - val_loss: 3.1744e-06 - val_mean_squared_error: 3.1744e-06 - 726ms/epoch - 28ms/step
# Epoch 288/1000
# 26/26 - 1s - loss: 2.6332e-06 - mean_squared_error: 2.6332e-06 - val_loss: 2.1982e-06 - val_mean_squared_error: 2.1982e-06 - 693ms/epoch - 27ms/step
# Epoch 289/1000
# 26/26 - 1s - loss: 3.2454e-06 - mean_squared_error: 3.2454e-06 - val_loss: 4.3886e-06 - val_mean_squared_error: 4.3886e-06 - 697ms/epoch - 27ms/step
# Epoch 290/1000
# 26/26 - 1s - loss: 4.7371e-06 - mean_squared_error: 4.7371e-06 - val_loss: 5.0310e-06 - val_mean_squared_error: 5.0310e-06 - 706ms/epoch - 27ms/step
# Epoch 291/1000
# 26/26 - 1s - loss: 3.2174e-06 - mean_squared_error: 3.2174e-06 - val_loss: 2.7231e-06 - val_mean_squared_error: 2.7231e-06 - 676ms/epoch - 26ms/step
# Epoch 292/1000
# 26/26 - 1s - loss: 1.1724e-05 - mean_squared_error: 1.1724e-05 - val_loss: 1.2341e-05 - val_mean_squared_error: 1.2341e-05 - 710ms/epoch - 27ms/step
# Epoch 293/1000
# 26/26 - 1s - loss: 7.9350e-06 - mean_squared_error: 7.9350e-06 - val_loss: 2.1300e-06 - val_mean_squared_error: 2.1300e-06 - 744ms/epoch - 29ms/step
# Epoch 294/1000
# 26/26 - 1s - loss: 2.2836e-06 - mean_squared_error: 2.2836e-06 - val_loss: 2.9833e-06 - val_mean_squared_error: 2.9833e-06 - 714ms/epoch - 27ms/step
# Epoch 295/1000
# ...
# Epoch 908/1000
# 26/26 - 1s - loss: 0.7022 - mean_squared_error: 0.7022 - val_loss: 0.9139 - val_mean_squared_error: 0.9139 - 1s/epoch - 53ms/step
# Epoch 909/1000
# 26/26 - 1s - loss: 0.7003 - mean_squared_error: 0.7003 - val_loss: 0.9145 - val_mean_squared_error: 0.9145 - 1s/epoch - 53ms/step
# Epoch 910/1000
# 26/26 - 1s - loss: 0.7007 - mean_squared_error: 0.7007 - val_loss: 0.9170 - val_mean_squared_error: 0.9170 - 1s/epoch - 53ms/step
# Epoch 911/1000
# 26/26 - 1s - loss: 0.6989 - mean_squared_error: 0.6989 - val_loss: 0.9164 - val_mean_squared_error: 0.9164 - 1s/epoch - 54ms/step
# Epoch 912/1000
# 26/26 - 1s - loss: 0.6994 - mean_squared_error: 0.6994 - val_loss: 0.9155 - val_mean_squared_error: 0.9155 - 1s/epoch - 53ms/step
# Epoch 913/1000
# 26/26 - 1s - loss: 0.6995 - mean_squared_error: 0.6995 - val_loss: 0.9166 - val_mean_squared_error: 0.9166 - 1s/epoch - 52ms/step
# Epoch 914/1000
# 26/26 - 1s - loss: 0.6983 - mean_squared_error: 0.6983 - val_loss: 0.9167 - val_mean_squared_error: 0.9167 - 1s/epoch - 54ms/step
# Epoch 915/1000
# 26/26 - 1s - loss: 0.6979 - mean_squared_error: 0.6979 - val_loss: 0.9177 - val_mean_squared_error: 0.9177 - 1s/epoch - 53ms/step
# Epoch 916/1000
# 26/26 - 1s - loss: 0.7007 - mean_squared_error: 0.7007 - val_loss: 0.9184 - val_mean_squared_error: 0.9184 - 1s/epoch - 53ms/step
# Epoch 917/1000
# 26/26 - 1s - loss: 0.6983 - mean_squared_error: 0.6983 - val_loss: 0.9175 - val_mean_squared_error: 0.9175 - 1s/epoch - 54ms/step
# Epoch 918/1000
# 26/26 - 1s - loss: 0.7003 - mean_squared_error: 0.7003 - val_loss: 0.9186 - val_mean_squared_error: 0.9186 - 1s/epoch - 53ms/step
# Epoch 919/1000
# 26/26 - 1s - loss: 0.6987 - mean_squared_error: 0.6987 - val_loss: 0.9179 - val_mean_squared_error: 0.9179 - 1s/epoch - 53ms/step
# Epoch 920/1000
# 26/26 - 1s - loss: 0.6977 - mean_squared_error: 0.6977 - val_loss: 0.9198 - val_mean_squared_error: 0.9198 - 1s/epoch - 53ms/step
# Epoch 921/1000
# 26/26 - 1s - loss: 0.6972 - mean_squared_error: 0.6972 - val_loss: 0.9177 - val_mean_squared_error: 0.9177 - 1s/epoch - 53ms/step
# Epoch 922/1000
# 26/26 - 1s - loss: 0.6995 - mean_squared_error: 0.6995 - val_loss: 0.9177 - val_mean_squared_error: 0.9177 - 1s/epoch - 52ms/step
# Epoch 923/1000
# 26/26 - 1s - loss: 0.6964 - mean_squared_error: 0.6964 - val_loss: 0.9182 - val_mean_squared_error: 0.9182 - 1s/epoch - 54ms/step
# Epoch 924/1000
# 26/26 - 1s - loss: 0.6971 - mean_squared_error: 0.6971 - val_loss: 0.9198 - val_mean_squared_error: 0.9198 - 1s/epoch - 53ms/step
# Epoch 925/1000
# 26/26 - 1s - loss: 0.6966 - mean_squared_error: 0.6966 - val_loss: 0.9192 - val_mean_squared_error: 0.9192 - 1s/epoch - 52ms/step
# Epoch 926/1000
# 26/26 - 1s - loss: 0.6971 - mean_squared_error: 0.6971 - val_loss: 0.9182 - val_mean_squared_error: 0.9182 - 1s/epoch - 52ms/step
# Epoch 927/1000
# 26/26 - 1s - loss: 0.6971 - mean_squared_error: 0.6971 - val_loss: 0.9195 - val_mean_squared_error: 0.9195 - 1s/epoch - 53ms/step
# Epoch 928/1000
# 26/26 - 1s - loss: 0.6980 - mean_squared_error: 0.6980 - val_loss: 0.9197 - val_mean_squared_error: 0.9197 - 1s/epoch - 53ms/step
# Epoch 929/1000
# 26/26 - 1s - loss: 0.6993 - mean_squared_error: 0.6993 - val_loss: 0.9197 - val_mean_squared_error: 0.9197 - 1s/epoch - 52ms/step
# Epoch 930/1000
# 26/26 - 1s - loss: 0.6974 - mean_squared_error: 0.6974 - val_loss: 0.9220 - val_mean_squared_error: 0.9220 - 1s/epoch - 53ms/step
# Epoch 931/1000
# 26/26 - 1s - loss: 0.6965 - mean_squared_error: 0.6965 - val_loss: 0.9208 - val_mean_squared_error: 0.9208 - 1s/epoch - 53ms/step
# Epoch 932/1000
# 26/26 - 1s - loss: 0.6954 - mean_squared_error: 0.6954 - val_loss: 0.9206 - val_mean_squared_error: 0.9206 - 1s/epoch - 53ms/step
# Epoch 933/1000
# 26/26 - 1s - loss: 0.6947 - mean_squared_error: 0.6947 - val_loss: 0.9212 - val_mean_squared_error: 0.9212 - 1s/epoch - 52ms/step
# Epoch 934/1000
# 26/26 - 1s - loss: 0.6957 - mean_squared_error: 0.6957 - val_loss: 0.9210 - val_mean_squared_error: 0.9210 - 1s/epoch - 54ms/step
# Epoch 935/1000
# 26/26 - 1s - loss: 0.6946 - mean_squared_error: 0.6946 - val_loss: 0.9213 - val_mean_squared_error: 0.9213 - 1s/epoch - 54ms/step
# Epoch 936/1000
# 26/26 - 1s - loss: 0.6953 - mean_squared_error: 0.6953 - val_loss: 0.9203 - val_mean_squared_error: 0.9203 - 1s/epoch - 53ms/step
# Epoch 937/1000
# 26/26 - 1s - loss: 0.6961 - mean_squared_error: 0.6961 - val_loss: 0.9206 - val_mean_squared_error: 0.9206 - 1s/epoch - 53ms/step
# Epoch 938/1000
# 26/26 - 1s - loss: 0.6945 - mean_squared_error: 0.6945 - val_loss: 0.9210 - val_mean_squared_error: 0.9210 - 1s/epoch - 53ms/step
# Epoch 939/1000
# 26/26 - 1s - loss: 0.6940 - mean_squared_error: 0.6940 - val_loss: 0.9216 - val_mean_squared_error: 0.9216 - 1s/epoch - 52ms/step
# Epoch 940/1000
# 26/26 - 1s - loss: 0.6934 - mean_squared_error: 0.6934 - val_loss: 0.9223 - val_mean_squared_error: 0.9223 - 1s/epoch - 52ms/step
# Epoch 941/1000
# 26/26 - 1s - loss: 0.6933 - mean_squared_error: 0.6933 - val_loss: 0.9230 - val_mean_squared_error: 0.9230 - 1s/epoch - 52ms/step
# Epoch 942/1000
# 26/26 - 1s - loss: 0.6947 - mean_squared_error: 0.6947 - val_loss: 0.9213 - val_mean_squared_error: 0.9213 - 1s/epoch - 53ms/step
# Epoch 943/1000
# 26/26 - 1s - loss: 0.6943 - mean_squared_error: 0.6943 - val_loss: 0.9220 - val_mean_squared_error: 0.9220 - 1s/epoch - 53ms/step
# Epoch 944/1000
# 26/26 - 1s - loss: 0.6935 - mean_squared_error: 0.6935 - val_loss: 0.9222 - val_mean_squared_error: 0.9222 - 1s/epoch - 53ms/step
# Epoch 945/1000
# 26/26 - 1s - loss: 0.6929 - mean_squared_error: 0.6929 - val_loss: 0.9229 - val_mean_squared_error: 0.9229 - 1s/epoch - 54ms/step
# Epoch 946/1000
# 26/26 - 1s - loss: 0.6973 - mean_squared_error: 0.6973 - val_loss: 0.9244 - val_mean_squared_error: 0.9244 - 1s/epoch - 52ms/step
# Epoch 947/1000
# 26/26 - 1s - loss: 0.6929 - mean_squared_error: 0.6929 - val_loss: 0.9233 - val_mean_squared_error: 0.9233 - 1s/epoch - 54ms/step
# Epoch 948/1000
# 26/26 - 1s - loss: 0.6918 - mean_squared_error: 0.6918 - val_loss: 0.9226 - val_mean_squared_error: 0.9226 - 1s/epoch - 52ms/step
# Epoch 949/1000
# 26/26 - 1s - loss: 0.6926 - mean_squared_error: 0.6926 - val_loss: 0.9243 - val_mean_squared_error: 0.9243 - 1s/epoch - 53ms/step
# Epoch 950/1000
# 26/26 - 1s - loss: 0.6925 - mean_squared_error: 0.6925 - val_loss: 0.9252 - val_mean_squared_error: 0.9252 - 1s/epoch - 53ms/step
# Epoch 951/1000
# 26/26 - 1s - loss: 0.6921 - mean_squared_error: 0.6921 - val_loss: 0.9256 - val_mean_squared_error: 0.9256 - 1s/epoch - 54ms/step
# Epoch 952/1000
# 26/26 - 1s - loss: 0.6908 - mean_squared_error: 0.6908 - val_loss: 0.9266 - val_mean_squared_error: 0.9266 - 1s/epoch - 53ms/step
# Epoch 953/1000
# 26/26 - 1s - loss: 0.6935 - mean_squared_error: 0.6935 - val_loss: 0.9251 - val_mean_squared_error: 0.9251 - 1s/epoch - 53ms/step
# Epoch 954/1000
# 26/26 - 1s - loss: 0.6908 - mean_squared_error: 0.6908 - val_loss: 0.9274 - val_mean_squared_error: 0.9274 - 1s/epoch - 54ms/step
# Epoch 955/1000
# 26/26 - 1s - loss: 0.6908 - mean_squared_error: 0.6908 - val_loss: 0.9255 - val_mean_squared_error: 0.9255 - 1s/epoch - 53ms/step
# Epoch 956/1000
# 26/26 - 1s - loss: 0.6905 - mean_squared_error: 0.6905 - val_loss: 0.9277 - val_mean_squared_error: 0.9277 - 1s/epoch - 53ms/step
# Epoch 957/1000
# 26/26 - 1s - loss: 0.6911 - mean_squared_error: 0.6911 - val_loss: 0.9264 - val_mean_squared_error: 0.9264 - 1s/epoch - 54ms/step
# Epoch 958/1000
# 26/26 - 1s - loss: 0.6907 - mean_squared_error: 0.6907 - val_loss: 0.9274 - val_mean_squared_error: 0.9274 - 1s/epoch - 53ms/step
# Epoch 959/1000
# 26/26 - 1s - loss: 0.6898 - mean_squared_error: 0.6898 - val_loss: 0.9282 - val_mean_squared_error: 0.9282 - 1s/epoch - 53ms/step
# Epoch 960/1000
# 26/26 - 1s - loss: 0.6903 - mean_squared_error: 0.6903 - val_loss: 0.9264 - val_mean_squared_error: 0.9264 - 1s/epoch - 53ms/step
# Epoch 961/1000
# 26/26 - 1s - loss: 0.6908 - mean_squared_error: 0.6908 - val_loss: 0.9279 - val_mean_squared_error: 0.9279 - 1s/epoch - 55ms/step
# Epoch 962/1000
# 26/26 - 1s - loss: 0.6900 - mean_squared_error: 0.6900 - val_loss: 0.9284 - val_mean_squared_error: 0.9284 - 1s/epoch - 55ms/step
# Epoch 963/1000
# 26/26 - 1s - loss: 0.6890 - mean_squared_error: 0.6890 - val_loss: 0.9263 - val_mean_squared_error: 0.9263 - 1s/epoch - 53ms/step
# Epoch 964/1000
# 26/26 - 1s - loss: 0.6900 - mean_squared_error: 0.6900 - val_loss: 0.9279 - val_mean_squared_error: 0.9279 - 1s/epoch - 55ms/step
# Epoch 965/1000
# 26/26 - 1s - loss: 0.6913 - mean_squared_error: 0.6913 - val_loss: 0.9276 - val_mean_squared_error: 0.9276 - 1s/epoch - 53ms/step
# Epoch 966/1000
# 26/26 - 1s - loss: 0.6908 - mean_squared_error: 0.6908 - val_loss: 0.9285 - val_mean_squared_error: 0.9285 - 1s/epoch - 52ms/step
# Epoch 967/1000
# 26/26 - 1s - loss: 0.6886 - mean_squared_error: 0.6886 - val_loss: 0.9295 - val_mean_squared_error: 0.9295 - 1s/epoch - 54ms/step
# Epoch 968/1000
# 26/26 - 1s - loss: 0.6890 - mean_squared_error: 0.6890 - val_loss: 0.9298 - val_mean_squared_error: 0.9298 - 1s/epoch - 53ms/step
# Epoch 969/1000
# 26/26 - 1s - loss: 0.6893 - mean_squared_error: 0.6893 - val_loss: 0.9281 - val_mean_squared_error: 0.9281 - 1s/epoch - 54ms/step
# Epoch 970/1000
# 26/26 - 1s - loss: 0.6893 - mean_squared_error: 0.6893 - val_loss: 0.9310 - val_mean_squared_error: 0.9310 - 1s/epoch - 53ms/step
# Epoch 971/1000
# 26/26 - 1s - loss: 0.6876 - mean_squared_error: 0.6876 - val_loss: 0.9299 - val_mean_squared_error: 0.9299 - 1s/epoch - 53ms/step
# Epoch 972/1000
# 26/26 - 1s - loss: 0.6873 - mean_squared_error: 0.6873 - val_loss: 0.9315 - val_mean_squared_error: 0.9315 - 1s/epoch - 54ms/step
# Epoch 973/1000
# 26/26 - 1s - loss: 0.6880 - mean_squared_error: 0.6880 - val_loss: 0.9313 - val_mean_squared_error: 0.9313 - 1s/epoch - 53ms/step
# Epoch 974/1000
# 26/26 - 1s - loss: 0.6871 - mean_squared_error: 0.6871 - val_loss: 0.9296 - val_mean_squared_error: 0.9296 - 1s/epoch - 54ms/step
# Epoch 975/1000
# 26/26 - 1s - loss: 0.6866 - mean_squared_error: 0.6866 - val_loss: 0.9319 - val_mean_squared_error: 0.9319 - 1s/epoch - 53ms/step
# Epoch 976/1000
# 26/26 - 1s - loss: 0.6866 - mean_squared_error: 0.6866 - val_loss: 0.9289 - val_mean_squared_error: 0.9289 - 1s/epoch - 53ms/step
# Epoch 977/1000
# 26/26 - 1s - loss: 0.6882 - mean_squared_error: 0.6882 - val_loss: 0.9314 - val_mean_squared_error: 0.9314 - 1s/epoch - 54ms/step
# Epoch 978/1000
# 26/26 - 1s - loss: 0.6874 - mean_squared_error: 0.6874 - val_loss: 0.9313 - val_mean_squared_error: 0.9313 - 1s/epoch - 53ms/step
# Epoch 979/1000
# 26/26 - 1s - loss: 0.6870 - mean_squared_error: 0.6870 - val_loss: 0.9346 - val_mean_squared_error: 0.9346 - 1s/epoch - 53ms/step
# Epoch 980/1000
# 26/26 - 1s - loss: 0.6872 - mean_squared_error: 0.6872 - val_loss: 0.9328 - val_mean_squared_error: 0.9328 - 1s/epoch - 54ms/step
# Epoch 981/1000
# 26/26 - 1s - loss: 0.6861 - mean_squared_error: 0.6861 - val_loss: 0.9301 - val_mean_squared_error: 0.9301 - 1s/epoch - 52ms/step
# Epoch 982/1000
# 26/26 - 1s - loss: 0.6867 - mean_squared_error: 0.6867 - val_loss: 0.9322 - val_mean_squared_error: 0.9322 - 1s/epoch - 53ms/step
# Epoch 983/1000
# 26/26 - 1s - loss: 0.6877 - mean_squared_error: 0.6877 - val_loss: 0.9326 - val_mean_squared_error: 0.9326 - 1s/epoch - 54ms/step
# Epoch 984/1000
# 26/26 - 1s - loss: 0.6866 - mean_squared_error: 0.6866 - val_loss: 0.9322 - val_mean_squared_error: 0.9322 - 1s/epoch - 54ms/step
# Epoch 985/1000
# 26/26 - 1s - loss: 0.6854 - mean_squared_error: 0.6854 - val_loss: 0.9319 - val_mean_squared_error: 0.9319 - 1s/epoch - 53ms/step
# Epoch 986/1000
# 26/26 - 1s - loss: 0.6853 - mean_squared_error: 0.6853 - val_loss: 0.9335 - val_mean_squared_error: 0.9335 - 1s/epoch - 54ms/step
# Epoch 987/1000
# 26/26 - 1s - loss: 0.6851 - mean_squared_error: 0.6851 - val_loss: 0.9319 - val_mean_squared_error: 0.9319 - 1s/epoch - 53ms/step
# Epoch 988/1000
# 26/26 - 1s - loss: 0.6850 - mean_squared_error: 0.6850 - val_loss: 0.9344 - val_mean_squared_error: 0.9344 - 1s/epoch - 53ms/step
# Epoch 989/1000
# 26/26 - 1s - loss: 0.6854 - mean_squared_error: 0.6854 - val_loss: 0.9343 - val_mean_squared_error: 0.9343 - 1s/epoch - 53ms/step
# Epoch 990/1000
# 26/26 - 1s - loss: 0.6855 - mean_squared_error: 0.6855 - val_loss: 0.9344 - val_mean_squared_error: 0.9344 - 1s/epoch - 53ms/step
# Epoch 991/1000
# 26/26 - 1s - loss: 0.6869 - mean_squared_error: 0.6869 - val_loss: 0.9351 - val_mean_squared_error: 0.9351 - 1s/epoch - 53ms/step
# Epoch 992/1000
# 26/26 - 1s - loss: 0.6858 - mean_squared_error: 0.6858 - val_loss: 0.9334 - val_mean_squared_error: 0.9334 - 1s/epoch - 53ms/step
# Epoch 993/1000
# 26/26 - 1s - loss: 0.6895 - mean_squared_error: 0.6895 - val_loss: 0.9352 - val_mean_squared_error: 0.9352 - 1s/epoch - 53ms/step
# Epoch 994/1000
# 26/26 - 1s - loss: 0.6895 - mean_squared_error: 0.6895 - val_loss: 0.9352 - val_mean_squared_error: 0.9352 - 1s/epoch - 53ms/step
# Epoch 995/1000
# 26/26 - 1s - loss: 0.6867 - mean_squared_error: 0.6867 - val_loss: 0.9354 - val_mean_squared_error: 0.9354 - 1s/epoch - 53ms/step
# Epoch 996/1000
# 26/26 - 1s - loss: 0.6846 - mean_squared_error: 0.6846 - val_loss: 0.9354 - val_mean_squared_error: 0.9354 - 1s/epoch - 55ms/step
# Epoch 997/1000
# 26/26 - 1s - loss: 0.6835 - mean_squared_error: 0.6835 - val_loss: 0.9334 - val_mean_squared_error: 0.9334 - 1s/epoch - 54ms/step
# Epoch 998/1000
# 26/26 - 1s - loss: 0.6838 - mean_squared_error: 0.6838 - val_loss: 0.9369 - val_mean_squared_error: 0.9369 - 1s/epoch - 52ms/step
# Epoch 999/1000
# 26/26 - 1s - loss: 0.6837 - mean_squared_error: 0.6837 - val_loss: 0.9367 - val_mean_squared_error: 0.9367 - 1s/epoch - 54ms/step
# Epoch 1000/1000
# 26/26 - 1s - loss: 0.6832 - mean_squared_error: 0.6832 - val_loss: 0.9380 - val_mean_squared_error: 0.9380 - 1s/epoch - 55ms/step
# [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# [5.301471901475452e-07, 0.0025159362703561783, 0.009954745881259441, 0.022839708253741264, 0.039994705468416214, 0.06318562477827072, 0.09153655916452408, 0.12502621114253998, 0.16886219382286072, 0.21219879388809204, 0.27464500069618225, 0.32395216822624207, 0.39979416131973267, 0.47676146030426025, 0.5660178661346436, 0.6322649121284485, 0.736379086971283, 0.8330552577972412, 0.9379527568817139]
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1309 - mean_squared_error: 0.1309
# [5.075940521237499e-07, 1.3084220881864894e-05, 7.34477216610685e-05, 7.697418186580762e-05, 0.00016896800661925226, 0.0005720517947338521, 0.001631921506486833, 0.0033125707414001226, 0.007516505196690559, 0.01093826163560152, 0.024848371744155884, 0.022117601707577705, 0.04127714782953262, 0.054211221635341644, 0.06738380342721939, 0.06503915041685104, 0.08983457833528519, 0.1036374419927597, 0.1308917999267578]
# Non-negative check failed in layer: lstm_36
# Non-negative check failed in layer: lstm_37
# Non-negative check failed in layer: dense_18
# Some weights are negative (ignoring biases).
# Lipschitz constant of the 2-layer RNN: [[1.2527011e+26]]
# 271/271 [==============================] - 2s 4ms/step
# 271/271 [==============================] - 1s 4ms/step
# lip cst: 137.436
# Estimated Lipschitz constant of the 2-layer RNN: 137.43612670898438
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_19 (InputLayer)       [(None, 10, 4)]           0
#
#  lstm_36 (LSTM)              (None, 10, 64)            17664
#
#  lstm_37 (LSTM)              (None, 10, 64)            33024
#
#  dense_18 (Dense)            (None, 10, 2)             130
#
# =================================================================
# Total params: 50818 (198.51 KB)
# Trainable params: 50818 (198.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# LSTM
# model.save('lstm_cstr.h5')
# model = tf.keras.models.load_model('lstm_cstr.h5')

# %%
results = model.evaluate(X_test, y_test_normalized, batch_size=256)
print("test loss, test acc:", results)
# Out:
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0144 - mean_squared_error: 0.0144
# test loss, test acc: [0.014399818144738674, 0.0143998172134161]

# %%
from tensorflow.python.framework.convert_to_constants import  convert_variables_to_constants_v2_as_graph

def get_flops(model):
    concrete = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete.get_concrete_function(
        [tf.TensorSpec([1, *inputs.shape[1:]]) for inputs in model.inputs])
    frozen_func, graph_def = convert_variables_to_constants_v2_as_graph(concrete_func, lower_control_flow=False)
    with tf.Graph().as_default() as graph:
        tf.graph_util.import_graph_def(graph_def, name='')
        run_meta = tf.compat.v1.RunMetadata()
        opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
        flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd="op", options=opts)
        return flops.total_float_ops

print("The FLOPs is:{}".format(get_flops(model)) ,flush=True )
model.summary()
# Out:
# The FLOPs is:27924
# Model: "model_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_24 (InputLayer)       [(None, 10, 4)]           0
#
#  simple_rnn_46 (SimpleRNN)   (None, 10, 64)            4416
#
#  simple_rnn_47 (SimpleRNN)   (None, 10, 64)            8256
#
#  dense_23 (Dense)            (None, 10, 2)             130
#
# =================================================================
# Total params: 12802 (50.01 KB)
# Trainable params: 12802 (50.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# plot training and validation losses against epochs

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Normal RNN Training and validation loss')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
"""
    equation for the stability ellipse is 1060x^2 + 44xy + 0.52y^2 - 372 = 0
"""
# prepare x and y coordinates for plotting the stability region
y = np.linspace(-100, 100, 100000, endpoint=True)

x_upper = list()
x_lower = list()
y_plot = list()

for i in y:
    sqrt = np.sqrt(-2688000 * i**2 + 15772800000)
    if sqrt >= 0:
        y_plot.append(i)
        x_upper.append((-4400 * i + sqrt) / 212000)
        x_lower.append((-4400 * i - sqrt) / 212000)
        pass
    pass

plt.figure(figsize=(10,10))

# # plot the first 10 samples and their trajectories
y_predict = model.predict(X_test)
print(y_predict.shape)

y_predict = y_predict.reshape(-1,2)
y_predict = scaler_y.inverse_transform(y_predict)
y_predict = y_predict.reshape(-1,num_step,2)

X_plot = X_test.reshape(-1,num_dims)
X_plot = scaler_X.inverse_transform(X_plot)
X_plot = X_plot.reshape(-1,num_step,num_dims)

for i in range(10):
    if i == 0:  # only add label to 1 data point
        plt.plot(X_plot[i, 0, 1], X_plot[i, 0, 0], marker="*", markersize=15, color='pink')
        plt.plot(y_test[i, :, 1], y_test[i, :, 0], color='cyan', lw=2, label='Test')
        plt.plot(y_predict[i, :, 1], y_predict[i, :, 0], color='black', lw=2, ls=':', label='Predicted')
    else:
        plt.plot(X_plot[i, 0, 1], X_plot[i, 0, 0], marker="*", markersize=15, color='pink')
        plt.plot(y_test[i, :, 1], y_test[i, :, 0], color='cyan', lw=2)
        plt.plot(y_predict[i, :, 1], y_predict[i, :, 0], color='black', lw=2, ls=':')

# plot stability region
plt.plot(x_lower, y_plot, color='steelblue', label='stability region')
plt.plot(x_upper, y_plot, color='steelblue')
plt.ylim([-100, 100])
plt.xlim([-2, 2])

plt.xlabel("C_A - C_As")
plt.ylabel("T - T_s")
plt.legend()
# plt.savefig('iclrnn_noise_0.4.pdf')
plt.show()
# Out:
# C:\Users\zihaow19\AppData\Local\Temp\ipykernel_17596\151401212.py:12: RuntimeWarning: invalid value encountered in sqrt
#   sqrt = np.sqrt(-2688000 * i**2 + 15772800000)
# 116/116 [==============================] - 0s 1ms/step
# (3706, 10, 2)
