# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input, Activation, Dropout, Add, LSTM, GRU, RNN, LayerNormalization, BatchNormalization, SpectralNormalization, Conv1D, MaxPooling1D, Flatten, Layer
from keras import backend as K
from keras.optimizers import Adam,SGD
import tensorflow as tf
from keras import Model, regularizers, activations, initializers
from keras.constraints import Constraint
import pickle

# load mat file
import h5py

# %%
with h5py.File('test_collected_data.mat', 'r') as file:
    U = file['U'][:]
    U = np.array(U)

    Y = file['Y'][:]
    Y = np.array(Y)

# %%
print(U.shape)
print(Y.shape)
# Out:
# (20001, 2)
# (20001, 2)

# %%
print(U.shape[0])
# Out:
# 20001

# %%
# get X and y data for training and testing

U_input = list()
Y_output = list()

for i in range(U.shape[0]-1):
    if i % 5 == 0:
        U_input.append(U[i:i+5, :])
        Y_output.append(Y[i:i+5, :])

# %%
U_input = np.array(U_input)
print(U_input.shape)
Y_output = np.array(Y_output)
print(Y_output.shape)
# Out:
# (4000, 5, 2)
# (4000, 5, 2)

# %%
print(Y_output[-1])
# Out:
# [[0.48259197 0.93018467]
#  [0.34779566 0.87790033]
#  [0.87823507 0.92530261]
#  [1.28194928 1.02012353]
#  [1.48795291 1.12338469]]

# %%
# RNN_input = U_input
RNN_input = np.concatenate((U_input, -U_input), axis=2)
print("RNN_input shape is {}".format(RNN_input.shape))
# Out:
# RNN_input shape is (4000, 5, 4)

# %%
print(RNN_input[0, :, :])
print(RNN_input[1, :, :])
# Out:
# [[ 16.19241666  15.76933193 -16.19241666 -15.76933193]
#  [ 12.70894193  15.86208482 -12.70894193 -15.86208482]
#  [ 19.2123671   16.62241755 -19.2123671  -16.62241755]
#  [ 19.75451791  15.65793096 -19.75451791 -15.65793096]
#  [ 18.4116695   14.67089197 -18.4116695  -14.67089197]]
# [[ 13.0167968   16.42839002 -13.0167968  -16.42839002]
#  [ 17.27902718  13.91422655 -17.27902718 -13.91422655]
#  [ 12.14333843  13.49401711 -12.14333843 -13.49401711]
#  [ 12.5352551   16.91193655 -12.5352551  -16.91193655]
#  [ 16.09581626  15.90299875 -16.09581626 -15.90299875]]

# %%
RNN_output = Y_output
print("RNN_output shape is {}".format(RNN_output.shape))
# Out:
# RNN_output shape is (4000, 5, 2)

# %%
print(RNN_output[0, :, :])
print(RNN_output[1, :, :])
# Out:
# [[1.         1.        ]
#  [1.22269359 1.11420623]
#  [0.70290225 0.94505017]
#  [0.66837481 0.90328351]
#  [0.90288417 0.91432542]]
# [[1.38545837 1.08183303]
#  [1.02589437 0.95628583]
#  [1.4512544  1.11007631]
#  [1.49351371 1.15346693]
#  [0.99319535 1.03252695]]

# %%
DEFAULT_EPS_SPECTRAL = 1e-3
DEFAULT_MAXITER_SPECTRAL = 10
SWAP_MEMORY = True
STOP_GRAD_SPECTRAL = True

def normalize_kernel(
    kernel,
    u,
    adjustment_coef,
    eps_spectral=DEFAULT_EPS_SPECTRAL,
    maxiter_spectral=DEFAULT_MAXITER_SPECTRAL,
):
    """
    Perform spectral normalization to the kernel given as input. It
    apply the power method to find the largest singular value and apply the spectral
    normalization.

    Args:
        kernel (tf.Tensor): the kernel to orthogonalize
        u (tf.Tensor): the vector used to do the power iteration method
        adjustment_coef (float): the adjustment coefficient as used in convolution
        eps_spectral (float): stopping criterion in spectral algorithm
        maxiter_spectral (int): maximum number of iterations for the power iteration

    Returns:
        tf.Tensor: the normalized kernel, the new u, and sigma which is the largest
            singular value

    """
    W_shape = kernel.shape

    # Flatten the Tensor
    W_reshaped = tf.reshape(kernel, [-1, W_shape[-1]])

    W_bar, u, sigma = spectral_normalization(
        W_reshaped, u, eps=eps_spectral, maxiter=maxiter_spectral
    )

    W_bar = W_bar * adjustment_coef
    W_bar = K.reshape(W_bar, kernel.shape)
    return W_bar, u, sigma

def _power_iteration(
    linear_operator,
    adjoint_operator,
    u,
    eps=DEFAULT_EPS_SPECTRAL,
    maxiter=DEFAULT_MAXITER_SPECTRAL,
    axis=None,
):
    """Internal function that performs the power iteration algorithm to estimate the
    largest singular vector of a linear operator.

    Args:
        linear_operator (Callable): a callable object that maps a linear operation.
        adjoint_operator (Callable): a callable object that maps the adjoint of the
            linear operator.
        u (tf.Tensor): initialization of the singular vector.
        eps (float, optional): stopping criterion of the algorithm, when
            norm(u[t] - u[t-1]) is less than eps. Defaults to DEFAULT_EPS_SPECTRAL.
        maxiter (int, optional): maximum number of iterations for the algorithm.
            Defaults to DEFAULT_MAXITER_SPECTRAL.
        axis (int/list, optional): dimension along which to normalize. Can be set for
            depthwise convolution for example. Defaults to None.

    Returns:
        tf.Tensor: the maximum singular vector.
    """

    # Prepare while loop variables
    u = tf.math.l2_normalize(u, axis=axis)
    # create a fake old_w that doesn't pass the loop condition, it will be overwritten
    old_u = u + 2 * eps

    # Loop body
    def body(u, old_u):
        old_u = u
        v = linear_operator(u)
        u = adjoint_operator(v)

        u = tf.math.l2_normalize(u, axis=axis)

        return u, old_u

    # Loop stopping condition
    def cond(u, old_u):
        return tf.linalg.norm(u - old_u) >= eps

    # Run the while loop
    u, _ = tf.while_loop(
        cond,
        body,
        (u, old_u),
        maximum_iterations=maxiter,
        swap_memory=SWAP_MEMORY,
    )

    # Prevent gradient to back-propagate into the while loop
    if STOP_GRAD_SPECTRAL:
        u = tf.stop_gradient(u)

    return u

def spectral_normalization(
    kernel, u, eps=DEFAULT_EPS_SPECTRAL, maxiter=DEFAULT_MAXITER_SPECTRAL
):
    """
    Normalize the kernel to have its maximum singular value equal to 1.

    Args:
        kernel (tf.Tensor): the kernel to normalize, assuming a 2D kernel.
        u (tf.Tensor): initialization of the maximum singular vector.
        eps (float, optional): stopping criterion of the algorithm, when
            norm(u[t] - u[t-1]) is less than eps. Defaults to DEFAULT_EPS_SPECTRAL.
        maxiter (int, optional): maximum number of iterations for the algorithm.
            Defaults to DEFAULT_MAXITER_SPECTRAL.

    Returns:
        the normalized kernel, the maximum singular vector, and the maximum singular
            value.
    """

    if u is None:
        u = tf.random.uniform(
            shape=(1, kernel.shape[-1]), minval=0.0, maxval=1.0, dtype=kernel.dtype
        )

    def linear_op(u):
        return u @ tf.transpose(kernel)

    def adjoint_op(v):
        return v @ kernel

    u = _power_iteration(linear_op, adjoint_op, u, eps, maxiter)

    # Compute the largest singular value and the normalized kernel.
    # We assume that in the worst case we converged to sigma + eps (as u and v are
    # normalized after each iteration)
    # In order to be sure that operator norm of normalized kernel is strictly less than
    # one we use sigma + eps
    sigma = tf.reshape(tf.norm(linear_op(u)), (1, 1))
    normalized_kernel = kernel / (sigma + eps)
    return normalized_kernel, u, sigma

# %%
class SpectralConstraint(Constraint):
    def __init__(
        self,
        k_coef_lip=1.0,
        eps_spectral=DEFAULT_EPS_SPECTRAL,
        u=None,
    ) -> None:
        """
        Ensure that maximum singular values of the weight matrix less than 1.

        Args:
            k_coef_lip (float): lipschitz coefficient of the weight matrix
            eps_spectral (float): stopping criterion for the iterative power algorithm.
            u (tf.Tensor): vector used for iterated power method, can be set to None
                (used for serialization/deserialization purposes).
        """
        self.eps_spectral = eps_spectral
        self.k_coef_lip = k_coef_lip
        if not (isinstance(u, tf.Tensor) or (u is None)):
            u = tf.convert_to_tensor(u)
        self.u = u
        super(SpectralConstraint, self).__init__()

    def __call__(self, w):
        # clip to ensure non-negative weight
        w = K.clip(w, 0, w)

        # perform spectral normalization to the kernel
        wbar, _, _ = normalize_kernel(
            w,
            self.u,
            self.k_coef_lip,
            self.eps_spectral,
        )

        return wbar

    def get_config(self):
        config = {
            "k_coef_lip": self.k_coef_lip,
            "eps_spectral": self.eps_spectral,
            "u": None if self.u is None else self.u.numpy(),
        }
        base_config = super(SpectralConstraint, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
def check_non_negative_weights_ignore_bias(model):
    all_non_negative = True
    for layer in model.layers:
        weights = layer.get_weights()
        if weights:  # tf the layer has weights
            # check only the weight matrices (ignoring biases if present)
            weight_only = weights[0]  # assume weights are the first element, bias (if any) is second
            if not np.all(weight_only >= 0):
                print(f"Non-negative check failed in layer: {layer.name}")
                all_non_negative = False
    if all_non_negative:
        print("All weights are non-negative (ignoring biases).")
    else:
        print("Some weights are negative (ignoring biases).")

# %%
# this method will provide an overestimate of the Lipschitz constant
def compute_lipschitz_constant_2layer_rnn(rnn_model, num_step):
    # extract weight matrices from the 2-layer RNN model
    # Layer 1: Input-to-hidden and Hidden-to-hidden weights
    Wxh1 = rnn_model.layers[1].get_weights()[0]  # Input-to-hidden weights for Layer 1
    Whh1 = rnn_model.layers[1].get_weights()[1]  # Hidden-to-hidden weights for Layer 1

    # Layer 2: Input-to-hidden and Hidden-to-hidden weights
    Wxh2 = rnn_model.layers[2].get_weights()[0]  # Input-to-hidden weights for Layer 2
    Whh2 = rnn_model.layers[2].get_weights()[1]  # Hidden-to-hidden weights for Layer 2

    # compute spectral norms (largest singular values) for each weight matrix
    _, _, spectral_norm_Wxh1 = spectral_normalization(Wxh1, None)
    _, _, spectral_norm_Whh1 = spectral_normalization(Whh1, None)
    _, _, spectral_norm_Wxh2 = spectral_normalization(Wxh2, None)
    _, _, spectral_norm_Whh2 = spectral_normalization(Whh2,None)

    # the Lipschitz constant is the maximum of the spectral norms
    lipschitz_constant = spectral_norm_Wxh1 * spectral_norm_Wxh2 * (spectral_norm_Whh1 ** num_step) * (spectral_norm_Whh2 ** num_step)

    return lipschitz_constant.numpy()

# %%
def evaluate_lip_const(model: Model, x, eps, seed=None):
    """
    Evaluate the Lipschitz constant of a model, with the naive method.
    Please note that the estimation of the lipschitz constant is done locally around
    input sample. This may not correctly estimate the behaviour in the whole domain.

    Args:
        model: built keras model used to make predictions
        x: inputs used to compute the lipschitz constant
        eps (float): magnitude of noise to add to input in order to compute the constant
        seed (int): seed used when generating the noise ( can be set to None )

    Returns:
        float: the empirically evaluated lipschitz constant. The computation might also
            be inaccurate in high dimensional space.

    """
    y_pred = model.predict(x)
    x_var = x + K.random_uniform(
        shape=x.shape, minval=eps * 0.25, maxval=eps, seed=seed
    )
#     x_var = x + K.random_normal(
#         shape=x.shape, mean=0, stddev=eps, seed=seed
#     )
    y_pred_var = model.predict(x_var)
    dx = x - x_var
    dfx = y_pred - y_pred_var
    ndx = K.sqrt(K.sum(K.square(dx), axis=range(1, len(x.shape))))
    ndfx = K.sqrt(K.sum(K.square(dfx), axis=range(1, len(y_pred.shape))))
    lip_cst = K.max(ndfx / ndx)
    print(f"lip cst: {lip_cst:.3f}")
    return lip_cst

# %%
# set the seed for reproducibility
tf.random.set_seed(42)

num_step = 5
training_loss = [0]*19
test_loss = [0]*19
lip = [0]*19
noise = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]

for i in range(19):
    num_dims = 4

    # split into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(RNN_input, RNN_output, test_size=0.3, random_state=123)

    # define scalers for both X and y base on training data only
    scaler_X = preprocessing.MinMaxScaler().fit(X_train.reshape(-1, num_dims))
    scaler_y = preprocessing.MinMaxScaler().fit(y_train.reshape(-1, 2))

    X_train = scaler_X.transform(X_train.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
    X_test = scaler_X.transform(X_test.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
    y_train = scaler_y.transform(y_train.reshape(-1,2)).reshape(-1,num_step,2)
    y_test_normalized = scaler_y.transform(y_test.reshape(-1,2)).reshape(-1,num_step,2)

    # X is just the initial condition, so we introduce noise to the output trajectory y
    y_train = y_train + np.random.normal(0, noise[i], y_train.shape)

    nh = 64
    constraint = SpectralConstraint()
    input = Input(shape=(X_train.shape[1],X_train.shape[2]))

    # ICLRNN
    x = SimpleRNN(nh,
          activation='relu',
          kernel_initializer=initializers.RandomNormal(mean=0.0, stddev=0.01),
          recurrent_initializer=initializers.Orthogonal(0.1),
          return_sequences=True,
          kernel_constraint=constraint,
          recurrent_constraint=constraint
          )(input)
    x = SimpleRNN(nh,
          activation='relu',
          kernel_initializer=initializers.RandomNormal(mean=0.0, stddev=0.01),
          recurrent_initializer=initializers.Orthogonal(0.1),
          return_sequences=True,
          kernel_constraint=constraint,
          recurrent_constraint=constraint
          )(x)
    x = Dense(2,
            activation='relu',
            kernel_constraint=constraint
            )(x)

    model = Model(input, x)

    model.compile(optimizer='adam', loss='mean_squared_error', metrics=[tf.keras.metrics.MeanSquaredError()])
    history = model.fit(X_train, y_train, epochs=1000, batch_size=256, validation_split=0.25, verbose=2)

    training_loss[i] = history.history['val_loss'][-1]
    print(noise)
    print(training_loss)

    loss = model.evaluate(X_test, y_test_normalized, batch_size=256)
    test_loss[i] = loss[0]
    print(test_loss)

    # check convexity by checking the weights
    check_non_negative_weights_ignore_bias(model)

    # compute the Lipschitz constant for the 2-layer RNN
    lipschitz_constant = evaluate_lip_const(model, X_train, 1e-04, 42)
    print(f"Estimated Lipschitz constant of the 2-layer RNN: {lipschitz_constant}")

    lip[i] = lipschitz_constant

model.summary()
# Out:
# Epoch 1/1000
# 9/9 - 3s - loss: 6.4882 - mean_squared_error: 6.4882 - val_loss: 5.8559 - val_mean_squared_error: 5.8559 - 3s/epoch - 335ms/step
# Epoch 2/1000
# 9/9 - 0s - loss: 4.9011 - mean_squared_error: 4.9011 - val_loss: 3.5724 - val_mean_squared_error: 3.5724 - 85ms/epoch - 9ms/step
# Epoch 3/1000
# 9/9 - 0s - loss: 2.9173 - mean_squared_error: 2.9173 - val_loss: 2.0431 - val_mean_squared_error: 2.0431 - 83ms/epoch - 9ms/step
# Epoch 4/1000
# 9/9 - 0s - loss: 1.6418 - mean_squared_error: 1.6418 - val_loss: 1.1219 - val_mean_squared_error: 1.1219 - 84ms/epoch - 9ms/step
# Epoch 5/1000
# 9/9 - 0s - loss: 0.9016 - mean_squared_error: 0.9016 - val_loss: 0.6223 - val_mean_squared_error: 0.6223 - 85ms/epoch - 9ms/step
# Epoch 6/1000
# 9/9 - 0s - loss: 0.5111 - mean_squared_error: 0.5111 - val_loss: 0.3705 - val_mean_squared_error: 0.3705 - 94ms/epoch - 10ms/step
# Epoch 7/1000
# 9/9 - 0s - loss: 0.3161 - mean_squared_error: 0.3161 - val_loss: 0.2461 - val_mean_squared_error: 0.2461 - 91ms/epoch - 10ms/step
# Epoch 8/1000
# 9/9 - 0s - loss: 0.2189 - mean_squared_error: 0.2189 - val_loss: 0.1846 - val_mean_squared_error: 0.1846 - 91ms/epoch - 10ms/step
# Epoch 9/1000
# 9/9 - 0s - loss: 0.1705 - mean_squared_error: 0.1705 - val_loss: 0.1539 - val_mean_squared_error: 0.1539 - 85ms/epoch - 9ms/step
# Epoch 10/1000
# 9/9 - 0s - loss: 0.1459 - mean_squared_error: 0.1459 - val_loss: 0.1380 - val_mean_squared_error: 0.1380 - 83ms/epoch - 9ms/step
# Epoch 11/1000
# 9/9 - 0s - loss: 0.1329 - mean_squared_error: 0.1329 - val_loss: 0.1294 - val_mean_squared_error: 0.1294 - 81ms/epoch - 9ms/step
# Epoch 12/1000
# 9/9 - 0s - loss: 0.1256 - mean_squared_error: 0.1256 - val_loss: 0.1244 - val_mean_squared_error: 0.1244 - 77ms/epoch - 9ms/step
# Epoch 13/1000
# 9/9 - 0s - loss: 0.1212 - mean_squared_error: 0.1212 - val_loss: 0.1212 - val_mean_squared_error: 0.1212 - 92ms/epoch - 10ms/step
# Epoch 14/1000
# 9/9 - 0s - loss: 0.1183 - mean_squared_error: 0.1183 - val_loss: 0.1188 - val_mean_squared_error: 0.1188 - 84ms/epoch - 9ms/step
# Epoch 15/1000
# 9/9 - 0s - loss: 0.1160 - mean_squared_error: 0.1160 - val_loss: 0.1168 - val_mean_squared_error: 0.1168 - 85ms/epoch - 9ms/step
# Epoch 16/1000
# 9/9 - 0s - loss: 0.1141 - mean_squared_error: 0.1141 - val_loss: 0.1150 - val_mean_squared_error: 0.1150 - 83ms/epoch - 9ms/step
# Epoch 17/1000
# 9/9 - 0s - loss: 0.1123 - mean_squared_error: 0.1123 - val_loss: 0.1132 - val_mean_squared_error: 0.1132 - 83ms/epoch - 9ms/step
# Epoch 18/1000
# 9/9 - 0s - loss: 0.1105 - mean_squared_error: 0.1105 - val_loss: 0.1114 - val_mean_squared_error: 0.1114 - 92ms/epoch - 10ms/step
# Epoch 19/1000
# 9/9 - 0s - loss: 0.1087 - mean_squared_error: 0.1087 - val_loss: 0.1095 - val_mean_squared_error: 0.1095 - 81ms/epoch - 9ms/step
# Epoch 20/1000
# 9/9 - 0s - loss: 0.1068 - mean_squared_error: 0.1068 - val_loss: 0.1076 - val_mean_squared_error: 0.1076 - 71ms/epoch - 8ms/step
# Epoch 21/1000
# 9/9 - 0s - loss: 0.1049 - mean_squared_error: 0.1049 - val_loss: 0.1055 - val_mean_squared_error: 0.1055 - 74ms/epoch - 8ms/step
# Epoch 22/1000
# 9/9 - 0s - loss: 0.1028 - mean_squared_error: 0.1028 - val_loss: 0.1034 - val_mean_squared_error: 0.1034 - 80ms/epoch - 9ms/step
# Epoch 23/1000
# 9/9 - 0s - loss: 0.1008 - mean_squared_error: 0.1008 - val_loss: 0.1012 - val_mean_squared_error: 0.1012 - 86ms/epoch - 10ms/step
# Epoch 24/1000
# 9/9 - 0s - loss: 0.0986 - mean_squared_error: 0.0986 - val_loss: 0.0990 - val_mean_squared_error: 0.0990 - 85ms/epoch - 9ms/step
# Epoch 25/1000
# 9/9 - 0s - loss: 0.0965 - mean_squared_error: 0.0965 - val_loss: 0.0968 - val_mean_squared_error: 0.0968 - 88ms/epoch - 10ms/step
# Epoch 26/1000
# 9/9 - 0s - loss: 0.0943 - mean_squared_error: 0.0943 - val_loss: 0.0946 - val_mean_squared_error: 0.0946 - 77ms/epoch - 9ms/step
# Epoch 27/1000
# 9/9 - 0s - loss: 0.0922 - mean_squared_error: 0.0922 - val_loss: 0.0924 - val_mean_squared_error: 0.0924 - 87ms/epoch - 10ms/step
# Epoch 28/1000
# 9/9 - 0s - loss: 0.0901 - mean_squared_error: 0.0901 - val_loss: 0.0903 - val_mean_squared_error: 0.0903 - 82ms/epoch - 9ms/step
# Epoch 29/1000
# 9/9 - 0s - loss: 0.0880 - mean_squared_error: 0.0880 - val_loss: 0.0882 - val_mean_squared_error: 0.0882 - 90ms/epoch - 10ms/step
# Epoch 30/1000
# 9/9 - 0s - loss: 0.0860 - mean_squared_error: 0.0860 - val_loss: 0.0861 - val_mean_squared_error: 0.0861 - 88ms/epoch - 10ms/step
# Epoch 31/1000
# 9/9 - 0s - loss: 0.0839 - mean_squared_error: 0.0839 - val_loss: 0.0840 - val_mean_squared_error: 0.0840 - 79ms/epoch - 9ms/step
# Epoch 32/1000
# 9/9 - 0s - loss: 0.0819 - mean_squared_error: 0.0819 - val_loss: 0.0820 - val_mean_squared_error: 0.0820 - 79ms/epoch - 9ms/step
# Epoch 33/1000
# 9/9 - 0s - loss: 0.0799 - mean_squared_error: 0.0799 - val_loss: 0.0800 - val_mean_squared_error: 0.0800 - 88ms/epoch - 10ms/step
# Epoch 34/1000
# 9/9 - 0s - loss: 0.0780 - mean_squared_error: 0.0780 - val_loss: 0.0780 - val_mean_squared_error: 0.0780 - 82ms/epoch - 9ms/step
# Epoch 35/1000
# 9/9 - 0s - loss: 0.0761 - mean_squared_error: 0.0761 - val_loss: 0.0762 - val_mean_squared_error: 0.0762 - 83ms/epoch - 9ms/step
# Epoch 36/1000
# 9/9 - 0s - loss: 0.0743 - mean_squared_error: 0.0743 - val_loss: 0.0743 - val_mean_squared_error: 0.0743 - 82ms/epoch - 9ms/step
# Epoch 37/1000
# 9/9 - 0s - loss: 0.0725 - mean_squared_error: 0.0725 - val_loss: 0.0725 - val_mean_squared_error: 0.0725 - 81ms/epoch - 9ms/step
# Epoch 38/1000
# 9/9 - 0s - loss: 0.0707 - mean_squared_error: 0.0707 - val_loss: 0.0708 - val_mean_squared_error: 0.0708 - 73ms/epoch - 8ms/step
# Epoch 39/1000
# 9/9 - 0s - loss: 0.0690 - mean_squared_error: 0.0690 - val_loss: 0.0691 - val_mean_squared_error: 0.0691 - 84ms/epoch - 9ms/step
# Epoch 40/1000
# 9/9 - 0s - loss: 0.0674 - mean_squared_error: 0.0674 - val_loss: 0.0674 - val_mean_squared_error: 0.0674 - 83ms/epoch - 9ms/step
# Epoch 41/1000
# 9/9 - 0s - loss: 0.0658 - mean_squared_error: 0.0658 - val_loss: 0.0659 - val_mean_squared_error: 0.0659 - 83ms/epoch - 9ms/step
# Epoch 42/1000
# 9/9 - 0s - loss: 0.0643 - mean_squared_error: 0.0643 - val_loss: 0.0643 - val_mean_squared_error: 0.0643 - 83ms/epoch - 9ms/step
# Epoch 43/1000
# 9/9 - 0s - loss: 0.0628 - mean_squared_error: 0.0628 - val_loss: 0.0628 - val_mean_squared_error: 0.0628 - 83ms/epoch - 9ms/step
# Epoch 44/1000
# 9/9 - 0s - loss: 0.0613 - mean_squared_error: 0.0613 - val_loss: 0.0614 - val_mean_squared_error: 0.0614 - 83ms/epoch - 9ms/step
# Epoch 45/1000
# 9/9 - 0s - loss: 0.0599 - mean_squared_error: 0.0599 - val_loss: 0.0600 - val_mean_squared_error: 0.0600 - 84ms/epoch - 9ms/step
# Epoch 46/1000
# 9/9 - 0s - loss: 0.0585 - mean_squared_error: 0.0585 - val_loss: 0.0586 - val_mean_squared_error: 0.0586 - 91ms/epoch - 10ms/step
# Epoch 47/1000
# 9/9 - 0s - loss: 0.0571 - mean_squared_error: 0.0571 - val_loss: 0.0573 - val_mean_squared_error: 0.0573 - 81ms/epoch - 9ms/step
# Epoch 48/1000
# 9/9 - 0s - loss: 0.0559 - mean_squared_error: 0.0559 - val_loss: 0.0560 - val_mean_squared_error: 0.0560 - 76ms/epoch - 8ms/step
# Epoch 49/1000
# 9/9 - 0s - loss: 0.0546 - mean_squared_error: 0.0546 - val_loss: 0.0547 - val_mean_squared_error: 0.0547 - 80ms/epoch - 9ms/step
# Epoch 50/1000
# 9/9 - 0s - loss: 0.0534 - mean_squared_error: 0.0534 - val_loss: 0.0535 - val_mean_squared_error: 0.0535 - 85ms/epoch - 9ms/step
# Epoch 51/1000
# 9/9 - 0s - loss: 0.0522 - mean_squared_error: 0.0522 - val_loss: 0.0524 - val_mean_squared_error: 0.0524 - 80ms/epoch - 9ms/step
# Epoch 52/1000
# 9/9 - 0s - loss: 0.0511 - mean_squared_error: 0.0511 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - 89ms/epoch - 10ms/step
# Epoch 53/1000
# 9/9 - 0s - loss: 0.0500 - mean_squared_error: 0.0500 - val_loss: 0.0502 - val_mean_squared_error: 0.0502 - 84ms/epoch - 9ms/step
# Epoch 54/1000
# 9/9 - 0s - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0492 - val_mean_squared_error: 0.0492 - 88ms/epoch - 10ms/step
# Epoch 55/1000
# 9/9 - 0s - loss: 0.0480 - mean_squared_error: 0.0480 - val_loss: 0.0482 - val_mean_squared_error: 0.0482 - 81ms/epoch - 9ms/step
# Epoch 56/1000
# 9/9 - 0s - loss: 0.0470 - mean_squared_error: 0.0470 - val_loss: 0.0472 - val_mean_squared_error: 0.0472 - 84ms/epoch - 9ms/step
# Epoch 57/1000
# 9/9 - 0s - loss: 0.0461 - mean_squared_error: 0.0461 - val_loss: 0.0463 - val_mean_squared_error: 0.0463 - 87ms/epoch - 10ms/step
# Epoch 58/1000
# 9/9 - 0s - loss: 0.0452 - mean_squared_error: 0.0452 - val_loss: 0.0454 - val_mean_squared_error: 0.0454 - 83ms/epoch - 9ms/step
# Epoch 59/1000
# 9/9 - 0s - loss: 0.0443 - mean_squared_error: 0.0443 - val_loss: 0.0445 - val_mean_squared_error: 0.0445 - 88ms/epoch - 10ms/step
# Epoch 60/1000
# 9/9 - 0s - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0437 - val_mean_squared_error: 0.0437 - 94ms/epoch - 10ms/step
# Epoch 61/1000
# 9/9 - 0s - loss: 0.0426 - mean_squared_error: 0.0426 - val_loss: 0.0429 - val_mean_squared_error: 0.0429 - 85ms/epoch - 9ms/step
# Epoch 62/1000
# 9/9 - 0s - loss: 0.0419 - mean_squared_error: 0.0419 - val_loss: 0.0421 - val_mean_squared_error: 0.0421 - 81ms/epoch - 9ms/step
# Epoch 63/1000
# 9/9 - 0s - loss: 0.0411 - mean_squared_error: 0.0411 - val_loss: 0.0414 - val_mean_squared_error: 0.0414 - 97ms/epoch - 11ms/step
# Epoch 64/1000
# 9/9 - 0s - loss: 0.0404 - mean_squared_error: 0.0404 - val_loss: 0.0407 - val_mean_squared_error: 0.0407 - 81ms/epoch - 9ms/step
# Epoch 65/1000
# 9/9 - 0s - loss: 0.0397 - mean_squared_error: 0.0397 - val_loss: 0.0400 - val_mean_squared_error: 0.0400 - 85ms/epoch - 9ms/step
# Epoch 66/1000
# 9/9 - 0s - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0394 - val_mean_squared_error: 0.0394 - 89ms/epoch - 10ms/step
# Epoch 67/1000
# 9/9 - 0s - loss: 0.0384 - mean_squared_error: 0.0384 - val_loss: 0.0388 - val_mean_squared_error: 0.0388 - 73ms/epoch - 8ms/step
# Epoch 68/1000
# 9/9 - 0s - loss: 0.0378 - mean_squared_error: 0.0378 - val_loss: 0.0382 - val_mean_squared_error: 0.0382 - 97ms/epoch - 11ms/step
# Epoch 69/1000
# 9/9 - 0s - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0376 - val_mean_squared_error: 0.0376 - 84ms/epoch - 9ms/step
# Epoch 70/1000
# 9/9 - 0s - loss: 0.0367 - mean_squared_error: 0.0367 - val_loss: 0.0370 - val_mean_squared_error: 0.0370 - 83ms/epoch - 9ms/step
# Epoch 71/1000
# 9/9 - 0s - loss: 0.0361 - mean_squared_error: 0.0361 - val_loss: 0.0365 - val_mean_squared_error: 0.0365 - 83ms/epoch - 9ms/step
# Epoch 72/1000
# 9/9 - 0s - loss: 0.0356 - mean_squared_error: 0.0356 - val_loss: 0.0360 - val_mean_squared_error: 0.0360 - 101ms/epoch - 11ms/step
# Epoch 73/1000
# 9/9 - 0s - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0355 - val_mean_squared_error: 0.0355 - 78ms/epoch - 9ms/step
# Epoch 74/1000
# 9/9 - 0s - loss: 0.0346 - mean_squared_error: 0.0346 - val_loss: 0.0350 - val_mean_squared_error: 0.0350 - 94ms/epoch - 10ms/step
# Epoch 75/1000
# 9/9 - 0s - loss: 0.0341 - mean_squared_error: 0.0341 - val_loss: 0.0346 - val_mean_squared_error: 0.0346 - 78ms/epoch - 9ms/step
# Epoch 76/1000
# 9/9 - 0s - loss: 0.0337 - mean_squared_error: 0.0337 - val_loss: 0.0341 - val_mean_squared_error: 0.0341 - 78ms/epoch - 9ms/step
# Epoch 77/1000
# 9/9 - 0s - loss: 0.0333 - mean_squared_error: 0.0333 - val_loss: 0.0337 - val_mean_squared_error: 0.0337 - 78ms/epoch - 9ms/step
# Epoch 78/1000
# 9/9 - 0s - loss: 0.0329 - mean_squared_error: 0.0329 - val_loss: 0.0333 - val_mean_squared_error: 0.0333 - 94ms/epoch - 10ms/step
# Epoch 79/1000
# 9/9 - 0s - loss: 0.0325 - mean_squared_error: 0.0325 - val_loss: 0.0329 - val_mean_squared_error: 0.0329 - 91ms/epoch - 10ms/step
# Epoch 80/1000
# 9/9 - 0s - loss: 0.0321 - mean_squared_error: 0.0321 - val_loss: 0.0325 - val_mean_squared_error: 0.0325 - 80ms/epoch - 9ms/step
# Epoch 81/1000
# 9/9 - 0s - loss: 0.0317 - mean_squared_error: 0.0317 - val_loss: 0.0321 - val_mean_squared_error: 0.0321 - 81ms/epoch - 9ms/step
# Epoch 82/1000
# 9/9 - 0s - loss: 0.0313 - mean_squared_error: 0.0313 - val_loss: 0.0318 - val_mean_squared_error: 0.0318 - 75ms/epoch - 8ms/step
# Epoch 83/1000
# 9/9 - 0s - loss: 0.0310 - mean_squared_error: 0.0310 - val_loss: 0.0314 - val_mean_squared_error: 0.0314 - 96ms/epoch - 11ms/step
# Epoch 84/1000
# 9/9 - 0s - loss: 0.0307 - mean_squared_error: 0.0307 - val_loss: 0.0311 - val_mean_squared_error: 0.0311 - 78ms/epoch - 9ms/step
# Epoch 85/1000
# 9/9 - 0s - loss: 0.0303 - mean_squared_error: 0.0303 - val_loss: 0.0308 - val_mean_squared_error: 0.0308 - 90ms/epoch - 10ms/step
# Epoch 86/1000
# 9/9 - 0s - loss: 0.0300 - mean_squared_error: 0.0300 - val_loss: 0.0305 - val_mean_squared_error: 0.0305 - 99ms/epoch - 11ms/step
# Epoch 87/1000
# 9/9 - 0s - loss: 0.0297 - mean_squared_error: 0.0297 - val_loss: 0.0302 - val_mean_squared_error: 0.0302 - 83ms/epoch - 9ms/step
# Epoch 88/1000
# 9/9 - 0s - loss: 0.0294 - mean_squared_error: 0.0294 - val_loss: 0.0299 - val_mean_squared_error: 0.0299 - 94ms/epoch - 10ms/step
# Epoch 89/1000
# 9/9 - 0s - loss: 0.0291 - mean_squared_error: 0.0291 - val_loss: 0.0296 - val_mean_squared_error: 0.0296 - 80ms/epoch - 9ms/step
# Epoch 90/1000
# 9/9 - 0s - loss: 0.0289 - mean_squared_error: 0.0289 - val_loss: 0.0293 - val_mean_squared_error: 0.0293 - 94ms/epoch - 10ms/step
# Epoch 91/1000
# 9/9 - 0s - loss: 0.0286 - mean_squared_error: 0.0286 - val_loss: 0.0290 - val_mean_squared_error: 0.0290 - 74ms/epoch - 8ms/step
# Epoch 92/1000
# 9/9 - 0s - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.0288 - val_mean_squared_error: 0.0288 - 91ms/epoch - 10ms/step
# Epoch 93/1000
# 9/9 - 0s - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0285 - val_mean_squared_error: 0.0285 - 81ms/epoch - 9ms/step
# Epoch 94/1000
# 9/9 - 0s - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - 74ms/epoch - 8ms/step
# Epoch 95/1000
# 9/9 - 0s - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - 80ms/epoch - 9ms/step
# Epoch 96/1000
# 9/9 - 0s - loss: 0.0273 - mean_squared_error: 0.0273 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - 73ms/epoch - 8ms/step
# Epoch 97/1000
# 9/9 - 0s - loss: 0.0271 - mean_squared_error: 0.0271 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - 93ms/epoch - 10ms/step
# Epoch 98/1000
# 9/9 - 0s - loss: 0.0269 - mean_squared_error: 0.0269 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - 86ms/epoch - 10ms/step
# Epoch 99/1000
# 9/9 - 0s - loss: 0.0266 - mean_squared_error: 0.0266 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - 83ms/epoch - 9ms/step
# Epoch 100/1000
# 9/9 - 0s - loss: 0.0264 - mean_squared_error: 0.0264 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - 83ms/epoch - 9ms/step
# Epoch 101/1000
# 9/9 - 0s - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - 83ms/epoch - 9ms/step
# Epoch 102/1000
# 9/9 - 0s - loss: 0.0260 - mean_squared_error: 0.0260 - val_loss: 0.0265 - val_mean_squared_error: 0.0265 - 83ms/epoch - 9ms/step
# Epoch 103/1000
# 9/9 - 0s - loss: 0.0258 - mean_squared_error: 0.0258 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - 91ms/epoch - 10ms/step
# Epoch 104/1000
# 9/9 - 0s - loss: 0.0256 - mean_squared_error: 0.0256 - val_loss: 0.0261 - val_mean_squared_error: 0.0261 - 88ms/epoch - 10ms/step
# Epoch 105/1000
# 9/9 - 0s - loss: 0.0254 - mean_squared_error: 0.0254 - val_loss: 0.0259 - val_mean_squared_error: 0.0259 - 83ms/epoch - 9ms/step
# Epoch 106/1000
# 9/9 - 0s - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - 93ms/epoch - 10ms/step
# Epoch 107/1000
# 9/9 - 0s - loss: 0.0250 - mean_squared_error: 0.0250 - val_loss: 0.0255 - val_mean_squared_error: 0.0255 - 85ms/epoch - 9ms/step
# Epoch 108/1000
# 9/9 - 0s - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.0253 - val_mean_squared_error: 0.0253 - 87ms/epoch - 10ms/step
# Epoch 109/1000
# 9/9 - 0s - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0251 - val_mean_squared_error: 0.0251 - 97ms/epoch - 11ms/step
# Epoch 110/1000
# 9/9 - 0s - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0249 - val_mean_squared_error: 0.0249 - 79ms/epoch - 9ms/step
# Epoch 111/1000
# 9/9 - 0s - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0248 - val_mean_squared_error: 0.0248 - 96ms/epoch - 11ms/step
# Epoch 112/1000
# 9/9 - 0s - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0246 - val_mean_squared_error: 0.0246 - 90ms/epoch - 10ms/step
# Epoch 113/1000
# 9/9 - 0s - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0244 - val_mean_squared_error: 0.0244 - 81ms/epoch - 9ms/step
# Epoch 114/1000
# 9/9 - 0s - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0242 - val_mean_squared_error: 0.0242 - 87ms/epoch - 10ms/step
# Epoch 115/1000
# 9/9 - 0s - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0241 - val_mean_squared_error: 0.0241 - 86ms/epoch - 10ms/step
# Epoch 116/1000
# 9/9 - 0s - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0239 - val_mean_squared_error: 0.0239 - 78ms/epoch - 9ms/step
# Epoch 117/1000
# 9/9 - 0s - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0237 - val_mean_squared_error: 0.0237 - 102ms/epoch - 11ms/step
# Epoch 118/1000
# 9/9 - 0s - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0236 - val_mean_squared_error: 0.0236 - 87ms/epoch - 10ms/step
# Epoch 119/1000
# 9/9 - 0s - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0234 - val_mean_squared_error: 0.0234 - 89ms/epoch - 10ms/step
# Epoch 120/1000
# 9/9 - 0s - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0233 - val_mean_squared_error: 0.0233 - 93ms/epoch - 10ms/step
# Epoch 121/1000
# 9/9 - 0s - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0231 - val_mean_squared_error: 0.0231 - 84ms/epoch - 9ms/step
# Epoch 122/1000
# 9/9 - 0s - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0230 - val_mean_squared_error: 0.0230 - 86ms/epoch - 10ms/step
# Epoch 123/1000
# 9/9 - 0s - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0228 - val_mean_squared_error: 0.0228 - 88ms/epoch - 10ms/step
# Epoch 124/1000
# 9/9 - 0s - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0227 - val_mean_squared_error: 0.0227 - 84ms/epoch - 9ms/step
# Epoch 125/1000
# 9/9 - 0s - loss: 0.0220 - mean_squared_error: 0.0220 - val_loss: 0.0225 - val_mean_squared_error: 0.0225 - 74ms/epoch - 8ms/step
# Epoch 126/1000
# 9/9 - 0s - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.0224 - val_mean_squared_error: 0.0224 - 84ms/epoch - 9ms/step
# Epoch 127/1000
# 9/9 - 0s - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0223 - val_mean_squared_error: 0.0223 - 92ms/epoch - 10ms/step
# Epoch 128/1000
# 9/9 - 0s - loss: 0.0216 - mean_squared_error: 0.0216 - val_loss: 0.0221 - val_mean_squared_error: 0.0221 - 89ms/epoch - 10ms/step
# Epoch 129/1000
# 9/9 - 0s - loss: 0.0215 - mean_squared_error: 0.0215 - val_loss: 0.0220 - val_mean_squared_error: 0.0220 - 82ms/epoch - 9ms/step
# Epoch 130/1000
# 9/9 - 0s - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.0219 - val_mean_squared_error: 0.0219 - 91ms/epoch - 10ms/step
# Epoch 131/1000
# 9/9 - 0s - loss: 0.0212 - mean_squared_error: 0.0212 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - 71ms/epoch - 8ms/step
# Epoch 132/1000
# 9/9 - 0s - loss: 0.0211 - mean_squared_error: 0.0211 - val_loss: 0.0216 - val_mean_squared_error: 0.0216 - 93ms/epoch - 10ms/step
# Epoch 133/1000
# 9/9 - 0s - loss: 0.0210 - mean_squared_error: 0.0210 - val_loss: 0.0215 - val_mean_squared_error: 0.0215 - 87ms/epoch - 10ms/step
# Epoch 134/1000
# 9/9 - 0s - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - 83ms/epoch - 9ms/step
# Epoch 135/1000
# 9/9 - 0s - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - 88ms/epoch - 10ms/step
# Epoch 136/1000
# 9/9 - 0s - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - 82ms/epoch - 9ms/step
# Epoch 137/1000
# 9/9 - 0s - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - 75ms/epoch - 8ms/step
# Epoch 138/1000
# 9/9 - 0s - loss: 0.0204 - mean_squared_error: 0.0204 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - 102ms/epoch - 11ms/step
# Epoch 139/1000
# 9/9 - 0s - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - 86ms/epoch - 10ms/step
# Epoch 140/1000
# 9/9 - 0s - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - 85ms/epoch - 9ms/step
# Epoch 141/1000
# 9/9 - 0s - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - 68ms/epoch - 8ms/step
# Epoch 142/1000
# 9/9 - 0s - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - 94ms/epoch - 10ms/step
# Epoch 143/1000
# 9/9 - 0s - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - 85ms/epoch - 9ms/step
# Epoch 144/1000
# 9/9 - 0s - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0201 - val_mean_squared_error: 0.0201 - 100ms/epoch - 11ms/step
# Epoch 145/1000
# 9/9 - 0s - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0200 - val_mean_squared_error: 0.0200 - 91ms/epoch - 10ms/step
# Epoch 146/1000
# 9/9 - 0s - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0199 - val_mean_squared_error: 0.0199 - 86ms/epoch - 10ms/step
# Epoch 147/1000
# 9/9 - 0s - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0198 - val_mean_squared_error: 0.0198 - 77ms/epoch - 9ms/step
# Epoch 148/1000
# 9/9 - 0s - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0197 - val_mean_squared_error: 0.0197 - 91ms/epoch - 10ms/step
# Epoch 149/1000
# 9/9 - 0s - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0196 - val_mean_squared_error: 0.0196 - 95ms/epoch - 11ms/step
# Epoch 150/1000
# 9/9 - 0s - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0195 - val_mean_squared_error: 0.0195 - 98ms/epoch - 11ms/step
# Epoch 151/1000
# 9/9 - 0s - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0194 - val_mean_squared_error: 0.0194 - 97ms/epoch - 11ms/step
# Epoch 152/1000
# 9/9 - 0s - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0193 - val_mean_squared_error: 0.0193 - 92ms/epoch - 10ms/step
# Epoch 153/1000
# 9/9 - 0s - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0192 - val_mean_squared_error: 0.0192 - 108ms/epoch - 12ms/step
# Epoch 154/1000
# 9/9 - 0s - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0191 - val_mean_squared_error: 0.0191 - 101ms/epoch - 11ms/step
# Epoch 155/1000
# 9/9 - 0s - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0191 - val_mean_squared_error: 0.0191 - 94ms/epoch - 10ms/step
# Epoch 156/1000
# 9/9 - 0s - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0190 - val_mean_squared_error: 0.0190 - 89ms/epoch - 10ms/step
# Epoch 157/1000
# 9/9 - 0s - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0189 - val_mean_squared_error: 0.0189 - 89ms/epoch - 10ms/step
# Epoch 158/1000
# 9/9 - 0s - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0188 - val_mean_squared_error: 0.0188 - 82ms/epoch - 9ms/step
# Epoch 159/1000
# 9/9 - 0s - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0187 - val_mean_squared_error: 0.0187 - 93ms/epoch - 10ms/step
# Epoch 160/1000
# 9/9 - 0s - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0186 - val_mean_squared_error: 0.0186 - 79ms/epoch - 9ms/step
# Epoch 161/1000
# 9/9 - 0s - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0185 - val_mean_squared_error: 0.0185 - 83ms/epoch - 9ms/step
# Epoch 162/1000
# 9/9 - 0s - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0184 - val_mean_squared_error: 0.0184 - 80ms/epoch - 9ms/step
# Epoch 163/1000
# 9/9 - 0s - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0183 - val_mean_squared_error: 0.0183 - 97ms/epoch - 11ms/step
# Epoch 164/1000
# 9/9 - 0s - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0182 - val_mean_squared_error: 0.0182 - 87ms/epoch - 10ms/step
# Epoch 165/1000
# 9/9 - 0s - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0182 - val_mean_squared_error: 0.0182 - 100ms/epoch - 11ms/step
# Epoch 166/1000
# 9/9 - 0s - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0181 - val_mean_squared_error: 0.0181 - 90ms/epoch - 10ms/step
# Epoch 167/1000
# 9/9 - 0s - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0180 - val_mean_squared_error: 0.0180 - 88ms/epoch - 10ms/step
# Epoch 168/1000
# 9/9 - 0s - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0179 - val_mean_squared_error: 0.0179 - 83ms/epoch - 9ms/step
# Epoch 169/1000
# 9/9 - 0s - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0178 - val_mean_squared_error: 0.0178 - 85ms/epoch - 9ms/step
# Epoch 170/1000
# 9/9 - 0s - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0178 - val_mean_squared_error: 0.0178 - 89ms/epoch - 10ms/step
# Epoch 171/1000
# 9/9 - 0s - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0177 - val_mean_squared_error: 0.0177 - 91ms/epoch - 10ms/step
# Epoch 172/1000
# 9/9 - 0s - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0176 - val_mean_squared_error: 0.0176 - 85ms/epoch - 9ms/step
# Epoch 173/1000
# 9/9 - 0s - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0175 - val_mean_squared_error: 0.0175 - 95ms/epoch - 11ms/step
# Epoch 174/1000
# 9/9 - 0s - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0175 - val_mean_squared_error: 0.0175 - 91ms/epoch - 10ms/step
# Epoch 175/1000
# 9/9 - 0s - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0174 - val_mean_squared_error: 0.0174 - 94ms/epoch - 10ms/step
# Epoch 176/1000
# 9/9 - 0s - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0173 - val_mean_squared_error: 0.0173 - 96ms/epoch - 11ms/step
# Epoch 177/1000
# 9/9 - 0s - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0172 - val_mean_squared_error: 0.0172 - 94ms/epoch - 10ms/step
# Epoch 178/1000
# 9/9 - 0s - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0172 - val_mean_squared_error: 0.0172 - 103ms/epoch - 11ms/step
# Epoch 179/1000
# 9/9 - 0s - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0171 - val_mean_squared_error: 0.0171 - 83ms/epoch - 9ms/step
# Epoch 180/1000
# 9/9 - 0s - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0170 - val_mean_squared_error: 0.0170 - 94ms/epoch - 10ms/step
# Epoch 181/1000
# 9/9 - 0s - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0170 - val_mean_squared_error: 0.0170 - 97ms/epoch - 11ms/step
# Epoch 182/1000
# 9/9 - 0s - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0169 - val_mean_squared_error: 0.0169 - 84ms/epoch - 9ms/step
# Epoch 183/1000
# 9/9 - 0s - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0169 - val_mean_squared_error: 0.0169 - 95ms/epoch - 11ms/step
# Epoch 184/1000
# 9/9 - 0s - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0168 - val_mean_squared_error: 0.0168 - 94ms/epoch - 10ms/step
# Epoch 185/1000
# 9/9 - 0s - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0167 - val_mean_squared_error: 0.0167 - 73ms/epoch - 8ms/step
# Epoch 186/1000
# 9/9 - 0s - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0167 - val_mean_squared_error: 0.0167 - 102ms/epoch - 11ms/step
# Epoch 187/1000
# 9/9 - 0s - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0166 - val_mean_squared_error: 0.0166 - 96ms/epoch - 11ms/step
# Epoch 188/1000
# 9/9 - 0s - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0166 - val_mean_squared_error: 0.0166 - 95ms/epoch - 11ms/step
# Epoch 189/1000
# 9/9 - 0s - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0165 - val_mean_squared_error: 0.0165 - 85ms/epoch - 9ms/step
# Epoch 190/1000
# 9/9 - 0s - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0164 - val_mean_squared_error: 0.0164 - 86ms/epoch - 10ms/step
# Epoch 191/1000
# 9/9 - 0s - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0164 - val_mean_squared_error: 0.0164 - 93ms/epoch - 10ms/step
# Epoch 192/1000
# 9/9 - 0s - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0163 - val_mean_squared_error: 0.0163 - 94ms/epoch - 10ms/step
# Epoch 193/1000
# 9/9 - 0s - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0163 - val_mean_squared_error: 0.0163 - 89ms/epoch - 10ms/step
# Epoch 194/1000
# 9/9 - 0s - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0162 - val_mean_squared_error: 0.0162 - 77ms/epoch - 9ms/step
# Epoch 195/1000
# 9/9 - 0s - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0162 - val_mean_squared_error: 0.0162 - 94ms/epoch - 10ms/step
# Epoch 196/1000
# 9/9 - 0s - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0161 - val_mean_squared_error: 0.0161 - 79ms/epoch - 9ms/step
# Epoch 197/1000
# 9/9 - 0s - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0161 - val_mean_squared_error: 0.0161 - 79ms/epoch - 9ms/step
# Epoch 198/1000
# 9/9 - 0s - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0160 - val_mean_squared_error: 0.0160 - 84ms/epoch - 9ms/step
# Epoch 199/1000
# 9/9 - 0s - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0160 - val_mean_squared_error: 0.0160 - 74ms/epoch - 8ms/step
# Epoch 200/1000
# 9/9 - 0s - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0159 - val_mean_squared_error: 0.0159 - 78ms/epoch - 9ms/step
# Epoch 201/1000
# 9/9 - 0s - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0159 - val_mean_squared_error: 0.0159 - 94ms/epoch - 10ms/step
# Epoch 202/1000
# 9/9 - 0s - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0158 - val_mean_squared_error: 0.0158 - 80ms/epoch - 9ms/step
# Epoch 203/1000
# 9/9 - 0s - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.0158 - val_mean_squared_error: 0.0158 - 94ms/epoch - 10ms/step
# Epoch 204/1000
# 9/9 - 0s - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.0157 - val_mean_squared_error: 0.0157 - 86ms/epoch - 10ms/step
# Epoch 205/1000
# 9/9 - 0s - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0157 - val_mean_squared_error: 0.0157 - 88ms/epoch - 10ms/step
# Epoch 206/1000
# 9/9 - 0s - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0156 - val_mean_squared_error: 0.0156 - 79ms/epoch - 9ms/step
# Epoch 207/1000
# 9/9 - 0s - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0156 - val_mean_squared_error: 0.0156 - 95ms/epoch - 11ms/step
# Epoch 208/1000
# 9/9 - 0s - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0155 - val_mean_squared_error: 0.0155 - 88ms/epoch - 10ms/step
# Epoch 209/1000
# 9/9 - 0s - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0155 - val_mean_squared_error: 0.0155 - 81ms/epoch - 9ms/step
# Epoch 210/1000
# 9/9 - 0s - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0154 - val_mean_squared_error: 0.0154 - 94ms/epoch - 10ms/step
# Epoch 211/1000
# 9/9 - 0s - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0154 - val_mean_squared_error: 0.0154 - 79ms/epoch - 9ms/step
# Epoch 212/1000
# 9/9 - 0s - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0154 - val_mean_squared_error: 0.0154 - 82ms/epoch - 9ms/step
# Epoch 213/1000
# 9/9 - 0s - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0153 - val_mean_squared_error: 0.0153 - 79ms/epoch - 9ms/step
# Epoch 214/1000
# 9/9 - 0s - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0153 - val_mean_squared_error: 0.0153 - 90ms/epoch - 10ms/step
# Epoch 215/1000
# 9/9 - 0s - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0152 - val_mean_squared_error: 0.0152 - 95ms/epoch - 11ms/step
# Epoch 216/1000
# 9/9 - 0s - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0152 - val_mean_squared_error: 0.0152 - 98ms/epoch - 11ms/step
# Epoch 217/1000
# 9/9 - 0s - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0152 - val_mean_squared_error: 0.0152 - 91ms/epoch - 10ms/step
# Epoch 218/1000
# 9/9 - 0s - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0151 - val_mean_squared_error: 0.0151 - 74ms/epoch - 8ms/step
# Epoch 219/1000
# 9/9 - 0s - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0151 - val_mean_squared_error: 0.0151 - 94ms/epoch - 10ms/step
# Epoch 220/1000
# 9/9 - 0s - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0151 - val_mean_squared_error: 0.0151 - 78ms/epoch - 9ms/step
# Epoch 221/1000
# 9/9 - 0s - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0150 - val_mean_squared_error: 0.0150 - 81ms/epoch - 9ms/step
# Epoch 222/1000
# 9/9 - 0s - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0150 - val_mean_squared_error: 0.0150 - 85ms/epoch - 9ms/step
# Epoch 223/1000
# 9/9 - 0s - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0149 - val_mean_squared_error: 0.0149 - 86ms/epoch - 10ms/step
# Epoch 224/1000
# 9/9 - 0s - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0149 - val_mean_squared_error: 0.0149 - 96ms/epoch - 11ms/step
# Epoch 225/1000
# 9/9 - 0s - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0149 - val_mean_squared_error: 0.0149 - 71ms/epoch - 8ms/step
# Epoch 226/1000
# 9/9 - 0s - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0148 - val_mean_squared_error: 0.0148 - 78ms/epoch - 9ms/step
# Epoch 227/1000
# 9/9 - 0s - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0148 - val_mean_squared_error: 0.0148 - 94ms/epoch - 10ms/step
# Epoch 228/1000
# 9/9 - 0s - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0148 - val_mean_squared_error: 0.0148 - 82ms/epoch - 9ms/step
# Epoch 229/1000
# 9/9 - 0s - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0147 - val_mean_squared_error: 0.0147 - 78ms/epoch - 9ms/step
# Epoch 230/1000
# 9/9 - 0s - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0147 - val_mean_squared_error: 0.0147 - 82ms/epoch - 9ms/step
# Epoch 231/1000
# 9/9 - 0s - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0147 - val_mean_squared_error: 0.0147 - 78ms/epoch - 9ms/step
# Epoch 232/1000
# 9/9 - 0s - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0146 - val_mean_squared_error: 0.0146 - 78ms/epoch - 9ms/step
# Epoch 233/1000
# 9/9 - 0s - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0146 - val_mean_squared_error: 0.0146 - 94ms/epoch - 10ms/step
# Epoch 234/1000
# 9/9 - 0s - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0146 - val_mean_squared_error: 0.0146 - 78ms/epoch - 9ms/step
# Epoch 235/1000
# 9/9 - 0s - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - 78ms/epoch - 9ms/step
# Epoch 236/1000
# 9/9 - 0s - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - 94ms/epoch - 10ms/step
# Epoch 237/1000
# 9/9 - 0s - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - 78ms/epoch - 9ms/step
# Epoch 238/1000
# 9/9 - 0s - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - 79ms/epoch - 9ms/step
# Epoch 239/1000
# 9/9 - 0s - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - 78ms/epoch - 9ms/step
# Epoch 240/1000
# 9/9 - 0s - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - 94ms/epoch - 10ms/step
# Epoch 241/1000
# 9/9 - 0s - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - 78ms/epoch - 9ms/step
# Epoch 242/1000
# 9/9 - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0143 - val_mean_squared_error: 0.0143 - 78ms/epoch - 9ms/step
# Epoch 243/1000
# 9/9 - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0143 - val_mean_squared_error: 0.0143 - 78ms/epoch - 9ms/step
# Epoch 244/1000
# 9/9 - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0143 - val_mean_squared_error: 0.0143 - 94ms/epoch - 10ms/step
# Epoch 245/1000
# 9/9 - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0143 - val_mean_squared_error: 0.0143 - 78ms/epoch - 9ms/step
# Epoch 246/1000
# 9/9 - 0s - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0142 - val_mean_squared_error: 0.0142 - 94ms/epoch - 10ms/step
# Epoch 247/1000
# 9/9 - 0s - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0142 - val_mean_squared_error: 0.0142 - 78ms/epoch - 9ms/step
# Epoch 248/1000
# 9/9 - 0s - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0142 - val_mean_squared_error: 0.0142 - 78ms/epoch - 9ms/step
# Epoch 249/1000
# 9/9 - 0s - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0142 - val_mean_squared_error: 0.0142 - 78ms/epoch - 9ms/step
# Epoch 250/1000
# 9/9 - 0s - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0141 - val_mean_squared_error: 0.0141 - 62ms/epoch - 7ms/step
# Epoch 251/1000
# 9/9 - 0s - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0141 - val_mean_squared_error: 0.0141 - 62ms/epoch - 7ms/step
# Epoch 252/1000
# 9/9 - 0s - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0141 - val_mean_squared_error: 0.0141 - 79ms/epoch - 9ms/step
# Epoch 253/1000
# 9/9 - 0s - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0141 - val_mean_squared_error: 0.0141 - 78ms/epoch - 9ms/step
# Epoch 254/1000
# 9/9 - 0s - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0140 - val_mean_squared_error: 0.0140 - 78ms/epoch - 9ms/step
# Epoch 255/1000
# 9/9 - 0s - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0140 - val_mean_squared_error: 0.0140 - 94ms/epoch - 10ms/step
# Epoch 256/1000
# 9/9 - 0s - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0140 - val_mean_squared_error: 0.0140 - 78ms/epoch - 9ms/step
# Epoch 257/1000
# 9/9 - 0s - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0140 - val_mean_squared_error: 0.0140 - 78ms/epoch - 9ms/step
# Epoch 258/1000
# 9/9 - 0s - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0139 - val_mean_squared_error: 0.0139 - 78ms/epoch - 9ms/step
# Epoch 259/1000
# 9/9 - 0s - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0139 - val_mean_squared_error: 0.0139 - 78ms/epoch - 9ms/step
# Epoch 260/1000
# 9/9 - 0s - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0139 - val_mean_squared_error: 0.0139 - 78ms/epoch - 9ms/step
# Epoch 261/1000
# 9/9 - 0s - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0139 - val_mean_squared_error: 0.0139 - 94ms/epoch - 10ms/step
# Epoch 262/1000
# 9/9 - 0s - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0139 - val_mean_squared_error: 0.0139 - 78ms/epoch - 9ms/step
# Epoch 263/1000
# 9/9 - 0s - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0139 - val_mean_squared_error: 0.0139 - 78ms/epoch - 9ms/step
# Epoch 264/1000
# 9/9 - 0s - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0138 - val_mean_squared_error: 0.0138 - 78ms/epoch - 9ms/step
# Epoch 265/1000
# 9/9 - 0s - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0138 - val_mean_squared_error: 0.0138 - 78ms/epoch - 9ms/step
# Epoch 266/1000
# 9/9 - 0s - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0138 - val_mean_squared_error: 0.0138 - 94ms/epoch - 10ms/step
# Epoch 267/1000
# 9/9 - 0s - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0138 - val_mean_squared_error: 0.0138 - 82ms/epoch - 9ms/step
# Epoch 268/1000
# 9/9 - 0s - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0138 - val_mean_squared_error: 0.0138 - 80ms/epoch - 9ms/step
# Epoch 269/1000
# 9/9 - 0s - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - 78ms/epoch - 9ms/step
# Epoch 270/1000
# 9/9 - 0s - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - 78ms/epoch - 9ms/step
# Epoch 271/1000
# 9/9 - 0s - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - 78ms/epoch - 9ms/step
# Epoch 272/1000
# 9/9 - 0s - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - 94ms/epoch - 10ms/step
# Epoch 273/1000
# 9/9 - 0s - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - 78ms/epoch - 9ms/step
# Epoch 274/1000
# 9/9 - 0s - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - 94ms/epoch - 10ms/step
# Epoch 275/1000
# 9/9 - 0s - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 78ms/epoch - 9ms/step
# Epoch 276/1000
# 9/9 - 0s - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 78ms/epoch - 9ms/step
# Epoch 277/1000
# 9/9 - 0s - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 94ms/epoch - 10ms/step
# Epoch 278/1000
# 9/9 - 0s - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 78ms/epoch - 9ms/step
# Epoch 279/1000
# 9/9 - 0s - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 78ms/epoch - 9ms/step
# Epoch 280/1000
# 9/9 - 0s - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 94ms/epoch - 10ms/step
# Epoch 281/1000
# 9/9 - 0s - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 78ms/epoch - 9ms/step
# Epoch 282/1000
# 9/9 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - 78ms/epoch - 9ms/step
# Epoch 283/1000
# 9/9 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - 94ms/epoch - 10ms/step
# Epoch 284/1000
# 9/9 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - 94ms/epoch - 10ms/step
# Epoch 285/1000
# 9/9 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - 78ms/epoch - 9ms/step
# Epoch 286/1000
# 9/9 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - 94ms/epoch - 10ms/step
# Epoch 287/1000
# 9/9 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - 78ms/epoch - 9ms/step
# Epoch 288/1000
# 9/9 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - 62ms/epoch - 7ms/step
# Epoch 289/1000
# 9/9 - 0s - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - 94ms/epoch - 10ms/step
# Epoch 290/1000
# 9/9 - 0s - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - 78ms/epoch - 9ms/step
# Epoch 291/1000
# 9/9 - 0s - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - 94ms/epoch - 10ms/step
# Epoch 292/1000
# 9/9 - 0s - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - 78ms/epoch - 9ms/step
# Epoch 293/1000
# 9/9 - 0s - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - 78ms/epoch - 9ms/step
# Epoch 294/1000
# 9/9 - 0s - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - 79ms/epoch - 9ms/step
# Epoch 295/1000
# 9/9 - 0s - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - 78ms/epoch - 9ms/step
# Epoch 296/1000
# 9/9 - 0s - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - 78ms/epoch - 9ms/step
# Epoch 297/1000
# 9/9 - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - 94ms/epoch - 10ms/step
# Epoch 298/1000
# 9/9 - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - 78ms/epoch - 9ms/step
# Epoch 299/1000
# 9/9 - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - 78ms/epoch - 9ms/step
# Epoch 300/1000
# 9/9 - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - 78ms/epoch - 9ms/step
# Epoch 301/1000
# 9/9 - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - 78ms/epoch - 9ms/step
# Epoch 302/1000
# 9/9 - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - 78ms/epoch - 9ms/step
# Epoch 303/1000
# 9/9 - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - 78ms/epoch - 9ms/step
# Epoch 304/1000
# 9/9 - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - 94ms/epoch - 10ms/step
# Epoch 305/1000
# 9/9 - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - 78ms/epoch - 9ms/step
# Epoch 306/1000
# 9/9 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - 78ms/epoch - 9ms/step
# Epoch 307/1000
# 9/9 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - 78ms/epoch - 9ms/step
# Epoch 308/1000
# 9/9 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - 78ms/epoch - 9ms/step
# Epoch 309/1000
# 9/9 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - 94ms/epoch - 10ms/step
# Epoch 310/1000
# 9/9 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - 94ms/epoch - 10ms/step
# Epoch 311/1000
# 9/9 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - 78ms/epoch - 9ms/step
# Epoch 312/1000
# 9/9 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - 90ms/epoch - 10ms/step
# Epoch 313/1000
# 9/9 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 78ms/epoch - 9ms/step
# Epoch 314/1000
# 9/9 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 94ms/epoch - 10ms/step
# Epoch 315/1000
# 9/9 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 78ms/epoch - 9ms/step
# Epoch 316/1000
# 9/9 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 78ms/epoch - 9ms/step
# Epoch 317/1000
# 9/9 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 94ms/epoch - 10ms/step
# Epoch 318/1000
# 9/9 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 78ms/epoch - 9ms/step
# Epoch 319/1000
# 9/9 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 79ms/epoch - 9ms/step
# Epoch 320/1000
# 9/9 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 78ms/epoch - 9ms/step
# Epoch 321/1000
# 9/9 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 78ms/epoch - 9ms/step
# Epoch 322/1000
# 9/9 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 78ms/epoch - 9ms/step
# Epoch 323/1000
# 9/9 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 78ms/epoch - 9ms/step
# Epoch 324/1000
# 9/9 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 62ms/epoch - 7ms/step
# Epoch 325/1000
# 9/9 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 78ms/epoch - 9ms/step
# Epoch 326/1000
# 9/9 - 0s - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 78ms/epoch - 9ms/step
# Epoch 327/1000
# 9/9 - 0s - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 78ms/epoch - 9ms/step
# Epoch 328/1000
# 9/9 - 0s - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 78ms/epoch - 9ms/step
# Epoch 329/1000
# 9/9 - 0s - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 78ms/epoch - 9ms/step
# Epoch 330/1000
# 9/9 - 0s - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 78ms/epoch - 9ms/step
# Epoch 331/1000
# 9/9 - 0s - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 78ms/epoch - 9ms/step
# Epoch 332/1000
# 9/9 - 0s - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 62ms/epoch - 7ms/step
# Epoch 333/1000
# 9/9 - 0s - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0129 - val_mean_squared_error: 0.0129 - 78ms/epoch - 9ms/step
# ...
# Epoch 907/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8212 - val_mean_squared_error: 0.8212 - 110ms/epoch - 12ms/step
# Epoch 908/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 119ms/epoch - 13ms/step
# Epoch 909/1000
# 9/9 - 0s - loss: 0.8176 - mean_squared_error: 0.8176 - val_loss: 0.8209 - val_mean_squared_error: 0.8209 - 113ms/epoch - 13ms/step
# Epoch 910/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8212 - val_mean_squared_error: 0.8212 - 115ms/epoch - 13ms/step
# Epoch 911/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8209 - val_mean_squared_error: 0.8209 - 117ms/epoch - 13ms/step
# Epoch 912/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 129ms/epoch - 14ms/step
# Epoch 913/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8209 - val_mean_squared_error: 0.8209 - 128ms/epoch - 14ms/step
# Epoch 914/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 120ms/epoch - 13ms/step
# Epoch 915/1000
# 9/9 - 0s - loss: 0.8179 - mean_squared_error: 0.8179 - val_loss: 0.8213 - val_mean_squared_error: 0.8213 - 115ms/epoch - 13ms/step
# Epoch 916/1000
# 9/9 - 0s - loss: 0.8179 - mean_squared_error: 0.8179 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 100ms/epoch - 11ms/step
# Epoch 917/1000
# 9/9 - 0s - loss: 0.8179 - mean_squared_error: 0.8179 - val_loss: 0.8214 - val_mean_squared_error: 0.8214 - 134ms/epoch - 15ms/step
# Epoch 918/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8208 - val_mean_squared_error: 0.8208 - 122ms/epoch - 14ms/step
# Epoch 919/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8209 - val_mean_squared_error: 0.8209 - 118ms/epoch - 13ms/step
# Epoch 920/1000
# 9/9 - 0s - loss: 0.8176 - mean_squared_error: 0.8176 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 121ms/epoch - 13ms/step
# Epoch 921/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 114ms/epoch - 13ms/step
# Epoch 922/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 115ms/epoch - 13ms/step
# Epoch 923/1000
# 9/9 - 0s - loss: 0.8176 - mean_squared_error: 0.8176 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 111ms/epoch - 12ms/step
# Epoch 924/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8212 - val_mean_squared_error: 0.8212 - 118ms/epoch - 13ms/step
# Epoch 925/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 140ms/epoch - 16ms/step
# Epoch 926/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8209 - val_mean_squared_error: 0.8209 - 107ms/epoch - 12ms/step
# Epoch 927/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 117ms/epoch - 13ms/step
# Epoch 928/1000
# 9/9 - 0s - loss: 0.8176 - mean_squared_error: 0.8176 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 122ms/epoch - 14ms/step
# Epoch 929/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 109ms/epoch - 12ms/step
# Epoch 930/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 114ms/epoch - 13ms/step
# Epoch 931/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 117ms/epoch - 13ms/step
# Epoch 932/1000
# 9/9 - 0s - loss: 0.8176 - mean_squared_error: 0.8176 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 123ms/epoch - 14ms/step
# Epoch 933/1000
# 9/9 - 0s - loss: 0.8176 - mean_squared_error: 0.8176 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 109ms/epoch - 12ms/step
# Epoch 934/1000
# 9/9 - 0s - loss: 0.8176 - mean_squared_error: 0.8176 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 116ms/epoch - 13ms/step
# Epoch 935/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8209 - val_mean_squared_error: 0.8209 - 124ms/epoch - 14ms/step
# Epoch 936/1000
# 9/9 - 0s - loss: 0.8179 - mean_squared_error: 0.8179 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 110ms/epoch - 12ms/step
# Epoch 937/1000
# 9/9 - 0s - loss: 0.8182 - mean_squared_error: 0.8182 - val_loss: 0.8216 - val_mean_squared_error: 0.8216 - 117ms/epoch - 13ms/step
# Epoch 938/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 132ms/epoch - 15ms/step
# Epoch 939/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 132ms/epoch - 15ms/step
# Epoch 940/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 117ms/epoch - 13ms/step
# Epoch 941/1000
# 9/9 - 0s - loss: 0.8176 - mean_squared_error: 0.8176 - val_loss: 0.8212 - val_mean_squared_error: 0.8212 - 132ms/epoch - 15ms/step
# Epoch 942/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8213 - val_mean_squared_error: 0.8213 - 138ms/epoch - 15ms/step
# Epoch 943/1000
# 9/9 - 0s - loss: 0.8176 - mean_squared_error: 0.8176 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 121ms/epoch - 13ms/step
# Epoch 944/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 125ms/epoch - 14ms/step
# Epoch 945/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 133ms/epoch - 15ms/step
# Epoch 946/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8212 - val_mean_squared_error: 0.8212 - 113ms/epoch - 13ms/step
# Epoch 947/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8212 - val_mean_squared_error: 0.8212 - 143ms/epoch - 16ms/step
# Epoch 948/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 116ms/epoch - 13ms/step
# Epoch 949/1000
# 9/9 - 0s - loss: 0.8179 - mean_squared_error: 0.8179 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 122ms/epoch - 14ms/step
# Epoch 950/1000
# 9/9 - 0s - loss: 0.8179 - mean_squared_error: 0.8179 - val_loss: 0.8212 - val_mean_squared_error: 0.8212 - 112ms/epoch - 12ms/step
# Epoch 951/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8213 - val_mean_squared_error: 0.8213 - 130ms/epoch - 14ms/step
# Epoch 952/1000
# 9/9 - 0s - loss: 0.8179 - mean_squared_error: 0.8179 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 123ms/epoch - 14ms/step
# Epoch 953/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 107ms/epoch - 12ms/step
# Epoch 954/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 114ms/epoch - 13ms/step
# Epoch 955/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 114ms/epoch - 13ms/step
# Epoch 956/1000
# 9/9 - 0s - loss: 0.8179 - mean_squared_error: 0.8179 - val_loss: 0.8212 - val_mean_squared_error: 0.8212 - 115ms/epoch - 13ms/step
# Epoch 957/1000
# 9/9 - 0s - loss: 0.8181 - mean_squared_error: 0.8181 - val_loss: 0.8213 - val_mean_squared_error: 0.8213 - 118ms/epoch - 13ms/step
# Epoch 958/1000
# 9/9 - 0s - loss: 0.8176 - mean_squared_error: 0.8176 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 116ms/epoch - 13ms/step
# Epoch 959/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 116ms/epoch - 13ms/step
# Epoch 960/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8213 - val_mean_squared_error: 0.8213 - 122ms/epoch - 14ms/step
# Epoch 961/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 111ms/epoch - 12ms/step
# Epoch 962/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8213 - val_mean_squared_error: 0.8213 - 118ms/epoch - 13ms/step
# Epoch 963/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8212 - val_mean_squared_error: 0.8212 - 110ms/epoch - 12ms/step
# Epoch 964/1000
# 9/9 - 0s - loss: 0.8180 - mean_squared_error: 0.8180 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 114ms/epoch - 13ms/step
# Epoch 965/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 100ms/epoch - 11ms/step
# Epoch 966/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 101ms/epoch - 11ms/step
# Epoch 967/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 108ms/epoch - 12ms/step
# Epoch 968/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 120ms/epoch - 13ms/step
# Epoch 969/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 114ms/epoch - 13ms/step
# Epoch 970/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 117ms/epoch - 13ms/step
# Epoch 971/1000
# 9/9 - 0s - loss: 0.8176 - mean_squared_error: 0.8176 - val_loss: 0.8212 - val_mean_squared_error: 0.8212 - 115ms/epoch - 13ms/step
# Epoch 972/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 98ms/epoch - 11ms/step
# Epoch 973/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8209 - val_mean_squared_error: 0.8209 - 99ms/epoch - 11ms/step
# Epoch 974/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 117ms/epoch - 13ms/step
# Epoch 975/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 112ms/epoch - 12ms/step
# Epoch 976/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 101ms/epoch - 11ms/step
# Epoch 977/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 122ms/epoch - 14ms/step
# Epoch 978/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 121ms/epoch - 13ms/step
# Epoch 979/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 117ms/epoch - 13ms/step
# Epoch 980/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 109ms/epoch - 12ms/step
# Epoch 981/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8213 - val_mean_squared_error: 0.8213 - 115ms/epoch - 13ms/step
# Epoch 982/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 119ms/epoch - 13ms/step
# Epoch 983/1000
# 9/9 - 0s - loss: 0.8179 - mean_squared_error: 0.8179 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 110ms/epoch - 12ms/step
# Epoch 984/1000
# 9/9 - 0s - loss: 0.8176 - mean_squared_error: 0.8176 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 133ms/epoch - 15ms/step
# Epoch 985/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8214 - val_mean_squared_error: 0.8214 - 140ms/epoch - 16ms/step
# Epoch 986/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 121ms/epoch - 13ms/step
# Epoch 987/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8212 - val_mean_squared_error: 0.8212 - 120ms/epoch - 13ms/step
# Epoch 988/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 118ms/epoch - 13ms/step
# Epoch 989/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 115ms/epoch - 13ms/step
# Epoch 990/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 114ms/epoch - 13ms/step
# Epoch 991/1000
# 9/9 - 0s - loss: 0.8176 - mean_squared_error: 0.8176 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 115ms/epoch - 13ms/step
# Epoch 992/1000
# 9/9 - 0s - loss: 0.8176 - mean_squared_error: 0.8176 - val_loss: 0.8208 - val_mean_squared_error: 0.8208 - 114ms/epoch - 13ms/step
# Epoch 993/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 107ms/epoch - 12ms/step
# Epoch 994/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8213 - val_mean_squared_error: 0.8213 - 116ms/epoch - 13ms/step
# Epoch 995/1000
# 9/9 - 0s - loss: 0.8178 - mean_squared_error: 0.8178 - val_loss: 0.8214 - val_mean_squared_error: 0.8214 - 110ms/epoch - 12ms/step
# Epoch 996/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 113ms/epoch - 13ms/step
# Epoch 997/1000
# 9/9 - 0s - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.8210 - val_mean_squared_error: 0.8210 - 117ms/epoch - 13ms/step
# Epoch 998/1000
# 9/9 - 0s - loss: 0.8179 - mean_squared_error: 0.8179 - val_loss: 0.8214 - val_mean_squared_error: 0.8214 - 115ms/epoch - 13ms/step
# Epoch 999/1000
# 9/9 - 0s - loss: 0.8180 - mean_squared_error: 0.8180 - val_loss: 0.8212 - val_mean_squared_error: 0.8212 - 119ms/epoch - 13ms/step
# Epoch 1000/1000
# 9/9 - 0s - loss: 0.8179 - mean_squared_error: 0.8179 - val_loss: 0.8211 - val_mean_squared_error: 0.8211 - 109ms/epoch - 12ms/step
# [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# [0.00840168446302414, 0.01084561925381422, 0.018385043367743492, 0.03128447011113167, 0.047759659588336945, 0.07041856646537781, 0.09931810945272446, 0.12736378610134125, 0.16625411808490753, 0.20997759699821472, 0.2579014301300049, 0.30456677079200745, 0.3656955063343048, 0.4270384907722473, 0.5152227878570557, 0.5784295201301575, 0.6546420454978943, 0.7438768744468689, 0.8211266994476318]
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0093 - mean_squared_error: 0.0093
# [0.008265729062259197, 0.008264788426458836, 0.00829374324530363, 0.00827586930245161, 0.008290378376841545, 0.008362216874957085, 0.008381828665733337, 0.008502003736793995, 0.008435973897576332, 0.008387706242501736, 0.008546910248696804, 0.008665078319609165, 0.008547521196305752, 0.00865282490849495, 0.008907593786716461, 0.00875362753868103, 0.008706439286470413, 0.009346390143036842, 0.00927593745291233]
# All weights are non-negative (ignoring biases).
# 88/88 [==============================] - 0s 2ms/step
# 88/88 [==============================] - 0s 1ms/step
# lip cst: 1.572
# Estimated Lipschitz constant of the 2-layer RNN: 1.5717589855194092
# Model: "model_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 5, 4)]            0
#
#  simple_rnn_38 (SimpleRNN)   (None, 5, 64)             4416
#
#  simple_rnn_39 (SimpleRNN)   (None, 5, 64)             8256
#
#  dense_19 (Dense)            (None, 5, 2)              130
#
# =================================================================
# Total params: 12802 (50.01 KB)
# Trainable params: 12802 (50.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
print(np.array(lip).tolist())
# Out:
# [1.0037497282028198, 0.9907609224319458, 0.9686551094055176, 1.0177382230758667, 1.0213122367858887, 1.029603362083435, 1.0968432426452637, 1.1660923957824707, 0.9727574586868286, 1.061330795288086, 0.9538975954055786, 1.1882529258728027, 1.0320713520050049, 1.111847162246704, 1.067275047302246, 1.1325587034225464, 1.2571359872817993, 1.1818952560424805, 1.5717589855194092]

# %%
# ICLRNN with ReLU
# model.save('iclrnn_cstr.h5')
# model = tf.keras.models.load_model('iclrnn_cstr.h5', custom_objects={'SpectralConstraint': SpectralConstraint})

# %%
from tensorflow.python.framework.convert_to_constants import  convert_variables_to_constants_v2_as_graph

def get_flops(model):
    concrete = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete.get_concrete_function(
        [tf.TensorSpec([1, *inputs.shape[1:]]) for inputs in model.inputs])
    frozen_func, graph_def = convert_variables_to_constants_v2_as_graph(concrete_func, lower_control_flow=False)
    with tf.Graph().as_default() as graph:
        tf.graph_util.import_graph_def(graph_def, name='')
        run_meta = tf.compat.v1.RunMetadata()
        opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
        flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd="op", options=opts)
        return flops.total_float_ops

print("The FLOPs is:{}".format(get_flops(model)) ,flush=True )
model.summary()
# Out:
# The FLOPs is:26634
# Model: "model_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 5, 4)]            0
#
#  simple_rnn_38 (SimpleRNN)   (None, 5, 64)             4416
#
#  simple_rnn_39 (SimpleRNN)   (None, 5, 64)             8256
#
#  dense_19 (Dense)            (None, 5, 2)              130
#
# =================================================================
# Total params: 12802 (50.01 KB)
# Trainable params: 12802 (50.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# plot training and validation losses against epochs

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Normal RNN Training and validation loss')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()
