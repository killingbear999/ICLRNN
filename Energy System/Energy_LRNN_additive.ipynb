# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input, Activation, Dropout, Add, LSTM, GRU, RNN, LayerNormalization, BatchNormalization, SpectralNormalization, Conv1D, MaxPooling1D, Flatten, Layer
from keras import backend as K
from keras.optimizers import Adam,SGD
import tensorflow as tf
from keras import Model, regularizers, activations, initializers
from keras.constraints import Constraint
import pickle

# %%
import h5py

with h5py.File('test_collected_data.mat', 'r') as file:
    U = file['U'][:]
    U = np.array(U)

    Y = file['Y'][:]
    Y = np.array(Y)

# %%
print(U.shape)
print(Y.shape)
# Out:
# (20001, 2)
# (20001, 2)

# %%
print(U.shape[0])
# Out:
# 20001

# %%
# get X and y data for training and testing

U_input = list()
Y_output = list()

for i in range(U.shape[0]-1):
    if i % 5 == 0:
        U_input.append(U[i:i+5, :])
        Y_output.append(Y[i:i+5, :])

# %%
U_input = np.array(U_input)
print(U_input.shape)
Y_output = np.array(Y_output)
print(Y_output.shape)
# Out:
# (4000, 5, 2)
# (4000, 5, 2)

# %%
print(Y_output[-1])
# Out:
# [[0.48259197 0.93018467]
#  [0.34779566 0.87790033]
#  [0.87823507 0.92530261]
#  [1.28194928 1.02012353]
#  [1.48795291 1.12338469]]

# %%
RNN_input = U_input
# RNN_input = np.concatenate((U_input, -U_input), axis=2)
print("RNN_input shape is {}".format(RNN_input.shape))
# Out:
# RNN_input shape is (4000, 5, 2)

# %%
print(RNN_input[0, :, :])
print(RNN_input[1, :, :])
# Out:
# [[16.19241666 15.76933193]
#  [12.70894193 15.86208482]
#  [19.2123671  16.62241755]
#  [19.75451791 15.65793096]
#  [18.4116695  14.67089197]]
# [[13.0167968  16.42839002]
#  [17.27902718 13.91422655]
#  [12.14333843 13.49401711]
#  [12.5352551  16.91193655]
#  [16.09581626 15.90299875]]

# %%
RNN_output = Y_output
print("RNN_output shape is {}".format(RNN_output.shape))
# Out:
# RNN_output shape is (4000, 5, 2)

# %%
print(RNN_output[0, :, :])
print(RNN_output[1, :, :])
# Out:
# [[1.         1.        ]
#  [1.22269359 1.11420623]
#  [0.70290225 0.94505017]
#  [0.66837481 0.90328351]
#  [0.90288417 0.91432542]]
# [[1.38545837 1.08183303]
#  [1.02589437 0.95628583]
#  [1.4512544  1.11007631]
#  [1.49351371 1.15346693]
#  [0.99319535 1.03252695]]

# %%
def check_non_negative_weights_ignore_bias(model):
    all_non_negative = True
    for layer in model.layers:
        weights = layer.get_weights()
        if weights:  # tf the layer has weights
            # check only the weight matrices (ignoring biases if present)
            weight_only = weights[0]  # assume weights are the first element, bias (if any) is second
            if not np.all(weight_only >= 0):
                print(f"Non-negative check failed in layer: {layer.name}")
                all_non_negative = False
    if all_non_negative:
        print("All weights are non-negative (ignoring biases).")
    else:
        print("Some weights are negative (ignoring biases).")

# %%
def evaluate_lip_const(model: Model, x, eps, seed=None):
    """
    Evaluate the Lipschitz constant of a model, with the naive method.
    Please note that the estimation of the lipschitz constant is done locally around
    input sample. This may not correctly estimate the behaviour in the whole domain.

    Args:
        model: built keras model used to make predictions
        x: inputs used to compute the lipschitz constant
        eps (float): magnitude of noise to add to input in order to compute the constant
        seed (int): seed used when generating the noise ( can be set to None )

    Returns:
        float: the empirically evaluated lipschitz constant. The computation might also
            be inaccurate in high dimensional space.

    """
    y_pred = model.predict(x)
    x_var = x + K.random_uniform(
        shape=x.shape, minval=eps * 0.25, maxval=eps, seed=seed
    )
#     x_var = x + K.random_normal(
#         shape=x.shape, mean=0, stddev=eps, seed=seed
#     )
    y_pred_var = model.predict(x_var)
    dx = x - x_var
    dfx = y_pred - y_pred_var
    ndx = K.sqrt(K.sum(K.square(dx), axis=range(1, len(x.shape))))
    ndfx = K.sqrt(K.sum(K.square(dfx), axis=range(1, len(y_pred.shape))))
    lip_cst = K.max(ndfx / ndx)
    print(f"lip cst: {lip_cst:.3f}")
    return lip_cst

# %%
class MyLRNNCell(tf.keras.layers.Layer):

    def __init__(self, units, eps=0.01, gamma=0.01, beta=0.8, alpha=1, **kwargs):
        self.units = units
        self.state_size = units
        self.I = tf.eye(units)
        self.eps = eps
        self.gamma = gamma
        self.beta = beta
        self.alpha = alpha
        super(MyLRNNCell, self).__init__(**kwargs)

    def build(self, input_shape):
        self.C = self.add_weight(shape=(self.units, self.units),
                                      initializer='random_normal',
                                      name='C',
                                      trainable=True)
        self.B = self.add_weight(shape=(self.units, self.units),
                                                initializer='random_normal',
                                                name='B',
                                                trainable=True)
        self.U = self.add_weight(shape=(input_shape[-1], self.units),
                                                initializer='random_normal',
                                                name='U',
                                                trainable=True)
        self.b = self.add_weight(shape=(self.units,),
                                    initializer='zeros',
                                    name='b',
                                    trainable=True)
        self.built = True

    def call(self, inputs, states):
        prev_h = states[0]

        A = self.beta * (self.B - tf.transpose(self.B)) + (1 - self.beta) * (self.B + tf.transpose(self.B)) - self.gamma * self.I
        W = self.beta * (self.C - tf.transpose(self.C)) + (1 - self.beta) * (self.C + tf.transpose(self.C)) - self.gamma * self.I

        h = prev_h + self.eps * self.alpha * K.dot(prev_h, A) + self.eps * tf.nn.tanh(K.dot(prev_h, W) + K.dot(inputs, self.U) + self.b)
        return h, [h]

    def get_config(self):
        config = super(MyLRNNCell, self).get_config()
        config.update({"units": self.units, "eps":self.eps, "gamma":self.gamma, "beta":self.beta, "alpha":self.alpha})
        return config

# %%
# set the seed for reproducibility
tf.random.set_seed(42)

num_step = 5
training_loss = [0]*19
test_loss = [0]*19
lip = [0]*19
noise = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]

for i in range(19):
    num_dims = 2

    # split into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(RNN_input, RNN_output, test_size=0.3, random_state=123)

    # define scalers for both X and y base on training data only
    scaler_X = preprocessing.MinMaxScaler().fit(X_train.reshape(-1, num_dims))
    scaler_y = preprocessing.MinMaxScaler().fit(y_train.reshape(-1, 2))

    X_train = scaler_X.transform(X_train.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
    X_test = scaler_X.transform(X_test.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
    y_train = scaler_y.transform(y_train.reshape(-1,2)).reshape(-1,num_step,2)
    y_test_normalized = scaler_y.transform(y_test.reshape(-1,2)).reshape(-1,num_step,2)

    # X is just the initial condition, so we introduce noise to the output trajectory y
    y_train = y_train + np.random.normal(0, noise[i], y_train.shape)

    # LRNN
    model = Sequential()
    model.add(RNN(MyLRNNCell(units=64),return_sequences=True))
    model.add(RNN(MyLRNNCell(units=64),return_sequences=True))
    model.add(Dense(2, activation='linear'))

    model.compile(optimizer='adam', loss='mean_squared_error', metrics=[tf.keras.metrics.MeanSquaredError()])
    history = model.fit(X_train, y_train, epochs=1000, batch_size=256, validation_split=0.25, verbose=2)

    training_loss[i] = history.history['val_loss'][-1]
    print(noise)
    print(training_loss)

    loss = model.evaluate(X_test, y_test_normalized, batch_size=256)
    test_loss[i] = loss[0]
    print(test_loss)

    # check convexity by checking the weights
    check_non_negative_weights_ignore_bias(model)

    # compute the Lipschitz constant for the 2-layer RNN
    lipschitz_constant = evaluate_lip_const(model, X_train, 1e-04, 42)
    print(f"Estimated Lipschitz constant of the 2-layer RNN: {lipschitz_constant}")

    lip[i] = lipschitz_constant

model.summary()
# Out:
# Epoch 1/1000
# 9/9 - 7s - loss: 0.2019 - mean_squared_error: 0.2019 - val_loss: 0.1981 - val_mean_squared_error: 0.1981 - 7s/epoch - 745ms/step
# Epoch 2/1000
# 9/9 - 0s - loss: 0.1930 - mean_squared_error: 0.1930 - val_loss: 0.1892 - val_mean_squared_error: 0.1892 - 85ms/epoch - 9ms/step
# Epoch 3/1000
# 9/9 - 0s - loss: 0.1840 - mean_squared_error: 0.1840 - val_loss: 0.1801 - val_mean_squared_error: 0.1801 - 94ms/epoch - 10ms/step
# Epoch 4/1000
# 9/9 - 0s - loss: 0.1749 - mean_squared_error: 0.1749 - val_loss: 0.1708 - val_mean_squared_error: 0.1708 - 94ms/epoch - 10ms/step
# Epoch 5/1000
# 9/9 - 0s - loss: 0.1656 - mean_squared_error: 0.1656 - val_loss: 0.1613 - val_mean_squared_error: 0.1613 - 78ms/epoch - 9ms/step
# Epoch 6/1000
# 9/9 - 0s - loss: 0.1560 - mean_squared_error: 0.1560 - val_loss: 0.1515 - val_mean_squared_error: 0.1515 - 93ms/epoch - 10ms/step
# Epoch 7/1000
# 9/9 - 0s - loss: 0.1462 - mean_squared_error: 0.1462 - val_loss: 0.1415 - val_mean_squared_error: 0.1415 - 99ms/epoch - 11ms/step
# Epoch 8/1000
# 9/9 - 0s - loss: 0.1361 - mean_squared_error: 0.1361 - val_loss: 0.1313 - val_mean_squared_error: 0.1313 - 91ms/epoch - 10ms/step
# Epoch 9/1000
# 9/9 - 0s - loss: 0.1258 - mean_squared_error: 0.1258 - val_loss: 0.1210 - val_mean_squared_error: 0.1210 - 94ms/epoch - 10ms/step
# Epoch 10/1000
# 9/9 - 0s - loss: 0.1155 - mean_squared_error: 0.1155 - val_loss: 0.1106 - val_mean_squared_error: 0.1106 - 93ms/epoch - 10ms/step
# Epoch 11/1000
# 9/9 - 0s - loss: 0.1053 - mean_squared_error: 0.1053 - val_loss: 0.1007 - val_mean_squared_error: 0.1007 - 98ms/epoch - 11ms/step
# Epoch 12/1000
# 9/9 - 0s - loss: 0.0956 - mean_squared_error: 0.0956 - val_loss: 0.0913 - val_mean_squared_error: 0.0913 - 74ms/epoch - 8ms/step
# Epoch 13/1000
# 9/9 - 0s - loss: 0.0866 - mean_squared_error: 0.0866 - val_loss: 0.0827 - val_mean_squared_error: 0.0827 - 83ms/epoch - 9ms/step
# Epoch 14/1000
# 9/9 - 0s - loss: 0.0785 - mean_squared_error: 0.0785 - val_loss: 0.0753 - val_mean_squared_error: 0.0753 - 97ms/epoch - 11ms/step
# Epoch 15/1000
# 9/9 - 0s - loss: 0.0716 - mean_squared_error: 0.0716 - val_loss: 0.0693 - val_mean_squared_error: 0.0693 - 95ms/epoch - 11ms/step
# Epoch 16/1000
# 9/9 - 0s - loss: 0.0661 - mean_squared_error: 0.0661 - val_loss: 0.0646 - val_mean_squared_error: 0.0646 - 85ms/epoch - 9ms/step
# Epoch 17/1000
# 9/9 - 0s - loss: 0.0620 - mean_squared_error: 0.0620 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - 94ms/epoch - 10ms/step
# Epoch 18/1000
# 9/9 - 0s - loss: 0.0592 - mean_squared_error: 0.0592 - val_loss: 0.0590 - val_mean_squared_error: 0.0590 - 94ms/epoch - 10ms/step
# Epoch 19/1000
# 9/9 - 0s - loss: 0.0573 - mean_squared_error: 0.0573 - val_loss: 0.0575 - val_mean_squared_error: 0.0575 - 78ms/epoch - 9ms/step
# Epoch 20/1000
# 9/9 - 0s - loss: 0.0560 - mean_squared_error: 0.0560 - val_loss: 0.0566 - val_mean_squared_error: 0.0566 - 107ms/epoch - 12ms/step
# Epoch 21/1000
# 9/9 - 0s - loss: 0.0552 - mean_squared_error: 0.0552 - val_loss: 0.0559 - val_mean_squared_error: 0.0559 - 78ms/epoch - 9ms/step
# Epoch 22/1000
# 9/9 - 0s - loss: 0.0545 - mean_squared_error: 0.0545 - val_loss: 0.0553 - val_mean_squared_error: 0.0553 - 108ms/epoch - 12ms/step
# Epoch 23/1000
# 9/9 - 0s - loss: 0.0540 - mean_squared_error: 0.0540 - val_loss: 0.0547 - val_mean_squared_error: 0.0547 - 95ms/epoch - 11ms/step
# Epoch 24/1000
# 9/9 - 0s - loss: 0.0534 - mean_squared_error: 0.0534 - val_loss: 0.0542 - val_mean_squared_error: 0.0542 - 76ms/epoch - 8ms/step
# Epoch 25/1000
# 9/9 - 0s - loss: 0.0529 - mean_squared_error: 0.0529 - val_loss: 0.0537 - val_mean_squared_error: 0.0537 - 97ms/epoch - 11ms/step
# Epoch 26/1000
# 9/9 - 0s - loss: 0.0524 - mean_squared_error: 0.0524 - val_loss: 0.0532 - val_mean_squared_error: 0.0532 - 91ms/epoch - 10ms/step
# Epoch 27/1000
# 9/9 - 0s - loss: 0.0519 - mean_squared_error: 0.0519 - val_loss: 0.0527 - val_mean_squared_error: 0.0527 - 78ms/epoch - 9ms/step
# Epoch 28/1000
# 9/9 - 0s - loss: 0.0514 - mean_squared_error: 0.0514 - val_loss: 0.0522 - val_mean_squared_error: 0.0522 - 98ms/epoch - 11ms/step
# Epoch 29/1000
# 9/9 - 0s - loss: 0.0509 - mean_squared_error: 0.0509 - val_loss: 0.0517 - val_mean_squared_error: 0.0517 - 88ms/epoch - 10ms/step
# Epoch 30/1000
# 9/9 - 0s - loss: 0.0504 - mean_squared_error: 0.0504 - val_loss: 0.0512 - val_mean_squared_error: 0.0512 - 78ms/epoch - 9ms/step
# Epoch 31/1000
# 9/9 - 0s - loss: 0.0500 - mean_squared_error: 0.0500 - val_loss: 0.0507 - val_mean_squared_error: 0.0507 - 78ms/epoch - 9ms/step
# Epoch 32/1000
# 9/9 - 0s - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0503 - val_mean_squared_error: 0.0503 - 95ms/epoch - 11ms/step
# Epoch 33/1000
# 9/9 - 0s - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0498 - val_mean_squared_error: 0.0498 - 91ms/epoch - 10ms/step
# Epoch 34/1000
# 9/9 - 0s - loss: 0.0486 - mean_squared_error: 0.0486 - val_loss: 0.0493 - val_mean_squared_error: 0.0493 - 87ms/epoch - 10ms/step
# Epoch 35/1000
# 9/9 - 0s - loss: 0.0482 - mean_squared_error: 0.0482 - val_loss: 0.0489 - val_mean_squared_error: 0.0489 - 86ms/epoch - 10ms/step
# Epoch 36/1000
# 9/9 - 0s - loss: 0.0477 - mean_squared_error: 0.0477 - val_loss: 0.0485 - val_mean_squared_error: 0.0485 - 88ms/epoch - 10ms/step
# Epoch 37/1000
# 9/9 - 0s - loss: 0.0473 - mean_squared_error: 0.0473 - val_loss: 0.0480 - val_mean_squared_error: 0.0480 - 97ms/epoch - 11ms/step
# Epoch 38/1000
# 9/9 - 0s - loss: 0.0469 - mean_squared_error: 0.0469 - val_loss: 0.0476 - val_mean_squared_error: 0.0476 - 78ms/epoch - 9ms/step
# Epoch 39/1000
# 9/9 - 0s - loss: 0.0464 - mean_squared_error: 0.0464 - val_loss: 0.0472 - val_mean_squared_error: 0.0472 - 85ms/epoch - 9ms/step
# Epoch 40/1000
# 9/9 - 0s - loss: 0.0460 - mean_squared_error: 0.0460 - val_loss: 0.0468 - val_mean_squared_error: 0.0468 - 93ms/epoch - 10ms/step
# Epoch 41/1000
# 9/9 - 0s - loss: 0.0456 - mean_squared_error: 0.0456 - val_loss: 0.0463 - val_mean_squared_error: 0.0463 - 91ms/epoch - 10ms/step
# Epoch 42/1000
# 9/9 - 0s - loss: 0.0452 - mean_squared_error: 0.0452 - val_loss: 0.0460 - val_mean_squared_error: 0.0460 - 91ms/epoch - 10ms/step
# Epoch 43/1000
# 9/9 - 0s - loss: 0.0449 - mean_squared_error: 0.0449 - val_loss: 0.0456 - val_mean_squared_error: 0.0456 - 97ms/epoch - 11ms/step
# Epoch 44/1000
# 9/9 - 0s - loss: 0.0445 - mean_squared_error: 0.0445 - val_loss: 0.0452 - val_mean_squared_error: 0.0452 - 86ms/epoch - 10ms/step
# Epoch 45/1000
# 9/9 - 0s - loss: 0.0441 - mean_squared_error: 0.0441 - val_loss: 0.0448 - val_mean_squared_error: 0.0448 - 82ms/epoch - 9ms/step
# Epoch 46/1000
# 9/9 - 0s - loss: 0.0437 - mean_squared_error: 0.0437 - val_loss: 0.0444 - val_mean_squared_error: 0.0444 - 87ms/epoch - 10ms/step
# Epoch 47/1000
# 9/9 - 0s - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0441 - val_mean_squared_error: 0.0441 - 83ms/epoch - 9ms/step
# Epoch 48/1000
# 9/9 - 0s - loss: 0.0430 - mean_squared_error: 0.0430 - val_loss: 0.0437 - val_mean_squared_error: 0.0437 - 102ms/epoch - 11ms/step
# Epoch 49/1000
# 9/9 - 0s - loss: 0.0427 - mean_squared_error: 0.0427 - val_loss: 0.0434 - val_mean_squared_error: 0.0434 - 94ms/epoch - 10ms/step
# Epoch 50/1000
# 9/9 - 0s - loss: 0.0423 - mean_squared_error: 0.0423 - val_loss: 0.0430 - val_mean_squared_error: 0.0430 - 95ms/epoch - 11ms/step
# Epoch 51/1000
# 9/9 - 0s - loss: 0.0420 - mean_squared_error: 0.0420 - val_loss: 0.0427 - val_mean_squared_error: 0.0427 - 99ms/epoch - 11ms/step
# Epoch 52/1000
# 9/9 - 0s - loss: 0.0417 - mean_squared_error: 0.0417 - val_loss: 0.0423 - val_mean_squared_error: 0.0423 - 94ms/epoch - 10ms/step
# Epoch 53/1000
# 9/9 - 0s - loss: 0.0414 - mean_squared_error: 0.0414 - val_loss: 0.0420 - val_mean_squared_error: 0.0420 - 78ms/epoch - 9ms/step
# Epoch 54/1000
# 9/9 - 0s - loss: 0.0411 - mean_squared_error: 0.0411 - val_loss: 0.0417 - val_mean_squared_error: 0.0417 - 78ms/epoch - 9ms/step
# Epoch 55/1000
# 9/9 - 0s - loss: 0.0408 - mean_squared_error: 0.0408 - val_loss: 0.0414 - val_mean_squared_error: 0.0414 - 102ms/epoch - 11ms/step
# Epoch 56/1000
# 9/9 - 0s - loss: 0.0405 - mean_squared_error: 0.0405 - val_loss: 0.0411 - val_mean_squared_error: 0.0411 - 84ms/epoch - 9ms/step
# Epoch 57/1000
# 9/9 - 0s - loss: 0.0402 - mean_squared_error: 0.0402 - val_loss: 0.0408 - val_mean_squared_error: 0.0408 - 90ms/epoch - 10ms/step
# Epoch 58/1000
# 9/9 - 0s - loss: 0.0399 - mean_squared_error: 0.0399 - val_loss: 0.0406 - val_mean_squared_error: 0.0406 - 95ms/epoch - 11ms/step
# Epoch 59/1000
# 9/9 - 0s - loss: 0.0397 - mean_squared_error: 0.0397 - val_loss: 0.0403 - val_mean_squared_error: 0.0403 - 122ms/epoch - 14ms/step
# Epoch 60/1000
# 9/9 - 0s - loss: 0.0394 - mean_squared_error: 0.0394 - val_loss: 0.0400 - val_mean_squared_error: 0.0400 - 109ms/epoch - 12ms/step
# Epoch 61/1000
# 9/9 - 0s - loss: 0.0392 - mean_squared_error: 0.0392 - val_loss: 0.0398 - val_mean_squared_error: 0.0398 - 107ms/epoch - 12ms/step
# Epoch 62/1000
# 9/9 - 0s - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0395 - val_mean_squared_error: 0.0395 - 109ms/epoch - 12ms/step
# Epoch 63/1000
# 9/9 - 0s - loss: 0.0387 - mean_squared_error: 0.0387 - val_loss: 0.0393 - val_mean_squared_error: 0.0393 - 106ms/epoch - 12ms/step
# Epoch 64/1000
# 9/9 - 0s - loss: 0.0385 - mean_squared_error: 0.0385 - val_loss: 0.0391 - val_mean_squared_error: 0.0391 - 120ms/epoch - 13ms/step
# Epoch 65/1000
# 9/9 - 0s - loss: 0.0383 - mean_squared_error: 0.0383 - val_loss: 0.0388 - val_mean_squared_error: 0.0388 - 107ms/epoch - 12ms/step
# Epoch 66/1000
# 9/9 - 0s - loss: 0.0381 - mean_squared_error: 0.0381 - val_loss: 0.0386 - val_mean_squared_error: 0.0386 - 102ms/epoch - 11ms/step
# Epoch 67/1000
# 9/9 - 0s - loss: 0.0379 - mean_squared_error: 0.0379 - val_loss: 0.0385 - val_mean_squared_error: 0.0385 - 130ms/epoch - 14ms/step
# Epoch 68/1000
# 9/9 - 0s - loss: 0.0377 - mean_squared_error: 0.0377 - val_loss: 0.0383 - val_mean_squared_error: 0.0383 - 105ms/epoch - 12ms/step
# Epoch 69/1000
# 9/9 - 0s - loss: 0.0375 - mean_squared_error: 0.0375 - val_loss: 0.0381 - val_mean_squared_error: 0.0381 - 102ms/epoch - 11ms/step
# Epoch 70/1000
# 9/9 - 0s - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0379 - val_mean_squared_error: 0.0379 - 132ms/epoch - 15ms/step
# Epoch 71/1000
# 9/9 - 0s - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0378 - val_mean_squared_error: 0.0378 - 107ms/epoch - 12ms/step
# Epoch 72/1000
# 9/9 - 0s - loss: 0.0371 - mean_squared_error: 0.0371 - val_loss: 0.0376 - val_mean_squared_error: 0.0376 - 106ms/epoch - 12ms/step
# Epoch 73/1000
# 9/9 - 0s - loss: 0.0369 - mean_squared_error: 0.0369 - val_loss: 0.0375 - val_mean_squared_error: 0.0375 - 117ms/epoch - 13ms/step
# Epoch 74/1000
# 9/9 - 0s - loss: 0.0368 - mean_squared_error: 0.0368 - val_loss: 0.0374 - val_mean_squared_error: 0.0374 - 95ms/epoch - 11ms/step
# Epoch 75/1000
# 9/9 - 0s - loss: 0.0367 - mean_squared_error: 0.0367 - val_loss: 0.0373 - val_mean_squared_error: 0.0373 - 123ms/epoch - 14ms/step
# Epoch 76/1000
# 9/9 - 0s - loss: 0.0366 - mean_squared_error: 0.0366 - val_loss: 0.0372 - val_mean_squared_error: 0.0372 - 126ms/epoch - 14ms/step
# Epoch 77/1000
# 9/9 - 0s - loss: 0.0365 - mean_squared_error: 0.0365 - val_loss: 0.0371 - val_mean_squared_error: 0.0371 - 97ms/epoch - 11ms/step
# Epoch 78/1000
# 9/9 - 0s - loss: 0.0364 - mean_squared_error: 0.0364 - val_loss: 0.0370 - val_mean_squared_error: 0.0370 - 105ms/epoch - 12ms/step
# Epoch 79/1000
# 9/9 - 0s - loss: 0.0363 - mean_squared_error: 0.0363 - val_loss: 0.0369 - val_mean_squared_error: 0.0369 - 106ms/epoch - 12ms/step
# Epoch 80/1000
# 9/9 - 0s - loss: 0.0362 - mean_squared_error: 0.0362 - val_loss: 0.0368 - val_mean_squared_error: 0.0368 - 109ms/epoch - 12ms/step
# Epoch 81/1000
# 9/9 - 0s - loss: 0.0362 - mean_squared_error: 0.0362 - val_loss: 0.0367 - val_mean_squared_error: 0.0367 - 110ms/epoch - 12ms/step
# Epoch 82/1000
# 9/9 - 0s - loss: 0.0361 - mean_squared_error: 0.0361 - val_loss: 0.0366 - val_mean_squared_error: 0.0366 - 104ms/epoch - 12ms/step
# Epoch 83/1000
# 9/9 - 0s - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.0366 - val_mean_squared_error: 0.0366 - 114ms/epoch - 13ms/step
# Epoch 84/1000
# 9/9 - 0s - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.0365 - val_mean_squared_error: 0.0365 - 123ms/epoch - 14ms/step
# Epoch 85/1000
# 9/9 - 0s - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0365 - val_mean_squared_error: 0.0365 - 98ms/epoch - 11ms/step
# Epoch 86/1000
# 9/9 - 0s - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0364 - val_mean_squared_error: 0.0364 - 102ms/epoch - 11ms/step
# Epoch 87/1000
# 9/9 - 0s - loss: 0.0358 - mean_squared_error: 0.0358 - val_loss: 0.0364 - val_mean_squared_error: 0.0364 - 116ms/epoch - 13ms/step
# Epoch 88/1000
# 9/9 - 0s - loss: 0.0358 - mean_squared_error: 0.0358 - val_loss: 0.0363 - val_mean_squared_error: 0.0363 - 100ms/epoch - 11ms/step
# Epoch 89/1000
# 9/9 - 0s - loss: 0.0357 - mean_squared_error: 0.0357 - val_loss: 0.0363 - val_mean_squared_error: 0.0363 - 118ms/epoch - 13ms/step
# Epoch 90/1000
# 9/9 - 0s - loss: 0.0357 - mean_squared_error: 0.0357 - val_loss: 0.0362 - val_mean_squared_error: 0.0362 - 135ms/epoch - 15ms/step
# Epoch 91/1000
# 9/9 - 0s - loss: 0.0357 - mean_squared_error: 0.0357 - val_loss: 0.0362 - val_mean_squared_error: 0.0362 - 104ms/epoch - 12ms/step
# Epoch 92/1000
# 9/9 - 0s - loss: 0.0356 - mean_squared_error: 0.0356 - val_loss: 0.0362 - val_mean_squared_error: 0.0362 - 115ms/epoch - 13ms/step
# Epoch 93/1000
# 9/9 - 0s - loss: 0.0356 - mean_squared_error: 0.0356 - val_loss: 0.0361 - val_mean_squared_error: 0.0361 - 122ms/epoch - 14ms/step
# Epoch 94/1000
# 9/9 - 0s - loss: 0.0356 - mean_squared_error: 0.0356 - val_loss: 0.0361 - val_mean_squared_error: 0.0361 - 84ms/epoch - 9ms/step
# Epoch 95/1000
# 9/9 - 0s - loss: 0.0355 - mean_squared_error: 0.0355 - val_loss: 0.0361 - val_mean_squared_error: 0.0361 - 117ms/epoch - 13ms/step
# Epoch 96/1000
# 9/9 - 0s - loss: 0.0355 - mean_squared_error: 0.0355 - val_loss: 0.0360 - val_mean_squared_error: 0.0360 - 99ms/epoch - 11ms/step
# Epoch 97/1000
# 9/9 - 0s - loss: 0.0355 - mean_squared_error: 0.0355 - val_loss: 0.0360 - val_mean_squared_error: 0.0360 - 117ms/epoch - 13ms/step
# Epoch 98/1000
# 9/9 - 0s - loss: 0.0355 - mean_squared_error: 0.0355 - val_loss: 0.0360 - val_mean_squared_error: 0.0360 - 120ms/epoch - 13ms/step
# Epoch 99/1000
# 9/9 - 0s - loss: 0.0354 - mean_squared_error: 0.0354 - val_loss: 0.0360 - val_mean_squared_error: 0.0360 - 111ms/epoch - 12ms/step
# Epoch 100/1000
# 9/9 - 0s - loss: 0.0354 - mean_squared_error: 0.0354 - val_loss: 0.0359 - val_mean_squared_error: 0.0359 - 126ms/epoch - 14ms/step
# Epoch 101/1000
# 9/9 - 0s - loss: 0.0354 - mean_squared_error: 0.0354 - val_loss: 0.0359 - val_mean_squared_error: 0.0359 - 104ms/epoch - 12ms/step
# Epoch 102/1000
# 9/9 - 0s - loss: 0.0354 - mean_squared_error: 0.0354 - val_loss: 0.0359 - val_mean_squared_error: 0.0359 - 97ms/epoch - 11ms/step
# Epoch 103/1000
# 9/9 - 0s - loss: 0.0353 - mean_squared_error: 0.0353 - val_loss: 0.0359 - val_mean_squared_error: 0.0359 - 133ms/epoch - 15ms/step
# Epoch 104/1000
# 9/9 - 0s - loss: 0.0353 - mean_squared_error: 0.0353 - val_loss: 0.0359 - val_mean_squared_error: 0.0359 - 105ms/epoch - 12ms/step
# Epoch 105/1000
# 9/9 - 0s - loss: 0.0353 - mean_squared_error: 0.0353 - val_loss: 0.0358 - val_mean_squared_error: 0.0358 - 111ms/epoch - 12ms/step
# Epoch 106/1000
# 9/9 - 0s - loss: 0.0353 - mean_squared_error: 0.0353 - val_loss: 0.0358 - val_mean_squared_error: 0.0358 - 117ms/epoch - 13ms/step
# Epoch 107/1000
# 9/9 - 0s - loss: 0.0353 - mean_squared_error: 0.0353 - val_loss: 0.0358 - val_mean_squared_error: 0.0358 - 104ms/epoch - 12ms/step
# Epoch 108/1000
# 9/9 - 0s - loss: 0.0353 - mean_squared_error: 0.0353 - val_loss: 0.0358 - val_mean_squared_error: 0.0358 - 110ms/epoch - 12ms/step
# Epoch 109/1000
# 9/9 - 0s - loss: 0.0352 - mean_squared_error: 0.0352 - val_loss: 0.0358 - val_mean_squared_error: 0.0358 - 111ms/epoch - 12ms/step
# Epoch 110/1000
# 9/9 - 0s - loss: 0.0352 - mean_squared_error: 0.0352 - val_loss: 0.0358 - val_mean_squared_error: 0.0358 - 89ms/epoch - 10ms/step
# Epoch 111/1000
# 9/9 - 0s - loss: 0.0352 - mean_squared_error: 0.0352 - val_loss: 0.0357 - val_mean_squared_error: 0.0357 - 127ms/epoch - 14ms/step
# Epoch 112/1000
# 9/9 - 0s - loss: 0.0352 - mean_squared_error: 0.0352 - val_loss: 0.0357 - val_mean_squared_error: 0.0357 - 120ms/epoch - 13ms/step
# Epoch 113/1000
# 9/9 - 0s - loss: 0.0352 - mean_squared_error: 0.0352 - val_loss: 0.0357 - val_mean_squared_error: 0.0357 - 113ms/epoch - 13ms/step
# Epoch 114/1000
# 9/9 - 0s - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0357 - val_mean_squared_error: 0.0357 - 102ms/epoch - 11ms/step
# Epoch 115/1000
# 9/9 - 0s - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0356 - val_mean_squared_error: 0.0356 - 111ms/epoch - 12ms/step
# Epoch 116/1000
# 9/9 - 0s - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0356 - val_mean_squared_error: 0.0356 - 132ms/epoch - 15ms/step
# Epoch 117/1000
# 9/9 - 0s - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0356 - val_mean_squared_error: 0.0356 - 108ms/epoch - 12ms/step
# Epoch 118/1000
# 9/9 - 0s - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0356 - val_mean_squared_error: 0.0356 - 108ms/epoch - 12ms/step
# Epoch 119/1000
# 9/9 - 0s - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0356 - val_mean_squared_error: 0.0356 - 121ms/epoch - 13ms/step
# Epoch 120/1000
# 9/9 - 0s - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0356 - val_mean_squared_error: 0.0356 - 101ms/epoch - 11ms/step
# Epoch 121/1000
# 9/9 - 0s - loss: 0.0350 - mean_squared_error: 0.0350 - val_loss: 0.0356 - val_mean_squared_error: 0.0356 - 111ms/epoch - 12ms/step
# Epoch 122/1000
# 9/9 - 0s - loss: 0.0350 - mean_squared_error: 0.0350 - val_loss: 0.0356 - val_mean_squared_error: 0.0356 - 126ms/epoch - 14ms/step
# Epoch 123/1000
# 9/9 - 0s - loss: 0.0350 - mean_squared_error: 0.0350 - val_loss: 0.0355 - val_mean_squared_error: 0.0355 - 104ms/epoch - 12ms/step
# Epoch 124/1000
# 9/9 - 0s - loss: 0.0350 - mean_squared_error: 0.0350 - val_loss: 0.0355 - val_mean_squared_error: 0.0355 - 111ms/epoch - 12ms/step
# Epoch 125/1000
# 9/9 - 0s - loss: 0.0350 - mean_squared_error: 0.0350 - val_loss: 0.0355 - val_mean_squared_error: 0.0355 - 118ms/epoch - 13ms/step
# Epoch 126/1000
# 9/9 - 0s - loss: 0.0350 - mean_squared_error: 0.0350 - val_loss: 0.0355 - val_mean_squared_error: 0.0355 - 120ms/epoch - 13ms/step
# Epoch 127/1000
# 9/9 - 0s - loss: 0.0350 - mean_squared_error: 0.0350 - val_loss: 0.0355 - val_mean_squared_error: 0.0355 - 113ms/epoch - 13ms/step
# Epoch 128/1000
# 9/9 - 0s - loss: 0.0349 - mean_squared_error: 0.0349 - val_loss: 0.0355 - val_mean_squared_error: 0.0355 - 102ms/epoch - 11ms/step
# Epoch 129/1000
# 9/9 - 0s - loss: 0.0349 - mean_squared_error: 0.0349 - val_loss: 0.0355 - val_mean_squared_error: 0.0355 - 108ms/epoch - 12ms/step
# Epoch 130/1000
# 9/9 - 0s - loss: 0.0349 - mean_squared_error: 0.0349 - val_loss: 0.0354 - val_mean_squared_error: 0.0354 - 96ms/epoch - 11ms/step
# Epoch 131/1000
# 9/9 - 0s - loss: 0.0349 - mean_squared_error: 0.0349 - val_loss: 0.0354 - val_mean_squared_error: 0.0354 - 130ms/epoch - 14ms/step
# Epoch 132/1000
# 9/9 - 0s - loss: 0.0349 - mean_squared_error: 0.0349 - val_loss: 0.0354 - val_mean_squared_error: 0.0354 - 114ms/epoch - 13ms/step
# Epoch 133/1000
# 9/9 - 0s - loss: 0.0349 - mean_squared_error: 0.0349 - val_loss: 0.0354 - val_mean_squared_error: 0.0354 - 105ms/epoch - 12ms/step
# Epoch 134/1000
# 9/9 - 0s - loss: 0.0349 - mean_squared_error: 0.0349 - val_loss: 0.0354 - val_mean_squared_error: 0.0354 - 100ms/epoch - 11ms/step
# Epoch 135/1000
# 9/9 - 0s - loss: 0.0348 - mean_squared_error: 0.0348 - val_loss: 0.0354 - val_mean_squared_error: 0.0354 - 103ms/epoch - 11ms/step
# Epoch 136/1000
# 9/9 - 0s - loss: 0.0348 - mean_squared_error: 0.0348 - val_loss: 0.0353 - val_mean_squared_error: 0.0353 - 113ms/epoch - 13ms/step
# Epoch 137/1000
# 9/9 - 0s - loss: 0.0348 - mean_squared_error: 0.0348 - val_loss: 0.0353 - val_mean_squared_error: 0.0353 - 108ms/epoch - 12ms/step
# Epoch 138/1000
# 9/9 - 0s - loss: 0.0348 - mean_squared_error: 0.0348 - val_loss: 0.0353 - val_mean_squared_error: 0.0353 - 107ms/epoch - 12ms/step
# Epoch 139/1000
# 9/9 - 0s - loss: 0.0348 - mean_squared_error: 0.0348 - val_loss: 0.0353 - val_mean_squared_error: 0.0353 - 118ms/epoch - 13ms/step
# Epoch 140/1000
# 9/9 - 0s - loss: 0.0348 - mean_squared_error: 0.0348 - val_loss: 0.0353 - val_mean_squared_error: 0.0353 - 104ms/epoch - 12ms/step
# Epoch 141/1000
# 9/9 - 0s - loss: 0.0348 - mean_squared_error: 0.0348 - val_loss: 0.0353 - val_mean_squared_error: 0.0353 - 119ms/epoch - 13ms/step
# Epoch 142/1000
# 9/9 - 0s - loss: 0.0348 - mean_squared_error: 0.0348 - val_loss: 0.0353 - val_mean_squared_error: 0.0353 - 114ms/epoch - 13ms/step
# Epoch 143/1000
# 9/9 - 0s - loss: 0.0347 - mean_squared_error: 0.0347 - val_loss: 0.0352 - val_mean_squared_error: 0.0352 - 93ms/epoch - 10ms/step
# Epoch 144/1000
# 9/9 - 0s - loss: 0.0347 - mean_squared_error: 0.0347 - val_loss: 0.0352 - val_mean_squared_error: 0.0352 - 101ms/epoch - 11ms/step
# Epoch 145/1000
# 9/9 - 0s - loss: 0.0347 - mean_squared_error: 0.0347 - val_loss: 0.0352 - val_mean_squared_error: 0.0352 - 96ms/epoch - 11ms/step
# Epoch 146/1000
# 9/9 - 0s - loss: 0.0347 - mean_squared_error: 0.0347 - val_loss: 0.0352 - val_mean_squared_error: 0.0352 - 98ms/epoch - 11ms/step
# Epoch 147/1000
# 9/9 - 0s - loss: 0.0347 - mean_squared_error: 0.0347 - val_loss: 0.0352 - val_mean_squared_error: 0.0352 - 93ms/epoch - 10ms/step
# Epoch 148/1000
# 9/9 - 0s - loss: 0.0347 - mean_squared_error: 0.0347 - val_loss: 0.0352 - val_mean_squared_error: 0.0352 - 85ms/epoch - 9ms/step
# Epoch 149/1000
# 9/9 - 0s - loss: 0.0347 - mean_squared_error: 0.0347 - val_loss: 0.0352 - val_mean_squared_error: 0.0352 - 91ms/epoch - 10ms/step
# Epoch 150/1000
# 9/9 - 0s - loss: 0.0347 - mean_squared_error: 0.0347 - val_loss: 0.0352 - val_mean_squared_error: 0.0352 - 94ms/epoch - 10ms/step
# Epoch 151/1000
# 9/9 - 0s - loss: 0.0346 - mean_squared_error: 0.0346 - val_loss: 0.0352 - val_mean_squared_error: 0.0352 - 96ms/epoch - 11ms/step
# Epoch 152/1000
# 9/9 - 0s - loss: 0.0346 - mean_squared_error: 0.0346 - val_loss: 0.0351 - val_mean_squared_error: 0.0351 - 89ms/epoch - 10ms/step
# Epoch 153/1000
# 9/9 - 0s - loss: 0.0346 - mean_squared_error: 0.0346 - val_loss: 0.0351 - val_mean_squared_error: 0.0351 - 78ms/epoch - 9ms/step
# Epoch 154/1000
# 9/9 - 0s - loss: 0.0346 - mean_squared_error: 0.0346 - val_loss: 0.0351 - val_mean_squared_error: 0.0351 - 108ms/epoch - 12ms/step
# Epoch 155/1000
# 9/9 - 0s - loss: 0.0346 - mean_squared_error: 0.0346 - val_loss: 0.0351 - val_mean_squared_error: 0.0351 - 78ms/epoch - 9ms/step
# Epoch 156/1000
# 9/9 - 0s - loss: 0.0346 - mean_squared_error: 0.0346 - val_loss: 0.0351 - val_mean_squared_error: 0.0351 - 102ms/epoch - 11ms/step
# Epoch 157/1000
# 9/9 - 0s - loss: 0.0346 - mean_squared_error: 0.0346 - val_loss: 0.0351 - val_mean_squared_error: 0.0351 - 97ms/epoch - 11ms/step
# Epoch 158/1000
# 9/9 - 0s - loss: 0.0345 - mean_squared_error: 0.0345 - val_loss: 0.0351 - val_mean_squared_error: 0.0351 - 90ms/epoch - 10ms/step
# Epoch 159/1000
# 9/9 - 0s - loss: 0.0345 - mean_squared_error: 0.0345 - val_loss: 0.0350 - val_mean_squared_error: 0.0350 - 99ms/epoch - 11ms/step
# Epoch 160/1000
# 9/9 - 0s - loss: 0.0345 - mean_squared_error: 0.0345 - val_loss: 0.0350 - val_mean_squared_error: 0.0350 - 78ms/epoch - 9ms/step
# Epoch 161/1000
# 9/9 - 0s - loss: 0.0345 - mean_squared_error: 0.0345 - val_loss: 0.0350 - val_mean_squared_error: 0.0350 - 121ms/epoch - 13ms/step
# Epoch 162/1000
# 9/9 - 0s - loss: 0.0345 - mean_squared_error: 0.0345 - val_loss: 0.0350 - val_mean_squared_error: 0.0350 - 101ms/epoch - 11ms/step
# Epoch 163/1000
# 9/9 - 0s - loss: 0.0345 - mean_squared_error: 0.0345 - val_loss: 0.0350 - val_mean_squared_error: 0.0350 - 93ms/epoch - 10ms/step
# Epoch 164/1000
# 9/9 - 0s - loss: 0.0345 - mean_squared_error: 0.0345 - val_loss: 0.0349 - val_mean_squared_error: 0.0349 - 116ms/epoch - 13ms/step
# Epoch 165/1000
# 9/9 - 0s - loss: 0.0345 - mean_squared_error: 0.0345 - val_loss: 0.0349 - val_mean_squared_error: 0.0349 - 106ms/epoch - 12ms/step
# Epoch 166/1000
# 9/9 - 0s - loss: 0.0344 - mean_squared_error: 0.0344 - val_loss: 0.0349 - val_mean_squared_error: 0.0349 - 118ms/epoch - 13ms/step
# Epoch 167/1000
# 9/9 - 0s - loss: 0.0344 - mean_squared_error: 0.0344 - val_loss: 0.0349 - val_mean_squared_error: 0.0349 - 99ms/epoch - 11ms/step
# Epoch 168/1000
# 9/9 - 0s - loss: 0.0344 - mean_squared_error: 0.0344 - val_loss: 0.0349 - val_mean_squared_error: 0.0349 - 80ms/epoch - 9ms/step
# Epoch 169/1000
# 9/9 - 0s - loss: 0.0344 - mean_squared_error: 0.0344 - val_loss: 0.0349 - val_mean_squared_error: 0.0349 - 107ms/epoch - 12ms/step
# Epoch 170/1000
# 9/9 - 0s - loss: 0.0344 - mean_squared_error: 0.0344 - val_loss: 0.0349 - val_mean_squared_error: 0.0349 - 80ms/epoch - 9ms/step
# Epoch 171/1000
# 9/9 - 0s - loss: 0.0344 - mean_squared_error: 0.0344 - val_loss: 0.0348 - val_mean_squared_error: 0.0348 - 85ms/epoch - 9ms/step
# Epoch 172/1000
# 9/9 - 0s - loss: 0.0343 - mean_squared_error: 0.0343 - val_loss: 0.0348 - val_mean_squared_error: 0.0348 - 96ms/epoch - 11ms/step
# Epoch 173/1000
# 9/9 - 0s - loss: 0.0343 - mean_squared_error: 0.0343 - val_loss: 0.0348 - val_mean_squared_error: 0.0348 - 81ms/epoch - 9ms/step
# Epoch 174/1000
# 9/9 - 0s - loss: 0.0343 - mean_squared_error: 0.0343 - val_loss: 0.0348 - val_mean_squared_error: 0.0348 - 90ms/epoch - 10ms/step
# Epoch 175/1000
# 9/9 - 0s - loss: 0.0343 - mean_squared_error: 0.0343 - val_loss: 0.0348 - val_mean_squared_error: 0.0348 - 87ms/epoch - 10ms/step
# Epoch 176/1000
# 9/9 - 0s - loss: 0.0343 - mean_squared_error: 0.0343 - val_loss: 0.0347 - val_mean_squared_error: 0.0347 - 97ms/epoch - 11ms/step
# Epoch 177/1000
# 9/9 - 0s - loss: 0.0343 - mean_squared_error: 0.0343 - val_loss: 0.0347 - val_mean_squared_error: 0.0347 - 105ms/epoch - 12ms/step
# Epoch 178/1000
# 9/9 - 0s - loss: 0.0342 - mean_squared_error: 0.0342 - val_loss: 0.0347 - val_mean_squared_error: 0.0347 - 89ms/epoch - 10ms/step
# Epoch 179/1000
# 9/9 - 0s - loss: 0.0342 - mean_squared_error: 0.0342 - val_loss: 0.0347 - val_mean_squared_error: 0.0347 - 111ms/epoch - 12ms/step
# Epoch 180/1000
# 9/9 - 0s - loss: 0.0342 - mean_squared_error: 0.0342 - val_loss: 0.0347 - val_mean_squared_error: 0.0347 - 92ms/epoch - 10ms/step
# Epoch 181/1000
# 9/9 - 0s - loss: 0.0342 - mean_squared_error: 0.0342 - val_loss: 0.0347 - val_mean_squared_error: 0.0347 - 95ms/epoch - 11ms/step
# Epoch 182/1000
# 9/9 - 0s - loss: 0.0342 - mean_squared_error: 0.0342 - val_loss: 0.0346 - val_mean_squared_error: 0.0346 - 94ms/epoch - 10ms/step
# Epoch 183/1000
# 9/9 - 0s - loss: 0.0341 - mean_squared_error: 0.0341 - val_loss: 0.0346 - val_mean_squared_error: 0.0346 - 78ms/epoch - 9ms/step
# Epoch 184/1000
# 9/9 - 0s - loss: 0.0341 - mean_squared_error: 0.0341 - val_loss: 0.0346 - val_mean_squared_error: 0.0346 - 99ms/epoch - 11ms/step
# Epoch 185/1000
# 9/9 - 0s - loss: 0.0341 - mean_squared_error: 0.0341 - val_loss: 0.0345 - val_mean_squared_error: 0.0345 - 97ms/epoch - 11ms/step
# Epoch 186/1000
# 9/9 - 0s - loss: 0.0341 - mean_squared_error: 0.0341 - val_loss: 0.0345 - val_mean_squared_error: 0.0345 - 83ms/epoch - 9ms/step
# Epoch 187/1000
# 9/9 - 0s - loss: 0.0340 - mean_squared_error: 0.0340 - val_loss: 0.0345 - val_mean_squared_error: 0.0345 - 97ms/epoch - 11ms/step
# Epoch 188/1000
# 9/9 - 0s - loss: 0.0340 - mean_squared_error: 0.0340 - val_loss: 0.0345 - val_mean_squared_error: 0.0345 - 76ms/epoch - 8ms/step
# Epoch 189/1000
# 9/9 - 0s - loss: 0.0340 - mean_squared_error: 0.0340 - val_loss: 0.0344 - val_mean_squared_error: 0.0344 - 99ms/epoch - 11ms/step
# Epoch 190/1000
# 9/9 - 0s - loss: 0.0340 - mean_squared_error: 0.0340 - val_loss: 0.0344 - val_mean_squared_error: 0.0344 - 94ms/epoch - 10ms/step
# Epoch 191/1000
# 9/9 - 0s - loss: 0.0339 - mean_squared_error: 0.0339 - val_loss: 0.0344 - val_mean_squared_error: 0.0344 - 91ms/epoch - 10ms/step
# Epoch 192/1000
# 9/9 - 0s - loss: 0.0339 - mean_squared_error: 0.0339 - val_loss: 0.0344 - val_mean_squared_error: 0.0344 - 91ms/epoch - 10ms/step
# Epoch 193/1000
# 9/9 - 0s - loss: 0.0339 - mean_squared_error: 0.0339 - val_loss: 0.0343 - val_mean_squared_error: 0.0343 - 94ms/epoch - 10ms/step
# Epoch 194/1000
# 9/9 - 0s - loss: 0.0338 - mean_squared_error: 0.0338 - val_loss: 0.0343 - val_mean_squared_error: 0.0343 - 94ms/epoch - 10ms/step
# Epoch 195/1000
# 9/9 - 0s - loss: 0.0338 - mean_squared_error: 0.0338 - val_loss: 0.0342 - val_mean_squared_error: 0.0342 - 94ms/epoch - 10ms/step
# Epoch 196/1000
# 9/9 - 0s - loss: 0.0338 - mean_squared_error: 0.0338 - val_loss: 0.0342 - val_mean_squared_error: 0.0342 - 102ms/epoch - 11ms/step
# Epoch 197/1000
# 9/9 - 0s - loss: 0.0337 - mean_squared_error: 0.0337 - val_loss: 0.0342 - val_mean_squared_error: 0.0342 - 104ms/epoch - 12ms/step
# Epoch 198/1000
# 9/9 - 0s - loss: 0.0337 - mean_squared_error: 0.0337 - val_loss: 0.0341 - val_mean_squared_error: 0.0341 - 87ms/epoch - 10ms/step
# Epoch 199/1000
# 9/9 - 0s - loss: 0.0336 - mean_squared_error: 0.0336 - val_loss: 0.0341 - val_mean_squared_error: 0.0341 - 101ms/epoch - 11ms/step
# Epoch 200/1000
# 9/9 - 0s - loss: 0.0336 - mean_squared_error: 0.0336 - val_loss: 0.0340 - val_mean_squared_error: 0.0340 - 104ms/epoch - 12ms/step
# Epoch 201/1000
# 9/9 - 0s - loss: 0.0336 - mean_squared_error: 0.0336 - val_loss: 0.0340 - val_mean_squared_error: 0.0340 - 92ms/epoch - 10ms/step
# Epoch 202/1000
# 9/9 - 0s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0339 - val_mean_squared_error: 0.0339 - 94ms/epoch - 10ms/step
# Epoch 203/1000
# 9/9 - 0s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0338 - val_mean_squared_error: 0.0338 - 94ms/epoch - 10ms/step
# Epoch 204/1000
# 9/9 - 0s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0338 - val_mean_squared_error: 0.0338 - 94ms/epoch - 10ms/step
# Epoch 205/1000
# 9/9 - 0s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0337 - val_mean_squared_error: 0.0337 - 93ms/epoch - 10ms/step
# Epoch 206/1000
# 9/9 - 0s - loss: 0.0333 - mean_squared_error: 0.0333 - val_loss: 0.0337 - val_mean_squared_error: 0.0337 - 93ms/epoch - 10ms/step
# Epoch 207/1000
# 9/9 - 0s - loss: 0.0332 - mean_squared_error: 0.0332 - val_loss: 0.0336 - val_mean_squared_error: 0.0336 - 88ms/epoch - 10ms/step
# Epoch 208/1000
# 9/9 - 0s - loss: 0.0332 - mean_squared_error: 0.0332 - val_loss: 0.0336 - val_mean_squared_error: 0.0336 - 94ms/epoch - 10ms/step
# Epoch 209/1000
# 9/9 - 0s - loss: 0.0331 - mean_squared_error: 0.0331 - val_loss: 0.0335 - val_mean_squared_error: 0.0335 - 94ms/epoch - 10ms/step
# Epoch 210/1000
# 9/9 - 0s - loss: 0.0330 - mean_squared_error: 0.0330 - val_loss: 0.0334 - val_mean_squared_error: 0.0334 - 94ms/epoch - 10ms/step
# Epoch 211/1000
# 9/9 - 0s - loss: 0.0330 - mean_squared_error: 0.0330 - val_loss: 0.0333 - val_mean_squared_error: 0.0333 - 96ms/epoch - 11ms/step
# Epoch 212/1000
# 9/9 - 0s - loss: 0.0329 - mean_squared_error: 0.0329 - val_loss: 0.0332 - val_mean_squared_error: 0.0332 - 91ms/epoch - 10ms/step
# Epoch 213/1000
# 9/9 - 0s - loss: 0.0328 - mean_squared_error: 0.0328 - val_loss: 0.0332 - val_mean_squared_error: 0.0332 - 78ms/epoch - 9ms/step
# Epoch 214/1000
# 9/9 - 0s - loss: 0.0327 - mean_squared_error: 0.0327 - val_loss: 0.0331 - val_mean_squared_error: 0.0331 - 100ms/epoch - 11ms/step
# Epoch 215/1000
# 9/9 - 0s - loss: 0.0326 - mean_squared_error: 0.0326 - val_loss: 0.0330 - val_mean_squared_error: 0.0330 - 92ms/epoch - 10ms/step
# Epoch 216/1000
# 9/9 - 0s - loss: 0.0326 - mean_squared_error: 0.0326 - val_loss: 0.0329 - val_mean_squared_error: 0.0329 - 102ms/epoch - 11ms/step
# Epoch 217/1000
# 9/9 - 0s - loss: 0.0325 - mean_squared_error: 0.0325 - val_loss: 0.0328 - val_mean_squared_error: 0.0328 - 90ms/epoch - 10ms/step
# Epoch 218/1000
# 9/9 - 0s - loss: 0.0324 - mean_squared_error: 0.0324 - val_loss: 0.0327 - val_mean_squared_error: 0.0327 - 103ms/epoch - 11ms/step
# Epoch 219/1000
# 9/9 - 0s - loss: 0.0323 - mean_squared_error: 0.0323 - val_loss: 0.0326 - val_mean_squared_error: 0.0326 - 97ms/epoch - 11ms/step
# Epoch 220/1000
# 9/9 - 0s - loss: 0.0322 - mean_squared_error: 0.0322 - val_loss: 0.0324 - val_mean_squared_error: 0.0324 - 100ms/epoch - 11ms/step
# Epoch 221/1000
# 9/9 - 0s - loss: 0.0320 - mean_squared_error: 0.0320 - val_loss: 0.0323 - val_mean_squared_error: 0.0323 - 96ms/epoch - 11ms/step
# Epoch 222/1000
# 9/9 - 0s - loss: 0.0319 - mean_squared_error: 0.0319 - val_loss: 0.0322 - val_mean_squared_error: 0.0322 - 95ms/epoch - 11ms/step
# Epoch 223/1000
# 9/9 - 0s - loss: 0.0318 - mean_squared_error: 0.0318 - val_loss: 0.0321 - val_mean_squared_error: 0.0321 - 105ms/epoch - 12ms/step
# Epoch 224/1000
# 9/9 - 0s - loss: 0.0317 - mean_squared_error: 0.0317 - val_loss: 0.0319 - val_mean_squared_error: 0.0319 - 90ms/epoch - 10ms/step
# Epoch 225/1000
# 9/9 - 0s - loss: 0.0316 - mean_squared_error: 0.0316 - val_loss: 0.0318 - val_mean_squared_error: 0.0318 - 105ms/epoch - 12ms/step
# Epoch 226/1000
# 9/9 - 0s - loss: 0.0314 - mean_squared_error: 0.0314 - val_loss: 0.0316 - val_mean_squared_error: 0.0316 - 97ms/epoch - 11ms/step
# Epoch 227/1000
# 9/9 - 0s - loss: 0.0313 - mean_squared_error: 0.0313 - val_loss: 0.0315 - val_mean_squared_error: 0.0315 - 95ms/epoch - 11ms/step
# Epoch 228/1000
# 9/9 - 0s - loss: 0.0312 - mean_squared_error: 0.0312 - val_loss: 0.0314 - val_mean_squared_error: 0.0314 - 102ms/epoch - 11ms/step
# Epoch 229/1000
# 9/9 - 0s - loss: 0.0310 - mean_squared_error: 0.0310 - val_loss: 0.0312 - val_mean_squared_error: 0.0312 - 94ms/epoch - 10ms/step
# Epoch 230/1000
# 9/9 - 0s - loss: 0.0309 - mean_squared_error: 0.0309 - val_loss: 0.0311 - val_mean_squared_error: 0.0311 - 105ms/epoch - 12ms/step
# Epoch 231/1000
# 9/9 - 0s - loss: 0.0308 - mean_squared_error: 0.0308 - val_loss: 0.0309 - val_mean_squared_error: 0.0309 - 96ms/epoch - 11ms/step
# Epoch 232/1000
# 9/9 - 0s - loss: 0.0306 - mean_squared_error: 0.0306 - val_loss: 0.0307 - val_mean_squared_error: 0.0307 - 92ms/epoch - 10ms/step
# Epoch 233/1000
# 9/9 - 0s - loss: 0.0305 - mean_squared_error: 0.0305 - val_loss: 0.0306 - val_mean_squared_error: 0.0306 - 110ms/epoch - 12ms/step
# Epoch 234/1000
# 9/9 - 0s - loss: 0.0303 - mean_squared_error: 0.0303 - val_loss: 0.0305 - val_mean_squared_error: 0.0305 - 103ms/epoch - 11ms/step
# Epoch 235/1000
# 9/9 - 0s - loss: 0.0302 - mean_squared_error: 0.0302 - val_loss: 0.0303 - val_mean_squared_error: 0.0303 - 93ms/epoch - 10ms/step
# Epoch 236/1000
# 9/9 - 0s - loss: 0.0301 - mean_squared_error: 0.0301 - val_loss: 0.0302 - val_mean_squared_error: 0.0302 - 100ms/epoch - 11ms/step
# Epoch 237/1000
# 9/9 - 0s - loss: 0.0299 - mean_squared_error: 0.0299 - val_loss: 0.0300 - val_mean_squared_error: 0.0300 - 101ms/epoch - 11ms/step
# Epoch 238/1000
# 9/9 - 0s - loss: 0.0298 - mean_squared_error: 0.0298 - val_loss: 0.0299 - val_mean_squared_error: 0.0299 - 111ms/epoch - 12ms/step
# Epoch 239/1000
# 9/9 - 0s - loss: 0.0297 - mean_squared_error: 0.0297 - val_loss: 0.0297 - val_mean_squared_error: 0.0297 - 98ms/epoch - 11ms/step
# Epoch 240/1000
# 9/9 - 0s - loss: 0.0295 - mean_squared_error: 0.0295 - val_loss: 0.0296 - val_mean_squared_error: 0.0296 - 105ms/epoch - 12ms/step
# Epoch 241/1000
# 9/9 - 0s - loss: 0.0294 - mean_squared_error: 0.0294 - val_loss: 0.0295 - val_mean_squared_error: 0.0295 - 99ms/epoch - 11ms/step
# Epoch 242/1000
# 9/9 - 0s - loss: 0.0293 - mean_squared_error: 0.0293 - val_loss: 0.0294 - val_mean_squared_error: 0.0294 - 108ms/epoch - 12ms/step
# Epoch 243/1000
# 9/9 - 0s - loss: 0.0292 - mean_squared_error: 0.0292 - val_loss: 0.0292 - val_mean_squared_error: 0.0292 - 104ms/epoch - 12ms/step
# Epoch 244/1000
# 9/9 - 0s - loss: 0.0291 - mean_squared_error: 0.0291 - val_loss: 0.0291 - val_mean_squared_error: 0.0291 - 98ms/epoch - 11ms/step
# Epoch 245/1000
# 9/9 - 0s - loss: 0.0290 - mean_squared_error: 0.0290 - val_loss: 0.0290 - val_mean_squared_error: 0.0290 - 98ms/epoch - 11ms/step
# Epoch 246/1000
# 9/9 - 0s - loss: 0.0289 - mean_squared_error: 0.0289 - val_loss: 0.0289 - val_mean_squared_error: 0.0289 - 103ms/epoch - 11ms/step
# Epoch 247/1000
# 9/9 - 0s - loss: 0.0288 - mean_squared_error: 0.0288 - val_loss: 0.0288 - val_mean_squared_error: 0.0288 - 97ms/epoch - 11ms/step
# Epoch 248/1000
# 9/9 - 0s - loss: 0.0287 - mean_squared_error: 0.0287 - val_loss: 0.0287 - val_mean_squared_error: 0.0287 - 98ms/epoch - 11ms/step
# Epoch 249/1000
# 9/9 - 0s - loss: 0.0286 - mean_squared_error: 0.0286 - val_loss: 0.0286 - val_mean_squared_error: 0.0286 - 95ms/epoch - 11ms/step
# Epoch 250/1000
# 9/9 - 0s - loss: 0.0286 - mean_squared_error: 0.0286 - val_loss: 0.0285 - val_mean_squared_error: 0.0285 - 92ms/epoch - 10ms/step
# Epoch 251/1000
# 9/9 - 0s - loss: 0.0285 - mean_squared_error: 0.0285 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - 95ms/epoch - 11ms/step
# Epoch 252/1000
# 9/9 - 0s - loss: 0.0284 - mean_squared_error: 0.0284 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - 109ms/epoch - 12ms/step
# Epoch 253/1000
# 9/9 - 0s - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - 94ms/epoch - 10ms/step
# Epoch 254/1000
# 9/9 - 0s - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - 93ms/epoch - 10ms/step
# Epoch 255/1000
# 9/9 - 0s - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - 97ms/epoch - 11ms/step
# Epoch 256/1000
# 9/9 - 0s - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - 111ms/epoch - 12ms/step
# Epoch 257/1000
# 9/9 - 0s - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - 84ms/epoch - 9ms/step
# Epoch 258/1000
# 9/9 - 0s - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0279 - val_mean_squared_error: 0.0279 - 122ms/epoch - 14ms/step
# Epoch 259/1000
# 9/9 - 0s - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - 106ms/epoch - 12ms/step
# Epoch 260/1000
# 9/9 - 0s - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - 109ms/epoch - 12ms/step
# Epoch 261/1000
# 9/9 - 0s - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - 109ms/epoch - 12ms/step
# Epoch 262/1000
# 9/9 - 0s - loss: 0.0277 - mean_squared_error: 0.0277 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - 96ms/epoch - 11ms/step
# Epoch 263/1000
# 9/9 - 0s - loss: 0.0277 - mean_squared_error: 0.0277 - val_loss: 0.0275 - val_mean_squared_error: 0.0275 - 101ms/epoch - 11ms/step
# Epoch 264/1000
# 9/9 - 0s - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - 109ms/epoch - 12ms/step
# Epoch 265/1000
# 9/9 - 0s - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - 97ms/epoch - 11ms/step
# Epoch 266/1000
# 9/9 - 0s - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - 103ms/epoch - 11ms/step
# Epoch 267/1000
# 9/9 - 0s - loss: 0.0274 - mean_squared_error: 0.0274 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - 108ms/epoch - 12ms/step
# Epoch 268/1000
# 9/9 - 0s - loss: 0.0273 - mean_squared_error: 0.0273 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - 92ms/epoch - 10ms/step
# Epoch 269/1000
# 9/9 - 0s - loss: 0.0273 - mean_squared_error: 0.0273 - val_loss: 0.0270 - val_mean_squared_error: 0.0270 - 104ms/epoch - 12ms/step
# Epoch 270/1000
# 9/9 - 0s - loss: 0.0272 - mean_squared_error: 0.0272 - val_loss: 0.0270 - val_mean_squared_error: 0.0270 - 101ms/epoch - 11ms/step
# Epoch 271/1000
# 9/9 - 0s - loss: 0.0271 - mean_squared_error: 0.0271 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - 100ms/epoch - 11ms/step
# Epoch 272/1000
# 9/9 - 0s - loss: 0.0270 - mean_squared_error: 0.0270 - val_loss: 0.0268 - val_mean_squared_error: 0.0268 - 111ms/epoch - 12ms/step
# Epoch 273/1000
# 9/9 - 0s - loss: 0.0270 - mean_squared_error: 0.0270 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - 93ms/epoch - 10ms/step
# Epoch 274/1000
# 9/9 - 0s - loss: 0.0269 - mean_squared_error: 0.0269 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - 112ms/epoch - 12ms/step
# Epoch 275/1000
# 9/9 - 0s - loss: 0.0268 - mean_squared_error: 0.0268 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - 99ms/epoch - 11ms/step
# Epoch 276/1000
# 9/9 - 0s - loss: 0.0267 - mean_squared_error: 0.0267 - val_loss: 0.0265 - val_mean_squared_error: 0.0265 - 94ms/epoch - 10ms/step
# Epoch 277/1000
# 9/9 - 0s - loss: 0.0267 - mean_squared_error: 0.0267 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - 102ms/epoch - 11ms/step
# Epoch 278/1000
# 9/9 - 0s - loss: 0.0266 - mean_squared_error: 0.0266 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - 84ms/epoch - 9ms/step
# Epoch 279/1000
# 9/9 - 0s - loss: 0.0265 - mean_squared_error: 0.0265 - val_loss: 0.0262 - val_mean_squared_error: 0.0262 - 93ms/epoch - 10ms/step
# Epoch 280/1000
# 9/9 - 0s - loss: 0.0264 - mean_squared_error: 0.0264 - val_loss: 0.0261 - val_mean_squared_error: 0.0261 - 99ms/epoch - 11ms/step
# Epoch 281/1000
# 9/9 - 0s - loss: 0.0263 - mean_squared_error: 0.0263 - val_loss: 0.0261 - val_mean_squared_error: 0.0261 - 92ms/epoch - 10ms/step
# Epoch 282/1000
# 9/9 - 0s - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.0260 - val_mean_squared_error: 0.0260 - 102ms/epoch - 11ms/step
# Epoch 283/1000
# 9/9 - 0s - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.0259 - val_mean_squared_error: 0.0259 - 97ms/epoch - 11ms/step
# Epoch 284/1000
# 9/9 - 0s - loss: 0.0261 - mean_squared_error: 0.0261 - val_loss: 0.0258 - val_mean_squared_error: 0.0258 - 104ms/epoch - 12ms/step
# Epoch 285/1000
# 9/9 - 0s - loss: 0.0260 - mean_squared_error: 0.0260 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - 110ms/epoch - 12ms/step
# Epoch 286/1000
# 9/9 - 0s - loss: 0.0259 - mean_squared_error: 0.0259 - val_loss: 0.0256 - val_mean_squared_error: 0.0256 - 115ms/epoch - 13ms/step
# Epoch 287/1000
# 9/9 - 0s - loss: 0.0258 - mean_squared_error: 0.0258 - val_loss: 0.0255 - val_mean_squared_error: 0.0255 - 116ms/epoch - 13ms/step
# Epoch 288/1000
# 9/9 - 0s - loss: 0.0257 - mean_squared_error: 0.0257 - val_loss: 0.0254 - val_mean_squared_error: 0.0254 - 106ms/epoch - 12ms/step
# Epoch 289/1000
# 9/9 - 0s - loss: 0.0256 - mean_squared_error: 0.0256 - val_loss: 0.0253 - val_mean_squared_error: 0.0253 - 102ms/epoch - 11ms/step
# Epoch 290/1000
# 9/9 - 0s - loss: 0.0255 - mean_squared_error: 0.0255 - val_loss: 0.0252 - val_mean_squared_error: 0.0252 - 126ms/epoch - 14ms/step
# Epoch 291/1000
# 9/9 - 0s - loss: 0.0254 - mean_squared_error: 0.0254 - val_loss: 0.0251 - val_mean_squared_error: 0.0251 - 104ms/epoch - 12ms/step
# Epoch 292/1000
# 9/9 - 0s - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0250 - val_mean_squared_error: 0.0250 - 104ms/epoch - 12ms/step
# Epoch 293/1000
# 9/9 - 0s - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0249 - val_mean_squared_error: 0.0249 - 123ms/epoch - 14ms/step
# Epoch 294/1000
# 9/9 - 0s - loss: 0.0251 - mean_squared_error: 0.0251 - val_loss: 0.0248 - val_mean_squared_error: 0.0248 - 87ms/epoch - 10ms/step
# Epoch 295/1000
# 9/9 - 0s - loss: 0.0250 - mean_squared_error: 0.0250 - val_loss: 0.0247 - val_mean_squared_error: 0.0247 - 119ms/epoch - 13ms/step
# Epoch 296/1000
# 9/9 - 0s - loss: 0.0249 - mean_squared_error: 0.0249 - val_loss: 0.0246 - val_mean_squared_error: 0.0246 - 138ms/epoch - 15ms/step
# Epoch 297/1000
# 9/9 - 0s - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.0245 - val_mean_squared_error: 0.0245 - 93ms/epoch - 10ms/step
# Epoch 298/1000
# 9/9 - 0s - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.0244 - val_mean_squared_error: 0.0244 - 125ms/epoch - 14ms/step
# Epoch 299/1000
# 9/9 - 0s - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0243 - val_mean_squared_error: 0.0243 - 110ms/epoch - 12ms/step
# Epoch 300/1000
# 9/9 - 0s - loss: 0.0245 - mean_squared_error: 0.0245 - val_loss: 0.0242 - val_mean_squared_error: 0.0242 - 104ms/epoch - 12ms/step
# Epoch 301/1000
# 9/9 - 0s - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0241 - val_mean_squared_error: 0.0241 - 126ms/epoch - 14ms/step
# Epoch 302/1000
# 9/9 - 0s - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0239 - val_mean_squared_error: 0.0239 - 111ms/epoch - 12ms/step
# Epoch 303/1000
# 9/9 - 0s - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0238 - val_mean_squared_error: 0.0238 - 100ms/epoch - 11ms/step
# Epoch 304/1000
# 9/9 - 0s - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0237 - val_mean_squared_error: 0.0237 - 116ms/epoch - 13ms/step
# Epoch 305/1000
# 9/9 - 0s - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0236 - val_mean_squared_error: 0.0236 - 104ms/epoch - 12ms/step
# Epoch 306/1000
# 9/9 - 0s - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0235 - val_mean_squared_error: 0.0235 - 91ms/epoch - 10ms/step
# Epoch 307/1000
# 9/9 - 0s - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0234 - val_mean_squared_error: 0.0234 - 119ms/epoch - 13ms/step
# Epoch 308/1000
# 9/9 - 0s - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0233 - val_mean_squared_error: 0.0233 - 106ms/epoch - 12ms/step
# Epoch 309/1000
# 9/9 - 0s - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0232 - val_mean_squared_error: 0.0232 - 106ms/epoch - 12ms/step
# Epoch 310/1000
# 9/9 - 0s - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0231 - val_mean_squared_error: 0.0231 - 117ms/epoch - 13ms/step
# Epoch 311/1000
# 9/9 - 0s - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0230 - val_mean_squared_error: 0.0230 - 103ms/epoch - 11ms/step
# Epoch 312/1000
# 9/9 - 0s - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0229 - val_mean_squared_error: 0.0229 - 114ms/epoch - 13ms/step
# Epoch 313/1000
# 9/9 - 0s - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0228 - val_mean_squared_error: 0.0228 - 112ms/epoch - 12ms/step
# Epoch 314/1000
# 9/9 - 0s - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0227 - val_mean_squared_error: 0.0227 - 105ms/epoch - 12ms/step
# Epoch 315/1000
# 9/9 - 0s - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0226 - val_mean_squared_error: 0.0226 - 137ms/epoch - 15ms/step
# Epoch 316/1000
# 9/9 - 0s - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0225 - val_mean_squared_error: 0.0225 - 100ms/epoch - 11ms/step
# Epoch 317/1000
# 9/9 - 0s - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0224 - val_mean_squared_error: 0.0224 - 108ms/epoch - 12ms/step
# Epoch 318/1000
# 9/9 - 0s - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0222 - val_mean_squared_error: 0.0222 - 95ms/epoch - 11ms/step
# Epoch 319/1000
# 9/9 - 0s - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0221 - val_mean_squared_error: 0.0221 - 115ms/epoch - 13ms/step
# Epoch 320/1000
# 9/9 - 0s - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0220 - val_mean_squared_error: 0.0220 - 100ms/epoch - 11ms/step
# Epoch 321/1000
# 9/9 - 0s - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0219 - val_mean_squared_error: 0.0219 - 115ms/epoch - 13ms/step
# Epoch 322/1000
# 9/9 - 0s - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0218 - val_mean_squared_error: 0.0218 - 108ms/epoch - 12ms/step
# Epoch 323/1000
# 9/9 - 0s - loss: 0.0221 - mean_squared_error: 0.0221 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - 107ms/epoch - 12ms/step
# Epoch 324/1000
# 9/9 - 0s - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.0216 - val_mean_squared_error: 0.0216 - 113ms/epoch - 13ms/step
# Epoch 325/1000
# 9/9 - 0s - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0215 - val_mean_squared_error: 0.0215 - 105ms/epoch - 12ms/step
# Epoch 326/1000
# 9/9 - 0s - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - 83ms/epoch - 9ms/step
# Epoch 327/1000
# 9/9 - 0s - loss: 0.0216 - mean_squared_error: 0.0216 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - 116ms/epoch - 13ms/step
# Epoch 328/1000
# 9/9 - 0s - loss: 0.0215 - mean_squared_error: 0.0215 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - 97ms/epoch - 11ms/step
# Epoch 329/1000
# 9/9 - 0s - loss: 0.0214 - mean_squared_error: 0.0214 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - 120ms/epoch - 13ms/step
# Epoch 330/1000
# 9/9 - 0s - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - 106ms/epoch - 12ms/step
# Epoch 331/1000
# ...
# Epoch 907/1000
# 9/9 - 0s - loss: 0.8268 - mean_squared_error: 0.8268 - val_loss: 0.8006 - val_mean_squared_error: 0.8006 - 149ms/epoch - 17ms/step
# Epoch 908/1000
# 9/9 - 0s - loss: 0.8267 - mean_squared_error: 0.8267 - val_loss: 0.8006 - val_mean_squared_error: 0.8006 - 134ms/epoch - 15ms/step
# Epoch 909/1000
# 9/9 - 0s - loss: 0.8268 - mean_squared_error: 0.8268 - val_loss: 0.8005 - val_mean_squared_error: 0.8005 - 149ms/epoch - 17ms/step
# Epoch 910/1000
# 9/9 - 0s - loss: 0.8268 - mean_squared_error: 0.8268 - val_loss: 0.8005 - val_mean_squared_error: 0.8005 - 133ms/epoch - 15ms/step
# Epoch 911/1000
# 9/9 - 0s - loss: 0.8267 - mean_squared_error: 0.8267 - val_loss: 0.8004 - val_mean_squared_error: 0.8004 - 133ms/epoch - 15ms/step
# Epoch 912/1000
# 9/9 - 0s - loss: 0.8267 - mean_squared_error: 0.8267 - val_loss: 0.8007 - val_mean_squared_error: 0.8007 - 149ms/epoch - 17ms/step
# Epoch 913/1000
# 9/9 - 0s - loss: 0.8267 - mean_squared_error: 0.8267 - val_loss: 0.8009 - val_mean_squared_error: 0.8009 - 134ms/epoch - 15ms/step
# Epoch 914/1000
# 9/9 - 0s - loss: 0.8267 - mean_squared_error: 0.8267 - val_loss: 0.8005 - val_mean_squared_error: 0.8005 - 134ms/epoch - 15ms/step
# Epoch 915/1000
# 9/9 - 0s - loss: 0.8267 - mean_squared_error: 0.8267 - val_loss: 0.8005 - val_mean_squared_error: 0.8005 - 133ms/epoch - 15ms/step
# Epoch 916/1000
# 9/9 - 0s - loss: 0.8268 - mean_squared_error: 0.8268 - val_loss: 0.8011 - val_mean_squared_error: 0.8011 - 119ms/epoch - 13ms/step
# Epoch 917/1000
# 9/9 - 0s - loss: 0.8267 - mean_squared_error: 0.8267 - val_loss: 0.8009 - val_mean_squared_error: 0.8009 - 149ms/epoch - 17ms/step
# Epoch 918/1000
# 9/9 - 0s - loss: 0.8267 - mean_squared_error: 0.8267 - val_loss: 0.8003 - val_mean_squared_error: 0.8003 - 149ms/epoch - 17ms/step
# Epoch 919/1000
# 9/9 - 0s - loss: 0.8266 - mean_squared_error: 0.8266 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 134ms/epoch - 15ms/step
# Epoch 920/1000
# 9/9 - 0s - loss: 0.8266 - mean_squared_error: 0.8266 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 149ms/epoch - 17ms/step
# Epoch 921/1000
# 9/9 - 0s - loss: 0.8266 - mean_squared_error: 0.8266 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 150ms/epoch - 17ms/step
# Epoch 922/1000
# 9/9 - 0s - loss: 0.8266 - mean_squared_error: 0.8266 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 134ms/epoch - 15ms/step
# Epoch 923/1000
# 9/9 - 0s - loss: 0.8266 - mean_squared_error: 0.8266 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 149ms/epoch - 17ms/step
# Epoch 924/1000
# 9/9 - 0s - loss: 0.8266 - mean_squared_error: 0.8266 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 134ms/epoch - 15ms/step
# Epoch 925/1000
# 9/9 - 0s - loss: 0.8266 - mean_squared_error: 0.8266 - val_loss: 0.8003 - val_mean_squared_error: 0.8003 - 134ms/epoch - 15ms/step
# Epoch 926/1000
# 9/9 - 0s - loss: 0.8265 - mean_squared_error: 0.8265 - val_loss: 0.8006 - val_mean_squared_error: 0.8006 - 149ms/epoch - 17ms/step
# Epoch 927/1000
# 9/9 - 0s - loss: 0.8266 - mean_squared_error: 0.8266 - val_loss: 0.8005 - val_mean_squared_error: 0.8005 - 150ms/epoch - 17ms/step
# Epoch 928/1000
# 9/9 - 0s - loss: 0.8266 - mean_squared_error: 0.8266 - val_loss: 0.8008 - val_mean_squared_error: 0.8008 - 134ms/epoch - 15ms/step
# Epoch 929/1000
# 9/9 - 0s - loss: 0.8265 - mean_squared_error: 0.8265 - val_loss: 0.8003 - val_mean_squared_error: 0.8003 - 149ms/epoch - 17ms/step
# Epoch 930/1000
# 9/9 - 0s - loss: 0.8266 - mean_squared_error: 0.8266 - val_loss: 0.7997 - val_mean_squared_error: 0.7997 - 134ms/epoch - 15ms/step
# Epoch 931/1000
# 9/9 - 0s - loss: 0.8266 - mean_squared_error: 0.8266 - val_loss: 0.7998 - val_mean_squared_error: 0.7998 - 150ms/epoch - 17ms/step
# Epoch 932/1000
# 9/9 - 0s - loss: 0.8265 - mean_squared_error: 0.8265 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 119ms/epoch - 13ms/step
# Epoch 933/1000
# 9/9 - 0s - loss: 0.8265 - mean_squared_error: 0.8265 - val_loss: 0.8006 - val_mean_squared_error: 0.8006 - 149ms/epoch - 17ms/step
# Epoch 934/1000
# 9/9 - 0s - loss: 0.8265 - mean_squared_error: 0.8265 - val_loss: 0.8004 - val_mean_squared_error: 0.8004 - 120ms/epoch - 13ms/step
# Epoch 935/1000
# 9/9 - 0s - loss: 0.8265 - mean_squared_error: 0.8265 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 163ms/epoch - 18ms/step
# Epoch 936/1000
# 9/9 - 0s - loss: 0.8265 - mean_squared_error: 0.8265 - val_loss: 0.8003 - val_mean_squared_error: 0.8003 - 133ms/epoch - 15ms/step
# Epoch 937/1000
# 9/9 - 0s - loss: 0.8265 - mean_squared_error: 0.8265 - val_loss: 0.8004 - val_mean_squared_error: 0.8004 - 133ms/epoch - 15ms/step
# Epoch 938/1000
# 9/9 - 0s - loss: 0.8265 - mean_squared_error: 0.8265 - val_loss: 0.8000 - val_mean_squared_error: 0.8000 - 141ms/epoch - 16ms/step
# Epoch 939/1000
# 9/9 - 0s - loss: 0.8265 - mean_squared_error: 0.8265 - val_loss: 0.8007 - val_mean_squared_error: 0.8007 - 134ms/epoch - 15ms/step
# Epoch 940/1000
# 9/9 - 0s - loss: 0.8264 - mean_squared_error: 0.8264 - val_loss: 0.8004 - val_mean_squared_error: 0.8004 - 134ms/epoch - 15ms/step
# Epoch 941/1000
# 9/9 - 0s - loss: 0.8264 - mean_squared_error: 0.8264 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 149ms/epoch - 17ms/step
# Epoch 942/1000
# 9/9 - 0s - loss: 0.8264 - mean_squared_error: 0.8264 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 135ms/epoch - 15ms/step
# Epoch 943/1000
# 9/9 - 0s - loss: 0.8264 - mean_squared_error: 0.8264 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 149ms/epoch - 17ms/step
# Epoch 944/1000
# 9/9 - 0s - loss: 0.8264 - mean_squared_error: 0.8264 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 134ms/epoch - 15ms/step
# Epoch 945/1000
# 9/9 - 0s - loss: 0.8264 - mean_squared_error: 0.8264 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 149ms/epoch - 17ms/step
# Epoch 946/1000
# 9/9 - 0s - loss: 0.8264 - mean_squared_error: 0.8264 - val_loss: 0.8006 - val_mean_squared_error: 0.8006 - 150ms/epoch - 17ms/step
# Epoch 947/1000
# 9/9 - 0s - loss: 0.8264 - mean_squared_error: 0.8264 - val_loss: 0.8004 - val_mean_squared_error: 0.8004 - 133ms/epoch - 15ms/step
# Epoch 948/1000
# 9/9 - 0s - loss: 0.8264 - mean_squared_error: 0.8264 - val_loss: 0.7999 - val_mean_squared_error: 0.7999 - 119ms/epoch - 13ms/step
# Epoch 949/1000
# 9/9 - 0s - loss: 0.8264 - mean_squared_error: 0.8264 - val_loss: 0.7997 - val_mean_squared_error: 0.7997 - 150ms/epoch - 17ms/step
# Epoch 950/1000
# 9/9 - 0s - loss: 0.8264 - mean_squared_error: 0.8264 - val_loss: 0.7999 - val_mean_squared_error: 0.7999 - 150ms/epoch - 17ms/step
# Epoch 951/1000
# 9/9 - 0s - loss: 0.8263 - mean_squared_error: 0.8263 - val_loss: 0.8003 - val_mean_squared_error: 0.8003 - 150ms/epoch - 17ms/step
# Epoch 952/1000
# 9/9 - 0s - loss: 0.8263 - mean_squared_error: 0.8263 - val_loss: 0.8005 - val_mean_squared_error: 0.8005 - 134ms/epoch - 15ms/step
# Epoch 953/1000
# 9/9 - 0s - loss: 0.8263 - mean_squared_error: 0.8263 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 149ms/epoch - 17ms/step
# Epoch 954/1000
# 9/9 - 0s - loss: 0.8263 - mean_squared_error: 0.8263 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 134ms/epoch - 15ms/step
# Epoch 955/1000
# 9/9 - 0s - loss: 0.8263 - mean_squared_error: 0.8263 - val_loss: 0.7999 - val_mean_squared_error: 0.7999 - 150ms/epoch - 17ms/step
# Epoch 956/1000
# 9/9 - 0s - loss: 0.8264 - mean_squared_error: 0.8264 - val_loss: 0.7997 - val_mean_squared_error: 0.7997 - 134ms/epoch - 15ms/step
# Epoch 957/1000
# 9/9 - 0s - loss: 0.8263 - mean_squared_error: 0.8263 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 133ms/epoch - 15ms/step
# Epoch 958/1000
# 9/9 - 0s - loss: 0.8263 - mean_squared_error: 0.8263 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 149ms/epoch - 17ms/step
# Epoch 959/1000
# 9/9 - 0s - loss: 0.8262 - mean_squared_error: 0.8262 - val_loss: 0.8008 - val_mean_squared_error: 0.8008 - 135ms/epoch - 15ms/step
# Epoch 960/1000
# 9/9 - 0s - loss: 0.8263 - mean_squared_error: 0.8263 - val_loss: 0.8008 - val_mean_squared_error: 0.8008 - 149ms/epoch - 17ms/step
# Epoch 961/1000
# 9/9 - 0s - loss: 0.8263 - mean_squared_error: 0.8263 - val_loss: 0.8004 - val_mean_squared_error: 0.8004 - 136ms/epoch - 15ms/step
# Epoch 962/1000
# 9/9 - 0s - loss: 0.8263 - mean_squared_error: 0.8263 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 149ms/epoch - 17ms/step
# Epoch 963/1000
# 9/9 - 0s - loss: 0.8262 - mean_squared_error: 0.8262 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 134ms/epoch - 15ms/step
# Epoch 964/1000
# 9/9 - 0s - loss: 0.8262 - mean_squared_error: 0.8262 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 148ms/epoch - 16ms/step
# Epoch 965/1000
# 9/9 - 0s - loss: 0.8262 - mean_squared_error: 0.8262 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 135ms/epoch - 15ms/step
# Epoch 966/1000
# 9/9 - 0s - loss: 0.8262 - mean_squared_error: 0.8262 - val_loss: 0.7998 - val_mean_squared_error: 0.7998 - 150ms/epoch - 17ms/step
# Epoch 967/1000
# 9/9 - 0s - loss: 0.8262 - mean_squared_error: 0.8262 - val_loss: 0.7999 - val_mean_squared_error: 0.7999 - 149ms/epoch - 17ms/step
# Epoch 968/1000
# 9/9 - 0s - loss: 0.8262 - mean_squared_error: 0.8262 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 150ms/epoch - 17ms/step
# Epoch 969/1000
# 9/9 - 0s - loss: 0.8262 - mean_squared_error: 0.8262 - val_loss: 0.8003 - val_mean_squared_error: 0.8003 - 134ms/epoch - 15ms/step
# Epoch 970/1000
# 9/9 - 0s - loss: 0.8262 - mean_squared_error: 0.8262 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 149ms/epoch - 17ms/step
# Epoch 971/1000
# 9/9 - 0s - loss: 0.8262 - mean_squared_error: 0.8262 - val_loss: 0.8006 - val_mean_squared_error: 0.8006 - 135ms/epoch - 15ms/step
# Epoch 972/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 165ms/epoch - 18ms/step
# Epoch 973/1000
# 9/9 - 0s - loss: 0.8262 - mean_squared_error: 0.8262 - val_loss: 0.8000 - val_mean_squared_error: 0.8000 - 137ms/epoch - 15ms/step
# Epoch 974/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.8005 - val_mean_squared_error: 0.8005 - 148ms/epoch - 16ms/step
# Epoch 975/1000
# 9/9 - 0s - loss: 0.8262 - mean_squared_error: 0.8262 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 135ms/epoch - 15ms/step
# Epoch 976/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.8000 - val_mean_squared_error: 0.8000 - 133ms/epoch - 15ms/step
# Epoch 977/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.7998 - val_mean_squared_error: 0.7998 - 133ms/epoch - 15ms/step
# Epoch 978/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.7999 - val_mean_squared_error: 0.7999 - 149ms/epoch - 17ms/step
# Epoch 979/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 135ms/epoch - 15ms/step
# Epoch 980/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 134ms/epoch - 15ms/step
# Epoch 981/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.8000 - val_mean_squared_error: 0.8000 - 134ms/epoch - 15ms/step
# Epoch 982/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.8000 - val_mean_squared_error: 0.8000 - 134ms/epoch - 15ms/step
# Epoch 983/1000
# 9/9 - 0s - loss: 0.8260 - mean_squared_error: 0.8260 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 149ms/epoch - 17ms/step
# Epoch 984/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.8005 - val_mean_squared_error: 0.8005 - 134ms/epoch - 15ms/step
# Epoch 985/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.8003 - val_mean_squared_error: 0.8003 - 148ms/epoch - 16ms/step
# Epoch 986/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.7998 - val_mean_squared_error: 0.7998 - 151ms/epoch - 17ms/step
# Epoch 987/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.7996 - val_mean_squared_error: 0.7996 - 134ms/epoch - 15ms/step
# Epoch 988/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 150ms/epoch - 17ms/step
# Epoch 989/1000
# 9/9 - 0s - loss: 0.8260 - mean_squared_error: 0.8260 - val_loss: 0.8004 - val_mean_squared_error: 0.8004 - 149ms/epoch - 17ms/step
# Epoch 990/1000
# 9/9 - 0s - loss: 0.8261 - mean_squared_error: 0.8261 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 134ms/epoch - 15ms/step
# Epoch 991/1000
# 9/9 - 0s - loss: 0.8260 - mean_squared_error: 0.8260 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 134ms/epoch - 15ms/step
# Epoch 992/1000
# 9/9 - 0s - loss: 0.8260 - mean_squared_error: 0.8260 - val_loss: 0.8000 - val_mean_squared_error: 0.8000 - 150ms/epoch - 17ms/step
# Epoch 993/1000
# 9/9 - 0s - loss: 0.8260 - mean_squared_error: 0.8260 - val_loss: 0.7997 - val_mean_squared_error: 0.7997 - 134ms/epoch - 15ms/step
# Epoch 994/1000
# 9/9 - 0s - loss: 0.8260 - mean_squared_error: 0.8260 - val_loss: 0.7999 - val_mean_squared_error: 0.7999 - 150ms/epoch - 17ms/step
# Epoch 995/1000
# 9/9 - 0s - loss: 0.8260 - mean_squared_error: 0.8260 - val_loss: 0.8003 - val_mean_squared_error: 0.8003 - 149ms/epoch - 17ms/step
# Epoch 996/1000
# 9/9 - 0s - loss: 0.8260 - mean_squared_error: 0.8260 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 150ms/epoch - 17ms/step
# Epoch 997/1000
# 9/9 - 0s - loss: 0.8260 - mean_squared_error: 0.8260 - val_loss: 0.8001 - val_mean_squared_error: 0.8001 - 135ms/epoch - 15ms/step
# Epoch 998/1000
# 9/9 - 0s - loss: 0.8260 - mean_squared_error: 0.8260 - val_loss: 0.8004 - val_mean_squared_error: 0.8004 - 132ms/epoch - 15ms/step
# Epoch 999/1000
# 9/9 - 0s - loss: 0.8260 - mean_squared_error: 0.8260 - val_loss: 0.8002 - val_mean_squared_error: 0.8002 - 136ms/epoch - 15ms/step
# Epoch 1000/1000
# 9/9 - 0s - loss: 0.8259 - mean_squared_error: 0.8259 - val_loss: 0.8003 - val_mean_squared_error: 0.8003 - 132ms/epoch - 15ms/step
# [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# [0.006016654893755913, 0.008475139737129211, 0.01579088158905506, 0.028257260099053383, 0.04534965381026268, 0.06806740164756775, 0.09525640308856964, 0.12599483132362366, 0.16983915865421295, 0.206452414393425, 0.2562214732170105, 0.3024822473526001, 0.3627411425113678, 0.4463241696357727, 0.4913310110569, 0.5777807831764221, 0.6352739930152893, 0.7231202721595764, 0.8002867698669434]
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_squared_error: 0.0078
# [0.00607635360211134, 0.006113084498792887, 0.0061704786494374275, 0.006166368722915649, 0.006323596462607384, 0.006455521564930677, 0.0064199878834187984, 0.006350974086672068, 0.006327561102807522, 0.0067063188180327415, 0.006857344415038824, 0.006983930245041847, 0.006740485783666372, 0.007402907125651836, 0.007428883574903011, 0.007528429850935936, 0.007696317043155432, 0.007963611744344234, 0.007762606721371412]
# Non-negative check failed in layer: rnn_36
# Non-negative check failed in layer: rnn_37
# Non-negative check failed in layer: dense_18
# Some weights are negative (ignoring biases).
# 88/88 [==============================] - 0s 2ms/step
# 88/88 [==============================] - 0s 2ms/step
# lip cst: 0.794
# Estimated Lipschitz constant of the 2-layer RNN: 0.7936312556266785
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rnn_36 (RNN)                (None, 5, 64)             8384
#
#  rnn_37 (RNN)                (None, 5, 64)             12352
#
#  dense_18 (Dense)            (None, 5, 2)              130
#
# =================================================================
# Total params: 20866 (81.51 KB)
# Trainable params: 20866 (81.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
print(np.array(lip).tolist())
# Out:
# [0.7896789312362671, 0.8195993900299072, 0.7752898931503296, 0.7572008371353149, 0.7594450116157532, 0.7942739725112915, 0.7717785835266113, 0.7271047234535217, 0.7288066744804382, 0.724848210811615, 0.7456270456314087, 0.7987311482429504, 0.7580036520957947, 0.7072315812110901, 0.708672821521759, 0.7472379803657532, 0.8132147789001465, 0.769967257976532, 0.7936312556266785]

# %%
# LRNN with ReLU
# model.save('lrnn_cstr.h5')
# model = tf.keras.models.load_model('lrnn_cstr.h5', custom_objects={'MyLRNNCell': MyLRNNCell})

# %%
from tensorflow.python.framework.convert_to_constants import  convert_variables_to_constants_v2_as_graph

def get_flops(model):
    concrete = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete.get_concrete_function(
        [tf.TensorSpec([1, *inputs.shape[1:]]) for inputs in model.inputs])
    frozen_func, graph_def = convert_variables_to_constants_v2_as_graph(concrete_func, lower_control_flow=False)
    with tf.Graph().as_default() as graph:
        tf.graph_util.import_graph_def(graph_def, name='')
        run_meta = tf.compat.v1.RunMetadata()
        opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
        flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd="op", options=opts)
        return flops.total_float_ops

print("The FLOPs is:{}".format(get_flops(model)) ,flush=True )
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\zihaow19\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\profiler\internal\flops_registry.py:140: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# The FLOPs is:157962
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rnn_36 (RNN)                (None, 5, 64)             8384
#
#  rnn_37 (RNN)                (None, 5, 64)             12352
#
#  dense_18 (Dense)            (None, 5, 2)              130
#
# =================================================================
# Total params: 20866 (81.51 KB)
# Trainable params: 20866 (81.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# plot training and validation losses against epochs

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Normal RNN Training and validation loss')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()
