# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input, Activation, Dropout, Add, LSTM, GRU, RNN, LayerNormalization, BatchNormalization, SpectralNormalization, Conv1D, MaxPooling1D, Flatten, Layer
from keras import backend as K
from keras.optimizers import Adam,SGD
import tensorflow as tf
from keras import Model, regularizers, activations, initializers
from keras.constraints import Constraint
import pickle

# %%
import h5py

with h5py.File('test_collected_data.mat', 'r') as file:
    U = file['U'][:]
    U = np.array(U)

    Y = file['Y'][:]
    Y = np.array(Y)

# %%
print(U.shape)
print(Y.shape)
# Out:
# (20001, 2)
# (20001, 2)

# %%
print(U.shape[0])
# Out:
# 20001

# %%
# get X and y data for training and testing

U_input = list()
Y_output = list()

for i in range(U.shape[0]-1):
    if i % 5 == 0:
        U_input.append(U[i:i+5, :])
        Y_output.append(Y[i:i+5, :])

# %%
U_input = np.array(U_input)
print(U_input.shape)
Y_output = np.array(Y_output)
print(Y_output.shape)
# Out:
# (4000, 5, 2)
# (4000, 5, 2)

# %%
print(Y_output[-1])
# Out:
# [[0.48259197 0.93018467]
#  [0.34779566 0.87790033]
#  [0.87823507 0.92530261]
#  [1.28194928 1.02012353]
#  [1.48795291 1.12338469]]

# %%
RNN_input = U_input
# RNN_input = np.concatenate((U_input, -U_input), axis=2)
print("RNN_input shape is {}".format(RNN_input.shape))
# Out:
# RNN_input shape is (4000, 5, 2)

# %%
print(RNN_input[0, :, :])
print(RNN_input[1, :, :])
# Out:
# [[16.19241666 15.76933193]
#  [12.70894193 15.86208482]
#  [19.2123671  16.62241755]
#  [19.75451791 15.65793096]
#  [18.4116695  14.67089197]]
# [[13.0167968  16.42839002]
#  [17.27902718 13.91422655]
#  [12.14333843 13.49401711]
#  [12.5352551  16.91193655]
#  [16.09581626 15.90299875]]

# %%
RNN_output = Y_output
print("RNN_output shape is {}".format(RNN_output.shape))
# Out:
# RNN_output shape is (4000, 5, 2)

# %%
print(RNN_output[0, :, :])
print(RNN_output[1, :, :])
# Out:
# [[1.         1.        ]
#  [1.22269359 1.11420623]
#  [0.70290225 0.94505017]
#  [0.66837481 0.90328351]
#  [0.90288417 0.91432542]]
# [[1.38545837 1.08183303]
#  [1.02589437 0.95628583]
#  [1.4512544  1.11007631]
#  [1.49351371 1.15346693]
#  [0.99319535 1.03252695]]

# %%
def check_non_negative_weights_ignore_bias(model):
    all_non_negative = True
    for layer in model.layers:
        weights = layer.get_weights()
        if weights:  # tf the layer has weights
            # check only the weight matrices (ignoring biases if present)
            weight_only = weights[0]  # assume weights are the first element, bias (if any) is second
            if not np.all(weight_only >= 0):
                print(f"Non-negative check failed in layer: {layer.name}")
                all_non_negative = False
    if all_non_negative:
        print("All weights are non-negative (ignoring biases).")
    else:
        print("Some weights are negative (ignoring biases).")

# %%
def evaluate_lip_const(model: Model, x, eps, seed=None):
    """
    Evaluate the Lipschitz constant of a model, with the naive method.
    Please note that the estimation of the lipschitz constant is done locally around
    input sample. This may not correctly estimate the behaviour in the whole domain.

    Args:
        model: built keras model used to make predictions
        x: inputs used to compute the lipschitz constant
        eps (float): magnitude of noise to add to input in order to compute the constant
        seed (int): seed used when generating the noise ( can be set to None )

    Returns:
        float: the empirically evaluated lipschitz constant. The computation might also
            be inaccurate in high dimensional space.

    """
    y_pred = model.predict(x)
    x_var = x + K.random_uniform(
        shape=x.shape, minval=eps * 0.25, maxval=eps, seed=seed
    )
#     x_var = x + K.random_normal(
#         shape=x.shape, mean=0, stddev=eps, seed=seed
#     )
    y_pred_var = model.predict(x_var)
    dx = x - x_var
    dfx = y_pred - y_pred_var
    ndx = K.sqrt(K.sum(K.square(dx), axis=range(1, len(x.shape))))
    ndfx = K.sqrt(K.sum(K.square(dfx), axis=range(1, len(y_pred.shape))))
    lip_cst = K.max(ndfx / ndx)
    print(f"lip cst: {lip_cst:.3f}")
    return lip_cst

# %%
# set the seed for reproducibility
tf.random.set_seed(42)

num_step = 5
training_loss = [0]*19
test_loss = [0]*19
lip = [0]*19
noise = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]

for i in range(19):
    num_dims = 2

    # split into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(RNN_input, RNN_output, test_size=0.3, random_state=123)

    # define scalers for both X and y base on training data only
    scaler_X = preprocessing.MinMaxScaler().fit(X_train.reshape(-1, num_dims))
    scaler_y = preprocessing.MinMaxScaler().fit(y_train.reshape(-1, 2))

    X_train = scaler_X.transform(X_train.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
    X_test = scaler_X.transform(X_test.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
    y_train = scaler_y.transform(y_train.reshape(-1,2)).reshape(-1,num_step,2)
    y_test_normalized = scaler_y.transform(y_test.reshape(-1,2)).reshape(-1,num_step,2)

    # X is just the initial condition, so we introduce noise to the output trajectory y
    y_train = y_train + np.random.normal(0, noise[i], y_train.shape)

    nh = 64
    input = Input(shape=(X_train.shape[1],X_train.shape[2]))

    # LSTM
    x = LSTM(nh,
          return_sequences=True,
          )(input)
    x = LSTM(nh,
          return_sequences=True,
          )(x)
    x = Dense(2,
            activation='linear',
            )(x)

    model = Model(input, x)

    model.compile(optimizer='adam', loss='mean_squared_error', metrics=[tf.keras.metrics.MeanSquaredError()])
    history = model.fit(X_train, y_train, epochs=1000, batch_size=256, validation_split=0.25, verbose=2)

    training_loss[i] = history.history['val_loss'][-1]
    print(noise)
    print(training_loss)

    loss = model.evaluate(X_test, y_test_normalized, batch_size=256)
    test_loss[i] = loss[0]
    print(test_loss)

    # check convexity by checking the weights
    check_non_negative_weights_ignore_bias(model)

    # compute the Lipschitz constant for the 2-layer RNN
    lipschitz_constant = evaluate_lip_const(model, X_train, 1e-04, 42)
    print(f"Estimated Lipschitz constant of the 2-layer RNN: {lipschitz_constant}")

    lip[i] = lipschitz_constant

model.summary()
# Out:
# Epoch 1/1000
# 9/9 - 8s - loss: 0.1533 - mean_squared_error: 0.1533 - val_loss: 0.1033 - val_mean_squared_error: 0.1033 - 8s/epoch - 834ms/step
# Epoch 2/1000
# 9/9 - 0s - loss: 0.0897 - mean_squared_error: 0.0897 - val_loss: 0.0884 - val_mean_squared_error: 0.0884 - 150ms/epoch - 17ms/step
# Epoch 3/1000
# 9/9 - 0s - loss: 0.0788 - mean_squared_error: 0.0788 - val_loss: 0.0733 - val_mean_squared_error: 0.0733 - 151ms/epoch - 17ms/step
# Epoch 4/1000
# 9/9 - 0s - loss: 0.0689 - mean_squared_error: 0.0689 - val_loss: 0.0662 - val_mean_squared_error: 0.0662 - 150ms/epoch - 17ms/step
# Epoch 5/1000
# 9/9 - 0s - loss: 0.0618 - mean_squared_error: 0.0618 - val_loss: 0.0593 - val_mean_squared_error: 0.0593 - 152ms/epoch - 17ms/step
# Epoch 6/1000
# 9/9 - 0s - loss: 0.0556 - mean_squared_error: 0.0556 - val_loss: 0.0534 - val_mean_squared_error: 0.0534 - 151ms/epoch - 17ms/step
# Epoch 7/1000
# 9/9 - 0s - loss: 0.0499 - mean_squared_error: 0.0499 - val_loss: 0.0480 - val_mean_squared_error: 0.0480 - 151ms/epoch - 17ms/step
# Epoch 8/1000
# 9/9 - 0s - loss: 0.0451 - mean_squared_error: 0.0451 - val_loss: 0.0434 - val_mean_squared_error: 0.0434 - 135ms/epoch - 15ms/step
# Epoch 9/1000
# 9/9 - 0s - loss: 0.0410 - mean_squared_error: 0.0410 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - 166ms/epoch - 18ms/step
# Epoch 10/1000
# 9/9 - 0s - loss: 0.0378 - mean_squared_error: 0.0378 - val_loss: 0.0367 - val_mean_squared_error: 0.0367 - 151ms/epoch - 17ms/step
# Epoch 11/1000
# 9/9 - 0s - loss: 0.0352 - mean_squared_error: 0.0352 - val_loss: 0.0343 - val_mean_squared_error: 0.0343 - 150ms/epoch - 17ms/step
# Epoch 12/1000
# 9/9 - 0s - loss: 0.0329 - mean_squared_error: 0.0329 - val_loss: 0.0320 - val_mean_squared_error: 0.0320 - 153ms/epoch - 17ms/step
# Epoch 13/1000
# 9/9 - 0s - loss: 0.0305 - mean_squared_error: 0.0305 - val_loss: 0.0295 - val_mean_squared_error: 0.0295 - 144ms/epoch - 16ms/step
# Epoch 14/1000
# 9/9 - 0s - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0270 - val_mean_squared_error: 0.0270 - 153ms/epoch - 17ms/step
# Epoch 15/1000
# 9/9 - 0s - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0241 - val_mean_squared_error: 0.0241 - 144ms/epoch - 16ms/step
# Epoch 16/1000
# 9/9 - 0s - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - 141ms/epoch - 16ms/step
# Epoch 17/1000
# 9/9 - 0s - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0179 - val_mean_squared_error: 0.0179 - 130ms/epoch - 14ms/step
# Epoch 18/1000
# 9/9 - 0s - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0152 - val_mean_squared_error: 0.0152 - 149ms/epoch - 17ms/step
# Epoch 19/1000
# 9/9 - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 151ms/epoch - 17ms/step
# Epoch 20/1000
# 9/9 - 0s - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - 151ms/epoch - 17ms/step
# Epoch 21/1000
# 9/9 - 0s - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 152ms/epoch - 17ms/step
# Epoch 22/1000
# 9/9 - 0s - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 151ms/epoch - 17ms/step
# Epoch 23/1000
# 9/9 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 151ms/epoch - 17ms/step
# Epoch 24/1000
# 9/9 - 0s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - 169ms/epoch - 19ms/step
# Epoch 25/1000
# 9/9 - 0s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0075 - val_mean_squared_error: 0.0075 - 153ms/epoch - 17ms/step
# Epoch 26/1000
# 9/9 - 0s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0073 - val_mean_squared_error: 0.0073 - 156ms/epoch - 17ms/step
# Epoch 27/1000
# 9/9 - 0s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0071 - val_mean_squared_error: 0.0071 - 167ms/epoch - 19ms/step
# Epoch 28/1000
# 9/9 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0069 - val_mean_squared_error: 0.0069 - 159ms/epoch - 18ms/step
# Epoch 29/1000
# 9/9 - 0s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0068 - val_mean_squared_error: 0.0068 - 159ms/epoch - 18ms/step
# Epoch 30/1000
# 9/9 - 0s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0068 - val_mean_squared_error: 0.0068 - 163ms/epoch - 18ms/step
# Epoch 31/1000
# 9/9 - 0s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - 146ms/epoch - 16ms/step
# Epoch 32/1000
# 9/9 - 0s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0066 - val_mean_squared_error: 0.0066 - 152ms/epoch - 17ms/step
# Epoch 33/1000
# 9/9 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - 154ms/epoch - 17ms/step
# Epoch 34/1000
# 9/9 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - 151ms/epoch - 17ms/step
# Epoch 35/1000
# 9/9 - 0s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0066 - val_mean_squared_error: 0.0066 - 133ms/epoch - 15ms/step
# Epoch 36/1000
# 9/9 - 0s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 149ms/epoch - 17ms/step
# Epoch 37/1000
# 9/9 - 0s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 151ms/epoch - 17ms/step
# Epoch 38/1000
# 9/9 - 0s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 152ms/epoch - 17ms/step
# Epoch 39/1000
# 9/9 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 151ms/epoch - 17ms/step
# Epoch 40/1000
# 9/9 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 150ms/epoch - 17ms/step
# Epoch 41/1000
# 9/9 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 151ms/epoch - 17ms/step
# Epoch 42/1000
# 9/9 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 135ms/epoch - 15ms/step
# Epoch 43/1000
# 9/9 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 151ms/epoch - 17ms/step
# Epoch 44/1000
# 9/9 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 161ms/epoch - 18ms/step
# Epoch 45/1000
# 9/9 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 151ms/epoch - 17ms/step
# Epoch 46/1000
# 9/9 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 162ms/epoch - 18ms/step
# Epoch 47/1000
# 9/9 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 151ms/epoch - 17ms/step
# Epoch 48/1000
# 9/9 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 155ms/epoch - 17ms/step
# Epoch 49/1000
# 9/9 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 142ms/epoch - 16ms/step
# Epoch 50/1000
# 9/9 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 141ms/epoch - 16ms/step
# Epoch 51/1000
# 9/9 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 161ms/epoch - 18ms/step
# Epoch 52/1000
# 9/9 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 152ms/epoch - 17ms/step
# Epoch 53/1000
# 9/9 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 161ms/epoch - 18ms/step
# Epoch 54/1000
# 9/9 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 153ms/epoch - 17ms/step
# Epoch 55/1000
# 9/9 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 156ms/epoch - 17ms/step
# Epoch 56/1000
# 9/9 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 148ms/epoch - 16ms/step
# Epoch 57/1000
# 9/9 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 137ms/epoch - 15ms/step
# Epoch 58/1000
# 9/9 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 150ms/epoch - 17ms/step
# Epoch 59/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 135ms/epoch - 15ms/step
# Epoch 60/1000
# 9/9 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 151ms/epoch - 17ms/step
# Epoch 61/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 151ms/epoch - 17ms/step
# Epoch 62/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 151ms/epoch - 17ms/step
# Epoch 63/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 151ms/epoch - 17ms/step
# Epoch 64/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 177ms/epoch - 20ms/step
# Epoch 65/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 156ms/epoch - 17ms/step
# Epoch 66/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 151ms/epoch - 17ms/step
# Epoch 67/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 162ms/epoch - 18ms/step
# Epoch 68/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 144ms/epoch - 16ms/step
# Epoch 69/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 139ms/epoch - 15ms/step
# Epoch 70/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 156ms/epoch - 17ms/step
# Epoch 71/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 142ms/epoch - 16ms/step
# Epoch 72/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 143ms/epoch - 16ms/step
# Epoch 73/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 150ms/epoch - 17ms/step
# Epoch 74/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 151ms/epoch - 17ms/step
# Epoch 75/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 166ms/epoch - 18ms/step
# Epoch 76/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 183ms/epoch - 20ms/step
# Epoch 77/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 177ms/epoch - 20ms/step
# Epoch 78/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 172ms/epoch - 19ms/step
# Epoch 79/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 136ms/epoch - 15ms/step
# Epoch 80/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 150ms/epoch - 17ms/step
# Epoch 81/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 153ms/epoch - 17ms/step
# Epoch 82/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 149ms/epoch - 17ms/step
# Epoch 83/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 152ms/epoch - 17ms/step
# Epoch 84/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 150ms/epoch - 17ms/step
# Epoch 85/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 167ms/epoch - 19ms/step
# Epoch 86/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 156ms/epoch - 17ms/step
# Epoch 87/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 155ms/epoch - 17ms/step
# Epoch 88/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 161ms/epoch - 18ms/step
# Epoch 89/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 156ms/epoch - 17ms/step
# Epoch 90/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 151ms/epoch - 17ms/step
# Epoch 91/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 141ms/epoch - 16ms/step
# Epoch 92/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 155ms/epoch - 17ms/step
# Epoch 93/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 145ms/epoch - 16ms/step
# Epoch 94/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 152ms/epoch - 17ms/step
# Epoch 95/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 143ms/epoch - 16ms/step
# Epoch 96/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 151ms/epoch - 17ms/step
# Epoch 97/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 150ms/epoch - 17ms/step
# Epoch 98/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 151ms/epoch - 17ms/step
# Epoch 99/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 151ms/epoch - 17ms/step
# Epoch 100/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 150ms/epoch - 17ms/step
# Epoch 101/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 151ms/epoch - 17ms/step
# Epoch 102/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 157ms/epoch - 17ms/step
# Epoch 103/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 151ms/epoch - 17ms/step
# Epoch 104/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 166ms/epoch - 18ms/step
# Epoch 105/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 154ms/epoch - 17ms/step
# Epoch 106/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 155ms/epoch - 17ms/step
# Epoch 107/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 152ms/epoch - 17ms/step
# Epoch 108/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 148ms/epoch - 16ms/step
# Epoch 109/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 133ms/epoch - 15ms/step
# Epoch 110/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 167ms/epoch - 19ms/step
# Epoch 111/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 134ms/epoch - 15ms/step
# Epoch 112/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 134ms/epoch - 15ms/step
# Epoch 113/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 151ms/epoch - 17ms/step
# Epoch 114/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 151ms/epoch - 17ms/step
# Epoch 115/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 151ms/epoch - 17ms/step
# Epoch 116/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 150ms/epoch - 17ms/step
# Epoch 117/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 150ms/epoch - 17ms/step
# Epoch 118/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 144ms/epoch - 16ms/step
# Epoch 119/1000
# 9/9 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 148ms/epoch - 16ms/step
# Epoch 120/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 135ms/epoch - 15ms/step
# Epoch 121/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 157ms/epoch - 17ms/step
# Epoch 122/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 156ms/epoch - 17ms/step
# Epoch 123/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 149ms/epoch - 17ms/step
# Epoch 124/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 151ms/epoch - 17ms/step
# Epoch 125/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 150ms/epoch - 17ms/step
# Epoch 126/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 152ms/epoch - 17ms/step
# Epoch 127/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 128/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 167ms/epoch - 19ms/step
# Epoch 129/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 151ms/epoch - 17ms/step
# Epoch 130/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 142ms/epoch - 16ms/step
# Epoch 131/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 153ms/epoch - 17ms/step
# Epoch 132/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 130ms/epoch - 14ms/step
# Epoch 133/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 141ms/epoch - 16ms/step
# Epoch 134/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 125ms/epoch - 14ms/step
# Epoch 135/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 179ms/epoch - 20ms/step
# Epoch 136/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 153ms/epoch - 17ms/step
# Epoch 137/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 140ms/epoch - 16ms/step
# Epoch 138/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 152ms/epoch - 17ms/step
# Epoch 139/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 146ms/epoch - 16ms/step
# Epoch 140/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 123ms/epoch - 14ms/step
# Epoch 141/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 125ms/epoch - 14ms/step
# Epoch 142/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 141ms/epoch - 16ms/step
# Epoch 143/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 141ms/epoch - 16ms/step
# Epoch 144/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 141ms/epoch - 16ms/step
# Epoch 145/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 125ms/epoch - 14ms/step
# Epoch 146/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 141ms/epoch - 16ms/step
# Epoch 147/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 141ms/epoch - 16ms/step
# Epoch 148/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 125ms/epoch - 14ms/step
# Epoch 149/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 125ms/epoch - 14ms/step
# Epoch 150/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 141ms/epoch - 16ms/step
# Epoch 151/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 141ms/epoch - 16ms/step
# Epoch 152/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 125ms/epoch - 14ms/step
# Epoch 153/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 141ms/epoch - 16ms/step
# Epoch 154/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 141ms/epoch - 16ms/step
# Epoch 155/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 125ms/epoch - 14ms/step
# Epoch 156/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 125ms/epoch - 14ms/step
# Epoch 157/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 141ms/epoch - 16ms/step
# Epoch 158/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 125ms/epoch - 14ms/step
# Epoch 159/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 136ms/epoch - 15ms/step
# Epoch 160/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 114ms/epoch - 13ms/step
# Epoch 161/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 125ms/epoch - 14ms/step
# Epoch 162/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 125ms/epoch - 14ms/step
# Epoch 163/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 141ms/epoch - 16ms/step
# Epoch 164/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 125ms/epoch - 14ms/step
# Epoch 165/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 141ms/epoch - 16ms/step
# Epoch 166/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 125ms/epoch - 14ms/step
# Epoch 167/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 156ms/epoch - 17ms/step
# Epoch 168/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 125ms/epoch - 14ms/step
# Epoch 169/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 141ms/epoch - 16ms/step
# Epoch 170/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 143ms/epoch - 16ms/step
# Epoch 171/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 142ms/epoch - 16ms/step
# Epoch 172/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 141ms/epoch - 16ms/step
# Epoch 173/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 156ms/epoch - 17ms/step
# Epoch 174/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 125ms/epoch - 14ms/step
# Epoch 175/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 125ms/epoch - 14ms/step
# Epoch 176/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 157ms/epoch - 17ms/step
# Epoch 177/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 143ms/epoch - 16ms/step
# Epoch 178/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 138ms/epoch - 15ms/step
# Epoch 179/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 133ms/epoch - 15ms/step
# Epoch 180/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 144ms/epoch - 16ms/step
# Epoch 181/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 144ms/epoch - 16ms/step
# Epoch 182/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 153ms/epoch - 17ms/step
# Epoch 183/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 156ms/epoch - 17ms/step
# Epoch 184/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 148ms/epoch - 16ms/step
# Epoch 185/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 149ms/epoch - 17ms/step
# Epoch 186/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 150ms/epoch - 17ms/step
# Epoch 187/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 188/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 134ms/epoch - 15ms/step
# Epoch 189/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 149ms/epoch - 17ms/step
# Epoch 190/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 158ms/epoch - 18ms/step
# Epoch 191/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 151ms/epoch - 17ms/step
# Epoch 192/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 158ms/epoch - 18ms/step
# Epoch 193/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 164ms/epoch - 18ms/step
# Epoch 194/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 195/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 150ms/epoch - 17ms/step
# Epoch 196/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 164ms/epoch - 18ms/step
# Epoch 197/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 150ms/epoch - 17ms/step
# Epoch 198/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 199/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 151ms/epoch - 17ms/step
# Epoch 200/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 201/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 149ms/epoch - 17ms/step
# Epoch 202/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 149ms/epoch - 17ms/step
# Epoch 203/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 151ms/epoch - 17ms/step
# Epoch 204/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 149ms/epoch - 17ms/step
# Epoch 205/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 206/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 154ms/epoch - 17ms/step
# Epoch 207/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 147ms/epoch - 16ms/step
# Epoch 208/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 168ms/epoch - 19ms/step
# Epoch 209/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 158ms/epoch - 18ms/step
# Epoch 210/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 149ms/epoch - 17ms/step
# Epoch 211/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 148ms/epoch - 16ms/step
# Epoch 212/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 151ms/epoch - 17ms/step
# Epoch 213/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 163ms/epoch - 18ms/step
# Epoch 214/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 133ms/epoch - 15ms/step
# Epoch 215/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 134ms/epoch - 15ms/step
# Epoch 216/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 160ms/epoch - 18ms/step
# Epoch 217/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 148ms/epoch - 16ms/step
# Epoch 218/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 219/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 153ms/epoch - 17ms/step
# Epoch 220/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 158ms/epoch - 18ms/step
# Epoch 221/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 148ms/epoch - 16ms/step
# Epoch 222/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 158ms/epoch - 18ms/step
# Epoch 223/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 147ms/epoch - 16ms/step
# Epoch 224/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 155ms/epoch - 17ms/step
# Epoch 225/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 151ms/epoch - 17ms/step
# Epoch 226/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 157ms/epoch - 17ms/step
# Epoch 227/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 142ms/epoch - 16ms/step
# Epoch 228/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 149ms/epoch - 17ms/step
# Epoch 229/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 150ms/epoch - 17ms/step
# Epoch 230/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 164ms/epoch - 18ms/step
# Epoch 231/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 232/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 144ms/epoch - 16ms/step
# Epoch 233/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 156ms/epoch - 17ms/step
# Epoch 234/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 171ms/epoch - 19ms/step
# Epoch 235/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 236/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 149ms/epoch - 17ms/step
# Epoch 237/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 238/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 153ms/epoch - 17ms/step
# Epoch 239/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 146ms/epoch - 16ms/step
# Epoch 240/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 158ms/epoch - 18ms/step
# Epoch 241/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 151ms/epoch - 17ms/step
# Epoch 242/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 167ms/epoch - 19ms/step
# Epoch 243/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 151ms/epoch - 17ms/step
# Epoch 244/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 150ms/epoch - 17ms/step
# Epoch 245/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 246/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 149ms/epoch - 17ms/step
# Epoch 247/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 248/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 157ms/epoch - 17ms/step
# Epoch 249/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 143ms/epoch - 16ms/step
# Epoch 250/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 153ms/epoch - 17ms/step
# Epoch 251/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 170ms/epoch - 19ms/step
# Epoch 252/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 148ms/epoch - 16ms/step
# Epoch 253/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 158ms/epoch - 18ms/step
# Epoch 254/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 149ms/epoch - 17ms/step
# Epoch 255/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 149ms/epoch - 17ms/step
# Epoch 256/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 166ms/epoch - 18ms/step
# Epoch 257/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 169ms/epoch - 19ms/step
# Epoch 258/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 147ms/epoch - 16ms/step
# Epoch 259/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 149ms/epoch - 17ms/step
# Epoch 260/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 150ms/epoch - 17ms/step
# Epoch 261/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 155ms/epoch - 17ms/step
# Epoch 262/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 155ms/epoch - 17ms/step
# Epoch 263/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 150ms/epoch - 17ms/step
# Epoch 264/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 151ms/epoch - 17ms/step
# Epoch 265/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 157ms/epoch - 17ms/step
# Epoch 266/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 153ms/epoch - 17ms/step
# Epoch 267/1000
# 9/9 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 165ms/epoch - 18ms/step
# Epoch 268/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 151ms/epoch - 17ms/step
# Epoch 269/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 158ms/epoch - 18ms/step
# Epoch 270/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 149ms/epoch - 17ms/step
# Epoch 271/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 272/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 162ms/epoch - 18ms/step
# Epoch 273/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 157ms/epoch - 17ms/step
# Epoch 274/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 151ms/epoch - 17ms/step
# Epoch 275/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 135ms/epoch - 15ms/step
# Epoch 276/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 134ms/epoch - 15ms/step
# Epoch 277/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 164ms/epoch - 18ms/step
# Epoch 278/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 150ms/epoch - 17ms/step
# Epoch 279/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 280/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 155ms/epoch - 17ms/step
# Epoch 281/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 155ms/epoch - 17ms/step
# Epoch 282/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 151ms/epoch - 17ms/step
# Epoch 283/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 145ms/epoch - 16ms/step
# Epoch 284/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 151ms/epoch - 17ms/step
# Epoch 285/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 150ms/epoch - 17ms/step
# Epoch 286/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 165ms/epoch - 18ms/step
# Epoch 287/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 288/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 289/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 152ms/epoch - 17ms/step
# Epoch 290/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 163ms/epoch - 18ms/step
# Epoch 291/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 149ms/epoch - 17ms/step
# Epoch 292/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 151ms/epoch - 17ms/step
# Epoch 293/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 164ms/epoch - 18ms/step
# Epoch 294/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 168ms/epoch - 19ms/step
# Epoch 295/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 154ms/epoch - 17ms/step
# Epoch 296/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 162ms/epoch - 18ms/step
# Epoch 297/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 150ms/epoch - 17ms/step
# Epoch 298/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 150ms/epoch - 17ms/step
# Epoch 299/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 165ms/epoch - 18ms/step
# Epoch 300/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 154ms/epoch - 17ms/step
# Epoch 301/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 155ms/epoch - 17ms/step
# Epoch 302/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 154ms/epoch - 17ms/step
# Epoch 303/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 153ms/epoch - 17ms/step
# Epoch 304/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 150ms/epoch - 17ms/step
# Epoch 305/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 165ms/epoch - 18ms/step
# Epoch 306/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 166ms/epoch - 18ms/step
# Epoch 307/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 151ms/epoch - 17ms/step
# Epoch 308/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 149ms/epoch - 17ms/step
# Epoch 309/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 310/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 149ms/epoch - 17ms/step
# Epoch 311/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 312/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 163ms/epoch - 18ms/step
# Epoch 313/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 159ms/epoch - 18ms/step
# Epoch 314/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 167ms/epoch - 19ms/step
# Epoch 315/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 161ms/epoch - 18ms/step
# Epoch 316/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 152ms/epoch - 17ms/step
# Epoch 317/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 165ms/epoch - 18ms/step
# Epoch 318/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 150ms/epoch - 17ms/step
# Epoch 319/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 165ms/epoch - 18ms/step
# Epoch 320/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 321/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 150ms/epoch - 17ms/step
# Epoch 322/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 147ms/epoch - 16ms/step
# Epoch 323/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 150ms/epoch - 17ms/step
# Epoch 324/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 156ms/epoch - 17ms/step
# Epoch 325/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 153ms/epoch - 17ms/step
# Epoch 326/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 150ms/epoch - 17ms/step
# Epoch 327/1000
# 9/9 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 152ms/epoch - 17ms/step
# Epoch 328/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 164ms/epoch - 18ms/step
# Epoch 329/1000
# 9/9 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 151ms/epoch - 17ms/step
# Epoch 330/1000
# ...
# Epoch 908/1000
# 9/9 - 0s - loss: 0.5295 - mean_squared_error: 0.5295 - val_loss: 1.0804 - val_mean_squared_error: 1.0804 - 333ms/epoch - 37ms/step
# Epoch 909/1000
# 9/9 - 0s - loss: 0.5288 - mean_squared_error: 0.5288 - val_loss: 1.0844 - val_mean_squared_error: 1.0844 - 425ms/epoch - 47ms/step
# Epoch 910/1000
# 9/9 - 0s - loss: 0.5294 - mean_squared_error: 0.5294 - val_loss: 1.0836 - val_mean_squared_error: 1.0836 - 387ms/epoch - 43ms/step
# Epoch 911/1000
# 9/9 - 0s - loss: 0.5284 - mean_squared_error: 0.5284 - val_loss: 1.0851 - val_mean_squared_error: 1.0851 - 462ms/epoch - 51ms/step
# Epoch 912/1000
# 9/9 - 0s - loss: 0.5272 - mean_squared_error: 0.5272 - val_loss: 1.0850 - val_mean_squared_error: 1.0850 - 325ms/epoch - 36ms/step
# Epoch 913/1000
# 9/9 - 0s - loss: 0.5268 - mean_squared_error: 0.5268 - val_loss: 1.0848 - val_mean_squared_error: 1.0848 - 428ms/epoch - 48ms/step
# Epoch 914/1000
# 9/9 - 0s - loss: 0.5276 - mean_squared_error: 0.5276 - val_loss: 1.0881 - val_mean_squared_error: 1.0881 - 401ms/epoch - 45ms/step
# Epoch 915/1000
# 9/9 - 0s - loss: 0.5266 - mean_squared_error: 0.5266 - val_loss: 1.0899 - val_mean_squared_error: 1.0899 - 370ms/epoch - 41ms/step
# Epoch 916/1000
# 9/9 - 0s - loss: 0.5265 - mean_squared_error: 0.5265 - val_loss: 1.0877 - val_mean_squared_error: 1.0877 - 369ms/epoch - 41ms/step
# Epoch 917/1000
# 9/9 - 0s - loss: 0.5250 - mean_squared_error: 0.5250 - val_loss: 1.0906 - val_mean_squared_error: 1.0906 - 319ms/epoch - 35ms/step
# Epoch 918/1000
# 9/9 - 0s - loss: 0.5254 - mean_squared_error: 0.5254 - val_loss: 1.0897 - val_mean_squared_error: 1.0897 - 380ms/epoch - 42ms/step
# Epoch 919/1000
# 9/9 - 0s - loss: 0.5255 - mean_squared_error: 0.5255 - val_loss: 1.0884 - val_mean_squared_error: 1.0884 - 399ms/epoch - 44ms/step
# Epoch 920/1000
# 9/9 - 0s - loss: 0.5248 - mean_squared_error: 0.5248 - val_loss: 1.0889 - val_mean_squared_error: 1.0889 - 415ms/epoch - 46ms/step
# Epoch 921/1000
# 9/9 - 0s - loss: 0.5237 - mean_squared_error: 0.5237 - val_loss: 1.0885 - val_mean_squared_error: 1.0885 - 339ms/epoch - 38ms/step
# Epoch 922/1000
# 9/9 - 0s - loss: 0.5245 - mean_squared_error: 0.5245 - val_loss: 1.0913 - val_mean_squared_error: 1.0913 - 318ms/epoch - 35ms/step
# Epoch 923/1000
# 9/9 - 0s - loss: 0.5243 - mean_squared_error: 0.5243 - val_loss: 1.0936 - val_mean_squared_error: 1.0936 - 489ms/epoch - 54ms/step
# Epoch 924/1000
# 9/9 - 0s - loss: 0.5238 - mean_squared_error: 0.5238 - val_loss: 1.0913 - val_mean_squared_error: 1.0913 - 391ms/epoch - 43ms/step
# Epoch 925/1000
# 9/9 - 0s - loss: 0.5226 - mean_squared_error: 0.5226 - val_loss: 1.0939 - val_mean_squared_error: 1.0939 - 415ms/epoch - 46ms/step
# Epoch 926/1000
# 9/9 - 0s - loss: 0.5224 - mean_squared_error: 0.5224 - val_loss: 1.0931 - val_mean_squared_error: 1.0931 - 401ms/epoch - 45ms/step
# Epoch 927/1000
# 9/9 - 0s - loss: 0.5216 - mean_squared_error: 0.5216 - val_loss: 1.0922 - val_mean_squared_error: 1.0922 - 384ms/epoch - 43ms/step
# Epoch 928/1000
# 9/9 - 0s - loss: 0.5214 - mean_squared_error: 0.5214 - val_loss: 1.0973 - val_mean_squared_error: 1.0973 - 368ms/epoch - 41ms/step
# Epoch 929/1000
# 9/9 - 0s - loss: 0.5214 - mean_squared_error: 0.5214 - val_loss: 1.0948 - val_mean_squared_error: 1.0948 - 320ms/epoch - 36ms/step
# Epoch 930/1000
# 9/9 - 0s - loss: 0.5204 - mean_squared_error: 0.5204 - val_loss: 1.0982 - val_mean_squared_error: 1.0982 - 364ms/epoch - 40ms/step
# Epoch 931/1000
# 9/9 - 0s - loss: 0.5221 - mean_squared_error: 0.5221 - val_loss: 1.0972 - val_mean_squared_error: 1.0972 - 368ms/epoch - 41ms/step
# Epoch 932/1000
# 9/9 - 0s - loss: 0.5202 - mean_squared_error: 0.5202 - val_loss: 1.0960 - val_mean_squared_error: 1.0960 - 381ms/epoch - 42ms/step
# Epoch 933/1000
# 9/9 - 0s - loss: 0.5201 - mean_squared_error: 0.5201 - val_loss: 1.0980 - val_mean_squared_error: 1.0980 - 353ms/epoch - 39ms/step
# Epoch 934/1000
# 9/9 - 0s - loss: 0.5199 - mean_squared_error: 0.5199 - val_loss: 1.0976 - val_mean_squared_error: 1.0976 - 272ms/epoch - 30ms/step
# Epoch 935/1000
# 9/9 - 0s - loss: 0.5191 - mean_squared_error: 0.5191 - val_loss: 1.0984 - val_mean_squared_error: 1.0984 - 353ms/epoch - 39ms/step
# Epoch 936/1000
# 9/9 - 0s - loss: 0.5184 - mean_squared_error: 0.5184 - val_loss: 1.1060 - val_mean_squared_error: 1.1060 - 343ms/epoch - 38ms/step
# Epoch 937/1000
# 9/9 - 0s - loss: 0.5189 - mean_squared_error: 0.5189 - val_loss: 1.0996 - val_mean_squared_error: 1.0996 - 287ms/epoch - 32ms/step
# Epoch 938/1000
# 9/9 - 0s - loss: 0.5177 - mean_squared_error: 0.5177 - val_loss: 1.1015 - val_mean_squared_error: 1.1015 - 315ms/epoch - 35ms/step
# Epoch 939/1000
# 9/9 - 0s - loss: 0.5176 - mean_squared_error: 0.5176 - val_loss: 1.1023 - val_mean_squared_error: 1.1023 - 316ms/epoch - 35ms/step
# Epoch 940/1000
# 9/9 - 0s - loss: 0.5174 - mean_squared_error: 0.5174 - val_loss: 1.1009 - val_mean_squared_error: 1.1009 - 332ms/epoch - 37ms/step
# Epoch 941/1000
# 9/9 - 0s - loss: 0.5170 - mean_squared_error: 0.5170 - val_loss: 1.1051 - val_mean_squared_error: 1.1051 - 297ms/epoch - 33ms/step
# Epoch 942/1000
# 9/9 - 0s - loss: 0.5166 - mean_squared_error: 0.5166 - val_loss: 1.1030 - val_mean_squared_error: 1.1030 - 445ms/epoch - 49ms/step
# Epoch 943/1000
# 9/9 - 0s - loss: 0.5169 - mean_squared_error: 0.5169 - val_loss: 1.1032 - val_mean_squared_error: 1.1032 - 341ms/epoch - 38ms/step
# Epoch 944/1000
# 9/9 - 0s - loss: 0.5165 - mean_squared_error: 0.5165 - val_loss: 1.1031 - val_mean_squared_error: 1.1031 - 380ms/epoch - 42ms/step
# Epoch 945/1000
# 9/9 - 0s - loss: 0.5158 - mean_squared_error: 0.5158 - val_loss: 1.1048 - val_mean_squared_error: 1.1048 - 291ms/epoch - 32ms/step
# Epoch 946/1000
# 9/9 - 0s - loss: 0.5149 - mean_squared_error: 0.5149 - val_loss: 1.1085 - val_mean_squared_error: 1.1085 - 378ms/epoch - 42ms/step
# Epoch 947/1000
# 9/9 - 0s - loss: 0.5144 - mean_squared_error: 0.5144 - val_loss: 1.1076 - val_mean_squared_error: 1.1076 - 383ms/epoch - 43ms/step
# Epoch 948/1000
# 9/9 - 1s - loss: 0.5147 - mean_squared_error: 0.5147 - val_loss: 1.1084 - val_mean_squared_error: 1.1084 - 648ms/epoch - 72ms/step
# Epoch 949/1000
# 9/9 - 0s - loss: 0.5149 - mean_squared_error: 0.5149 - val_loss: 1.1097 - val_mean_squared_error: 1.1097 - 384ms/epoch - 43ms/step
# Epoch 950/1000
# 9/9 - 0s - loss: 0.5135 - mean_squared_error: 0.5135 - val_loss: 1.1127 - val_mean_squared_error: 1.1127 - 336ms/epoch - 37ms/step
# Epoch 951/1000
# 9/9 - 0s - loss: 0.5138 - mean_squared_error: 0.5138 - val_loss: 1.1093 - val_mean_squared_error: 1.1093 - 365ms/epoch - 41ms/step
# Epoch 952/1000
# 9/9 - 0s - loss: 0.5136 - mean_squared_error: 0.5136 - val_loss: 1.1123 - val_mean_squared_error: 1.1123 - 430ms/epoch - 48ms/step
# Epoch 953/1000
# 9/9 - 0s - loss: 0.5139 - mean_squared_error: 0.5139 - val_loss: 1.1126 - val_mean_squared_error: 1.1126 - 355ms/epoch - 39ms/step
# Epoch 954/1000
# 9/9 - 0s - loss: 0.5120 - mean_squared_error: 0.5120 - val_loss: 1.1118 - val_mean_squared_error: 1.1118 - 399ms/epoch - 44ms/step
# Epoch 955/1000
# 9/9 - 1s - loss: 0.5126 - mean_squared_error: 0.5126 - val_loss: 1.1108 - val_mean_squared_error: 1.1108 - 509ms/epoch - 57ms/step
# Epoch 956/1000
# 9/9 - 0s - loss: 0.5125 - mean_squared_error: 0.5125 - val_loss: 1.1151 - val_mean_squared_error: 1.1151 - 360ms/epoch - 40ms/step
# Epoch 957/1000
# 9/9 - 0s - loss: 0.5122 - mean_squared_error: 0.5122 - val_loss: 1.1169 - val_mean_squared_error: 1.1169 - 383ms/epoch - 43ms/step
# Epoch 958/1000
# 9/9 - 0s - loss: 0.5115 - mean_squared_error: 0.5115 - val_loss: 1.1109 - val_mean_squared_error: 1.1109 - 351ms/epoch - 39ms/step
# Epoch 959/1000
# 9/9 - 0s - loss: 0.5122 - mean_squared_error: 0.5122 - val_loss: 1.1108 - val_mean_squared_error: 1.1108 - 288ms/epoch - 32ms/step
# Epoch 960/1000
# 9/9 - 0s - loss: 0.5108 - mean_squared_error: 0.5108 - val_loss: 1.1136 - val_mean_squared_error: 1.1136 - 298ms/epoch - 33ms/step
# Epoch 961/1000
# 9/9 - 0s - loss: 0.5117 - mean_squared_error: 0.5117 - val_loss: 1.1160 - val_mean_squared_error: 1.1160 - 285ms/epoch - 32ms/step
# Epoch 962/1000
# 9/9 - 0s - loss: 0.5106 - mean_squared_error: 0.5106 - val_loss: 1.1175 - val_mean_squared_error: 1.1175 - 316ms/epoch - 35ms/step
# Epoch 963/1000
# 9/9 - 0s - loss: 0.5097 - mean_squared_error: 0.5097 - val_loss: 1.1183 - val_mean_squared_error: 1.1183 - 347ms/epoch - 39ms/step
# Epoch 964/1000
# 9/9 - 0s - loss: 0.5095 - mean_squared_error: 0.5095 - val_loss: 1.1177 - val_mean_squared_error: 1.1177 - 287ms/epoch - 32ms/step
# Epoch 965/1000
# 9/9 - 0s - loss: 0.5083 - mean_squared_error: 0.5083 - val_loss: 1.1178 - val_mean_squared_error: 1.1178 - 379ms/epoch - 42ms/step
# Epoch 966/1000
# 9/9 - 1s - loss: 0.5087 - mean_squared_error: 0.5087 - val_loss: 1.1171 - val_mean_squared_error: 1.1171 - 506ms/epoch - 56ms/step
# Epoch 967/1000
# 9/9 - 0s - loss: 0.5080 - mean_squared_error: 0.5080 - val_loss: 1.1227 - val_mean_squared_error: 1.1227 - 329ms/epoch - 37ms/step
# Epoch 968/1000
# 9/9 - 0s - loss: 0.5080 - mean_squared_error: 0.5080 - val_loss: 1.1221 - val_mean_squared_error: 1.1221 - 287ms/epoch - 32ms/step
# Epoch 969/1000
# 9/9 - 0s - loss: 0.5077 - mean_squared_error: 0.5077 - val_loss: 1.1207 - val_mean_squared_error: 1.1207 - 299ms/epoch - 33ms/step
# Epoch 970/1000
# 9/9 - 0s - loss: 0.5067 - mean_squared_error: 0.5067 - val_loss: 1.1225 - val_mean_squared_error: 1.1225 - 425ms/epoch - 47ms/step
# Epoch 971/1000
# 9/9 - 0s - loss: 0.5074 - mean_squared_error: 0.5074 - val_loss: 1.1198 - val_mean_squared_error: 1.1198 - 324ms/epoch - 36ms/step
# Epoch 972/1000
# 9/9 - 0s - loss: 0.5070 - mean_squared_error: 0.5070 - val_loss: 1.1261 - val_mean_squared_error: 1.1261 - 270ms/epoch - 30ms/step
# Epoch 973/1000
# 9/9 - 0s - loss: 0.5072 - mean_squared_error: 0.5072 - val_loss: 1.1235 - val_mean_squared_error: 1.1235 - 299ms/epoch - 33ms/step
# Epoch 974/1000
# 9/9 - 0s - loss: 0.5068 - mean_squared_error: 0.5068 - val_loss: 1.1233 - val_mean_squared_error: 1.1233 - 425ms/epoch - 47ms/step
# Epoch 975/1000
# 9/9 - 0s - loss: 0.5065 - mean_squared_error: 0.5065 - val_loss: 1.1279 - val_mean_squared_error: 1.1279 - 370ms/epoch - 41ms/step
# Epoch 976/1000
# 9/9 - 0s - loss: 0.5046 - mean_squared_error: 0.5046 - val_loss: 1.1236 - val_mean_squared_error: 1.1236 - 321ms/epoch - 36ms/step
# Epoch 977/1000
# 9/9 - 0s - loss: 0.5049 - mean_squared_error: 0.5049 - val_loss: 1.1282 - val_mean_squared_error: 1.1282 - 380ms/epoch - 42ms/step
# Epoch 978/1000
# 9/9 - 0s - loss: 0.5046 - mean_squared_error: 0.5046 - val_loss: 1.1261 - val_mean_squared_error: 1.1261 - 304ms/epoch - 34ms/step
# Epoch 979/1000
# 9/9 - 0s - loss: 0.5049 - mean_squared_error: 0.5049 - val_loss: 1.1288 - val_mean_squared_error: 1.1288 - 472ms/epoch - 52ms/step
# Epoch 980/1000
# 9/9 - 0s - loss: 0.5032 - mean_squared_error: 0.5032 - val_loss: 1.1277 - val_mean_squared_error: 1.1277 - 343ms/epoch - 38ms/step
# Epoch 981/1000
# 9/9 - 0s - loss: 0.5029 - mean_squared_error: 0.5029 - val_loss: 1.1282 - val_mean_squared_error: 1.1282 - 382ms/epoch - 42ms/step
# Epoch 982/1000
# 9/9 - 0s - loss: 0.5030 - mean_squared_error: 0.5030 - val_loss: 1.1297 - val_mean_squared_error: 1.1297 - 336ms/epoch - 37ms/step
# Epoch 983/1000
# 9/9 - 0s - loss: 0.5027 - mean_squared_error: 0.5027 - val_loss: 1.1349 - val_mean_squared_error: 1.1349 - 271ms/epoch - 30ms/step
# Epoch 984/1000
# 9/9 - 0s - loss: 0.5022 - mean_squared_error: 0.5022 - val_loss: 1.1331 - val_mean_squared_error: 1.1331 - 331ms/epoch - 37ms/step
# Epoch 985/1000
# 9/9 - 0s - loss: 0.5024 - mean_squared_error: 0.5024 - val_loss: 1.1311 - val_mean_squared_error: 1.1311 - 364ms/epoch - 40ms/step
# Epoch 986/1000
# 9/9 - 0s - loss: 0.5025 - mean_squared_error: 0.5025 - val_loss: 1.1317 - val_mean_squared_error: 1.1317 - 273ms/epoch - 30ms/step
# Epoch 987/1000
# 9/9 - 0s - loss: 0.5012 - mean_squared_error: 0.5012 - val_loss: 1.1374 - val_mean_squared_error: 1.1374 - 330ms/epoch - 37ms/step
# Epoch 988/1000
# 9/9 - 0s - loss: 0.5013 - mean_squared_error: 0.5013 - val_loss: 1.1367 - val_mean_squared_error: 1.1367 - 364ms/epoch - 40ms/step
# Epoch 989/1000
# 9/9 - 0s - loss: 0.5011 - mean_squared_error: 0.5011 - val_loss: 1.1356 - val_mean_squared_error: 1.1356 - 370ms/epoch - 41ms/step
# Epoch 990/1000
# 9/9 - 0s - loss: 0.5009 - mean_squared_error: 0.5009 - val_loss: 1.1348 - val_mean_squared_error: 1.1348 - 489ms/epoch - 54ms/step
# Epoch 991/1000
# 9/9 - 0s - loss: 0.5003 - mean_squared_error: 0.5003 - val_loss: 1.1347 - val_mean_squared_error: 1.1347 - 297ms/epoch - 33ms/step
# Epoch 992/1000
# 9/9 - 0s - loss: 0.4994 - mean_squared_error: 0.4994 - val_loss: 1.1381 - val_mean_squared_error: 1.1381 - 364ms/epoch - 40ms/step
# Epoch 993/1000
# 9/9 - 0s - loss: 0.4997 - mean_squared_error: 0.4997 - val_loss: 1.1372 - val_mean_squared_error: 1.1372 - 459ms/epoch - 51ms/step
# Epoch 994/1000
# 9/9 - 0s - loss: 0.4992 - mean_squared_error: 0.4992 - val_loss: 1.1356 - val_mean_squared_error: 1.1356 - 326ms/epoch - 36ms/step
# Epoch 995/1000
# 9/9 - 0s - loss: 0.4996 - mean_squared_error: 0.4996 - val_loss: 1.1416 - val_mean_squared_error: 1.1416 - 318ms/epoch - 35ms/step
# Epoch 996/1000
# 9/9 - 0s - loss: 0.4990 - mean_squared_error: 0.4990 - val_loss: 1.1418 - val_mean_squared_error: 1.1418 - 333ms/epoch - 37ms/step
# Epoch 997/1000
# 9/9 - 0s - loss: 0.4995 - mean_squared_error: 0.4995 - val_loss: 1.1400 - val_mean_squared_error: 1.1400 - 444ms/epoch - 49ms/step
# Epoch 998/1000
# 9/9 - 0s - loss: 0.4990 - mean_squared_error: 0.4990 - val_loss: 1.1391 - val_mean_squared_error: 1.1391 - 355ms/epoch - 39ms/step
# Epoch 999/1000
# 9/9 - 0s - loss: 0.4977 - mean_squared_error: 0.4977 - val_loss: 1.1380 - val_mean_squared_error: 1.1380 - 350ms/epoch - 39ms/step
# Epoch 1000/1000
# 9/9 - 1s - loss: 0.4970 - mean_squared_error: 0.4970 - val_loss: 1.1408 - val_mean_squared_error: 1.1408 - 537ms/epoch - 60ms/step
# [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# [0.005886182188987732, 0.008378485217690468, 0.01578657142817974, 0.029168404638767242, 0.04836000129580498, 0.07246145606040955, 0.10366825759410858, 0.15823347866535187, 0.18508407473564148, 0.2629156708717346, 0.32965147495269775, 0.38788560032844543, 0.49172577261924744, 0.5907782912254333, 0.672784149646759, 0.8056157827377319, 0.9315147995948792, 1.04398512840271, 1.140839695930481]
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3577 - mean_squared_error: 0.3577
# [0.005909723695367575, 0.005915704183280468, 0.005994221195578575, 0.006197974551469088, 0.009243381209671497, 0.010233165696263313, 0.012626398354768753, 0.03182030841708183, 0.02346367947757244, 0.0600675530731678, 0.07977943122386932, 0.09021076560020447, 0.11839339137077332, 0.16856978833675385, 0.17499573528766632, 0.2550930678844452, 0.2852960526943207, 0.3134070932865143, 0.35771527886390686]
# Non-negative check failed in layer: lstm_36
# Non-negative check failed in layer: lstm_37
# Non-negative check failed in layer: dense_18
# Some weights are negative (ignoring biases).
# 88/88 [==============================] - 1s 2ms/step
# 88/88 [==============================] - 0s 2ms/step
# lip cst: 29.401
# Estimated Lipschitz constant of the 2-layer RNN: 29.40106964111328
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_19 (InputLayer)       [(None, 5, 2)]            0
#
#  lstm_36 (LSTM)              (None, 5, 64)             17152
#
#  lstm_37 (LSTM)              (None, 5, 64)             33024
#
#  dense_18 (Dense)            (None, 5, 2)              130
#
# =================================================================
# Total params: 50306 (196.51 KB)
# Trainable params: 50306 (196.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
print(np.array(lip).tolist())
# Out:
# [0.8309104442596436, 0.8667122721672058, 0.9399820566177368, 0.9307634830474854, 2.3296878337860107, 1.8945417404174805, 4.7528462409973145, 8.326557159423828, 7.046604156494141, 12.793898582458496, 17.238378524780273, 15.590875625610352, 12.051568984985352, 22.42714500427246, 20.239248275756836, 31.779312133789062, 25.713769912719727, 36.615474700927734, 29.40106964111328]

# %%
# LSTM with ReLU
# model.save('lstm_cstr.h5')
# model = tf.keras.models.load_model('lstm_cstr.h5')

# %%
from tensorflow.python.framework.convert_to_constants import  convert_variables_to_constants_v2_as_graph

def get_flops(model):
    concrete = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete.get_concrete_function(
        [tf.TensorSpec([1, *inputs.shape[1:]]) for inputs in model.inputs])
    frozen_func, graph_def = convert_variables_to_constants_v2_as_graph(concrete_func, lower_control_flow=False)
    with tf.Graph().as_default() as graph:
        tf.graph_util.import_graph_def(graph_def, name='')
        run_meta = tf.compat.v1.RunMetadata()
        opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
        flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd="op", options=opts)
        return flops.total_float_ops

print("The FLOPs is:{}".format(get_flops(model)) ,flush=True )
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\zihaow19\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\profiler\internal\flops_registry.py:453: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# The FLOPs is:102154
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_19 (InputLayer)       [(None, 5, 2)]            0
#
#  lstm_36 (LSTM)              (None, 5, 64)             17152
#
#  lstm_37 (LSTM)              (None, 5, 64)             33024
#
#  dense_18 (Dense)            (None, 5, 2)              130
#
# =================================================================
# Total params: 50306 (196.51 KB)
# Trainable params: 50306 (196.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# plot training and validation losses against epochs

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Normal RNN Training and validation loss')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()
