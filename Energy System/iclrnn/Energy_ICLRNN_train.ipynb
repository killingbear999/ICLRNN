# %%
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input, Activation, Dropout, Add, LSTM, GRU, RNN, Layer
from keras import backend as K
from keras.optimizers import Adam,SGD
import tensorflow as tf
from keras import Model, regularizers, activations, initializers
from keras.constraints import Constraint
import pickle

# load and save mat file
import h5py
import hdf5storage

# %%
with h5py.File('test_collected_data.mat', 'r') as file:
    U = file['U'][:]
    U = np.array(U)

    Y = file['Y'][:]
    Y = np.array(Y)

# %%
# get X and y data for training and testing

U_input = list()
Y_output = list()

for i in range(U.shape[0]-1):
    if i % 5 == 0:
        U_input.append(U[i:i+5, :])
        Y_output.append(Y[i:i+5, :])

# %%
U_input = np.array(U_input)
print(U_input.shape)
Y_output = np.array(Y_output)
print(Y_output.shape)
# Out:
# (4000, 5, 2)
# (4000, 5, 2)

# %%
RNN_input = np.concatenate((U_input, -U_input), axis=2)
print("RNN_input shape is {}".format(RNN_input.shape))
# Out:
# RNN_input shape is (4000, 5, 4)

# %%
RNN_output = Y_output
print("RNN_output shape is {}".format(RNN_output.shape))
# Out:
# RNN_output shape is (4000, 5, 2)

# %%
DEFAULT_EPS_SPECTRAL = 1e-3
DEFAULT_MAXITER_SPECTRAL = 10
SWAP_MEMORY = True
STOP_GRAD_SPECTRAL = True

def normalize_kernel(
    kernel,
    u,
    adjustment_coef,
    eps_spectral=DEFAULT_EPS_SPECTRAL,
    maxiter_spectral=DEFAULT_MAXITER_SPECTRAL,
):
    """
    Perform spectral normalization to the kernel given as input. It
    apply the power method to find the largest singular value and apply the spectral
    normalization.

    Args:
        kernel (tf.Tensor): the kernel to orthogonalize
        u (tf.Tensor): the vector used to do the power iteration method
        adjustment_coef (float): the adjustment coefficient as used in convolution
        eps_spectral (float): stopping criterion in spectral algorithm
        maxiter_spectral (int): maximum number of iterations for the power iteration

    Returns:
        tf.Tensor: the normalized kernel, the new u, and sigma which is the largest
            singular value

    """
    W_shape = kernel.shape

    # Flatten the Tensor
    W_reshaped = tf.reshape(kernel, [-1, W_shape[-1]])

    W_bar, u, sigma = spectral_normalization(
        W_reshaped, u, eps=eps_spectral, maxiter=maxiter_spectral
    )

    W_bar = W_bar * adjustment_coef
    W_bar = K.reshape(W_bar, kernel.shape)
    return W_bar, u, sigma

def _power_iteration(
    linear_operator,
    adjoint_operator,
    u,
    eps=DEFAULT_EPS_SPECTRAL,
    maxiter=DEFAULT_MAXITER_SPECTRAL,
    axis=None,
):
    """Internal function that performs the power iteration algorithm to estimate the
    largest singular vector of a linear operator.

    Args:
        linear_operator (Callable): a callable object that maps a linear operation.
        adjoint_operator (Callable): a callable object that maps the adjoint of the
            linear operator.
        u (tf.Tensor): initialization of the singular vector.
        eps (float, optional): stopping criterion of the algorithm, when
            norm(u[t] - u[t-1]) is less than eps. Defaults to DEFAULT_EPS_SPECTRAL.
        maxiter (int, optional): maximum number of iterations for the algorithm.
            Defaults to DEFAULT_MAXITER_SPECTRAL.
        axis (int/list, optional): dimension along which to normalize. Can be set for
            depthwise convolution for example. Defaults to None.

    Returns:
        tf.Tensor: the maximum singular vector.
    """

    # Prepare while loop variables
    u = tf.math.l2_normalize(u, axis=axis)
    # create a fake old_w that doesn't pass the loop condition, it will be overwritten
    old_u = u + 2 * eps

    # Loop body
    def body(u, old_u):
        old_u = u
        v = linear_operator(u)
        u = adjoint_operator(v)

        u = tf.math.l2_normalize(u, axis=axis)

        return u, old_u

    # Loop stopping condition
    def cond(u, old_u):
        return tf.linalg.norm(u - old_u) >= eps

    # Run the while loop
    u, _ = tf.while_loop(
        cond,
        body,
        (u, old_u),
        maximum_iterations=maxiter,
        swap_memory=SWAP_MEMORY,
    )

    # Prevent gradient to back-propagate into the while loop
    if STOP_GRAD_SPECTRAL:
        u = tf.stop_gradient(u)

    return u

def spectral_normalization(
    kernel, u, eps=DEFAULT_EPS_SPECTRAL, maxiter=DEFAULT_MAXITER_SPECTRAL
):
    """
    Normalize the kernel to have its maximum singular value equal to 1.

    Args:
        kernel (tf.Tensor): the kernel to normalize, assuming a 2D kernel.
        u (tf.Tensor): initialization of the maximum singular vector.
        eps (float, optional): stopping criterion of the algorithm, when
            norm(u[t] - u[t-1]) is less than eps. Defaults to DEFAULT_EPS_SPECTRAL.
        maxiter (int, optional): maximum number of iterations for the algorithm.
            Defaults to DEFAULT_MAXITER_SPECTRAL.

    Returns:
        the normalized kernel, the maximum singular vector, and the maximum singular
            value.
    """

    if u is None:
        u = tf.random.uniform(
            shape=(1, kernel.shape[-1]), minval=0.0, maxval=1.0, dtype=kernel.dtype
        )

    def linear_op(u):
        return u @ tf.transpose(kernel)

    def adjoint_op(v):
        return v @ kernel

    u = _power_iteration(linear_op, adjoint_op, u, eps, maxiter)

    # Compute the largest singular value and the normalized kernel.
    # We assume that in the worst case we converged to sigma + eps (as u and v are
    # normalized after each iteration)
    # In order to be sure that operator norm of normalized kernel is strictly less than
    # one we use sigma + eps
    sigma = tf.reshape(tf.norm(linear_op(u)), (1, 1))
    normalized_kernel = kernel / (sigma + eps)
    return normalized_kernel, u, sigma

# %%
class SpectralConstraint(Constraint):
    def __init__(
        self,
        k_coef_lip=1.0,
        eps_spectral=DEFAULT_EPS_SPECTRAL,
        u=None,
    ) -> None:
        """
        Ensure that maximum singular values of the weight matrix less than 1.

        Args:
            k_coef_lip (float): lipschitz coefficient of the weight matrix
            eps_spectral (float): stopping criterion for the iterative power algorithm.
            u (tf.Tensor): vector used for iterated power method, can be set to None
                (used for serialization/deserialization purposes).
        """
        self.eps_spectral = eps_spectral
        self.k_coef_lip = k_coef_lip
        if not (isinstance(u, tf.Tensor) or (u is None)):
            u = tf.convert_to_tensor(u)
        self.u = u
        super(SpectralConstraint, self).__init__()

    def __call__(self, w):
        # clip to ensure non-negative weight
        w = K.clip(w, 0, w)

        # perform spectral normalization to the kernel
        wbar, _, _ = normalize_kernel(
            w,
            self.u,
            self.k_coef_lip,
            self.eps_spectral,
        )

        return wbar

    def get_config(self):
        config = {
            "k_coef_lip": self.k_coef_lip,
            "eps_spectral": self.eps_spectral,
            "u": None if self.u is None else self.u.numpy(),
        }
        base_config = super(SpectralConstraint, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
# set the seed for reproducibility
tf.random.set_seed(42)

# define parameter values
num_step = 5
num_dims = 4

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(RNN_input, RNN_output, test_size=0.1, random_state=123)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)

# define scalers for both X and y base on training data only
scaler_X = preprocessing.MinMaxScaler().fit(X_train.reshape(-1, num_dims))
scaler_y = preprocessing.MinMaxScaler().fit(y_train.reshape(-1, 2))

X_train = scaler_X.transform(X_train.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
X_test = scaler_X.transform(X_test.reshape(-1, num_dims)).reshape(-1,num_step,num_dims)
y_train = scaler_y.transform(y_train.reshape(-1,2)).reshape(-1,num_step,2)
y_test_normalized = scaler_y.transform(y_test.reshape(-1,2)).reshape(-1,num_step,2)

# ICLRNN model training and evaluation
nh = 64
constraint = SpectralConstraint()
input = Input(shape=(X_train.shape[1],X_train.shape[2]))
x = SimpleRNN(nh,
      activation='relu',
      kernel_initializer=initializers.RandomNormal(mean=0.0, stddev=0.01),
      recurrent_initializer=initializers.Orthogonal(0.1),
      return_sequences=True,
      kernel_constraint=constraint,
      recurrent_constraint=constraint
      )(input)
x = SimpleRNN(nh,
      activation='relu',
      kernel_initializer=initializers.RandomNormal(mean=0.0, stddev=0.01),
      recurrent_initializer=initializers.Orthogonal(0.1),
      return_sequences=True,
      kernel_constraint=constraint,
      recurrent_constraint=constraint
      )(x)
x = Dense(2,
        activation='relu',
        kernel_constraint=constraint
        )(x)
model = Model(input, x)

model.compile(optimizer='adam', loss='mean_squared_error', metrics=[tf.keras.metrics.MeanSquaredError()])
history = model.fit(X_train, y_train, epochs=1000, batch_size=256, validation_split=0, verbose=2)

loss = model.evaluate(X_test, y_test_normalized, batch_size=256)
test_loss = loss[0]
print(test_loss)

model.summary()
# Out:
# (3600, 5, 4)
# (400, 5, 4)
# (3600, 5, 2)
# (400, 5, 2)
# Epoch 1/1000
# 15/15 - 2s - loss: 6.5775 - mean_squared_error: 6.5775 - 2s/epoch - 124ms/step
# Epoch 2/1000
# 15/15 - 0s - loss: 3.4703 - mean_squared_error: 3.4703 - 63ms/epoch - 4ms/step
# Epoch 3/1000
# 15/15 - 0s - loss: 1.4865 - mean_squared_error: 1.4865 - 97ms/epoch - 6ms/step
# Epoch 4/1000
# 15/15 - 0s - loss: 0.6310 - mean_squared_error: 0.6310 - 57ms/epoch - 4ms/step
# Epoch 5/1000
# 15/15 - 0s - loss: 0.3105 - mean_squared_error: 0.3105 - 58ms/epoch - 4ms/step
# Epoch 6/1000
# 15/15 - 0s - loss: 0.1939 - mean_squared_error: 0.1939 - 74ms/epoch - 5ms/step
# Epoch 7/1000
# 15/15 - 0s - loss: 0.1489 - mean_squared_error: 0.1489 - 73ms/epoch - 5ms/step
# Epoch 8/1000
# 15/15 - 0s - loss: 0.1302 - mean_squared_error: 0.1302 - 125ms/epoch - 8ms/step
# Epoch 9/1000
# 15/15 - 0s - loss: 0.1217 - mean_squared_error: 0.1217 - 193ms/epoch - 13ms/step
# Epoch 10/1000
# 15/15 - 0s - loss: 0.1173 - mean_squared_error: 0.1173 - 136ms/epoch - 9ms/step
# Epoch 11/1000
# 15/15 - 0s - loss: 0.1146 - mean_squared_error: 0.1146 - 69ms/epoch - 5ms/step
# Epoch 12/1000
# 15/15 - 0s - loss: 0.1125 - mean_squared_error: 0.1125 - 54ms/epoch - 4ms/step
# Epoch 13/1000
# 15/15 - 0s - loss: 0.1105 - mean_squared_error: 0.1105 - 70ms/epoch - 5ms/step
# Epoch 14/1000
# 15/15 - 0s - loss: 0.1084 - mean_squared_error: 0.1084 - 62ms/epoch - 4ms/step
# Epoch 15/1000
# 15/15 - 0s - loss: 0.1061 - mean_squared_error: 0.1061 - 72ms/epoch - 5ms/step
# Epoch 16/1000
# 15/15 - 0s - loss: 0.1035 - mean_squared_error: 0.1035 - 90ms/epoch - 6ms/step
# Epoch 17/1000
# 15/15 - 0s - loss: 0.1007 - mean_squared_error: 0.1007 - 54ms/epoch - 4ms/step
# Epoch 18/1000
# 15/15 - 0s - loss: 0.0977 - mean_squared_error: 0.0977 - 109ms/epoch - 7ms/step
# Epoch 19/1000
# 15/15 - 0s - loss: 0.0946 - mean_squared_error: 0.0946 - 78ms/epoch - 5ms/step
# Epoch 20/1000
# 15/15 - 0s - loss: 0.0915 - mean_squared_error: 0.0915 - 78ms/epoch - 5ms/step
# Epoch 21/1000
# 15/15 - 0s - loss: 0.0884 - mean_squared_error: 0.0884 - 103ms/epoch - 7ms/step
# Epoch 22/1000
# 15/15 - 0s - loss: 0.0854 - mean_squared_error: 0.0854 - 45ms/epoch - 3ms/step
# Epoch 23/1000
# 15/15 - 0s - loss: 0.0824 - mean_squared_error: 0.0824 - 63ms/epoch - 4ms/step
# Epoch 24/1000
# 15/15 - 0s - loss: 0.0795 - mean_squared_error: 0.0795 - 65ms/epoch - 4ms/step
# Epoch 25/1000
# 15/15 - 0s - loss: 0.0766 - mean_squared_error: 0.0766 - 72ms/epoch - 5ms/step
# Epoch 26/1000
# 15/15 - 0s - loss: 0.0738 - mean_squared_error: 0.0738 - 67ms/epoch - 4ms/step
# Epoch 27/1000
# 15/15 - 0s - loss: 0.0712 - mean_squared_error: 0.0712 - 63ms/epoch - 4ms/step
# Epoch 28/1000
# 15/15 - 0s - loss: 0.0686 - mean_squared_error: 0.0686 - 69ms/epoch - 5ms/step
# Epoch 29/1000
# 15/15 - 0s - loss: 0.0661 - mean_squared_error: 0.0661 - 63ms/epoch - 4ms/step
# Epoch 30/1000
# 15/15 - 0s - loss: 0.0638 - mean_squared_error: 0.0638 - 93ms/epoch - 6ms/step
# Epoch 31/1000
# 15/15 - 0s - loss: 0.0616 - mean_squared_error: 0.0616 - 49ms/epoch - 3ms/step
# Epoch 32/1000
# 15/15 - 0s - loss: 0.0595 - mean_squared_error: 0.0595 - 50ms/epoch - 3ms/step
# Epoch 33/1000
# 15/15 - 0s - loss: 0.0575 - mean_squared_error: 0.0575 - 54ms/epoch - 4ms/step
# Epoch 34/1000
# 15/15 - 0s - loss: 0.0556 - mean_squared_error: 0.0556 - 74ms/epoch - 5ms/step
# Epoch 35/1000
# 15/15 - 0s - loss: 0.0537 - mean_squared_error: 0.0537 - 76ms/epoch - 5ms/step
# Epoch 36/1000
# 15/15 - 0s - loss: 0.0521 - mean_squared_error: 0.0521 - 65ms/epoch - 4ms/step
# Epoch 37/1000
# 15/15 - 0s - loss: 0.0505 - mean_squared_error: 0.0505 - 89ms/epoch - 6ms/step
# Epoch 38/1000
# 15/15 - 0s - loss: 0.0490 - mean_squared_error: 0.0490 - 97ms/epoch - 6ms/step
# Epoch 39/1000
# 15/15 - 0s - loss: 0.0475 - mean_squared_error: 0.0475 - 74ms/epoch - 5ms/step
# Epoch 40/1000
# 15/15 - 0s - loss: 0.0462 - mean_squared_error: 0.0462 - 66ms/epoch - 4ms/step
# Epoch 41/1000
# 15/15 - 0s - loss: 0.0449 - mean_squared_error: 0.0449 - 83ms/epoch - 6ms/step
# Epoch 42/1000
# 15/15 - 0s - loss: 0.0437 - mean_squared_error: 0.0437 - 85ms/epoch - 6ms/step
# Epoch 43/1000
# 15/15 - 0s - loss: 0.0426 - mean_squared_error: 0.0426 - 68ms/epoch - 5ms/step
# Epoch 44/1000
# 15/15 - 0s - loss: 0.0416 - mean_squared_error: 0.0416 - 63ms/epoch - 4ms/step
# Epoch 45/1000
# 15/15 - 0s - loss: 0.0406 - mean_squared_error: 0.0406 - 117ms/epoch - 8ms/step
# Epoch 46/1000
# 15/15 - 0s - loss: 0.0396 - mean_squared_error: 0.0396 - 107ms/epoch - 7ms/step
# Epoch 47/1000
# 15/15 - 0s - loss: 0.0387 - mean_squared_error: 0.0387 - 67ms/epoch - 4ms/step
# Epoch 48/1000
# 15/15 - 0s - loss: 0.0379 - mean_squared_error: 0.0379 - 62ms/epoch - 4ms/step
# Epoch 49/1000
# 15/15 - 0s - loss: 0.0371 - mean_squared_error: 0.0371 - 71ms/epoch - 5ms/step
# Epoch 50/1000
# 15/15 - 0s - loss: 0.0363 - mean_squared_error: 0.0363 - 67ms/epoch - 4ms/step
# Epoch 51/1000
# 15/15 - 0s - loss: 0.0356 - mean_squared_error: 0.0356 - 86ms/epoch - 6ms/step
# Epoch 52/1000
# 15/15 - 0s - loss: 0.0350 - mean_squared_error: 0.0350 - 59ms/epoch - 4ms/step
# Epoch 53/1000
# 15/15 - 0s - loss: 0.0344 - mean_squared_error: 0.0344 - 66ms/epoch - 4ms/step
# Epoch 54/1000
# 15/15 - 0s - loss: 0.0338 - mean_squared_error: 0.0338 - 49ms/epoch - 3ms/step
# Epoch 55/1000
# 15/15 - 0s - loss: 0.0332 - mean_squared_error: 0.0332 - 71ms/epoch - 5ms/step
# Epoch 56/1000
# 15/15 - 0s - loss: 0.0326 - mean_squared_error: 0.0326 - 94ms/epoch - 6ms/step
# Epoch 57/1000
# 15/15 - 0s - loss: 0.0321 - mean_squared_error: 0.0321 - 128ms/epoch - 9ms/step
# Epoch 58/1000
# 15/15 - 0s - loss: 0.0316 - mean_squared_error: 0.0316 - 60ms/epoch - 4ms/step
# Epoch 59/1000
# 15/15 - 0s - loss: 0.0311 - mean_squared_error: 0.0311 - 56ms/epoch - 4ms/step
# Epoch 60/1000
# 15/15 - 0s - loss: 0.0306 - mean_squared_error: 0.0306 - 46ms/epoch - 3ms/step
# Epoch 61/1000
# 15/15 - 0s - loss: 0.0302 - mean_squared_error: 0.0302 - 84ms/epoch - 6ms/step
# Epoch 62/1000
# 15/15 - 0s - loss: 0.0297 - mean_squared_error: 0.0297 - 49ms/epoch - 3ms/step
# Epoch 63/1000
# 15/15 - 0s - loss: 0.0293 - mean_squared_error: 0.0293 - 56ms/epoch - 4ms/step
# Epoch 64/1000
# 15/15 - 0s - loss: 0.0289 - mean_squared_error: 0.0289 - 52ms/epoch - 3ms/step
# Epoch 65/1000
# 15/15 - 0s - loss: 0.0285 - mean_squared_error: 0.0285 - 61ms/epoch - 4ms/step
# Epoch 66/1000
# 15/15 - 0s - loss: 0.0281 - mean_squared_error: 0.0281 - 52ms/epoch - 3ms/step
# Epoch 67/1000
# 15/15 - 0s - loss: 0.0277 - mean_squared_error: 0.0277 - 65ms/epoch - 4ms/step
# Epoch 68/1000
# 15/15 - 0s - loss: 0.0273 - mean_squared_error: 0.0273 - 79ms/epoch - 5ms/step
# Epoch 69/1000
# 15/15 - 0s - loss: 0.0270 - mean_squared_error: 0.0270 - 119ms/epoch - 8ms/step
# Epoch 70/1000
# 15/15 - 0s - loss: 0.0266 - mean_squared_error: 0.0266 - 111ms/epoch - 7ms/step
# Epoch 71/1000
# 15/15 - 0s - loss: 0.0263 - mean_squared_error: 0.0263 - 178ms/epoch - 12ms/step
# Epoch 72/1000
# 15/15 - 0s - loss: 0.0260 - mean_squared_error: 0.0260 - 154ms/epoch - 10ms/step
# Epoch 73/1000
# 15/15 - 0s - loss: 0.0257 - mean_squared_error: 0.0257 - 99ms/epoch - 7ms/step
# Epoch 74/1000
# 15/15 - 0s - loss: 0.0253 - mean_squared_error: 0.0253 - 194ms/epoch - 13ms/step
# Epoch 75/1000
# 15/15 - 0s - loss: 0.0250 - mean_squared_error: 0.0250 - 179ms/epoch - 12ms/step
# Epoch 76/1000
# 15/15 - 0s - loss: 0.0247 - mean_squared_error: 0.0247 - 127ms/epoch - 8ms/step
# Epoch 77/1000
# 15/15 - 0s - loss: 0.0244 - mean_squared_error: 0.0244 - 159ms/epoch - 11ms/step
# Epoch 78/1000
# 15/15 - 0s - loss: 0.0242 - mean_squared_error: 0.0242 - 135ms/epoch - 9ms/step
# Epoch 79/1000
# 15/15 - 0s - loss: 0.0239 - mean_squared_error: 0.0239 - 63ms/epoch - 4ms/step
# Epoch 80/1000
# 15/15 - 0s - loss: 0.0236 - mean_squared_error: 0.0236 - 47ms/epoch - 3ms/step
# Epoch 81/1000
# 15/15 - 0s - loss: 0.0234 - mean_squared_error: 0.0234 - 73ms/epoch - 5ms/step
# Epoch 82/1000
# 15/15 - 0s - loss: 0.0231 - mean_squared_error: 0.0231 - 114ms/epoch - 8ms/step
# Epoch 83/1000
# 15/15 - 0s - loss: 0.0229 - mean_squared_error: 0.0229 - 202ms/epoch - 13ms/step
# Epoch 84/1000
# 15/15 - 0s - loss: 0.0226 - mean_squared_error: 0.0226 - 109ms/epoch - 7ms/step
# Epoch 85/1000
# 15/15 - 0s - loss: 0.0224 - mean_squared_error: 0.0224 - 78ms/epoch - 5ms/step
# Epoch 86/1000
# 15/15 - 0s - loss: 0.0222 - mean_squared_error: 0.0222 - 172ms/epoch - 11ms/step
# Epoch 87/1000
# 15/15 - 0s - loss: 0.0219 - mean_squared_error: 0.0219 - 120ms/epoch - 8ms/step
# Epoch 88/1000
# 15/15 - 0s - loss: 0.0217 - mean_squared_error: 0.0217 - 159ms/epoch - 11ms/step
# Epoch 89/1000
# 15/15 - 0s - loss: 0.0215 - mean_squared_error: 0.0215 - 187ms/epoch - 12ms/step
# Epoch 90/1000
# 15/15 - 0s - loss: 0.0213 - mean_squared_error: 0.0213 - 109ms/epoch - 7ms/step
# Epoch 91/1000
# 15/15 - 0s - loss: 0.0211 - mean_squared_error: 0.0211 - 80ms/epoch - 5ms/step
# Epoch 92/1000
# 15/15 - 0s - loss: 0.0209 - mean_squared_error: 0.0209 - 117ms/epoch - 8ms/step
# Epoch 93/1000
# 15/15 - 0s - loss: 0.0207 - mean_squared_error: 0.0207 - 65ms/epoch - 4ms/step
# Epoch 94/1000
# 15/15 - 0s - loss: 0.0206 - mean_squared_error: 0.0206 - 83ms/epoch - 6ms/step
# Epoch 95/1000
# 15/15 - 0s - loss: 0.0204 - mean_squared_error: 0.0204 - 120ms/epoch - 8ms/step
# Epoch 96/1000
# 15/15 - 0s - loss: 0.0202 - mean_squared_error: 0.0202 - 82ms/epoch - 5ms/step
# Epoch 97/1000
# 15/15 - 0s - loss: 0.0200 - mean_squared_error: 0.0200 - 107ms/epoch - 7ms/step
# Epoch 98/1000
# 15/15 - 0s - loss: 0.0199 - mean_squared_error: 0.0199 - 134ms/epoch - 9ms/step
# Epoch 99/1000
# 15/15 - 0s - loss: 0.0197 - mean_squared_error: 0.0197 - 81ms/epoch - 5ms/step
# Epoch 100/1000
# 15/15 - 0s - loss: 0.0196 - mean_squared_error: 0.0196 - 62ms/epoch - 4ms/step
# Epoch 101/1000
# 15/15 - 0s - loss: 0.0194 - mean_squared_error: 0.0194 - 92ms/epoch - 6ms/step
# Epoch 102/1000
# 15/15 - 0s - loss: 0.0193 - mean_squared_error: 0.0193 - 175ms/epoch - 12ms/step
# Epoch 103/1000
# 15/15 - 0s - loss: 0.0191 - mean_squared_error: 0.0191 - 73ms/epoch - 5ms/step
# Epoch 104/1000
# 15/15 - 0s - loss: 0.0190 - mean_squared_error: 0.0190 - 51ms/epoch - 3ms/step
# Epoch 105/1000
# 15/15 - 0s - loss: 0.0188 - mean_squared_error: 0.0188 - 45ms/epoch - 3ms/step
# Epoch 106/1000
# 15/15 - 0s - loss: 0.0187 - mean_squared_error: 0.0187 - 70ms/epoch - 5ms/step
# Epoch 107/1000
# 15/15 - 0s - loss: 0.0186 - mean_squared_error: 0.0186 - 79ms/epoch - 5ms/step
# Epoch 108/1000
# 15/15 - 0s - loss: 0.0184 - mean_squared_error: 0.0184 - 78ms/epoch - 5ms/step
# Epoch 109/1000
# 15/15 - 0s - loss: 0.0183 - mean_squared_error: 0.0183 - 94ms/epoch - 6ms/step
# Epoch 110/1000
# 15/15 - 0s - loss: 0.0182 - mean_squared_error: 0.0182 - 141ms/epoch - 9ms/step
# Epoch 111/1000
# 15/15 - 0s - loss: 0.0181 - mean_squared_error: 0.0181 - 124ms/epoch - 8ms/step
# Epoch 112/1000
# 15/15 - 0s - loss: 0.0179 - mean_squared_error: 0.0179 - 47ms/epoch - 3ms/step
# Epoch 113/1000
# 15/15 - 0s - loss: 0.0178 - mean_squared_error: 0.0178 - 79ms/epoch - 5ms/step
# Epoch 114/1000
# 15/15 - 0s - loss: 0.0177 - mean_squared_error: 0.0177 - 61ms/epoch - 4ms/step
# Epoch 115/1000
# 15/15 - 0s - loss: 0.0176 - mean_squared_error: 0.0176 - 38ms/epoch - 3ms/step
# Epoch 116/1000
# 15/15 - 0s - loss: 0.0175 - mean_squared_error: 0.0175 - 47ms/epoch - 3ms/step
# Epoch 117/1000
# 15/15 - 0s - loss: 0.0174 - mean_squared_error: 0.0174 - 109ms/epoch - 7ms/step
# Epoch 118/1000
# 15/15 - 0s - loss: 0.0173 - mean_squared_error: 0.0173 - 88ms/epoch - 6ms/step
# Epoch 119/1000
# 15/15 - 0s - loss: 0.0171 - mean_squared_error: 0.0171 - 83ms/epoch - 6ms/step
# Epoch 120/1000
# 15/15 - 0s - loss: 0.0170 - mean_squared_error: 0.0170 - 80ms/epoch - 5ms/step
# Epoch 121/1000
# 15/15 - 0s - loss: 0.0169 - mean_squared_error: 0.0169 - 128ms/epoch - 9ms/step
# Epoch 122/1000
# 15/15 - 0s - loss: 0.0168 - mean_squared_error: 0.0168 - 104ms/epoch - 7ms/step
# Epoch 123/1000
# 15/15 - 0s - loss: 0.0167 - mean_squared_error: 0.0167 - 88ms/epoch - 6ms/step
# Epoch 124/1000
# 15/15 - 0s - loss: 0.0166 - mean_squared_error: 0.0166 - 150ms/epoch - 10ms/step
# Epoch 125/1000
# 15/15 - 0s - loss: 0.0166 - mean_squared_error: 0.0166 - 119ms/epoch - 8ms/step
# Epoch 126/1000
# 15/15 - 0s - loss: 0.0165 - mean_squared_error: 0.0165 - 95ms/epoch - 6ms/step
# Epoch 127/1000
# 15/15 - 0s - loss: 0.0164 - mean_squared_error: 0.0164 - 98ms/epoch - 7ms/step
# Epoch 128/1000
# 15/15 - 0s - loss: 0.0163 - mean_squared_error: 0.0163 - 73ms/epoch - 5ms/step
# Epoch 129/1000
# 15/15 - 0s - loss: 0.0162 - mean_squared_error: 0.0162 - 67ms/epoch - 4ms/step
# Epoch 130/1000
# 15/15 - 0s - loss: 0.0161 - mean_squared_error: 0.0161 - 89ms/epoch - 6ms/step
# Epoch 131/1000
# 15/15 - 0s - loss: 0.0160 - mean_squared_error: 0.0160 - 106ms/epoch - 7ms/step
# Epoch 132/1000
# 15/15 - 0s - loss: 0.0159 - mean_squared_error: 0.0159 - 90ms/epoch - 6ms/step
# Epoch 133/1000
# 15/15 - 0s - loss: 0.0158 - mean_squared_error: 0.0158 - 58ms/epoch - 4ms/step
# Epoch 134/1000
# 15/15 - 0s - loss: 0.0158 - mean_squared_error: 0.0158 - 102ms/epoch - 7ms/step
# Epoch 135/1000
# 15/15 - 0s - loss: 0.0157 - mean_squared_error: 0.0157 - 91ms/epoch - 6ms/step
# Epoch 136/1000
# 15/15 - 0s - loss: 0.0156 - mean_squared_error: 0.0156 - 54ms/epoch - 4ms/step
# Epoch 137/1000
# 15/15 - 0s - loss: 0.0155 - mean_squared_error: 0.0155 - 62ms/epoch - 4ms/step
# Epoch 138/1000
# 15/15 - 0s - loss: 0.0155 - mean_squared_error: 0.0155 - 87ms/epoch - 6ms/step
# Epoch 139/1000
# 15/15 - 0s - loss: 0.0154 - mean_squared_error: 0.0154 - 52ms/epoch - 3ms/step
# Epoch 140/1000
# 15/15 - 0s - loss: 0.0153 - mean_squared_error: 0.0153 - 55ms/epoch - 4ms/step
# Epoch 141/1000
# 15/15 - 0s - loss: 0.0152 - mean_squared_error: 0.0152 - 89ms/epoch - 6ms/step
# Epoch 142/1000
# 15/15 - 0s - loss: 0.0152 - mean_squared_error: 0.0152 - 119ms/epoch - 8ms/step
# Epoch 143/1000
# 15/15 - 0s - loss: 0.0151 - mean_squared_error: 0.0151 - 119ms/epoch - 8ms/step
# Epoch 144/1000
# 15/15 - 0s - loss: 0.0150 - mean_squared_error: 0.0150 - 177ms/epoch - 12ms/step
# Epoch 145/1000
# 15/15 - 0s - loss: 0.0150 - mean_squared_error: 0.0150 - 103ms/epoch - 7ms/step
# Epoch 146/1000
# 15/15 - 0s - loss: 0.0149 - mean_squared_error: 0.0149 - 88ms/epoch - 6ms/step
# Epoch 147/1000
# 15/15 - 0s - loss: 0.0149 - mean_squared_error: 0.0149 - 99ms/epoch - 7ms/step
# Epoch 148/1000
# 15/15 - 0s - loss: 0.0148 - mean_squared_error: 0.0148 - 105ms/epoch - 7ms/step
# Epoch 149/1000
# 15/15 - 0s - loss: 0.0147 - mean_squared_error: 0.0147 - 62ms/epoch - 4ms/step
# Epoch 150/1000
# 15/15 - 0s - loss: 0.0147 - mean_squared_error: 0.0147 - 94ms/epoch - 6ms/step
# Epoch 151/1000
# 15/15 - 0s - loss: 0.0146 - mean_squared_error: 0.0146 - 108ms/epoch - 7ms/step
# Epoch 152/1000
# 15/15 - 0s - loss: 0.0146 - mean_squared_error: 0.0146 - 78ms/epoch - 5ms/step
# Epoch 153/1000
# 15/15 - 0s - loss: 0.0145 - mean_squared_error: 0.0145 - 91ms/epoch - 6ms/step
# Epoch 154/1000
# 15/15 - 0s - loss: 0.0144 - mean_squared_error: 0.0144 - 120ms/epoch - 8ms/step
# Epoch 155/1000
# 15/15 - 0s - loss: 0.0144 - mean_squared_error: 0.0144 - 101ms/epoch - 7ms/step
# Epoch 156/1000
# 15/15 - 0s - loss: 0.0143 - mean_squared_error: 0.0143 - 74ms/epoch - 5ms/step
# Epoch 157/1000
# 15/15 - 0s - loss: 0.0143 - mean_squared_error: 0.0143 - 66ms/epoch - 4ms/step
# Epoch 158/1000
# 15/15 - 0s - loss: 0.0142 - mean_squared_error: 0.0142 - 83ms/epoch - 6ms/step
# Epoch 159/1000
# 15/15 - 0s - loss: 0.0142 - mean_squared_error: 0.0142 - 70ms/epoch - 5ms/step
# Epoch 160/1000
# 15/15 - 0s - loss: 0.0141 - mean_squared_error: 0.0141 - 86ms/epoch - 6ms/step
# Epoch 161/1000
# 15/15 - 0s - loss: 0.0141 - mean_squared_error: 0.0141 - 102ms/epoch - 7ms/step
# Epoch 162/1000
# 15/15 - 0s - loss: 0.0140 - mean_squared_error: 0.0140 - 94ms/epoch - 6ms/step
# Epoch 163/1000
# 15/15 - 0s - loss: 0.0140 - mean_squared_error: 0.0140 - 124ms/epoch - 8ms/step
# Epoch 164/1000
# 15/15 - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - 69ms/epoch - 5ms/step
# Epoch 165/1000
# 15/15 - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - 69ms/epoch - 5ms/step
# Epoch 166/1000
# 15/15 - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - 72ms/epoch - 5ms/step
# Epoch 167/1000
# 15/15 - 0s - loss: 0.0138 - mean_squared_error: 0.0138 - 66ms/epoch - 4ms/step
# Epoch 168/1000
# 15/15 - 0s - loss: 0.0138 - mean_squared_error: 0.0138 - 85ms/epoch - 6ms/step
# Epoch 169/1000
# 15/15 - 0s - loss: 0.0137 - mean_squared_error: 0.0137 - 109ms/epoch - 7ms/step
# Epoch 170/1000
# 15/15 - 0s - loss: 0.0137 - mean_squared_error: 0.0137 - 92ms/epoch - 6ms/step
# Epoch 171/1000
# 15/15 - 0s - loss: 0.0136 - mean_squared_error: 0.0136 - 219ms/epoch - 15ms/step
# Epoch 172/1000
# 15/15 - 0s - loss: 0.0136 - mean_squared_error: 0.0136 - 163ms/epoch - 11ms/step
# Epoch 173/1000
# 15/15 - 0s - loss: 0.0136 - mean_squared_error: 0.0136 - 102ms/epoch - 7ms/step
# Epoch 174/1000
# 15/15 - 0s - loss: 0.0135 - mean_squared_error: 0.0135 - 98ms/epoch - 7ms/step
# Epoch 175/1000
# 15/15 - 0s - loss: 0.0135 - mean_squared_error: 0.0135 - 82ms/epoch - 5ms/step
# Epoch 176/1000
# 15/15 - 0s - loss: 0.0135 - mean_squared_error: 0.0135 - 83ms/epoch - 6ms/step
# Epoch 177/1000
# 15/15 - 0s - loss: 0.0134 - mean_squared_error: 0.0134 - 82ms/epoch - 5ms/step
# Epoch 178/1000
# 15/15 - 0s - loss: 0.0134 - mean_squared_error: 0.0134 - 83ms/epoch - 6ms/step
# Epoch 179/1000
# 15/15 - 0s - loss: 0.0133 - mean_squared_error: 0.0133 - 149ms/epoch - 10ms/step
# Epoch 180/1000
# 15/15 - 0s - loss: 0.0133 - mean_squared_error: 0.0133 - 117ms/epoch - 8ms/step
# Epoch 181/1000
# 15/15 - 0s - loss: 0.0133 - mean_squared_error: 0.0133 - 61ms/epoch - 4ms/step
# Epoch 182/1000
# 15/15 - 0s - loss: 0.0132 - mean_squared_error: 0.0132 - 68ms/epoch - 5ms/step
# Epoch 183/1000
# 15/15 - 0s - loss: 0.0132 - mean_squared_error: 0.0132 - 83ms/epoch - 6ms/step
# Epoch 184/1000
# 15/15 - 0s - loss: 0.0132 - mean_squared_error: 0.0132 - 97ms/epoch - 6ms/step
# Epoch 185/1000
# 15/15 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - 70ms/epoch - 5ms/step
# Epoch 186/1000
# 15/15 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - 82ms/epoch - 5ms/step
# Epoch 187/1000
# 15/15 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - 98ms/epoch - 7ms/step
# Epoch 188/1000
# 15/15 - 0s - loss: 0.0130 - mean_squared_error: 0.0130 - 107ms/epoch - 7ms/step
# Epoch 189/1000
# 15/15 - 0s - loss: 0.0130 - mean_squared_error: 0.0130 - 66ms/epoch - 4ms/step
# Epoch 190/1000
# 15/15 - 0s - loss: 0.0130 - mean_squared_error: 0.0130 - 85ms/epoch - 6ms/step
# Epoch 191/1000
# 15/15 - 0s - loss: 0.0130 - mean_squared_error: 0.0130 - 98ms/epoch - 7ms/step
# Epoch 192/1000
# 15/15 - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - 94ms/epoch - 6ms/step
# Epoch 193/1000
# 15/15 - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - 89ms/epoch - 6ms/step
# Epoch 194/1000
# 15/15 - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - 92ms/epoch - 6ms/step
# Epoch 195/1000
# 15/15 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - 90ms/epoch - 6ms/step
# Epoch 196/1000
# 15/15 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - 104ms/epoch - 7ms/step
# Epoch 197/1000
# 15/15 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - 71ms/epoch - 5ms/step
# Epoch 198/1000
# 15/15 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - 66ms/epoch - 4ms/step
# Epoch 199/1000
# 15/15 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - 125ms/epoch - 8ms/step
# Epoch 200/1000
# 15/15 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - 164ms/epoch - 11ms/step
# Epoch 201/1000
# 15/15 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - 143ms/epoch - 10ms/step
# Epoch 202/1000
# 15/15 - 0s - loss: 0.0126 - mean_squared_error: 0.0126 - 79ms/epoch - 5ms/step
# Epoch 203/1000
# 15/15 - 0s - loss: 0.0126 - mean_squared_error: 0.0126 - 73ms/epoch - 5ms/step
# Epoch 204/1000
# 15/15 - 0s - loss: 0.0126 - mean_squared_error: 0.0126 - 84ms/epoch - 6ms/step
# Epoch 205/1000
# 15/15 - 0s - loss: 0.0126 - mean_squared_error: 0.0126 - 69ms/epoch - 5ms/step
# Epoch 206/1000
# 15/15 - 0s - loss: 0.0125 - mean_squared_error: 0.0125 - 64ms/epoch - 4ms/step
# Epoch 207/1000
# 15/15 - 0s - loss: 0.0125 - mean_squared_error: 0.0125 - 63ms/epoch - 4ms/step
# Epoch 208/1000
# 15/15 - 0s - loss: 0.0125 - mean_squared_error: 0.0125 - 65ms/epoch - 4ms/step
# Epoch 209/1000
# 15/15 - 0s - loss: 0.0125 - mean_squared_error: 0.0125 - 87ms/epoch - 6ms/step
# Epoch 210/1000
# 15/15 - 0s - loss: 0.0124 - mean_squared_error: 0.0124 - 93ms/epoch - 6ms/step
# Epoch 211/1000
# 15/15 - 0s - loss: 0.0124 - mean_squared_error: 0.0124 - 146ms/epoch - 10ms/step
# Epoch 212/1000
# 15/15 - 0s - loss: 0.0124 - mean_squared_error: 0.0124 - 174ms/epoch - 12ms/step
# Epoch 213/1000
# 15/15 - 0s - loss: 0.0124 - mean_squared_error: 0.0124 - 62ms/epoch - 4ms/step
# Epoch 214/1000
# 15/15 - 0s - loss: 0.0123 - mean_squared_error: 0.0123 - 84ms/epoch - 6ms/step
# Epoch 215/1000
# 15/15 - 0s - loss: 0.0123 - mean_squared_error: 0.0123 - 135ms/epoch - 9ms/step
# Epoch 216/1000
# 15/15 - 0s - loss: 0.0123 - mean_squared_error: 0.0123 - 118ms/epoch - 8ms/step
# Epoch 217/1000
# 15/15 - 0s - loss: 0.0123 - mean_squared_error: 0.0123 - 65ms/epoch - 4ms/step
# Epoch 218/1000
# 15/15 - 0s - loss: 0.0122 - mean_squared_error: 0.0122 - 67ms/epoch - 4ms/step
# Epoch 219/1000
# 15/15 - 0s - loss: 0.0122 - mean_squared_error: 0.0122 - 99ms/epoch - 7ms/step
# Epoch 220/1000
# 15/15 - 0s - loss: 0.0122 - mean_squared_error: 0.0122 - 67ms/epoch - 4ms/step
# Epoch 221/1000
# 15/15 - 0s - loss: 0.0122 - mean_squared_error: 0.0122 - 69ms/epoch - 5ms/step
# Epoch 222/1000
# 15/15 - 0s - loss: 0.0122 - mean_squared_error: 0.0122 - 118ms/epoch - 8ms/step
# Epoch 223/1000
# 15/15 - 0s - loss: 0.0121 - mean_squared_error: 0.0121 - 134ms/epoch - 9ms/step
# Epoch 224/1000
# 15/15 - 0s - loss: 0.0121 - mean_squared_error: 0.0121 - 120ms/epoch - 8ms/step
# Epoch 225/1000
# 15/15 - 0s - loss: 0.0121 - mean_squared_error: 0.0121 - 136ms/epoch - 9ms/step
# Epoch 226/1000
# 15/15 - 0s - loss: 0.0121 - mean_squared_error: 0.0121 - 126ms/epoch - 8ms/step
# Epoch 227/1000
# 15/15 - 0s - loss: 0.0120 - mean_squared_error: 0.0120 - 87ms/epoch - 6ms/step
# Epoch 228/1000
# 15/15 - 0s - loss: 0.0120 - mean_squared_error: 0.0120 - 96ms/epoch - 6ms/step
# Epoch 229/1000
# 15/15 - 0s - loss: 0.0120 - mean_squared_error: 0.0120 - 123ms/epoch - 8ms/step
# Epoch 230/1000
# 15/15 - 0s - loss: 0.0120 - mean_squared_error: 0.0120 - 81ms/epoch - 5ms/step
# Epoch 231/1000
# 15/15 - 0s - loss: 0.0120 - mean_squared_error: 0.0120 - 89ms/epoch - 6ms/step
# Epoch 232/1000
# 15/15 - 0s - loss: 0.0119 - mean_squared_error: 0.0119 - 163ms/epoch - 11ms/step
# Epoch 233/1000
# 15/15 - 0s - loss: 0.0119 - mean_squared_error: 0.0119 - 88ms/epoch - 6ms/step
# Epoch 234/1000
# 15/15 - 0s - loss: 0.0119 - mean_squared_error: 0.0119 - 83ms/epoch - 6ms/step
# Epoch 235/1000
# 15/15 - 0s - loss: 0.0119 - mean_squared_error: 0.0119 - 103ms/epoch - 7ms/step
# Epoch 236/1000
# 15/15 - 0s - loss: 0.0118 - mean_squared_error: 0.0118 - 133ms/epoch - 9ms/step
# Epoch 237/1000
# 15/15 - 0s - loss: 0.0118 - mean_squared_error: 0.0118 - 121ms/epoch - 8ms/step
# Epoch 238/1000
# 15/15 - 0s - loss: 0.0118 - mean_squared_error: 0.0118 - 108ms/epoch - 7ms/step
# Epoch 239/1000
# 15/15 - 0s - loss: 0.0118 - mean_squared_error: 0.0118 - 116ms/epoch - 8ms/step
# Epoch 240/1000
# 15/15 - 0s - loss: 0.0118 - mean_squared_error: 0.0118 - 105ms/epoch - 7ms/step
# Epoch 241/1000
# 15/15 - 0s - loss: 0.0117 - mean_squared_error: 0.0117 - 57ms/epoch - 4ms/step
# Epoch 242/1000
# 15/15 - 0s - loss: 0.0117 - mean_squared_error: 0.0117 - 67ms/epoch - 4ms/step
# Epoch 243/1000
# 15/15 - 0s - loss: 0.0117 - mean_squared_error: 0.0117 - 95ms/epoch - 6ms/step
# Epoch 244/1000
# 15/15 - 0s - loss: 0.0117 - mean_squared_error: 0.0117 - 77ms/epoch - 5ms/step
# Epoch 245/1000
# 15/15 - 0s - loss: 0.0116 - mean_squared_error: 0.0116 - 99ms/epoch - 7ms/step
# Epoch 246/1000
# 15/15 - 0s - loss: 0.0116 - mean_squared_error: 0.0116 - 163ms/epoch - 11ms/step
# Epoch 247/1000
# 15/15 - 0s - loss: 0.0116 - mean_squared_error: 0.0116 - 168ms/epoch - 11ms/step
# Epoch 248/1000
# 15/15 - 0s - loss: 0.0116 - mean_squared_error: 0.0116 - 153ms/epoch - 10ms/step
# Epoch 249/1000
# 15/15 - 0s - loss: 0.0116 - mean_squared_error: 0.0116 - 95ms/epoch - 6ms/step
# Epoch 250/1000
# 15/15 - 0s - loss: 0.0115 - mean_squared_error: 0.0115 - 102ms/epoch - 7ms/step
# Epoch 251/1000
# 15/15 - 0s - loss: 0.0115 - mean_squared_error: 0.0115 - 95ms/epoch - 6ms/step
# Epoch 252/1000
# 15/15 - 0s - loss: 0.0115 - mean_squared_error: 0.0115 - 84ms/epoch - 6ms/step
# Epoch 253/1000
# 15/15 - 0s - loss: 0.0115 - mean_squared_error: 0.0115 - 129ms/epoch - 9ms/step
# Epoch 254/1000
# 15/15 - 0s - loss: 0.0114 - mean_squared_error: 0.0114 - 119ms/epoch - 8ms/step
# Epoch 255/1000
# 15/15 - 0s - loss: 0.0114 - mean_squared_error: 0.0114 - 156ms/epoch - 10ms/step
# Epoch 256/1000
# 15/15 - 0s - loss: 0.0114 - mean_squared_error: 0.0114 - 120ms/epoch - 8ms/step
# Epoch 257/1000
# 15/15 - 0s - loss: 0.0114 - mean_squared_error: 0.0114 - 132ms/epoch - 9ms/step
# Epoch 258/1000
# 15/15 - 0s - loss: 0.0113 - mean_squared_error: 0.0113 - 153ms/epoch - 10ms/step
# Epoch 259/1000
# 15/15 - 0s - loss: 0.0113 - mean_squared_error: 0.0113 - 100ms/epoch - 7ms/step
# Epoch 260/1000
# 15/15 - 0s - loss: 0.0113 - mean_squared_error: 0.0113 - 85ms/epoch - 6ms/step
# Epoch 261/1000
# 15/15 - 0s - loss: 0.0112 - mean_squared_error: 0.0112 - 98ms/epoch - 7ms/step
# Epoch 262/1000
# 15/15 - 0s - loss: 0.0112 - mean_squared_error: 0.0112 - 100ms/epoch - 7ms/step
# Epoch 263/1000
# 15/15 - 0s - loss: 0.0112 - mean_squared_error: 0.0112 - 84ms/epoch - 6ms/step
# Epoch 264/1000
# 15/15 - 0s - loss: 0.0112 - mean_squared_error: 0.0112 - 100ms/epoch - 7ms/step
# Epoch 265/1000
# 15/15 - 0s - loss: 0.0111 - mean_squared_error: 0.0111 - 67ms/epoch - 4ms/step
# Epoch 266/1000
# 15/15 - 0s - loss: 0.0111 - mean_squared_error: 0.0111 - 133ms/epoch - 9ms/step
# Epoch 267/1000
# 15/15 - 0s - loss: 0.0111 - mean_squared_error: 0.0111 - 178ms/epoch - 12ms/step
# Epoch 268/1000
# 15/15 - 0s - loss: 0.0110 - mean_squared_error: 0.0110 - 121ms/epoch - 8ms/step
# Epoch 269/1000
# 15/15 - 0s - loss: 0.0110 - mean_squared_error: 0.0110 - 133ms/epoch - 9ms/step
# Epoch 270/1000
# 15/15 - 0s - loss: 0.0110 - mean_squared_error: 0.0110 - 56ms/epoch - 4ms/step
# Epoch 271/1000
# 15/15 - 0s - loss: 0.0110 - mean_squared_error: 0.0110 - 95ms/epoch - 6ms/step
# Epoch 272/1000
# 15/15 - 0s - loss: 0.0109 - mean_squared_error: 0.0109 - 131ms/epoch - 9ms/step
# Epoch 273/1000
# 15/15 - 0s - loss: 0.0109 - mean_squared_error: 0.0109 - 196ms/epoch - 13ms/step
# Epoch 274/1000
# 15/15 - 0s - loss: 0.0109 - mean_squared_error: 0.0109 - 75ms/epoch - 5ms/step
# Epoch 275/1000
# 15/15 - 0s - loss: 0.0108 - mean_squared_error: 0.0108 - 62ms/epoch - 4ms/step
# Epoch 276/1000
# 15/15 - 0s - loss: 0.0108 - mean_squared_error: 0.0108 - 117ms/epoch - 8ms/step
# Epoch 277/1000
# 15/15 - 0s - loss: 0.0108 - mean_squared_error: 0.0108 - 163ms/epoch - 11ms/step
# Epoch 278/1000
# 15/15 - 0s - loss: 0.0107 - mean_squared_error: 0.0107 - 198ms/epoch - 13ms/step
# Epoch 279/1000
# 15/15 - 0s - loss: 0.0107 - mean_squared_error: 0.0107 - 104ms/epoch - 7ms/step
# Epoch 280/1000
# 15/15 - 0s - loss: 0.0107 - mean_squared_error: 0.0107 - 148ms/epoch - 10ms/step
# Epoch 281/1000
# 15/15 - 0s - loss: 0.0106 - mean_squared_error: 0.0106 - 119ms/epoch - 8ms/step
# Epoch 282/1000
# 15/15 - 0s - loss: 0.0106 - mean_squared_error: 0.0106 - 133ms/epoch - 9ms/step
# Epoch 283/1000
# 15/15 - 0s - loss: 0.0106 - mean_squared_error: 0.0106 - 71ms/epoch - 5ms/step
# Epoch 284/1000
# 15/15 - 0s - loss: 0.0105 - mean_squared_error: 0.0105 - 82ms/epoch - 5ms/step
# Epoch 285/1000
# 15/15 - 0s - loss: 0.0105 - mean_squared_error: 0.0105 - 115ms/epoch - 8ms/step
# Epoch 286/1000
# 15/15 - 0s - loss: 0.0105 - mean_squared_error: 0.0105 - 148ms/epoch - 10ms/step
# Epoch 287/1000
# 15/15 - 0s - loss: 0.0104 - mean_squared_error: 0.0104 - 150ms/epoch - 10ms/step
# Epoch 288/1000
# 15/15 - 0s - loss: 0.0104 - mean_squared_error: 0.0104 - 151ms/epoch - 10ms/step
# Epoch 289/1000
# 15/15 - 0s - loss: 0.0104 - mean_squared_error: 0.0104 - 165ms/epoch - 11ms/step
# Epoch 290/1000
# 15/15 - 0s - loss: 0.0103 - mean_squared_error: 0.0103 - 199ms/epoch - 13ms/step
# Epoch 291/1000
# 15/15 - 0s - loss: 0.0103 - mean_squared_error: 0.0103 - 138ms/epoch - 9ms/step
# Epoch 292/1000
# 15/15 - 0s - loss: 0.0103 - mean_squared_error: 0.0103 - 132ms/epoch - 9ms/step
# Epoch 293/1000
# 15/15 - 0s - loss: 0.0102 - mean_squared_error: 0.0102 - 88ms/epoch - 6ms/step
# Epoch 294/1000
# 15/15 - 0s - loss: 0.0102 - mean_squared_error: 0.0102 - 89ms/epoch - 6ms/step
# Epoch 295/1000
# 15/15 - 0s - loss: 0.0101 - mean_squared_error: 0.0101 - 59ms/epoch - 4ms/step
# Epoch 296/1000
# 15/15 - 0s - loss: 0.0101 - mean_squared_error: 0.0101 - 100ms/epoch - 7ms/step
# Epoch 297/1000
# 15/15 - 0s - loss: 0.0101 - mean_squared_error: 0.0101 - 60ms/epoch - 4ms/step
# Epoch 298/1000
# 15/15 - 0s - loss: 0.0100 - mean_squared_error: 0.0100 - 51ms/epoch - 3ms/step
# Epoch 299/1000
# 15/15 - 0s - loss: 0.0100 - mean_squared_error: 0.0100 - 53ms/epoch - 4ms/step
# Epoch 300/1000
# 15/15 - 0s - loss: 0.0100 - mean_squared_error: 0.0100 - 82ms/epoch - 5ms/step
# Epoch 301/1000
# 15/15 - 0s - loss: 0.0099 - mean_squared_error: 0.0099 - 163ms/epoch - 11ms/step
# Epoch 302/1000
# 15/15 - 0s - loss: 0.0099 - mean_squared_error: 0.0099 - 214ms/epoch - 14ms/step
# Epoch 303/1000
# 15/15 - 0s - loss: 0.0099 - mean_squared_error: 0.0099 - 184ms/epoch - 12ms/step
# Epoch 304/1000
# 15/15 - 0s - loss: 0.0098 - mean_squared_error: 0.0098 - 122ms/epoch - 8ms/step
# Epoch 305/1000
# 15/15 - 0s - loss: 0.0098 - mean_squared_error: 0.0098 - 104ms/epoch - 7ms/step
# Epoch 306/1000
# 15/15 - 0s - loss: 0.0098 - mean_squared_error: 0.0098 - 67ms/epoch - 4ms/step
# Epoch 307/1000
# 15/15 - 0s - loss: 0.0097 - mean_squared_error: 0.0097 - 83ms/epoch - 6ms/step
# Epoch 308/1000
# 15/15 - 0s - loss: 0.0097 - mean_squared_error: 0.0097 - 98ms/epoch - 7ms/step
# Epoch 309/1000
# 15/15 - 0s - loss: 0.0097 - mean_squared_error: 0.0097 - 178ms/epoch - 12ms/step
# Epoch 310/1000
# 15/15 - 0s - loss: 0.0096 - mean_squared_error: 0.0096 - 107ms/epoch - 7ms/step
# Epoch 311/1000
# 15/15 - 0s - loss: 0.0096 - mean_squared_error: 0.0096 - 101ms/epoch - 7ms/step
# Epoch 312/1000
# 15/15 - 0s - loss: 0.0096 - mean_squared_error: 0.0096 - 162ms/epoch - 11ms/step
# Epoch 313/1000
# 15/15 - 0s - loss: 0.0095 - mean_squared_error: 0.0095 - 197ms/epoch - 13ms/step
# Epoch 314/1000
# 15/15 - 0s - loss: 0.0095 - mean_squared_error: 0.0095 - 153ms/epoch - 10ms/step
# Epoch 315/1000
# 15/15 - 0s - loss: 0.0095 - mean_squared_error: 0.0095 - 120ms/epoch - 8ms/step
# Epoch 316/1000
# 15/15 - 0s - loss: 0.0095 - mean_squared_error: 0.0095 - 101ms/epoch - 7ms/step
# Epoch 317/1000
# 15/15 - 0s - loss: 0.0094 - mean_squared_error: 0.0094 - 85ms/epoch - 6ms/step
# Epoch 318/1000
# 15/15 - 0s - loss: 0.0094 - mean_squared_error: 0.0094 - 78ms/epoch - 5ms/step
# Epoch 319/1000
# 15/15 - 0s - loss: 0.0094 - mean_squared_error: 0.0094 - 54ms/epoch - 4ms/step
# Epoch 320/1000
# 15/15 - 0s - loss: 0.0094 - mean_squared_error: 0.0094 - 145ms/epoch - 10ms/step
# Epoch 321/1000
# 15/15 - 0s - loss: 0.0094 - mean_squared_error: 0.0094 - 88ms/epoch - 6ms/step
# Epoch 322/1000
# 15/15 - 0s - loss: 0.0093 - mean_squared_error: 0.0093 - 99ms/epoch - 7ms/step
# Epoch 323/1000
# 15/15 - 0s - loss: 0.0093 - mean_squared_error: 0.0093 - 142ms/epoch - 9ms/step
# Epoch 324/1000
# 15/15 - 0s - loss: 0.0093 - mean_squared_error: 0.0093 - 120ms/epoch - 8ms/step
# Epoch 325/1000
# 15/15 - 0s - loss: 0.0093 - mean_squared_error: 0.0093 - 118ms/epoch - 8ms/step
# Epoch 326/1000
# 15/15 - 0s - loss: 0.0092 - mean_squared_error: 0.0092 - 85ms/epoch - 6ms/step
# Epoch 327/1000
# 15/15 - 0s - loss: 0.0092 - mean_squared_error: 0.0092 - 85ms/epoch - 6ms/step
# Epoch 328/1000
# 15/15 - 0s - loss: 0.0092 - mean_squared_error: 0.0092 - 116ms/epoch - 8ms/step
# Epoch 329/1000
# 15/15 - 0s - loss: 0.0092 - mean_squared_error: 0.0092 - 86ms/epoch - 6ms/step
# Epoch 330/1000
# 15/15 - 0s - loss: 0.0092 - mean_squared_error: 0.0092 - 61ms/epoch - 4ms/step
# Epoch 331/1000
# 15/15 - 0s - loss: 0.0091 - mean_squared_error: 0.0091 - 102ms/epoch - 7ms/step
# Epoch 332/1000
# 15/15 - 0s - loss: 0.0091 - mean_squared_error: 0.0091 - 165ms/epoch - 11ms/step
# Epoch 333/1000
# 15/15 - 0s - loss: 0.0091 - mean_squared_error: 0.0091 - 182ms/epoch - 12ms/step
# Epoch 334/1000
# 15/15 - 0s - loss: 0.0091 - mean_squared_error: 0.0091 - 108ms/epoch - 7ms/step
# Epoch 335/1000
# 15/15 - 0s - loss: 0.0091 - mean_squared_error: 0.0091 - 67ms/epoch - 4ms/step
# Epoch 336/1000
# 15/15 - 0s - loss: 0.0091 - mean_squared_error: 0.0091 - 101ms/epoch - 7ms/step
# Epoch 337/1000
# 15/15 - 0s - loss: 0.0091 - mean_squared_error: 0.0091 - 63ms/epoch - 4ms/step
# Epoch 338/1000
# 15/15 - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - 68ms/epoch - 5ms/step
# Epoch 339/1000
# 15/15 - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - 98ms/epoch - 7ms/step
# Epoch 340/1000
# 15/15 - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - 86ms/epoch - 6ms/step
# Epoch 341/1000
# 15/15 - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - 130ms/epoch - 9ms/step
# Epoch 342/1000
# 15/15 - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - 71ms/epoch - 5ms/step
# Epoch 343/1000
# 15/15 - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - 83ms/epoch - 6ms/step
# Epoch 344/1000
# 15/15 - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - 163ms/epoch - 11ms/step
# Epoch 345/1000
# 15/15 - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - 73ms/epoch - 5ms/step
# Epoch 346/1000
# 15/15 - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - 81ms/epoch - 5ms/step
# Epoch 347/1000
# 15/15 - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - 130ms/epoch - 9ms/step
# Epoch 348/1000
# 15/15 - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - 86ms/epoch - 6ms/step
# Epoch 349/1000
# 15/15 - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - 100ms/epoch - 7ms/step
# Epoch 350/1000
# 15/15 - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - 100ms/epoch - 7ms/step
# Epoch 351/1000
# 15/15 - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - 194ms/epoch - 13ms/step
# Epoch 352/1000
# 15/15 - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - 230ms/epoch - 15ms/step
# Epoch 353/1000
# 15/15 - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - 78ms/epoch - 5ms/step
# Epoch 354/1000
# 15/15 - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - 67ms/epoch - 4ms/step
# Epoch 355/1000
# 15/15 - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - 82ms/epoch - 5ms/step
# Epoch 356/1000
# 15/15 - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - 99ms/epoch - 7ms/step
# Epoch 357/1000
# 15/15 - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - 98ms/epoch - 7ms/step
# Epoch 358/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 133ms/epoch - 9ms/step
# Epoch 359/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 150ms/epoch - 10ms/step
# Epoch 360/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 118ms/epoch - 8ms/step
# Epoch 361/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 101ms/epoch - 7ms/step
# Epoch 362/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 84ms/epoch - 6ms/step
# Epoch 363/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 130ms/epoch - 9ms/step
# Epoch 364/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 119ms/epoch - 8ms/step
# Epoch 365/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 65ms/epoch - 4ms/step
# Epoch 366/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 115ms/epoch - 8ms/step
# Epoch 367/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 228ms/epoch - 15ms/step
# Epoch 368/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 170ms/epoch - 11ms/step
# Epoch 369/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 88ms/epoch - 6ms/step
# Epoch 370/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 68ms/epoch - 5ms/step
# Epoch 371/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 63ms/epoch - 4ms/step
# Epoch 372/1000
# 15/15 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - 85ms/epoch - 6ms/step
# Epoch 373/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 115ms/epoch - 8ms/step
# Epoch 374/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 133ms/epoch - 9ms/step
# Epoch 375/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 71ms/epoch - 5ms/step
# Epoch 376/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 82ms/epoch - 5ms/step
# Epoch 377/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 179ms/epoch - 12ms/step
# Epoch 378/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 150ms/epoch - 10ms/step
# Epoch 379/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 180ms/epoch - 12ms/step
# Epoch 380/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 138ms/epoch - 9ms/step
# Epoch 381/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 118ms/epoch - 8ms/step
# Epoch 382/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 70ms/epoch - 5ms/step
# Epoch 383/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 100ms/epoch - 7ms/step
# Epoch 384/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 162ms/epoch - 11ms/step
# Epoch 385/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 149ms/epoch - 10ms/step
# Epoch 386/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 57ms/epoch - 4ms/step
# Epoch 387/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 116ms/epoch - 8ms/step
# Epoch 388/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 178ms/epoch - 12ms/step
# Epoch 389/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 136ms/epoch - 9ms/step
# Epoch 390/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 118ms/epoch - 8ms/step
# Epoch 391/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 63ms/epoch - 4ms/step
# Epoch 392/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 70ms/epoch - 5ms/step
# Epoch 393/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 193ms/epoch - 13ms/step
# Epoch 394/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 138ms/epoch - 9ms/step
# Epoch 395/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 118ms/epoch - 8ms/step
# Epoch 396/1000
# 15/15 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - 118ms/epoch - 8ms/step
# Epoch 397/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 100ms/epoch - 7ms/step
# Epoch 398/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 131ms/epoch - 9ms/step
# Epoch 399/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 60ms/epoch - 4ms/step
# Epoch 400/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 106ms/epoch - 7ms/step
# Epoch 401/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 85ms/epoch - 6ms/step
# Epoch 402/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 99ms/epoch - 7ms/step
# Epoch 403/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 85ms/epoch - 6ms/step
# Epoch 404/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 116ms/epoch - 8ms/step
# Epoch 405/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 130ms/epoch - 9ms/step
# Epoch 406/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 166ms/epoch - 11ms/step
# Epoch 407/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 88ms/epoch - 6ms/step
# Epoch 408/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 69ms/epoch - 5ms/step
# Epoch 409/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 66ms/epoch - 4ms/step
# Epoch 410/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 67ms/epoch - 4ms/step
# Epoch 411/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 84ms/epoch - 6ms/step
# Epoch 412/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 129ms/epoch - 9ms/step
# Epoch 413/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 164ms/epoch - 11ms/step
# Epoch 414/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 121ms/epoch - 8ms/step
# Epoch 415/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 150ms/epoch - 10ms/step
# Epoch 416/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 133ms/epoch - 9ms/step
# Epoch 417/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 67ms/epoch - 4ms/step
# Epoch 418/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 84ms/epoch - 6ms/step
# Epoch 419/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 100ms/epoch - 7ms/step
# Epoch 420/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 132ms/epoch - 9ms/step
# Epoch 421/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 87ms/epoch - 6ms/step
# Epoch 422/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 68ms/epoch - 5ms/step
# Epoch 423/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 113ms/epoch - 8ms/step
# Epoch 424/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 101ms/epoch - 7ms/step
# Epoch 425/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 84ms/epoch - 6ms/step
# Epoch 426/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 73ms/epoch - 5ms/step
# Epoch 427/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 59ms/epoch - 4ms/step
# Epoch 428/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 98ms/epoch - 7ms/step
# Epoch 429/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 131ms/epoch - 9ms/step
# Epoch 430/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 149ms/epoch - 10ms/step
# Epoch 431/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 72ms/epoch - 5ms/step
# Epoch 432/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 82ms/epoch - 5ms/step
# Epoch 433/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 130ms/epoch - 9ms/step
# Epoch 434/1000
# 15/15 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - 167ms/epoch - 11ms/step
# Epoch 435/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 71ms/epoch - 5ms/step
# Epoch 436/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 131ms/epoch - 9ms/step
# Epoch 437/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 195ms/epoch - 13ms/step
# Epoch 438/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 153ms/epoch - 10ms/step
# Epoch 439/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 72ms/epoch - 5ms/step
# Epoch 440/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 74ms/epoch - 5ms/step
# Epoch 441/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 104ms/epoch - 7ms/step
# Epoch 442/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 148ms/epoch - 10ms/step
# Epoch 443/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 134ms/epoch - 9ms/step
# Epoch 444/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 149ms/epoch - 10ms/step
# Epoch 445/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 165ms/epoch - 11ms/step
# Epoch 446/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 73ms/epoch - 5ms/step
# Epoch 447/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 99ms/epoch - 7ms/step
# Epoch 448/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 100ms/epoch - 7ms/step
# Epoch 449/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 68ms/epoch - 5ms/step
# Epoch 450/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 67ms/epoch - 4ms/step
# Epoch 451/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 82ms/epoch - 5ms/step
# Epoch 452/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 163ms/epoch - 11ms/step
# Epoch 453/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 212ms/epoch - 14ms/step
# Epoch 454/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 121ms/epoch - 8ms/step
# Epoch 455/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 87ms/epoch - 6ms/step
# Epoch 456/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 115ms/epoch - 8ms/step
# Epoch 457/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 132ms/epoch - 9ms/step
# Epoch 458/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 72ms/epoch - 5ms/step
# Epoch 459/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 82ms/epoch - 5ms/step
# Epoch 460/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 114ms/epoch - 8ms/step
# Epoch 461/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 211ms/epoch - 14ms/step
# Epoch 462/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 202ms/epoch - 13ms/step
# Epoch 463/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 90ms/epoch - 6ms/step
# Epoch 464/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 67ms/epoch - 4ms/step
# Epoch 465/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 82ms/epoch - 5ms/step
# Epoch 466/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 115ms/epoch - 8ms/step
# Epoch 467/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 180ms/epoch - 12ms/step
# Epoch 468/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 120ms/epoch - 8ms/step
# Epoch 469/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 87ms/epoch - 6ms/step
# Epoch 470/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 100ms/epoch - 7ms/step
# Epoch 471/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 99ms/epoch - 7ms/step
# Epoch 472/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 194ms/epoch - 13ms/step
# Epoch 473/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 122ms/epoch - 8ms/step
# Epoch 474/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 119ms/epoch - 8ms/step
# Epoch 475/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 69ms/epoch - 5ms/step
# Epoch 476/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 67ms/epoch - 4ms/step
# Epoch 477/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 82ms/epoch - 5ms/step
# Epoch 478/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 161ms/epoch - 11ms/step
# Epoch 479/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 183ms/epoch - 12ms/step
# Epoch 480/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 136ms/epoch - 9ms/step
# Epoch 481/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 88ms/epoch - 6ms/step
# Epoch 482/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 100ms/epoch - 7ms/step
# Epoch 483/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 67ms/epoch - 4ms/step
# Epoch 484/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 114ms/epoch - 8ms/step
# Epoch 485/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 70ms/epoch - 5ms/step
# Epoch 486/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 64ms/epoch - 4ms/step
# Epoch 487/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 84ms/epoch - 6ms/step
# Epoch 488/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 75ms/epoch - 5ms/step
# Epoch 489/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 58ms/epoch - 4ms/step
# Epoch 490/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 65ms/epoch - 4ms/step
# Epoch 491/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 60ms/epoch - 4ms/step
# Epoch 492/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 71ms/epoch - 5ms/step
# Epoch 493/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 115ms/epoch - 8ms/step
# Epoch 494/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 148ms/epoch - 10ms/step
# Epoch 495/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 182ms/epoch - 12ms/step
# Epoch 496/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 137ms/epoch - 9ms/step
# Epoch 497/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 86ms/epoch - 6ms/step
# Epoch 498/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 75ms/epoch - 5ms/step
# Epoch 499/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 75ms/epoch - 5ms/step
# Epoch 500/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 97ms/epoch - 6ms/step
# Epoch 501/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 147ms/epoch - 10ms/step
# Epoch 502/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 104ms/epoch - 7ms/step
# Epoch 503/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 132ms/epoch - 9ms/step
# Epoch 504/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 134ms/epoch - 9ms/step
# Epoch 505/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 180ms/epoch - 12ms/step
# Epoch 506/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 72ms/epoch - 5ms/step
# Epoch 507/1000
# 15/15 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - 68ms/epoch - 5ms/step
# Epoch 508/1000
# ...
# Epoch 844/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 70ms/epoch - 5ms/step
# Epoch 845/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 131ms/epoch - 9ms/step
# Epoch 846/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 103ms/epoch - 7ms/step
# Epoch 847/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 164ms/epoch - 11ms/step
# Epoch 848/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 102ms/epoch - 7ms/step
# Epoch 849/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 64ms/epoch - 4ms/step
# Epoch 850/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 85ms/epoch - 6ms/step
# Epoch 851/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 162ms/epoch - 11ms/step
# Epoch 852/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 136ms/epoch - 9ms/step
# Epoch 853/1000
# 15/15 - 0s - loss: 0.0084 - mean_squared_error: 0.0084 - 165ms/epoch - 11ms/step
# Epoch 854/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 135ms/epoch - 9ms/step
# Epoch 855/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 72ms/epoch - 5ms/step
# Epoch 856/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 71ms/epoch - 5ms/step
# Epoch 857/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 107ms/epoch - 7ms/step
# Epoch 858/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 134ms/epoch - 9ms/step
# Epoch 859/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 102ms/epoch - 7ms/step
# Epoch 860/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 118ms/epoch - 8ms/step
# Epoch 861/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 195ms/epoch - 13ms/step
# Epoch 862/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 106ms/epoch - 7ms/step
# Epoch 863/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 68ms/epoch - 5ms/step
# Epoch 864/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 84ms/epoch - 6ms/step
# Epoch 865/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 98ms/epoch - 7ms/step
# Epoch 866/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 131ms/epoch - 9ms/step
# Epoch 867/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 133ms/epoch - 9ms/step
# Epoch 868/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 86ms/epoch - 6ms/step
# Epoch 869/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 83ms/epoch - 6ms/step
# Epoch 870/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 68ms/epoch - 5ms/step
# Epoch 871/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 82ms/epoch - 5ms/step
# Epoch 872/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 145ms/epoch - 10ms/step
# Epoch 873/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 166ms/epoch - 11ms/step
# Epoch 874/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 104ms/epoch - 7ms/step
# Epoch 875/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 70ms/epoch - 5ms/step
# Epoch 876/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 59ms/epoch - 4ms/step
# Epoch 877/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 87ms/epoch - 6ms/step
# Epoch 878/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 101ms/epoch - 7ms/step
# Epoch 879/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 100ms/epoch - 7ms/step
# Epoch 880/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 147ms/epoch - 10ms/step
# Epoch 881/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 135ms/epoch - 9ms/step
# Epoch 882/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 102ms/epoch - 7ms/step
# Epoch 883/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 84ms/epoch - 6ms/step
# Epoch 884/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 68ms/epoch - 5ms/step
# Epoch 885/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 98ms/epoch - 7ms/step
# Epoch 886/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 148ms/epoch - 10ms/step
# Epoch 887/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 120ms/epoch - 8ms/step
# Epoch 888/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 70ms/epoch - 5ms/step
# Epoch 889/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 129ms/epoch - 9ms/step
# Epoch 890/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 102ms/epoch - 7ms/step
# Epoch 891/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 100ms/epoch - 7ms/step
# Epoch 892/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 148ms/epoch - 10ms/step
# Epoch 893/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 119ms/epoch - 8ms/step
# Epoch 894/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 147ms/epoch - 10ms/step
# Epoch 895/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 88ms/epoch - 6ms/step
# Epoch 896/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 81ms/epoch - 5ms/step
# Epoch 897/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 69ms/epoch - 5ms/step
# Epoch 898/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 68ms/epoch - 5ms/step
# Epoch 899/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 73ms/epoch - 5ms/step
# Epoch 900/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 56ms/epoch - 4ms/step
# Epoch 901/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 83ms/epoch - 6ms/step
# Epoch 902/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 146ms/epoch - 10ms/step
# Epoch 903/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 104ms/epoch - 7ms/step
# Epoch 904/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 67ms/epoch - 4ms/step
# Epoch 905/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 82ms/epoch - 5ms/step
# Epoch 906/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 131ms/epoch - 9ms/step
# Epoch 907/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 212ms/epoch - 14ms/step
# Epoch 908/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 108ms/epoch - 7ms/step
# Epoch 909/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 196ms/epoch - 13ms/step
# Epoch 910/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 90ms/epoch - 6ms/step
# Epoch 911/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 115ms/epoch - 8ms/step
# Epoch 912/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 102ms/epoch - 7ms/step
# Epoch 913/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 70ms/epoch - 5ms/step
# Epoch 914/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 62ms/epoch - 4ms/step
# Epoch 915/1000
# 15/15 - 0s - loss: 0.0084 - mean_squared_error: 0.0084 - 82ms/epoch - 5ms/step
# Epoch 916/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 131ms/epoch - 9ms/step
# Epoch 917/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 195ms/epoch - 13ms/step
# Epoch 918/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 123ms/epoch - 8ms/step
# Epoch 919/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 69ms/epoch - 5ms/step
# Epoch 920/1000
# 15/15 - 0s - loss: 0.0084 - mean_squared_error: 0.0084 - 98ms/epoch - 7ms/step
# Epoch 921/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 100ms/epoch - 7ms/step
# Epoch 922/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 163ms/epoch - 11ms/step
# Epoch 923/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 88ms/epoch - 6ms/step
# Epoch 924/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 100ms/epoch - 7ms/step
# Epoch 925/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 101ms/epoch - 7ms/step
# Epoch 926/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 67ms/epoch - 4ms/step
# Epoch 927/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 67ms/epoch - 4ms/step
# Epoch 928/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 84ms/epoch - 6ms/step
# Epoch 929/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 128ms/epoch - 9ms/step
# Epoch 930/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 133ms/epoch - 9ms/step
# Epoch 931/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 136ms/epoch - 9ms/step
# Epoch 932/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 70ms/epoch - 5ms/step
# Epoch 933/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 115ms/epoch - 8ms/step
# Epoch 934/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 102ms/epoch - 7ms/step
# Epoch 935/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 84ms/epoch - 6ms/step
# Epoch 936/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 60ms/epoch - 4ms/step
# Epoch 937/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 57ms/epoch - 4ms/step
# Epoch 938/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 84ms/epoch - 6ms/step
# Epoch 939/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 161ms/epoch - 11ms/step
# Epoch 940/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 104ms/epoch - 7ms/step
# Epoch 941/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 100ms/epoch - 7ms/step
# Epoch 942/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 164ms/epoch - 11ms/step
# Epoch 943/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 151ms/epoch - 10ms/step
# Epoch 944/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 167ms/epoch - 11ms/step
# Epoch 945/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 135ms/epoch - 9ms/step
# Epoch 946/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 118ms/epoch - 8ms/step
# Epoch 947/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 85ms/epoch - 6ms/step
# Epoch 948/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 115ms/epoch - 8ms/step
# Epoch 949/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 117ms/epoch - 8ms/step
# Epoch 950/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 85ms/epoch - 6ms/step
# Epoch 951/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 116ms/epoch - 8ms/step
# Epoch 952/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 116ms/epoch - 8ms/step
# Epoch 953/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 132ms/epoch - 9ms/step
# Epoch 954/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 70ms/epoch - 5ms/step
# Epoch 955/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 82ms/epoch - 5ms/step
# Epoch 956/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 104ms/epoch - 7ms/step
# Epoch 957/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 111ms/epoch - 7ms/step
# Epoch 958/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 85ms/epoch - 6ms/step
# Epoch 959/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 68ms/epoch - 5ms/step
# Epoch 960/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 66ms/epoch - 4ms/step
# Epoch 961/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 104ms/epoch - 7ms/step
# Epoch 962/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 91ms/epoch - 6ms/step
# Epoch 963/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 99ms/epoch - 7ms/step
# Epoch 964/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 194ms/epoch - 13ms/step
# Epoch 965/1000
# 15/15 - 0s - loss: 0.0084 - mean_squared_error: 0.0084 - 154ms/epoch - 10ms/step
# Epoch 966/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 102ms/epoch - 7ms/step
# Epoch 967/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 133ms/epoch - 9ms/step
# Epoch 968/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 74ms/epoch - 5ms/step
# Epoch 969/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 62ms/epoch - 4ms/step
# Epoch 970/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 82ms/epoch - 5ms/step
# Epoch 971/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 83ms/epoch - 6ms/step
# Epoch 972/1000
# 15/15 - 0s - loss: 0.0084 - mean_squared_error: 0.0084 - 63ms/epoch - 4ms/step
# Epoch 973/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 84ms/epoch - 6ms/step
# Epoch 974/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 100ms/epoch - 7ms/step
# Epoch 975/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 100ms/epoch - 7ms/step
# Epoch 976/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 85ms/epoch - 6ms/step
# Epoch 977/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 116ms/epoch - 8ms/step
# Epoch 978/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 133ms/epoch - 9ms/step
# Epoch 979/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 86ms/epoch - 6ms/step
# Epoch 980/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 67ms/epoch - 4ms/step
# Epoch 981/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 115ms/epoch - 8ms/step
# Epoch 982/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 196ms/epoch - 13ms/step
# Epoch 983/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 137ms/epoch - 9ms/step
# Epoch 984/1000
# 15/15 - 0s - loss: 0.0084 - mean_squared_error: 0.0084 - 133ms/epoch - 9ms/step
# Epoch 985/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 180ms/epoch - 12ms/step
# Epoch 986/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 151ms/epoch - 10ms/step
# Epoch 987/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 88ms/epoch - 6ms/step
# Epoch 988/1000
# 15/15 - 0s - loss: 0.0084 - mean_squared_error: 0.0084 - 130ms/epoch - 9ms/step
# Epoch 989/1000
# 15/15 - 0s - loss: 0.0082 - mean_squared_error: 0.0082 - 134ms/epoch - 9ms/step
# Epoch 990/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 118ms/epoch - 8ms/step
# Epoch 991/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 117ms/epoch - 8ms/step
# Epoch 992/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 118ms/epoch - 8ms/step
# Epoch 993/1000
# 15/15 - 0s - loss: 0.0082 - mean_squared_error: 0.0082 - 69ms/epoch - 5ms/step
# Epoch 994/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 67ms/epoch - 4ms/step
# Epoch 995/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 83ms/epoch - 6ms/step
# Epoch 996/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 129ms/epoch - 9ms/step
# Epoch 997/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 166ms/epoch - 11ms/step
# Epoch 998/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 166ms/epoch - 11ms/step
# Epoch 999/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 183ms/epoch - 12ms/step
# Epoch 1000/1000
# 15/15 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - 122ms/epoch - 8ms/step
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0081 - mean_squared_error: 0.0081
# 0.008144130930304527
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5, 4)]            0
#
#  simple_rnn (SimpleRNN)      (None, 5, 64)             4416
#
#  simple_rnn_1 (SimpleRNN)    (None, 5, 64)             8256
#
#  dense (Dense)               (None, 5, 2)              130
#
# =================================================================
# Total params: 12802 (50.01 KB)
# Trainable params: 12802 (50.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# save model and scalers
model.save('iclrnn_energy.keras')
pickle.dump(scaler_X, open('iclrnn_scaler_X', 'wb'))
pickle.dump(scaler_y, open('iclrnn_scaler_y', 'wb'))
