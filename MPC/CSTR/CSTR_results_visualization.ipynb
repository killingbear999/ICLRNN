# %%
# load packages
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# modify global setting
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['font.family'] = 'Arial'

# %%
x = np.arange(0,1,0.1)
rnn = [1.9929504560423084e-05, 0.0029890763107687235, 0.0007628234452567995, 0.006277138367295265, 0.0022313299123197794, 0.015488119795918465, 0.022150304168462753, 0.040027666836977005, 0.06476244330406189, 0.10336155444383621]
iclrnn_plain = [0.0022407404612749815, 0.001714741112664342, 0.0021008590701967478, 0.0023564514704048634, 0.004948985762894154, 0.006532805506139994, 0.00653434544801712, 0.008654224686324596, 0.013648640364408493, 0.01816556602716446]
lstm = [3.8107330055936472e-06, 0.0003028587670996785, 0.0007704166346229613, 0.0018962525064125657, 0.005170674994587898, 0.011511877179145813, 0.020207788795232773, 0.0458001047372818, 0.0619167797267437, 0.10389592498540878]
lrnn = [0.0013309906935319304, 0.002030326519161463, 0.0029276434797793627, 0.0033425274305045605, 0.0035561169497668743, 0.004496005363762379, 0.0042604259215295315, 0.0052352058701217175, 0.005339187104254961, 0.00604361342266202]

# color code: "#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"
plt.figure(figsize=(10,6))
# plt.rc('font', size=20)
plt.plot(x, rnn, '--', color='#009E73', marker='4', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='RNN')
plt.plot(x, lstm, '--', color='#E69F00', marker='3', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LSTM')
plt.plot(x, iclrnn_plain, '--', color='#56B4E9', marker='2', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='ICLRNN_plain')
plt.plot(x, lrnn, '--', color='#0072B2', marker='1', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LRNN')
plt.title("Layer = (640, 640), Testing")
plt.legend()
plt.xlabel("Degree of Noise")
plt.ylabel("Testing MSE")
# plt.margins(x=0)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
# plt.xticks(fontsize=20)
# plt.yticks(fontsize=20)
plt.show()

# %%
x = np.arange(0,1,0.1)
rnn = [1.608160528121516e-05, 0.0003722018445841968, 0.00041204289300367236, 0.005187700968235731, 0.003832519054412842, 0.015205656178295612, 0.024674251675605774, 0.03435754403471947, 0.04779055342078209, 0.0759897530078888]
iclrnn_plain = [0.0010987306013703346, 0.001372158876620233, 0.0023197471164166927, 0.002736184047535062, 0.0033225344959646463, 0.00459881778806448, 0.006947680376470089, 0.006916255224496126, 0.009603699669241905, 0.013763107359409332]
lstm = [6.435276191041339e-06, 0.00043095683213323355, 0.0005029731546528637, 0.0016646147705614567, 0.003407157026231289, 0.00560038723051548, 0.010052616707980633, 0.015903187915682793, 0.03350706398487091, 0.03984004631638527]
lrnn = [0.0013309906935319304, 0.002030326519161463, 0.0029276434797793627, 0.0033425274305045605, 0.0035561169497668743, 0.004496005363762379, 0.0042604259215295315, 0.0052352058701217175, 0.005339187104254961, 0.00604361342266202]

# color code: "#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"
plt.figure(figsize=(10,6))
# plt.rc('font', size=20)
plt.plot(x, rnn, '--', color='#009E73', marker='4', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='RNN')
plt.plot(x, lstm, '--', color='#E69F00', marker='3', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LSTM')
plt.plot(x, iclrnn_plain, '--', color='#56B4E9', marker='2', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='ICLRNN_plain')
plt.plot(x, lrnn, '--', color='#0072B2', marker='1', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LRNN')
plt.title("Layer = (320, 320), Testing")
plt.legend()
plt.xlabel("Degree of Noise")
plt.ylabel("Testing MSE")
# plt.margins(x=0)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
# plt.xticks(fontsize=20)
# plt.yticks(fontsize=20)
plt.show()

# %%
# Trainable parameters:
    # RNN: 790,530
    # ICLRNN: 790,530
    # LRNN: 1,314,818
    # LSTM: 3,159,042
    # ICRNN: 2,372,610

# FLOPs:
    # RNN: 1,599,508
    # ICLRNN: 1,599,508
    # LRNN: 9,992,212
    # LSTM: 6,340,628
    # ICRNN: 4,767,764

size = 8

# Testing
x = np.arange(0,size/10,0.1)
rnn =
lrnn = [0.0032483264803886414, 0.0045153298415243626, 0.005376963410526514, 0.006100676953792572, 0.0070757498033344746, 0.007585780695080757, 0.008403555490076542, 0.009585770778357983, 0.00964444875717163, 0.011546333320438862]
icrnn_elu = [0.7951034903526306, 17.109342575073242, 2.1994974613189697, 2.788841962814331, 10.191690444946289, 4.808038711547852, 2.3550608158111572, 0.7925869226455688, 1.6852030754089355, 0.9027551412582397]
icrnn_relu = [379.4994201660156, 8967.8212890625, 21466.125, 17770.01953125, 1.3605917692184448, 6091.4443359375, 1.3224210739135742, 26787.6875, 1.0236057043075562, 12444.7587890625]

# color code: "#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"
plt.figure(figsize=(10,6))
plt.rc('font', size=17)
plt.plot(x, rnn[:size], '--', color='#009E73', marker='4', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='RNN')
plt.plot(x, lstm[:size], '--', color='#E69F00', marker='3', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LSTM')
plt.plot(x, lrnn[:size], '--', color='#0072B2', marker='2', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LRNN')
# plt.plot(x, icrnn_elu[:size], '--', color='#D55E00', marker='1', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='ICRNN')
plt.plot(x, iclrnn_plain[:size], '--', color='#56B4E9', marker='x', linewidth=1.5, markersize=7.5, markeredgewidth=2.5, label='ICLRNN (Ours)')
plt.text(0.015, 0.055, "ICRNN suffers from vanishing/exploding gradient problem", fontsize=15, bbox=dict(facecolor='#D55E00', alpha=0.5))
# plt.title("Layer = (256, 256), Testing")
plt.legend()
plt.xlabel("Degree of Noise")
plt.ylabel("Testing MSE")
plt.margins(x=0)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
# plt.savefig('testing_256.pdf')
plt.show()

# Validation
x = np.arange(0,size/10,0.1)
rnn = [2.1104355255374685e-05, 0.01105431653559208, 0.04536247253417969, 0.10004110634326935, 0.186227485537529, 0.28872618079185486, 0.41668567061424255, 0.5751587748527527, 0.7683913111686707, 0.9703543186187744]
iclrnn_plain = [0.0014134116936475039, 0.011308515444397926, 0.04230883717536926, 0.09296029061079025, 0.1633952558040619, 0.2565690875053406, 0.3652960956096649, 0.49968865513801575, 0.656390368938446, 0.8268097043037415]
iclrnn_plain_real = [0.0011739070760086179, 0.010961205698549747, 0.041407473385334015, 0.09306600689888, 0.16506488621234894, 0.25976264476776123, 0.36931705474853516, 0.5136574506759644, 0.6716516613960266, 0.8584632277488708]
lstm = [1.0279356501996517e-05, 0.010181433521211147, 0.040132660418748856, 0.0915403887629509, 0.16169413924217224, 0.2563154697418213, 0.37009793519973755, 0.4979446232318878, 0.6676031947135925, 0.834041953086853]
lrnn = [0.003208186011761427, 0.014481625519692898, 0.045241519808769226, 0.09805897623300552, 0.16669006645679474, 0.2605062425136566, 0.3664798438549042, 0.4982937276363373, 0.6530522108078003, 0.8184213042259216]
icrnn_elu = [0.7907484769821167, 17.44146156311035, 2.2664082050323486, 2.850710391998291, 10.488532066345215, 5.128468036651611, 2.7511157989501953, 1.2923541069030762, 2.307443618774414, 1.7200826406478882]
icrnn_relu= [381.0431213378906, 8990.2373046875, 21453.30859375, 17715.419921875, 1.5700041055679321, 6125.28564453125, 1.6780461072921753, 26761.490234375, 1.6963704824447632, 12450.3408203125]

plt.figure(figsize=(10,6))
plt.rc('font', size=17)
plt.plot(x, rnn[:size], '--', color='#009E73', marker='4', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='RNN')
plt.plot(x, lstm[:size], '--', color='#E69F00', marker='3', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LSTM')
plt.plot(x, lrnn[:size], '--', color='#0072B2', marker='2', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='ICRNN')
# plt.plot(x, icrnn_elu[:size], '--', color='#D55E00', marker='1', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='ICRNN')
plt.plot(x, iclrnn_plain[:size], '--', color='#56B4E9', marker='x', linewidth=1.5, markersize=7.5, markeredgewidth=2.5, label='ICLRNN (Ours)')
plt.text(0.015, 0.34, "ICRNN suffers from vanishing/exploding gradient problem", fontsize=15, bbox=dict(facecolor='#D55E00', alpha=0.5))
# plt.title("Layer = (256, 256), Validation")
plt.legend()
plt.xlabel("Degree of Noise")
plt.ylabel("Validation MSE")
plt.margins(x=0)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
# plt.savefig('validation_256.pdf')
plt.show()

# %%
# Trainable parameters:
    # RNN: 50,178
    # ICLRNN: 50,178
    # LRNN: 82,946
    # LSTM: 199,938
    # ICRNN: 150,786

# FLOPs:
    # RNN: 104,980
    # ICLRNN: 104,980
    # LRNN: 630,192
    # LSTM: 405,524
    # ICRNN: 307,220

size = 8

# Testing
x = np.arange(0,size/10,0.1)
rnn = [0.00014597672270610929, 0.0007410199614241719, 0.0019735086243599653, 0.005157033447176218, 0.010846996679902077, 0.01922106370329857, 0.029390383511781693, 0.04047315567731857, 0.0536530464887619, 0.07745920121669769]
iclrnn_plain = [0.0010811772663146257, 0.0010313896927982569, 0.0015078565338626504, 0.0019848321098834276, 0.0022148697171360254, 0.003154746489599347, 0.0046766274608671665, 0.005356303881853819, 0.0065024252980947495, 0.007985194213688374]
lstm = [2.096695789077785e-05, 0.0002682887716218829, 0.0005893180496059358, 0.000771109655033797, 0.0020551043562591076, 0.0032000625506043434, 0.0034791866783052683, 0.005692134611308575, 0.00865593645721674, 0.012746374122798443]
lrnn = [0.008489048108458519, 0.009775500744581223, 0.011304102838039398, 0.013234464451670647, 0.0145647544413805, 0.015586432069540024, 0.016690075397491455, 0.01800387166440487, 0.018752340227365494, 0.020116416737437248]
icrnn_elu = [0.014349807053804398, 0.003800122532993555, 0.0010947288246825337, 0.00127715477719903, 0.001201090170070529, 0.0008167133782990277, 0.020613614469766617, 0.0017598433187231421, 0.0013083057710900903, 0.0030078061390668154]
icrnn_relu = [0.17251740396022797, 0.012012999504804611, 0.008597592823207378, 0.15078425407409668, 0.18098831176757812, 0.01030592992901802, 0.18594816327095032, 0.17766723036766052, 0.03061537817120552, 0.17358751595020294]

# color code: "#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"
plt.figure(figsize=(10,6))
plt.rc('font', size=17)
plt.plot(x, rnn[:size], '--', color='#009E73', marker='4', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='RNN')
plt.plot(x, lstm[:size], '--', color='#E69F00', marker='3', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LSTM')
plt.plot(x, lrnn[:size], '--', color='#0072B2', marker='2', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LRNN')
plt.plot(x, icrnn_relu[:size], '--', color='#D55E00', marker='1', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='ICRNN')
plt.plot(x, iclrnn_plain[:size], '--', color='#56B4E9', marker='x', linewidth=1.5, markersize=7.5, markeredgewidth=2.5, label='ICLRNN (Ours)')
# plt.title("Layer = (128, 128), Testing")
plt.legend()
plt.xlabel("Degree of Noise")
plt.ylabel("Testing MSE")
plt.margins(x=0)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
plt.savefig('testing_128.pdf')
plt.show()

# Validation
x = np.arange(0,size/10,0.1)
rnn = [0.0001531252928543836, 0.010655248537659645, 0.042201630771160126, 0.0944582149386406, 0.17285382747650146, 0.2705353796482086, 0.39076659083366394, 0.5284321904182434, 0.6970939040184021, 0.8860759735107422]
iclrnn_plain = [0.001091374084353447, 0.01117008738219738, 0.041633717715740204, 0.09224473685026169, 0.16229747235774994, 0.25159183144569397, 0.3630298674106598, 0.4922555983066559, 0.6407604217529297, 0.829309344291687]
lstm = [2.124335333064664e-05, 0.010316828265786171, 0.04086064174771309, 0.09037573635578156, 0.16447672247886658, 0.2543998956680298, 0.3601762354373932, 0.4932679533958435, 0.650597870349884, 0.8198627233505249]
lrnn = [0.008398198522627354, 0.01978062279522419, 0.051477208733558655, 0.10297646373510361, 0.17259714007377625, 0.26523423194885254, 0.37340882420539856, 0.5090972781181335, 0.6705273985862732, 0.8197944164276123]
icrnn_elu = [0.014171765185892582, 0.013687597587704659, 0.04139505326747894, 0.09134425967931747, 0.1617065966129303, 0.24871577322483063, 0.3776020407676697, 0.4925864040851593, 0.6391327977180481, 0.807723343372345]
icrnn_relu = [0.16479164361953735, 0.021376507356762886, 0.04920455440878868, 0.24723123013973236, 0.33399781584739685, 0.2601834833621979, 0.5506890416145325, 0.672005832195282, 0.6670955419540405, 0.9887214303016663]

plt.figure(figsize=(10,6))
plt.rc('font', size=17)
plt.plot(x, rnn[:size], '--', color='#009E73', marker='4', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='RNN')
plt.plot(x, lstm[:size], '--', color='#E69F00', marker='3', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LSTM')
plt.plot(x, lrnn[:size], '--', color='#0072B2', marker='2', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LRNN')
plt.plot(x, icrnn_relu[:size], '--', color='#D55E00', marker='1', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='ICRNN')
plt.plot(x, iclrnn_plain[:size], '--', color='#56B4E9', marker='x', linewidth=1.5, markersize=7.5, markeredgewidth=2.5, label='ICLRNN (Ours)')
# plt.title("Layer = (128, 128), Validation")
plt.legend()
plt.xlabel("Degree of Noise")
plt.ylabel("Validation MSE")
plt.margins(x=0)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
plt.savefig('validation_128.pdf')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %%
# Trainable parameters:
    # RNN: 12,802
    # ICLRNN: 12,802
    # LRNN: 20,994
    # LSTM: 50,818
    # ICRNN: 38,530

# FLOPs:
    # RNN: 27,924
    # ICLRNN: 27,924
    # LRNN: 159,508
    # LSTM: 104,468
    # ICRNN: 79,892

size = 8

# Testing
x = np.arange(0,size/10,0.1)
rnn = [6.152434798423201e-05, 0.0003553596616256982, 0.0008682032930664718, 0.002175342757254839, 0.005304753314703703, 0.008866001851856709, 0.013193168677389622, 0.015141795389354229, 0.02384444884955883, 0.03276246413588524]
iclrnn_plain = [0.0009540886385366321, 0.0013633044436573982, 0.0014985055895522237, 0.00151765625923872, 0.001985493814572692, 0.0023651709780097008, 0.002683738013729453, 0.004603108856827021, 0.004045116249471903, 0.0054365224204957485]
lstm = [2.304906229255721e-05, 0.00028822929016314447, 0.0005078620160929859, 0.0007890753913670778, 0.000976795214228332, 0.002103938488289714, 0.0017951859626919031, 0.0038465778343379498, 0.0044250283390283585, 0.007315693888813257]
lrnn = [0.02718106284737587, 0.028306622058153152, 0.030215362086892128, 0.03184136003255844, 0.03472529724240303, 0.0357283391058445, 0.038042910397052765, 0.03990178927779198, 0.0415162555873394, 0.04256404563784599]
icrnn = [0.00011330653069308028, 0.0002189748192904517, 0.0005036524380557239, 0.0006776449736207724, 0.000813326973002404, 0.0011250890092924237, 0.0017483602277934551, 0.002302611945196986, 0.0019624328706413507, 0.003381599672138691]

# color code: "#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"
plt.figure(figsize=(10,6))
plt.rc('font', size=17)
plt.plot(x, rnn[:size], '--', color='#009E73', marker='4', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='RNN')
plt.plot(x, lstm[:size], '--', color='#E69F00', marker='3', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LSTM')
plt.plot(x, lrnn[:size], '--', color='#0072B2', marker='2', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LRNN')
plt.plot(x, icrnn[:size], '--', color='#D55E00', marker='1', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='ICRNN')
plt.plot(x, iclrnn_plain[:size], '--', color='#56B4E9', marker='x', linewidth=1.5, markersize=7.5, markeredgewidth=2.5, label='ICLRNN (Ours)')
# plt.title("Layer = (64, 64), Testing")
plt.legend(loc='center left')
plt.xlabel("Degree of Noise")
plt.ylabel("Testing MSE")
plt.margins(x=0)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
plt.savefig('testing_64.pdf')
plt.show()

# Validation
x = np.arange(0,size/10,0.1)
rnn = [6.10772694926709e-05, 0.01042434573173523, 0.04052874073386192, 0.09232445806264877, 0.16645461320877075, 0.25737446546554565, 0.373394250869751, 0.5062320232391357, 0.6658387780189514, 0.8434387445449829]
iclrnn_plain = [0.0009562380146235228, 0.011399040929973125, 0.041280172765254974, 0.09248636662960052, 0.1608920395374298, 0.2515488266944885, 0.3611130714416504, 0.4968012273311615, 0.6385895609855652, 0.8068216443061829]
lstm = [2.333205338800326e-05, 0.010128662921488285, 0.040797751396894455, 0.09111855179071426, 0.15929995477199554, 0.2510035037994385, 0.36114323139190674, 0.49296462535858154, 0.6396706104278564, 0.8141288757324219]
lrnn = [0.027097852900624275, 0.038020599633455276, 0.06953022629022598, 0.12242161482572556, 0.19589658081531525, 0.28706905245780945, 0.3943924605846405, 0.5334675312042236, 0.6868897676467896, 0.8491249084472656]
icrnn = [0.0001144655907410197, 0.010363354347646236, 0.0405968613922596, 0.0910094827413559, 0.16055434942245483, 0.24981723725795746, 0.3625723719596863, 0.4934121072292328, 0.6459648013114929, 0.8150936961174011]

plt.figure(figsize=(10,6))
plt.rc('font', size=17)
plt.plot(x, rnn[:size], '--', color='#009E73', marker='4', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='RNN')
plt.plot(x, lstm[:size], '--', color='#E69F00', marker='3', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LSTM')
plt.plot(x, lrnn[:size], '--', color='#0072B2', marker='2', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='LRNN')
plt.plot(x, icrnn[:size], '--', color='#D55E00', marker='1', linewidth=1.5, markersize=10, markeredgewidth=2.5, label='ICRNN')
plt.plot(x, iclrnn_plain[:size], '--', color='#56B4E9', marker='x', linewidth=1.5, markersize=7.5, markeredgewidth=2.5, label='ICLRNN (Ours)')
# plt.title("Layer = (64, 64), Validation")
plt.legend()
plt.xlabel("Degree of Noise")
plt.ylabel("Validation MSE")
plt.margins(x=0)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
plt.savefig('validation_64.pdf')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
